# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#loading the baseline and debiased embeddings
baseline_path = "profession_embeddings_baseline.csv"
debiased_path = "profession_embeddings_debiased_w=1_c=1.csv"

df_baseline = pd.read_csv(baseline_path)
df_debiased = pd.read_csv(debiased_path)

#ensuring the professions in both files match
common_professions = set(df_baseline['Profession']).intersection(set(df_debiased['Profession']))
print(f"Found {len(common_professions)} common professions")

cosine_similarities = {}

for prof in common_professions:
    base_vec = df_baseline.loc[df_baseline['Profession'] == prof].iloc[:, 1:].values
    debiased_vec = df_debiased.loc[df_debiased['Profession'] == prof].iloc[:, 1:].values
    
    #cosine_similarity expects 2D arrays so these base_vec and debiased_vec have shape (1, dim)
    cos_sim = cosine_similarity(base_vec, debiased_vec)[0][0]
    cosine_similarities[prof] = cos_sim

#converting to df for easier inspection and saving
sim_df = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['Cosine_Similarity'])
sim_df = sim_df.sort_values('Cosine_Similarity')

print(sim_df)

#plotting

plt.figure(figsize=(8,5))
sns.histplot(sim_df['Cosine_Similarity'], bins=20, kde=True)
plt.title("Distribution of Cosine Similarities: Baseline vs Debiased Embeddings")
plt.xlabel("Cosine Similarity")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12,8))
sim_df_sorted = sim_df.sort_values('Cosine_Similarity')
sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
plt.title("Cosine Similarity of Professions (Baseline vs Debiased)")
plt.xlabel("Cosine Similarity")
plt.ylabel("Profession")
plt.show()

print("Top 5 professions with lowest cosine similarity (most changed):")
print(sim_df_sorted.head(5))

mean_cos_sim = sim_df['Cosine_Similarity'].mean()
print(f"Mean Cosine Similarity: {mean_cos_sim:.4f}")


log_mean_cos_sim = np.log(0.9260)
print(f"Log Mean Cosine Similarity (natural log): {log_mean_cos_sim:.4f}")
# Out:
# Found 58 common professions
#                                  Cosine_Similarity
# director                                  0.900911
# postal worker                             0.903395
# engineer                                  0.904371
# fisherman                                 0.904929
# maid                                      0.905300
# salesperson                               0.908543
# computer programmer                       0.910087
# construction worker                       0.914225
# bus driver                                0.916049
# actor                                     0.916265
# secretary                                 0.917117
# landscaper                                0.917846
# mechanic                                  0.918248
# architect                                 0.918622
# accountant                                0.918808
# manager                                   0.919101
# lab technician                            0.919576
# news anchor                               0.919798
# politician                                0.920843
# bank teller                               0.922689
# chef                                      0.922741
# farmer                                    0.922832
# factory worker                            0.923404
# garbage collector                         0.923546
# bartender                                 0.924345
# dentist                                   0.924927
# vet                                       0.925080
# librarian                                 0.925474
# technical support worker                  0.926584
# teacher                                   0.926618
# plumber                                   0.927249
# customer service representative           0.927910
# firefighter                               0.928007
# medical assistant                         0.928179
# taxi driver                               0.928365
# artist                                    0.929770
# custodian                                 0.930137
# psychiatrist                              0.930385
# waiter                                    0.930603
# electrician                               0.931551
# childcare worker                          0.932339
# travel agent                              0.933228
# financial advisor                         0.933586
# pilot                                     0.934573
# nurse                                     0.934712
# truck driver                              0.935694
# scientist                                 0.935876
# cashier                                   0.937748
# police                                    0.938537
# writer                                    0.939058
# doctor                                    0.939418
# professor                                 0.940660
# security guard                            0.940831
# c.e.o                                     0.940989
# graphic designer                          0.941300
# lawyer                                    0.941685
# paramedic                                 0.943531
# welder                                    0.952016
# /var/folders/j8/zf_4c85j5plbmvlpz_x018h40000gn/T/ipykernel_6930/3263262923.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
# Top 5 professions with lowest cosine similarity (most changed):
#                Cosine_Similarity
# director                0.900911
# postal worker           0.903395
# engineer                0.904371
# fisherman               0.904929
# maid                    0.905300
# Mean Cosine Similarity: 0.9260
# Log Mean Cosine Similarity (natural log): -0.0769

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#loading the baseline and debiased embeddings csv
baseline_path = "profession_embeddings_baseline.csv"
debiased_path = "profession_embeddings_debiased_w=0_c=0.csv"

df_baseline = pd.read_csv(baseline_path)
df_debiased = pd.read_csv(debiased_path)

#ensuring the professions in both files match
common_professions = set(df_baseline['Profession']).intersection(set(df_debiased['Profession']))
print(f"Found {len(common_professions)} common professions")

cosine_similarities = {}

for prof in common_professions:
    base_vec = df_baseline.loc[df_baseline['Profession'] == prof].iloc[:, 1:].values
    debiased_vec = df_debiased.loc[df_debiased['Profession'] == prof].iloc[:, 1:].values
    
    #cosine_similarity expects 2d arrays
    cos_sim = cosine_similarity(base_vec, debiased_vec)[0][0]
    cosine_similarities[prof] = cos_sim

#convert to DataFrame for easier checks
sim_df = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['Cosine_Similarity'])
sim_df = sim_df.sort_values('Cosine_Similarity')

print(sim_df)

#plotting

plt.figure(figsize=(8,5))
sns.histplot(sim_df['Cosine_Similarity'], bins=20, kde=True)
plt.title("Distribution of Cosine Similarities: Baseline vs Debiased Embeddings")
plt.xlabel("Cosine Similarity")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12,8))
sim_df_sorted = sim_df.sort_values('Cosine_Similarity')
sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
plt.title("Cosine Similarity of Professions (Baseline vs Debiased)")
plt.xlabel("Cosine Similarity")
plt.ylabel("Profession")
plt.show()

print("Top 5 professions with lowest cosine similarity (most changed):")
print(sim_df_sorted.head(5))

mean_cos_sim = sim_df['Cosine_Similarity'].mean()
print(f"Mean Cosine Similarity: {mean_cos_sim:.4f}")


log_mean_cos_sim = np.log(0.9260)
print(f"Log Mean Cosine Similarity (natural log): {log_mean_cos_sim:.4f}")
# Out:
# Found 58 common professions
#                                  Cosine_Similarity
# director                                  0.901299
# engineer                                  0.902686
# maid                                      0.907583
# salesperson                               0.909630
# computer programmer                       0.910971
# fisherman                                 0.911476
# postal worker                             0.912585
# accountant                                0.912938
# chef                                      0.917155
# actor                                     0.917267
# manager                                   0.917399
# secretary                                 0.918232
# construction worker                       0.918484
# bus driver                                0.919105
# lab technician                            0.919375
# landscaper                                0.920602
# architect                                 0.920637
# librarian                                 0.921194
# politician                                0.921339
# garbage collector                         0.921399
# news anchor                               0.921831
# factory worker                            0.922992
# mechanic                                  0.923116
# waiter                                    0.923194
# farmer                                    0.923788
# bartender                                 0.924411
# teacher                                   0.924896
# bank teller                               0.925542
# psychiatrist                              0.930198
# taxi driver                               0.930601
# artist                                    0.930879
# dentist                                   0.931403
# technical support worker                  0.931580
# vet                                       0.931781
# plumber                                   0.932044
# customer service representative           0.933583
# medical assistant                         0.934470
# scientist                                 0.934844
# firefighter                               0.936442
# custodian                                 0.936645
# professor                                 0.936832
# truck driver                              0.936924
# pilot                                     0.937032
# financial advisor                         0.937295
# travel agent                              0.937500
# childcare worker                          0.938234
# nurse                                     0.938766
# doctor                                    0.939941
# electrician                               0.940238
# writer                                    0.940855
# cashier                                   0.941430
# lawyer                                    0.941698
# police                                    0.942921
# graphic designer                          0.944276
# security guard                            0.945415
# c.e.o                                     0.947455
# paramedic                                 0.947716
# welder                                    0.957022
# /var/folders/j8/zf_4c85j5plbmvlpz_x018h40000gn/T/ipykernel_6930/791599934.py:43: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
# Top 5 professions with lowest cosine similarity (most changed):
#                      Cosine_Similarity
# director                      0.901299
# engineer                      0.902686
# maid                          0.907583
# salesperson                   0.909630
# computer programmer           0.910971
# Mean Cosine Similarity: 0.9282
# Log Mean Cosine Similarity (natural log): -0.0769

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#loading baseline and debiased embeddings
baseline_path = "profession_embeddings_baseline.csv"
debiased_path = "profession_embeddings_debiased_w=1_c=0.csv"

df_baseline = pd.read_csv(baseline_path)
df_debiased = pd.read_csv(debiased_path)

#ensuring the professions in both files are matching
common_professions = set(df_baseline['Profession']).intersection(set(df_debiased['Profession']))
print(f"Found {len(common_professions)} common professions")

cosine_similarities = {}

for prof in common_professions:
    base_vec = df_baseline.loc[df_baseline['Profession'] == prof].iloc[:, 1:].values
    debiased_vec = df_debiased.loc[df_debiased['Profession'] == prof].iloc[:, 1:].values
    
    #shape (1, dim)
    cos_sim = cosine_similarity(base_vec, debiased_vec)[0][0]
    cosine_similarities[prof] = cos_sim

#convert to df for easier checks
sim_df = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['Cosine_Similarity'])
sim_df = sim_df.sort_values('Cosine_Similarity')

print(sim_df)

#plotting

plt.figure(figsize=(8,5))
sns.histplot(sim_df['Cosine_Similarity'], bins=20, kde=True)
plt.title("Distribution of Cosine Similarities: Baseline vs Debiased Embeddings")
plt.xlabel("Cosine Similarity")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12,8))
sim_df_sorted = sim_df.sort_values('Cosine_Similarity')
sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
plt.title("Cosine Similarity of Professions (Baseline vs Debiased)")
plt.xlabel("Cosine Similarity")
plt.ylabel("Profession")
plt.show()

print("Top 5 professions with lowest cosine similarity (most changed):")
print(sim_df_sorted.head(5))


mean_cos_sim = sim_df['Cosine_Similarity'].mean()
print(f"Mean Cosine Similarity: {mean_cos_sim:.4f}")


log_mean_cos_sim = np.log(0.9260)
print(f"Log Mean Cosine Similarity (natural log): {log_mean_cos_sim:.4f}")
# Out:
# Found 58 common professions
#                                  Cosine_Similarity
# director                                  0.910710
# engineer                                  0.913037
# maid                                      0.916719
# salesperson                               0.918250
# postal worker                             0.919713
# computer programmer                       0.920764
# accountant                                0.921358
# fisherman                                 0.921429
# landscaper                                0.922226
# secretary                                 0.922823
# manager                                   0.923981
# architect                                 0.925713
# bus driver                                0.926101
# news anchor                               0.926879
# mechanic                                  0.927140
# lab technician                            0.927410
# construction worker                       0.928346
# politician                                0.928654
# actor                                     0.929551
# bartender                                 0.930632
# garbage collector                         0.931601
# chef                                      0.932588
# librarian                                 0.932647
# waiter                                    0.933013
# dentist                                   0.934394
# custodian                                 0.934938
# teacher                                   0.935019
# customer service representative           0.935390
# bank teller                               0.935455
# farmer                                    0.935749
# factory worker                            0.935801
# vet                                       0.936297
# psychiatrist                              0.936423
# taxi driver                               0.936491
# technical support worker                  0.936542
# medical assistant                         0.937777
# artist                                    0.937806
# financial advisor                         0.938365
# firefighter                               0.938804
# plumber                                   0.939694
# travel agent                              0.940075
# pilot                                     0.940181
# nurse                                     0.941712
# scientist                                 0.941843
# truck driver                              0.942001
# electrician                               0.942058
# professor                                 0.943683
# childcare worker                          0.944387
# doctor                                    0.945247
# cashier                                   0.945398
# writer                                    0.945556
# lawyer                                    0.945728
# graphic designer                          0.946203
# police                                    0.947247
# security guard                            0.948781
# c.e.o                                     0.949609
# paramedic                                 0.950721
# welder                                    0.955160
# /var/folders/j8/zf_4c85j5plbmvlpz_x018h40000gn/T/ipykernel_5801/2077076840.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
# Top 5 professions with lowest cosine similarity (most changed):
#                Cosine_Similarity
# director                0.910710
# engineer                0.913037
# maid                    0.916719
# salesperson             0.918250
# postal worker           0.919713
# Mean Cosine Similarity: 0.9343
# Log Mean Cosine Similarity (natural log): -0.0769

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#loading baseline and debiased embeddings
baseline_path = "profession_embeddings_baseline.csv"
debiased_path = "profession_embeddings_debiased_w=0_c=1.csv"

df_baseline = pd.read_csv(baseline_path)
df_debiased = pd.read_csv(debiased_path)

#ensuring the professions in both files matching
common_professions = set(df_baseline['Profession']).intersection(set(df_debiased['Profession']))
print(f"Found {len(common_professions)} common professions")

cosine_similarities = {}

for prof in common_professions:
    base_vec = df_baseline.loc[df_baseline['Profession'] == prof].iloc[:, 1:].values
    debiased_vec = df_debiased.loc[df_debiased['Profession'] == prof].iloc[:, 1:].values
    
    #cosine_similarity expects 2d arrays
    cos_sim = cosine_similarity(base_vec, debiased_vec)[0][0]
    cosine_similarities[prof] = cos_sim

#converting to df for checkiing
sim_df = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['Cosine_Similarity'])
sim_df = sim_df.sort_values('Cosine_Similarity')

print(sim_df)

#plotting
plt.figure(figsize=(8,5))
sns.histplot(sim_df['Cosine_Similarity'], bins=20, kde=True)
plt.title("Distribution of Cosine Similarities: Baseline vs Debiased Embeddings")
plt.xlabel("Cosine Similarity")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12,8))
sim_df_sorted = sim_df.sort_values('Cosine_Similarity')
sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
plt.title("Cosine Similarity of Professions (Baseline vs Debiased)")
plt.xlabel("Cosine Similarity")
plt.ylabel("Profession")
plt.show()

print("Top 5 professions with lowest cosine similarity (most changed):")
print(sim_df_sorted.head(5))

mean_cos_sim = sim_df['Cosine_Similarity'].mean()
print(f"Mean Cosine Similarity: {mean_cos_sim:.4f}")
# Out:
# Found 58 common professions
#                                  Cosine_Similarity
# postal worker                             0.898770
# engineer                                  0.901683
# maid                                      0.902441
# salesperson                               0.904412
# director                                  0.904654
# fisherman                                 0.905245
# mechanic                                  0.908760
# computer programmer                       0.910796
# construction worker                       0.911306
# bus driver                                0.911824
# waiter                                    0.913956
# secretary                                 0.914016
# accountant                                0.915498
# architect                                 0.916363
# farmer                                    0.916908
# manager                                   0.917350
# lab technician                            0.918025
# garbage collector                         0.918430
# bartender                                 0.919083
# actor                                     0.919373
# chef                                      0.920389
# factory worker                            0.920424
# bank teller                               0.920734
# news anchor                               0.921502
# politician                                0.921651
# landscaper                                0.921652
# custodian                                 0.922222
# taxi driver                               0.922886
# customer service representative           0.923876
# plumber                                   0.924072
# technical support worker                  0.924564
# dentist                                   0.925222
# vet                                       0.925660
# medical assistant                         0.927076
# teacher                                   0.927531
# electrician                               0.927731
# truck driver                              0.927813
# psychiatrist                              0.927903
# librarian                                 0.927957
# travel agent                              0.930305
# pilot                                     0.930620
# firefighter                               0.930632
# artist                                    0.931072
# financial advisor                         0.931077
# childcare worker                          0.931857
# nurse                                     0.932716
# graphic designer                          0.932813
# cashier                                   0.932939
# security guard                            0.935872
# scientist                                 0.936053
# doctor                                    0.938408
# writer                                    0.939636
# lawyer                                    0.939819
# police                                    0.940639
# professor                                 0.940989
# c.e.o                                     0.941269
# paramedic                                 0.944197
# welder                                    0.946908
# /var/folders/j8/zf_4c85j5plbmvlpz_x018h40000gn/T/ipykernel_5801/3914913587.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
# Top 5 professions with lowest cosine similarity (most changed):
#                Cosine_Similarity
# postal worker           0.898770
# engineer                0.901683
# maid                    0.902441
# salesperson             0.904412
# director                0.904654
# Mean Cosine Similarity: 0.9238

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#load the baseline and debiased embeddings csv
baseline_path = "profession_embeddings_baseline.csv"
debiased_path = "profession_embeddings_debiased_w=0.5_c=0.5.csv"

df_baseline = pd.read_csv(baseline_path)
df_debiased = pd.read_csv(debiased_path)

#ensuring the professions in both files match
common_professions = set(df_baseline['Profession']).intersection(set(df_debiased['Profession']))
print(f"Found {len(common_professions)} common professions")

cosine_similarities = {}

for prof in common_professions:
    base_vec = df_baseline.loc[df_baseline['Profession'] == prof].iloc[:, 1:].values
    debiased_vec = df_debiased.loc[df_debiased['Profession'] == prof].iloc[:, 1:].values
    
    cos_sim = cosine_similarity(base_vec, debiased_vec)[0][0]
    cosine_similarities[prof] = cos_sim

#convert to df for easier inspect
sim_df = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['Cosine_Similarity'])
sim_df = sim_df.sort_values('Cosine_Similarity')

print(sim_df)

#plotting
plt.figure(figsize=(8,5))
sns.histplot(sim_df['Cosine_Similarity'], bins=20, kde=True)
plt.title("Distribution of Cosine Similarities: Baseline vs Debiased Embeddings")
plt.xlabel("Cosine Similarity")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(12,8))
sim_df_sorted = sim_df.sort_values('Cosine_Similarity')
sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
plt.title("Cosine Similarity of Professions (Baseline vs Debiased)")
plt.xlabel("Cosine Similarity")
plt.ylabel("Profession")
plt.show()

print("Top 5 professions with lowest cosine similarity (most changed):")
print(sim_df_sorted.head(5))

mean_cos_sim = sim_df['Cosine_Similarity'].mean()
print(f"Mean Cosine Similarity: {mean_cos_sim:.4f}")
# Out:
# Found 58 common professions
#                                  Cosine_Similarity
# engineer                                  0.903783
# director                                  0.905547
# maid                                      0.908731
# postal worker                             0.909388
# fisherman                                 0.910540
# salesperson                               0.911423
# accountant                                0.913775
# computer programmer                       0.914663
# lab technician                            0.917422
# actor                                     0.918028
# waiter                                    0.918196
# construction worker                       0.918324
# architect                                 0.918394
# chef                                      0.919397
# manager                                   0.920187
# librarian                                 0.920287
# bus driver                                0.920624
# mechanic                                  0.921750
# secretary                                 0.922966
# landscaper                                0.923347
# bartender                                 0.923500
# factory worker                            0.923639
# news anchor                               0.923660
# politician                                0.923808
# farmer                                    0.926234
# teacher                                   0.928459
# garbage collector                         0.928621
# plumber                                   0.928848
# technical support worker                  0.929222
# dentist                                   0.930086
# vet                                       0.930354
# psychiatrist                              0.931493
# bank teller                               0.932183
# artist                                    0.932479
# customer service representative           0.932549
# scientist                                 0.933508
# taxi driver                               0.935050
# custodian                                 0.935147
# pilot                                     0.936118
# medical assistant                         0.936363
# firefighter                               0.936390
# childcare worker                          0.937477
# financial advisor                         0.937509
# nurse                                     0.937778
# professor                                 0.939769
# electrician                               0.939852
# truck driver                              0.940065
# doctor                                    0.940213
# travel agent                              0.940443
# writer                                    0.941149
# lawyer                                    0.941300
# police                                    0.942106
# graphic designer                          0.943471
# cashier                                   0.943551
# c.e.o                                     0.944130
# security guard                            0.945699
# paramedic                                 0.950042
# welder                                    0.955813
# /var/folders/j8/zf_4c85j5plbmvlpz_x018h40000gn/T/ipykernel_5801/703046000.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sim_df_sorted['Cosine_Similarity'], y=sim_df_sorted.index, palette="viridis")
# Top 5 professions with lowest cosine similarity (most changed):
#                Cosine_Similarity
# engineer                0.903783
# director                0.905547
# maid                    0.908731
# postal worker           0.909388
# fisherman               0.910540
# Mean Cosine Similarity: 0.9289
