# %%
########w=1, c=0################


import torch
from transformers import BertTokenizer, BertForMaskedLM
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from tqdm import tqdm
import torch.nn.functional as F
from contextlib import contextmanager
import os
import copy

#load and normalize warmth/competence vectors
#warmth_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/warmth_direction.csv').values.flatten()
#competence_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/competence_direction.csv').values.flatten()

warmth_vector = pd.read_csv('data/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('data/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

def gram_schmidt(vectors):
    ortho = []
    for v in vectors:
        for u in ortho:
            v = v - torch.dot(v, u) * u
        v = v / torch.norm(v)
        ortho.append(v)
    return ortho

g0, g1 = gram_schmidt([warmth_vector, competence_vector])
components = [g0, g1]
weights = [1.0, 0.0]

def debias_custom(h, components, weights, n_mask=None):
    debiased = h.clone()
    for i, g in enumerate(components):
        weight = weights[i]
        n = n_mask[i] if n_mask is not None else 1
        debiased -= weight * n * torch.dot(h, g) * g
    return debiased

class MLM_Dataset(Dataset):
    def __init__(self, texts, tokenizer, max_len=128, mask_prob=0.15):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.mask_prob = mask_prob
        self.mask_token_id = tokenizer.mask_token_id

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        text = self.texts[item]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].flatten()
        attention_mask = encoding["attention_mask"].flatten()

        labels = input_ids.clone()

        #identify manually placed [MASK] tokens
        manual_mask_positions = (input_ids == self.mask_token_id)

        #create random mask with 15% probability
        rand = torch.rand(input_ids.shape)
        special_tokens = torch.tensor([
            self.tokenizer.cls_token_id,
            self.tokenizer.sep_token_id,
            self.tokenizer.pad_token_id
        ])
        is_special_token = input_ids.unsqueeze(-1).eq(special_tokens).any(dim=-1)

        #random mask (excluding special tokens and manually masked tokens)
        random_mask_positions = (rand < self.mask_prob) & (~is_special_token) & (~manual_mask_positions)

        #final mask = manual [MASK] + random 15%
        final_mask = manual_mask_positions | random_mask_positions

        labels[~final_mask] = -100  # Only compute loss on these
        input_ids[random_mask_positions] = self.mask_token_id  # Replace random ones with [MASK]

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels
        }


class DebiasedBertForMaskedLM(BertForMaskedLM):
    def __init__(self, config, components, weights, tokenizer, debias_all_tokens=True):
        super().__init__(config)
        self.components = components
        self.weights = weights
        self.tokenizer = tokenizer
        self.debias_all_tokens = debias_all_tokens

    def forward(self, input_ids, attention_mask=None, token_type_ids=None, labels=None):
        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            return_dict=True
        )
        sequence_output = outputs.last_hidden_state
        debiased_sequence_output = sequence_output.clone()
        if self.debias_all_tokens:
            for batch_idx in range(input_ids.size(0)):
                for token_idx in range(input_ids.size(1)):
                    h = sequence_output[batch_idx, token_idx]
                    debiased_sequence_output[batch_idx, token_idx] = debias_custom(h, self.components, self.weights)
        else:
            mask_token_index = (input_ids == self.tokenizer.mask_token_id)
            for batch_idx in range(input_ids.size(0)):
                for token_idx in torch.where(mask_token_index[batch_idx])[0]:
                    h = sequence_output[batch_idx, token_idx]
                    debiased_sequence_output[batch_idx, token_idx] = debias_custom(h, self.components, self.weights)

        prediction_scores = self.cls(debiased_sequence_output)
        loss = None
        if labels is not None:
            loss_fct = torch.nn.CrossEntropyLoss()
            loss = loss_fct(prediction_scores.view(-1, self.config.vocab_size), labels.view(-1))
        return {"loss": loss, "logits": prediction_scores}

#setup device and AMP support
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_amp = torch.cuda.is_available()

if use_amp:
    from torch.cuda.amp import autocast, GradScaler
    scaler = GradScaler()
else:
    @contextmanager
    def autocast():
        yield
    scaler = None

def train_finetune(model, train_loader, val_loader, epochs=7, learning_rate=5e-6, weight_decay=0.01):
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    model.train()

    for epoch in range(epochs):
        epoch_loss = 0
        loop = tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{epochs}")
        for batch in loop:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            optimizer.zero_grad()
            with autocast():
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs['loss']

            if use_amp:
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                optimizer.step()

            epoch_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = epoch_loss / len(train_loader)

        # Validation step
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                val_loss += outputs['loss'].item()
        avg_val_loss = val_loss / len(val_loader)
        model.train()

        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

def print_masked_predictions(model, tokenizer, sentences, top_k=5):
    model.eval()
    for sent in sentences:
        encoding = tokenizer.encode_plus(
            sent,
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].to(device)
        attention_mask = encoding["attention_mask"].to(device)

        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs["logits"]

        mask_token_index = (input_ids == tokenizer.mask_token_id)[0].nonzero(as_tuple=True)[0]
        probs = F.softmax(logits[0, mask_token_index, :], dim=-1)
        top_probs, top_indices = probs.topk(top_k, dim=-1)

        print(f"\nInput: {sent}")
        print("Top predictions for [MASK]:")
        for prob, idx in zip(top_probs[0], top_indices[0]):
            token = tokenizer.decode([idx.item()])
            print(f"  {token.strip()} (prob={prob.item():.4f})")

#setup tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

#load csv with sentences (using only 2nd column)
df = pd.read_csv('data/cleaned_one_masked_sentence_per_job.csv', header=None)
all_sentences = df.iloc[:, 1].dropna().tolist()  # Use second column

#split dataset 80/20 train/val
train_size = int(0.8 * len(all_sentences))
val_size = len(all_sentences) - train_size

train_texts = all_sentences[:train_size]
val_texts = all_sentences[train_size:]

train_dataset = MLM_Dataset(train_texts, tokenizer)
val_dataset = MLM_Dataset(val_texts, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0, pin_memory=(device.type=="cuda"))
val_loader = DataLoader(val_dataset, batch_size=16, num_workers=0, pin_memory=(device.type=="cuda"))

debias_model = DebiasedBertForMaskedLM.from_pretrained(
    "bert-base-uncased",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

debias_model.to(device)

#train with a lower learning rate and add gradient clipping for stability
def train_finetune_stable(
    model, train_loader, val_loader,
    epochs=7, learning_rate=5e-6,
    max_grad_norm=1.0, weight_decay=0.01,
    patience=2,
    save_dir="data/BERT_finetuned"
):
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    best_val_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    os.makedirs(save_dir, exist_ok=True)

    for epoch in range(epochs):
        epoch_loss = 0
        model.train()
        loop = tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{epochs}")
        for batch in loop:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            optimizer.zero_grad()
            with autocast():
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs['loss']

            if use_amp:
                scaler.scale(loss).backward()
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                optimizer.step()

            epoch_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = epoch_loss / len(train_loader)

        #validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                val_loss += outputs['loss'].item()
        avg_val_loss = val_loss / len(val_loader)

        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

        #early stopping check
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print("Validation loss improved. Saving model...")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    #restore best model weights
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    #save final model and tokenizer
    model.save_pretrained(save_dir)
    tokenizer.save_pretrained(save_dir)

    torch.save({
        'components': components,
        'weights': weights
    }, os.path.join(save_dir, 'bias_vectors.pt'))

    print(f"Model saved to: {save_dir}")

# Run training with weight decay
train_finetune_stable(
    debias_model,
    train_loader,
    val_loader,
    epochs=7,
    learning_rate=5e-6,
    patience=2,
    save_dir="data/BERT_finetuned"
)
# Out:
# Training Epoch 1/7: 100%|████████████| 51/51 [07:08<00:00,  8.41s/it, loss=3.45]
# Epoch 1, Train Loss: 4.6601, Val Loss: 3.9886
# Validation loss improved. Saving model...
# Training Epoch 2/7: 100%|████████████| 51/51 [06:55<00:00,  8.15s/it, loss=2.38]
# Epoch 2, Train Loss: 3.1734, Val Loss: 2.5186
# Validation loss improved. Saving model...
# Training Epoch 3/7: 100%|████████████| 51/51 [07:11<00:00,  8.46s/it, loss=2.37]
# Epoch 3, Train Loss: 2.2219, Val Loss: 1.8966
# Validation loss improved. Saving model...
# Training Epoch 4/7: 100%|████████████| 51/51 [06:53<00:00,  8.12s/it, loss=1.79]
# Epoch 4, Train Loss: 1.7076, Val Loss: 2.0058
# Training Epoch 5/7: 100%|████████████| 51/51 [06:58<00:00,  8.21s/it, loss=1.87]
# Epoch 5, Train Loss: 1.6605, Val Loss: 1.8344
# Validation loss improved. Saving model...
# Training Epoch 6/7: 100%|████████████| 51/51 [06:55<00:00,  8.15s/it, loss=2.26]
# Epoch 6, Train Loss: 1.6517, Val Loss: 1.8890
# Training Epoch 7/7: 100%|████████████| 51/51 [06:55<00:00,  8.14s/it, loss=1.71]
# Epoch 7, Train Loss: 1.5839, Val Loss: 1.9453
# Early stopping triggered.
# Model saved to: /Users/aleksandragarbat/Desktop/BERT_finetuned

# %%
##### access model
#load debiasing components (bias directions)
bias_data = torch.load('data/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer
tokenizer = BertTokenizer.from_pretrained("data/BERT_finetuned")

#load model (custom class)
model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True 
)
###access model
bias_data = torch.load('data/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer and model
tokenizer = BertTokenizer.from_pretrained("data/BERT_finetuned")
model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True 
)

# %%
#WARMTH PLL + evaluation

# %%
#batched pll (warmth)
import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForMaskedLM
import csv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#load sentences from csv
sentences_file = "data/pll_sentences_warmth.csv"
sentence_templates = []

with open(sentences_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        #csv has a column named 'sentence'
        sentence_templates.append(row['sentence'])

print(f"Loaded {len(sentence_templates)} sentences from {sentences_file}")



#list of professions (some multi-token)
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"

]

def approximate_pll_batched(sentence_template, profession):
    sentence = sentence_template.replace("[MASK]", profession)

    full_tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    def find_sublist(full, sub):
        for i in range(len(full) - len(sub) + 1):
            if full[i:i+len(sub)] == sub:
                return i
        return -1

    start_idx = find_sublist(full_tokens, profession_tokens)
    if start_idx == -1:
        print(f"Could not find profession tokens in the sentence tokens: {profession}")
        return None

    masked_inputs = []
    mask_positions = []
    for i in range(len(profession_tokens)):
        masked_tokens = full_tokens.copy()
        masked_tokens[start_idx + i] = tokenizer.mask_token
        input_ids = tokenizer.convert_tokens_to_ids(masked_tokens)
        input_ids = tokenizer.build_inputs_with_special_tokens(input_ids)
        masked_inputs.append(input_ids)

    #pad the batch
    max_len = max(len(x) for x in masked_inputs)
    padded_inputs = []
    attention_masks = []

    for input_ids in masked_inputs:
        padding_length = max_len - len(input_ids)
        padded = input_ids + [tokenizer.pad_token_id] * padding_length
        padded_inputs.append(padded)
        attention_masks.append([1] * len(input_ids) + [0] * padding_length)

    input_ids_tensor = torch.tensor(padded_inputs).to(device)
    attention_mask_tensor = torch.tensor(attention_masks).to(device)

    with torch.no_grad():
        outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
        logits = outputs['logits']

    log_probs = []
    for i in range(len(profession_tokens)):
        #find mask token index in this input
        mask_token_index = (input_ids_tensor[i] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0].item()
        softmax_logits = F.softmax(logits[i, mask_token_index], dim=0)
        target_token_id = tokenizer.convert_tokens_to_ids(profession_tokens[i])
        token_prob = softmax_logits[target_token_id].item()
        token_prob = max(token_prob, 1e-10)
        log_probs.append(torch.log(torch.tensor(token_prob)))

    approx_pll = torch.sum(torch.stack(log_probs)).item()
    return approx_pll


#evaluate PLL for each profession on each sentence template
for sentence_template in sentence_templates:
    print(f"\nSentence: \"{sentence_template}\"\n{'-'*60}")

    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
   

    print()
# Out:
# Loaded 200 sentences from /Users/aleksandragarbat/Desktop/pll_sentences_warmth.csv
#
# Sentence: "A pleased [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.1783
# Profession: vet                  -> Approx. PLL: -9.5157
# Profession: paramedic            -> Approx. PLL: -0.0018
# Profession: chef                 -> Approx. PLL: -8.4495
# Profession: dentist              -> Approx. PLL: -10.1151
# Profession: maid                 -> Approx. PLL: -11.4707
# Profession: doctor               -> Approx. PLL: -6.5227
# Profession: nurse                -> Approx. PLL: -8.1775
# Profession: scientist            -> Approx. PLL: -7.0071
# Profession: welder               -> Approx. PLL: -1.9674
# Profession: teacher              -> Approx. PLL: -6.6988
# Profession: waiter               -> Approx. PLL: -9.3731
# Profession: mechanic             -> Approx. PLL: -9.6433
# Profession: police               -> Approx. PLL: -14.1983
# Profession: secretary            -> Approx. PLL: -10.5707
# Profession: psychiatrist         -> Approx. PLL: -13.0546
# Profession: farmer               -> Approx. PLL: -9.3651
# Profession: pilot                -> Approx. PLL: -7.9686
# Profession: director             -> Approx. PLL: -8.0864
# Profession: architect            -> Approx. PLL: -11.2715
# Profession: c.e.o                -> Approx. PLL: -10.5769
# Profession: artist               -> Approx. PLL: -9.0703
# Profession: writer               -> Approx. PLL: -9.3517
# Profession: fisherman            -> Approx. PLL: -11.0467
# Profession: medical assistant    -> Approx. PLL: -7.5617
# Profession: manager              -> Approx. PLL: -5.9337
# Profession: librarian            -> Approx. PLL: -11.3149
# Profession: politician           -> Approx. PLL: -7.2903
# Profession: engineer             -> Approx. PLL: -9.2103
# Profession: bartender            -> Approx. PLL: -9.2303
# Profession: accountant           -> Approx. PLL: -10.9509
# Profession: firefighter          -> Approx. PLL: -0.7605
# Profession: travel agent         -> Approx. PLL: -8.4136
# Profession: lawyer               -> Approx. PLL: -8.1214
# Profession: actor                -> Approx. PLL: -6.9007
# Profession: lab technician       -> Approx. PLL: -3.5567
# Profession: security guard       -> Approx. PLL: -0.9253
# Profession: custodian            -> Approx. PLL: -0.0014
# Profession: childcare worker     -> Approx. PLL: -3.5604
# Profession: bank teller          -> Approx. PLL: -4.3334
# Profession: taxi driver          -> Approx. PLL: -7.1420
# Profession: bus driver           -> Approx. PLL: -6.9332
# Profession: news anchor          -> Approx. PLL: -3.2954
# Profession: customer service representative -> Approx. PLL: -9.9243
# Profession: cashier              -> Approx. PLL: -1.3957
# Profession: plumber              -> Approx. PLL: -0.3431
# Profession: technical support worker -> Approx. PLL: -10.5047
# Profession: electrician          -> Approx. PLL: -1.4905
# Profession: graphic designer     -> Approx. PLL: -4.7326
# Profession: financial advisor    -> Approx. PLL: -6.5201
# Profession: salesperson          -> Approx. PLL: -3.7595
# Profession: truck driver         -> Approx. PLL: -7.1479
# Profession: landscaper           -> Approx. PLL: -7.8152
# Profession: postal worker        -> Approx. PLL: -7.3458
# Profession: factory worker       -> Approx. PLL: -5.3426
# Profession: garbage collector    -> Approx. PLL: -5.2988
# Profession: computer programmer  -> Approx. PLL: -4.8683
# Profession: construction worker  -> Approx. PLL: -3.6804
#
#
# Sentence: "Everyone admired the pleased [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.8168
# Profession: vet                  -> Approx. PLL: -11.6445
# Profession: paramedic            -> Approx. PLL: -1.9438
# Profession: chef                 -> Approx. PLL: -8.4241
# Profession: dentist              -> Approx. PLL: -10.3808
# Profession: maid                 -> Approx. PLL: -10.4532
# Profession: doctor               -> Approx. PLL: -6.3771
# Profession: nurse                -> Approx. PLL: -8.3784
# Profession: scientist            -> Approx. PLL: -7.3301
# Profession: welder               -> Approx. PLL: -13.5002
# Profession: teacher              -> Approx. PLL: -7.8986
# Profession: waiter               -> Approx. PLL: -8.7038
# Profession: mechanic             -> Approx. PLL: -10.4078
# Profession: police               -> Approx. PLL: -8.1464
# Profession: secretary            -> Approx. PLL: -10.7115
# Profession: psychiatrist         -> Approx. PLL: -13.3317
# Profession: farmer               -> Approx. PLL: -8.6987
# Profession: pilot                -> Approx. PLL: -10.0409
# Profession: director             -> Approx. PLL: -8.8928
# Profession: architect            -> Approx. PLL: -9.8282
# Profession: c.e.o                -> Approx. PLL: -10.3023
# Profession: artist               -> Approx. PLL: -6.9386
# Profession: writer               -> Approx. PLL: -11.6813
# Profession: fisherman            -> Approx. PLL: -11.0280
# Profession: medical assistant    -> Approx. PLL: -11.7868
# Profession: manager              -> Approx. PLL: -8.1667
# Profession: librarian            -> Approx. PLL: -9.3519
# Profession: politician           -> Approx. PLL: -7.8230
# Profession: engineer             -> Approx. PLL: -9.0261
# Profession: bartender            -> Approx. PLL: -8.7260
# Profession: accountant           -> Approx. PLL: -10.7320
# Profession: firefighter          -> Approx. PLL: -4.5456
# Profession: travel agent         -> Approx. PLL: -7.9852
# Profession: lawyer               -> Approx. PLL: -8.5344
# Profession: actor                -> Approx. PLL: -8.6798
# Profession: lab technician       -> Approx. PLL: -6.3047
# Profession: security guard       -> Approx. PLL: -2.0750
# Profession: custodian            -> Approx. PLL: -0.0132
# Profession: childcare worker     -> Approx. PLL: -8.1869
# Profession: bank teller          -> Approx. PLL: -8.3305
# Profession: taxi driver          -> Approx. PLL: -4.8484
# Profession: bus driver           -> Approx. PLL: -4.8936
# Profession: news anchor          -> Approx. PLL: -6.7016
# Profession: customer service representative -> Approx. PLL: -12.9380
# Profession: cashier              -> Approx. PLL: -1.4611
# Profession: plumber              -> Approx. PLL: -2.6004
# Profession: technical support worker -> Approx. PLL: -15.8905
# Profession: electrician          -> Approx. PLL: -4.5199
# Profession: graphic designer     -> Approx. PLL: -6.8540
# Profession: financial advisor    -> Approx. PLL: -6.1399
# Profession: salesperson          -> Approx. PLL: -3.6868
# Profession: truck driver         -> Approx. PLL: -7.0511
# Profession: landscaper           -> Approx. PLL: -9.7529
# Profession: postal worker        -> Approx. PLL: -8.6558
# Profession: factory worker       -> Approx. PLL: -7.9329
# Profession: garbage collector    -> Approx. PLL: -8.8070
# Profession: computer programmer  -> Approx. PLL: -6.0600
# Profession: construction worker  -> Approx. PLL: -6.6682
#
#
# Sentence: "It was clear the pleased [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.5006
# Profession: vet                  -> Approx. PLL: -9.1571
# Profession: paramedic            -> Approx. PLL: -0.1069
# Profession: chef                 -> Approx. PLL: -6.9138
# Profession: dentist              -> Approx. PLL: -9.2330
# Profession: maid                 -> Approx. PLL: -8.6362
# Profession: doctor               -> Approx. PLL: -5.5724
# Profession: nurse                -> Approx. PLL: -6.1835
# Profession: scientist            -> Approx. PLL: -7.1611
# Profession: welder               -> Approx. PLL: -11.2265
# Profession: teacher              -> Approx. PLL: -7.5939
# Profession: waiter               -> Approx. PLL: -7.2249
# Profession: mechanic             -> Approx. PLL: -9.4210
# Profession: police               -> Approx. PLL: -9.2482
# Profession: secretary            -> Approx. PLL: -8.9472
# Profession: psychiatrist         -> Approx. PLL: -12.1420
# Profession: farmer               -> Approx. PLL: -7.1215
# Profession: pilot                -> Approx. PLL: -7.8143
# Profession: director             -> Approx. PLL: -7.6395
# Profession: architect            -> Approx. PLL: -10.1104
# Profession: c.e.o                -> Approx. PLL: -12.8183
# Profession: artist               -> Approx. PLL: -7.9625
# Profession: writer               -> Approx. PLL: -9.6583
# Profession: fisherman            -> Approx. PLL: -10.3098
# Profession: medical assistant    -> Approx. PLL: -9.7822
# Profession: manager              -> Approx. PLL: -5.8427
# Profession: librarian            -> Approx. PLL: -8.9765
# Profession: politician           -> Approx. PLL: -6.2287
# Profession: engineer             -> Approx. PLL: -8.5336
# Profession: bartender            -> Approx. PLL: -7.6537
# Profession: accountant           -> Approx. PLL: -10.1081
# Profession: firefighter          -> Approx. PLL: -2.9809
# Profession: travel agent         -> Approx. PLL: -7.0382
# Profession: lawyer               -> Approx. PLL: -7.3502
# Profession: actor                -> Approx. PLL: -7.5138
# Profession: lab technician       -> Approx. PLL: -3.7160
# Profession: security guard       -> Approx. PLL: -1.8180
# Profession: custodian            -> Approx. PLL: -0.0027
# Profession: childcare worker     -> Approx. PLL: -4.1009
# Profession: bank teller          -> Approx. PLL: -5.6966
# Profession: taxi driver          -> Approx. PLL: -2.8657
# Profession: bus driver           -> Approx. PLL: -4.2737
# Profession: news anchor          -> Approx. PLL: -7.8917
# Profession: customer service representative -> Approx. PLL: -8.9880
# Profession: cashier              -> Approx. PLL: -0.8789
# Profession: plumber              -> Approx. PLL: -0.4731
# Profession: technical support worker -> Approx. PLL: -10.9811
# Profession: electrician          -> Approx. PLL: -2.3851
# Profession: graphic designer     -> Approx. PLL: -5.4417
# Profession: financial advisor    -> Approx. PLL: -5.0889
# Profession: salesperson          -> Approx. PLL: -2.1598
# Profession: truck driver         -> Approx. PLL: -5.6501
# Profession: landscaper           -> Approx. PLL: -8.0696
# Profession: postal worker        -> Approx. PLL: -5.7378
# Profession: factory worker       -> Approx. PLL: -4.6897
# Profession: garbage collector    -> Approx. PLL: -8.0463
# Profession: computer programmer  -> Approx. PLL: -4.1983
# Profession: construction worker  -> Approx. PLL: -3.8984
#
#
# Sentence: "A pleased [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.6276
# Profession: vet                  -> Approx. PLL: -10.9231
# Profession: paramedic            -> Approx. PLL: -0.0024
# Profession: chef                 -> Approx. PLL: -8.3764
# Profession: dentist              -> Approx. PLL: -9.6151
# Profession: maid                 -> Approx. PLL: -10.9483
# Profession: doctor               -> Approx. PLL: -7.0777
# Profession: nurse                -> Approx. PLL: -7.4444
# Profession: scientist            -> Approx. PLL: -6.2280
# Profession: welder               -> Approx. PLL: -1.3441
# Profession: teacher              -> Approx. PLL: -4.8460
# Profession: waiter               -> Approx. PLL: -8.1453
# Profession: mechanic             -> Approx. PLL: -9.2048
# Profession: police               -> Approx. PLL: -14.5637
# Profession: secretary            -> Approx. PLL: -9.0452
# Profession: psychiatrist         -> Approx. PLL: -12.3934
# Profession: farmer               -> Approx. PLL: -9.2903
# Profession: pilot                -> Approx. PLL: -9.8917
# Profession: director             -> Approx. PLL: -6.4311
# Profession: architect            -> Approx. PLL: -10.4878
# Profession: c.e.o                -> Approx. PLL: -9.3786
# Profession: artist               -> Approx. PLL: -7.0611
# Profession: writer               -> Approx. PLL: -8.1074
# Profession: fisherman            -> Approx. PLL: -13.3738
# Profession: medical assistant    -> Approx. PLL: -8.2944
# Profession: manager              -> Approx. PLL: -5.0868
# Profession: librarian            -> Approx. PLL: -10.0855
# Profession: politician           -> Approx. PLL: -8.1377
# Profession: engineer             -> Approx. PLL: -7.5368
# Profession: bartender            -> Approx. PLL: -9.0286
# Profession: accountant           -> Approx. PLL: -9.9973
# Profession: firefighter          -> Approx. PLL: -0.8225
# Profession: travel agent         -> Approx. PLL: -8.1994
# Profession: lawyer               -> Approx. PLL: -8.9985
# Profession: actor                -> Approx. PLL: -6.9976
# Profession: lab technician       -> Approx. PLL: -4.4953
# Profession: security guard       -> Approx. PLL: -0.6328
# Profession: custodian            -> Approx. PLL: -0.0051
# Profession: childcare worker     -> Approx. PLL: -3.6025
# Profession: bank teller          -> Approx. PLL: -4.3591
# Profession: taxi driver          -> Approx. PLL: -3.3802
# Profession: bus driver           -> Approx. PLL: -2.0994
# Profession: news anchor          -> Approx. PLL: -4.1841
# Profession: customer service representative -> Approx. PLL: -8.4786
# Profession: cashier              -> Approx. PLL: -1.2184
# Profession: plumber              -> Approx. PLL: -0.2922
# Profession: technical support worker -> Approx. PLL: -9.4882
# Profession: electrician          -> Approx. PLL: -1.5433
# Profession: graphic designer     -> Approx. PLL: -4.5317
# Profession: financial advisor    -> Approx. PLL: -6.2386
# Profession: salesperson          -> Approx. PLL: -2.8852
# Profession: truck driver         -> Approx. PLL: -3.5060
# Profession: landscaper           -> Approx. PLL: -7.4762
# Profession: postal worker        -> Approx. PLL: -8.8700
# Profession: factory worker       -> Approx. PLL: -4.7668
# Profession: garbage collector    -> Approx. PLL: -2.7924
# Profession: computer programmer  -> Approx. PLL: -4.7519
# Profession: construction worker  -> Approx. PLL: -5.6163
#
#
# Sentence: "The pleased [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.7057
# Profession: vet                  -> Approx. PLL: -11.7650
# Profession: paramedic            -> Approx. PLL: -1.7753
# Profession: chef                 -> Approx. PLL: -8.9389
# Profession: dentist              -> Approx. PLL: -11.0850
# Profession: maid                 -> Approx. PLL: -9.9657
# Profession: doctor               -> Approx. PLL: -7.0412
# Profession: nurse                -> Approx. PLL: -8.3312
# Profession: scientist            -> Approx. PLL: -8.4707
# Profession: welder               -> Approx. PLL: -14.9796
# Profession: teacher              -> Approx. PLL: -7.6895
# Profession: waiter               -> Approx. PLL: -9.3659
# Profession: mechanic             -> Approx. PLL: -11.5198
# Profession: police               -> Approx. PLL: -8.5465
# Profession: secretary            -> Approx. PLL: -10.9145
# Profession: psychiatrist         -> Approx. PLL: -13.8874
# Profession: farmer               -> Approx. PLL: -7.5318
# Profession: pilot                -> Approx. PLL: -11.4244
# Profession: director             -> Approx. PLL: -9.2539
# Profession: architect            -> Approx. PLL: -10.2550
# Profession: c.e.o                -> Approx. PLL: -10.1498
# Profession: artist               -> Approx. PLL: -8.1121
# Profession: writer               -> Approx. PLL: -11.4459
# Profession: fisherman            -> Approx. PLL: -10.0466
# Profession: medical assistant    -> Approx. PLL: -12.8381
# Profession: manager              -> Approx. PLL: -7.6343
# Profession: librarian            -> Approx. PLL: -9.4418
# Profession: politician           -> Approx. PLL: -8.2209
# Profession: engineer             -> Approx. PLL: -10.9143
# Profession: bartender            -> Approx. PLL: -8.4460
# Profession: accountant           -> Approx. PLL: -10.1877
# Profession: firefighter          -> Approx. PLL: -4.3472
# Profession: travel agent         -> Approx. PLL: -7.0577
# Profession: lawyer               -> Approx. PLL: -9.0909
# Profession: actor                -> Approx. PLL: -9.0992
# Profession: lab technician       -> Approx. PLL: -6.8091
# Profession: security guard       -> Approx. PLL: -2.6322
# Profession: custodian            -> Approx. PLL: -0.0078
# Profession: childcare worker     -> Approx. PLL: -6.3895
# Profession: bank teller          -> Approx. PLL: -6.0401
# Profession: taxi driver          -> Approx. PLL: -3.8834
# Profession: bus driver           -> Approx. PLL: -3.4411
# Profession: news anchor          -> Approx. PLL: -5.4729
# Profession: customer service representative -> Approx. PLL: -10.5684
# Profession: cashier              -> Approx. PLL: -1.8261
# Profession: plumber              -> Approx. PLL: -0.9882
# Profession: technical support worker -> Approx. PLL: -15.2654
# Profession: electrician          -> Approx. PLL: -3.7622
# Profession: graphic designer     -> Approx. PLL: -5.6852
# Profession: financial advisor    -> Approx. PLL: -7.6125
# Profession: salesperson          -> Approx. PLL: -6.4825
# Profession: truck driver         -> Approx. PLL: -6.7713
# Profession: landscaper           -> Approx. PLL: -7.8929
# Profession: postal worker        -> Approx. PLL: -10.0283
# Profession: factory worker       -> Approx. PLL: -9.6655
# Profession: garbage collector    -> Approx. PLL: -4.8678
# Profession: computer programmer  -> Approx. PLL: -6.4286
# Profession: construction worker  -> Approx. PLL: -9.4240
#
#
# Sentence: "A benevolent [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.3568
# Profession: vet                  -> Approx. PLL: -9.2780
# Profession: paramedic            -> Approx. PLL: -0.0025
# Profession: chef                 -> Approx. PLL: -8.9897
# Profession: dentist              -> Approx. PLL: -9.9201
# Profession: maid                 -> Approx. PLL: -11.7050
# Profession: doctor               -> Approx. PLL: -5.6402
# Profession: nurse                -> Approx. PLL: -6.1671
# Profession: scientist            -> Approx. PLL: -8.5986
# Profession: welder               -> Approx. PLL: -0.6957
# Profession: teacher              -> Approx. PLL: -5.6754
# Profession: waiter               -> Approx. PLL: -10.2768
# Profession: mechanic             -> Approx. PLL: -8.8568
# Profession: police               -> Approx. PLL: -12.1183
# Profession: secretary            -> Approx. PLL: -9.3641
# Profession: psychiatrist         -> Approx. PLL: -11.1028
# Profession: farmer               -> Approx. PLL: -9.7398
# Profession: pilot                -> Approx. PLL: -8.8017
# Profession: director             -> Approx. PLL: -6.4608
# Profession: architect            -> Approx. PLL: -9.6939
# Profession: c.e.o                -> Approx. PLL: -10.1551
# Profession: artist               -> Approx. PLL: -9.8066
# Profession: writer               -> Approx. PLL: -10.2536
# Profession: fisherman            -> Approx. PLL: -10.0841
# Profession: medical assistant    -> Approx. PLL: -6.8139
# Profession: manager              -> Approx. PLL: -4.6086
# Profession: librarian            -> Approx. PLL: -8.5852
# Profession: politician           -> Approx. PLL: -7.5303
# Profession: engineer             -> Approx. PLL: -8.6689
# Profession: bartender            -> Approx. PLL: -8.7329
# Profession: accountant           -> Approx. PLL: -9.4120
# Profession: firefighter          -> Approx. PLL: -0.7015
# Profession: travel agent         -> Approx. PLL: -9.4043
# Profession: lawyer               -> Approx. PLL: -7.6846
# Profession: actor                -> Approx. PLL: -8.2552
# Profession: lab technician       -> Approx. PLL: -4.3369
# Profession: security guard       -> Approx. PLL: -2.2899
# Profession: custodian            -> Approx. PLL: -0.0017
# Profession: childcare worker     -> Approx. PLL: -5.6277
# Profession: bank teller          -> Approx. PLL: -9.9968
# Profession: taxi driver          -> Approx. PLL: -6.4022
# Profession: bus driver           -> Approx. PLL: -5.9265
# Profession: news anchor          -> Approx. PLL: -2.9908
# Profession: customer service representative -> Approx. PLL: -12.5579
# Profession: cashier              -> Approx. PLL: -5.3935
# Profession: plumber              -> Approx. PLL: -0.2913
# Profession: technical support worker -> Approx. PLL: -13.3969
# Profession: electrician          -> Approx. PLL: -1.3661
# Profession: graphic designer     -> Approx. PLL: -4.0507
# Profession: financial advisor    -> Approx. PLL: -6.2286
# Profession: salesperson          -> Approx. PLL: -6.2872
# Profession: truck driver         -> Approx. PLL: -5.7097
# Profession: landscaper           -> Approx. PLL: -8.3903
# Profession: postal worker        -> Approx. PLL: -9.5060
# Profession: factory worker       -> Approx. PLL: -6.1678
# Profession: garbage collector    -> Approx. PLL: -1.7837
# Profession: computer programmer  -> Approx. PLL: -5.0394
# Profession: construction worker  -> Approx. PLL: -6.2898
#
#
# Sentence: "Everyone admired the benevolent [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.4234
# Profession: vet                  -> Approx. PLL: -11.6811
# Profession: paramedic            -> Approx. PLL: -3.5397
# Profession: chef                 -> Approx. PLL: -11.2715
# Profession: dentist              -> Approx. PLL: -10.5394
# Profession: maid                 -> Approx. PLL: -12.4300
# Profession: doctor               -> Approx. PLL: -8.0793
# Profession: nurse                -> Approx. PLL: -8.5365
# Profession: scientist            -> Approx. PLL: -8.8971
# Profession: welder               -> Approx. PLL: -11.3582
# Profession: teacher              -> Approx. PLL: -8.8660
# Profession: waiter               -> Approx. PLL: -11.8405
# Profession: mechanic             -> Approx. PLL: -11.5374
# Profession: police               -> Approx. PLL: -5.6700
# Profession: secretary            -> Approx. PLL: -10.0368
# Profession: psychiatrist         -> Approx. PLL: -12.5227
# Profession: farmer               -> Approx. PLL: -9.8521
# Profession: pilot                -> Approx. PLL: -11.0326
# Profession: director             -> Approx. PLL: -8.5428
# Profession: architect            -> Approx. PLL: -9.5495
# Profession: c.e.o                -> Approx. PLL: -10.0577
# Profession: artist               -> Approx. PLL: -9.4415
# Profession: writer               -> Approx. PLL: -12.9873
# Profession: fisherman            -> Approx. PLL: -9.7296
# Profession: medical assistant    -> Approx. PLL: -13.0451
# Profession: manager              -> Approx. PLL: -8.9079
# Profession: librarian            -> Approx. PLL: -8.6674
# Profession: politician           -> Approx. PLL: -9.9060
# Profession: engineer             -> Approx. PLL: -10.3313
# Profession: bartender            -> Approx. PLL: -11.3450
# Profession: accountant           -> Approx. PLL: -11.1118
# Profession: firefighter          -> Approx. PLL: -5.5784
# Profession: travel agent         -> Approx. PLL: -9.2440
# Profession: lawyer               -> Approx. PLL: -9.6701
# Profession: actor                -> Approx. PLL: -10.7514
# Profession: lab technician       -> Approx. PLL: -9.6101
# Profession: security guard       -> Approx. PLL: -2.8974
# Profession: custodian            -> Approx. PLL: -0.1378
# Profession: childcare worker     -> Approx. PLL: -8.7340
# Profession: bank teller          -> Approx. PLL: -14.2717
# Profession: taxi driver          -> Approx. PLL: -7.2226
# Profession: bus driver           -> Approx. PLL: -5.5732
# Profession: news anchor          -> Approx. PLL: -9.3506
# Profession: customer service representative -> Approx. PLL: -13.4710
# Profession: cashier              -> Approx. PLL: -3.5900
# Profession: plumber              -> Approx. PLL: -4.5434
# Profession: technical support worker -> Approx. PLL: -19.0747
# Profession: electrician          -> Approx. PLL: -5.2043
# Profession: graphic designer     -> Approx. PLL: -7.8065
# Profession: financial advisor    -> Approx. PLL: -8.5956
# Profession: salesperson          -> Approx. PLL: -7.7164
# Profession: truck driver         -> Approx. PLL: -7.4950
# Profession: landscaper           -> Approx. PLL: -11.0880
# Profession: postal worker        -> Approx. PLL: -11.8896
# Profession: factory worker       -> Approx. PLL: -11.4322
# Profession: garbage collector    -> Approx. PLL: -6.3892
# Profession: computer programmer  -> Approx. PLL: -7.2343
# Profession: construction worker  -> Approx. PLL: -10.7216
#
#
# Sentence: "It was clear the benevolent [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -5.6259
# Profession: vet                  -> Approx. PLL: -7.7109
# Profession: paramedic            -> Approx. PLL: -0.3738
# Profession: chef                 -> Approx. PLL: -7.9303
# Profession: dentist              -> Approx. PLL: -9.1856
# Profession: maid                 -> Approx. PLL: -9.5144
# Profession: doctor               -> Approx. PLL: -4.9107
# Profession: nurse                -> Approx. PLL: -5.6240
# Profession: scientist            -> Approx. PLL: -6.3743
# Profession: welder               -> Approx. PLL: -8.6139
# Profession: teacher              -> Approx. PLL: -5.4979
# Profession: waiter               -> Approx. PLL: -8.5087
# Profession: mechanic             -> Approx. PLL: -9.0239
# Profession: police               -> Approx. PLL: -7.5192
# Profession: secretary            -> Approx. PLL: -7.4307
# Profession: psychiatrist         -> Approx. PLL: -9.0246
# Profession: farmer               -> Approx. PLL: -6.8459
# Profession: pilot                -> Approx. PLL: -7.4528
# Profession: director             -> Approx. PLL: -6.0986
# Profession: architect            -> Approx. PLL: -7.5688
# Profession: c.e.o                -> Approx. PLL: -11.8194
# Profession: artist               -> Approx. PLL: -8.1847
# Profession: writer               -> Approx. PLL: -9.1630
# Profession: fisherman            -> Approx. PLL: -8.0807
# Profession: medical assistant    -> Approx. PLL: -8.3560
# Profession: manager              -> Approx. PLL: -6.1804
# Profession: librarian            -> Approx. PLL: -5.3376
# Profession: politician           -> Approx. PLL: -6.9314
# Profession: engineer             -> Approx. PLL: -8.3917
# Profession: bartender            -> Approx. PLL: -7.7218
# Profession: accountant           -> Approx. PLL: -7.7511
# Profession: firefighter          -> Approx. PLL: -4.0514
# Profession: travel agent         -> Approx. PLL: -7.5534
# Profession: lawyer               -> Approx. PLL: -7.2203
# Profession: actor                -> Approx. PLL: -7.9346
# Profession: lab technician       -> Approx. PLL: -4.3981
# Profession: security guard       -> Approx. PLL: -2.6185
# Profession: custodian            -> Approx. PLL: -0.0034
# Profession: childcare worker     -> Approx. PLL: -4.3099
# Profession: bank teller          -> Approx. PLL: -11.7805
# Profession: taxi driver          -> Approx. PLL: -3.2604
# Profession: bus driver           -> Approx. PLL: -3.8294
# Profession: news anchor          -> Approx. PLL: -5.6971
# Profession: customer service representative -> Approx. PLL: -10.7440
# Profession: cashier              -> Approx. PLL: -3.0694
# Profession: plumber              -> Approx. PLL: -0.2351
# Profession: technical support worker -> Approx. PLL: -12.3067
# Profession: electrician          -> Approx. PLL: -1.9255
# Profession: graphic designer     -> Approx. PLL: -4.7181
# Profession: financial advisor    -> Approx. PLL: -5.2295
# Profession: salesperson          -> Approx. PLL: -3.9974
# Profession: truck driver         -> Approx. PLL: -5.3888
# Profession: landscaper           -> Approx. PLL: -8.2220
# Profession: postal worker        -> Approx. PLL: -8.0250
# Profession: factory worker       -> Approx. PLL: -6.3871
# Profession: garbage collector    -> Approx. PLL: -4.3057
# Profession: computer programmer  -> Approx. PLL: -4.9730
# Profession: construction worker  -> Approx. PLL: -5.9996
#
#
# Sentence: "A benevolent [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.8131
# Profession: vet                  -> Approx. PLL: -9.0334
# Profession: paramedic            -> Approx. PLL: -0.0039
# Profession: chef                 -> Approx. PLL: -8.5735
# Profession: dentist              -> Approx. PLL: -7.5644
# Profession: maid                 -> Approx. PLL: -12.0344
# Profession: doctor               -> Approx. PLL: -6.0801
# Profession: nurse                -> Approx. PLL: -5.7929
# Profession: scientist            -> Approx. PLL: -7.3372
# Profession: welder               -> Approx. PLL: -0.1356
# Profession: teacher              -> Approx. PLL: -4.8821
# Profession: waiter               -> Approx. PLL: -11.0359
# Profession: mechanic             -> Approx. PLL: -8.6072
# Profession: police               -> Approx. PLL: -11.8922
# Profession: secretary            -> Approx. PLL: -8.7722
# Profession: psychiatrist         -> Approx. PLL: -9.8006
# Profession: farmer               -> Approx. PLL: -8.6091
# Profession: pilot                -> Approx. PLL: -10.3750
# Profession: director             -> Approx. PLL: -4.9737
# Profession: architect            -> Approx. PLL: -8.1693
# Profession: c.e.o                -> Approx. PLL: -8.9625
# Profession: artist               -> Approx. PLL: -8.4055
# Profession: writer               -> Approx. PLL: -9.5991
# Profession: fisherman            -> Approx. PLL: -11.1084
# Profession: medical assistant    -> Approx. PLL: -8.8344
# Profession: manager              -> Approx. PLL: -3.6484
# Profession: librarian            -> Approx. PLL: -7.2144
# Profession: politician           -> Approx. PLL: -8.7718
# Profession: engineer             -> Approx. PLL: -6.5521
# Profession: bartender            -> Approx. PLL: -9.8414
# Profession: accountant           -> Approx. PLL: -7.6026
# Profession: firefighter          -> Approx. PLL: -1.4836
# Profession: travel agent         -> Approx. PLL: -10.4673
# Profession: lawyer               -> Approx. PLL: -7.3847
# Profession: actor                -> Approx. PLL: -8.6415
# Profession: lab technician       -> Approx. PLL: -5.5383
# Profession: security guard       -> Approx. PLL: -2.9014
# Profession: custodian            -> Approx. PLL: -0.0090
# Profession: childcare worker     -> Approx. PLL: -5.7594
# Profession: bank teller          -> Approx. PLL: -11.3206
# Profession: taxi driver          -> Approx. PLL: -4.4543
# Profession: bus driver           -> Approx. PLL: -3.9992
# Profession: news anchor          -> Approx. PLL: -8.0918
# Profession: customer service representative -> Approx. PLL: -8.1698
# Profession: cashier              -> Approx. PLL: -3.6421
# Profession: plumber              -> Approx. PLL: -0.2298
# Profession: technical support worker -> Approx. PLL: -10.8427
# Profession: electrician          -> Approx. PLL: -0.8649
# Profession: graphic designer     -> Approx. PLL: -3.9363
# Profession: financial advisor    -> Approx. PLL: -7.1546
# Profession: salesperson          -> Approx. PLL: -5.3479
# Profession: truck driver         -> Approx. PLL: -3.2308
# Profession: landscaper           -> Approx. PLL: -8.3043
# Profession: postal worker        -> Approx. PLL: -11.6874
# Profession: factory worker       -> Approx. PLL: -6.2047
# Profession: garbage collector    -> Approx. PLL: -0.9151
# Profession: computer programmer  -> Approx. PLL: -3.5745
# Profession: construction worker  -> Approx. PLL: -7.4758
#
#
# Sentence: "The benevolent [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.3698
# Profession: vet                  -> Approx. PLL: -10.6262
# Profession: paramedic            -> Approx. PLL: -1.8823
# Profession: chef                 -> Approx. PLL: -10.0206
# Profession: dentist              -> Approx. PLL: -10.0398
# Profession: maid                 -> Approx. PLL: -11.7107
# Profession: doctor               -> Approx. PLL: -7.2845
# Profession: nurse                -> Approx. PLL: -6.7497
# Profession: scientist            -> Approx. PLL: -9.7868
# Profession: welder               -> Approx. PLL: -9.4298
# Profession: teacher              -> Approx. PLL: -7.3904
# Profession: waiter               -> Approx. PLL: -11.2513
# Profession: mechanic             -> Approx. PLL: -11.1873
# Profession: police               -> Approx. PLL: -7.5156
# Profession: secretary            -> Approx. PLL: -8.4091
# Profession: psychiatrist         -> Approx. PLL: -12.0479
# Profession: farmer               -> Approx. PLL: -7.7949
# Profession: pilot                -> Approx. PLL: -11.2047
# Profession: director             -> Approx. PLL: -6.0321
# Profession: architect            -> Approx. PLL: -8.8123
# Profession: c.e.o                -> Approx. PLL: -9.7509
# Profession: artist               -> Approx. PLL: -8.9273
# Profession: writer               -> Approx. PLL: -11.3830
# Profession: fisherman            -> Approx. PLL: -10.0373
# Profession: medical assistant    -> Approx. PLL: -11.7215
# Profession: manager              -> Approx. PLL: -7.0679
# Profession: librarian            -> Approx. PLL: -7.6777
# Profession: politician           -> Approx. PLL: -12.0332
# Profession: engineer             -> Approx. PLL: -9.8388
# Profession: bartender            -> Approx. PLL: -11.4056
# Profession: accountant           -> Approx. PLL: -8.4820
# Profession: firefighter          -> Approx. PLL: -6.2962
# Profession: travel agent         -> Approx. PLL: -11.0286
# Profession: lawyer               -> Approx. PLL: -9.3143
# Profession: actor                -> Approx. PLL: -10.0286
# Profession: lab technician       -> Approx. PLL: -12.9840
# Profession: security guard       -> Approx. PLL: -6.7136
# Profession: custodian            -> Approx. PLL: -0.0108
# Profession: childcare worker     -> Approx. PLL: -9.3080
# Profession: bank teller          -> Approx. PLL: -17.3964
# Profession: taxi driver          -> Approx. PLL: -5.7225
# Profession: bus driver           -> Approx. PLL: -5.1588
# Profession: news anchor          -> Approx. PLL: -10.1206
# Profession: customer service representative -> Approx. PLL: -13.5119
# Profession: cashier              -> Approx. PLL: -1.7392
# Profession: plumber              -> Approx. PLL: -1.4264
# Profession: technical support worker -> Approx. PLL: -17.3976
# Profession: electrician          -> Approx. PLL: -3.2175
# Profession: graphic designer     -> Approx. PLL: -8.2274
# Profession: financial advisor    -> Approx. PLL: -9.4920
# Profession: salesperson          -> Approx. PLL: -9.5463
# Profession: truck driver         -> Approx. PLL: -5.6937
# Profession: landscaper           -> Approx. PLL: -9.4386
# Profession: postal worker        -> Approx. PLL: -12.4906
# Profession: factory worker       -> Approx. PLL: -10.5011
# Profession: garbage collector    -> Approx. PLL: -5.6746
# Profession: computer programmer  -> Approx. PLL: -9.8698
# Profession: construction worker  -> Approx. PLL: -10.9486
#
#
# Sentence: "A funny [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.2878
# Profession: vet                  -> Approx. PLL: -11.1463
# Profession: paramedic            -> Approx. PLL: -0.0020
# Profession: chef                 -> Approx. PLL: -11.6669
# Profession: dentist              -> Approx. PLL: -10.7985
# Profession: maid                 -> Approx. PLL: -12.7447
# Profession: doctor               -> Approx. PLL: -8.5043
# Profession: nurse                -> Approx. PLL: -10.2199
# Profession: scientist            -> Approx. PLL: -9.4738
# Profession: welder               -> Approx. PLL: -3.1629
# Profession: teacher              -> Approx. PLL: -7.5660
# Profession: waiter               -> Approx. PLL: -10.9127
# Profession: mechanic             -> Approx. PLL: -9.6753
# Profession: police               -> Approx. PLL: -14.0262
# Profession: secretary            -> Approx. PLL: -13.9632
# Profession: psychiatrist         -> Approx. PLL: -13.6024
# Profession: farmer               -> Approx. PLL: -11.8170
# Profession: pilot                -> Approx. PLL: -11.7647
# Profession: director             -> Approx. PLL: -9.5877
# Profession: architect            -> Approx. PLL: -15.1953
# Profession: c.e.o                -> Approx. PLL: -12.2878
# Profession: artist               -> Approx. PLL: -10.9037
# Profession: writer               -> Approx. PLL: -9.3830
# Profession: fisherman            -> Approx. PLL: -11.1335
# Profession: medical assistant    -> Approx. PLL: -11.1011
# Profession: manager              -> Approx. PLL: -10.7680
# Profession: librarian            -> Approx. PLL: -13.2036
# Profession: politician           -> Approx. PLL: -10.0795
# Profession: engineer             -> Approx. PLL: -13.4005
# Profession: bartender            -> Approx. PLL: -10.8600
# Profession: accountant           -> Approx. PLL: -13.5559
# Profession: firefighter          -> Approx. PLL: -4.5893
# Profession: travel agent         -> Approx. PLL: -13.3400
# Profession: lawyer               -> Approx. PLL: -10.2103
# Profession: actor                -> Approx. PLL: -7.6687
# Profession: lab technician       -> Approx. PLL: -7.4985
# Profession: security guard       -> Approx. PLL: -5.1208
# Profession: custodian            -> Approx. PLL: -0.0034
# Profession: childcare worker     -> Approx. PLL: -8.0658
# Profession: bank teller          -> Approx. PLL: -11.2393
# Profession: taxi driver          -> Approx. PLL: -7.1868
# Profession: bus driver           -> Approx. PLL: -7.8491
# Profession: news anchor          -> Approx. PLL: -5.4017
# Profession: customer service representative -> Approx. PLL: -11.1853
# Profession: cashier              -> Approx. PLL: -8.3913
# Profession: plumber              -> Approx. PLL: -0.9027
# Profession: technical support worker -> Approx. PLL: -14.9930
# Profession: electrician          -> Approx. PLL: -5.9285
# Profession: graphic designer     -> Approx. PLL: -10.1490
# Profession: financial advisor    -> Approx. PLL: -10.7678
# Profession: salesperson          -> Approx. PLL: -7.3236
# Profession: truck driver         -> Approx. PLL: -7.2576
# Profession: landscaper           -> Approx. PLL: -17.1050
# Profession: postal worker        -> Approx. PLL: -9.8897
# Profession: factory worker       -> Approx. PLL: -9.6148
# Profession: garbage collector    -> Approx. PLL: -6.9173
# Profession: computer programmer  -> Approx. PLL: -8.2651
# Profession: construction worker  -> Approx. PLL: -9.0409
#
#
# Sentence: "Everyone admired the funny [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.7150
# Profession: vet                  -> Approx. PLL: -12.7824
# Profession: paramedic            -> Approx. PLL: -3.3706
# Profession: chef                 -> Approx. PLL: -11.6960
# Profession: dentist              -> Approx. PLL: -11.1416
# Profession: maid                 -> Approx. PLL: -11.1788
# Profession: doctor               -> Approx. PLL: -7.9829
# Profession: nurse                -> Approx. PLL: -10.2268
# Profession: scientist            -> Approx. PLL: -10.4587
# Profession: welder               -> Approx. PLL: -12.4500
# Profession: teacher              -> Approx. PLL: -10.0177
# Profession: waiter               -> Approx. PLL: -10.8062
# Profession: mechanic             -> Approx. PLL: -12.6380
# Profession: police               -> Approx. PLL: -8.9353
# Profession: secretary            -> Approx. PLL: -13.6585
# Profession: psychiatrist         -> Approx. PLL: -13.5275
# Profession: farmer               -> Approx. PLL: -11.9244
# Profession: pilot                -> Approx. PLL: -13.7916
# Profession: director             -> Approx. PLL: -10.8323
# Profession: architect            -> Approx. PLL: -15.5514
# Profession: c.e.o                -> Approx. PLL: -12.0664
# Profession: artist               -> Approx. PLL: -11.1289
# Profession: writer               -> Approx. PLL: -11.8492
# Profession: fisherman            -> Approx. PLL: -10.2748
# Profession: medical assistant    -> Approx. PLL: -13.2735
# Profession: manager              -> Approx. PLL: -12.1471
# Profession: librarian            -> Approx. PLL: -11.7586
# Profession: politician           -> Approx. PLL: -12.2627
# Profession: engineer             -> Approx. PLL: -14.7337
# Profession: bartender            -> Approx. PLL: -10.2669
# Profession: accountant           -> Approx. PLL: -12.4420
# Profession: firefighter          -> Approx. PLL: -6.9684
# Profession: travel agent         -> Approx. PLL: -14.0763
# Profession: lawyer               -> Approx. PLL: -10.9718
# Profession: actor                -> Approx. PLL: -9.5658
# Profession: lab technician       -> Approx. PLL: -10.0892
# Profession: security guard       -> Approx. PLL: -3.6202
# Profession: custodian            -> Approx. PLL: -0.0899
# Profession: childcare worker     -> Approx. PLL: -13.1671
# Profession: bank teller          -> Approx. PLL: -12.3678
# Profession: taxi driver          -> Approx. PLL: -6.4501
# Profession: bus driver           -> Approx. PLL: -5.1753
# Profession: news anchor          -> Approx. PLL: -6.3678
# Profession: customer service representative -> Approx. PLL: -11.7847
# Profession: cashier              -> Approx. PLL: -5.8473
# Profession: plumber              -> Approx. PLL: -4.6814
# Profession: technical support worker -> Approx. PLL: -18.8321
# Profession: electrician          -> Approx. PLL: -7.4908
# Profession: graphic designer     -> Approx. PLL: -11.3123
# Profession: financial advisor    -> Approx. PLL: -10.9307
# Profession: salesperson          -> Approx. PLL: -7.2442
# Profession: truck driver         -> Approx. PLL: -7.2452
# Profession: landscaper           -> Approx. PLL: -15.0843
# Profession: postal worker        -> Approx. PLL: -11.3965
# Profession: factory worker       -> Approx. PLL: -11.8851
# Profession: garbage collector    -> Approx. PLL: -8.4415
# Profession: computer programmer  -> Approx. PLL: -9.3742
# Profession: construction worker  -> Approx. PLL: -10.5987
#
#
# Sentence: "It was clear the funny [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -5.5686
# Profession: vet                  -> Approx. PLL: -9.0377
# Profession: paramedic            -> Approx. PLL: -0.1703
# Profession: chef                 -> Approx. PLL: -9.3824
# Profession: dentist              -> Approx. PLL: -8.4460
# Profession: maid                 -> Approx. PLL: -9.0141
# Profession: doctor               -> Approx. PLL: -5.1430
# Profession: nurse                -> Approx. PLL: -6.7504
# Profession: scientist            -> Approx. PLL: -8.6860
# Profession: welder               -> Approx. PLL: -14.0329
# Profession: teacher              -> Approx. PLL: -7.5015
# Profession: waiter               -> Approx. PLL: -8.9070
# Profession: mechanic             -> Approx. PLL: -9.8011
# Profession: police               -> Approx. PLL: -9.9531
# Profession: secretary            -> Approx. PLL: -9.3143
# Profession: psychiatrist         -> Approx. PLL: -11.2487
# Profession: farmer               -> Approx. PLL: -8.8923
# Profession: pilot                -> Approx. PLL: -11.3313
# Profession: director             -> Approx. PLL: -8.3275
# Profession: architect            -> Approx. PLL: -14.0125
# Profession: c.e.o                -> Approx. PLL: -15.2210
# Profession: artist               -> Approx. PLL: -10.0843
# Profession: writer               -> Approx. PLL: -9.3936
# Profession: fisherman            -> Approx. PLL: -9.0723
# Profession: medical assistant    -> Approx. PLL: -7.7121
# Profession: manager              -> Approx. PLL: -9.3504
# Profession: librarian            -> Approx. PLL: -8.3125
# Profession: politician           -> Approx. PLL: -10.2938
# Profession: engineer             -> Approx. PLL: -12.7070
# Profession: bartender            -> Approx. PLL: -8.1756
# Profession: accountant           -> Approx. PLL: -9.5851
# Profession: firefighter          -> Approx. PLL: -4.1486
# Profession: travel agent         -> Approx. PLL: -10.8147
# Profession: lawyer               -> Approx. PLL: -8.3044
# Profession: actor                -> Approx. PLL: -7.5041
# Profession: lab technician       -> Approx. PLL: -7.2104
# Profession: security guard       -> Approx. PLL: -2.4658
# Profession: custodian            -> Approx. PLL: -0.0020
# Profession: childcare worker     -> Approx. PLL: -7.5709
# Profession: bank teller          -> Approx. PLL: -7.8079
# Profession: taxi driver          -> Approx. PLL: -4.2233
# Profession: bus driver           -> Approx. PLL: -3.0550
# Profession: news anchor          -> Approx. PLL: -8.9745
# Profession: customer service representative -> Approx. PLL: -8.6063
# Profession: cashier              -> Approx. PLL: -2.6467
# Profession: plumber              -> Approx. PLL: -0.8877
# Profession: technical support worker -> Approx. PLL: -14.0499
# Profession: electrician          -> Approx. PLL: -3.2590
# Profession: graphic designer     -> Approx. PLL: -9.8838
# Profession: financial advisor    -> Approx. PLL: -7.5156
# Profession: salesperson          -> Approx. PLL: -4.9658
# Profession: truck driver         -> Approx. PLL: -3.9514
# Profession: landscaper           -> Approx. PLL: -10.8369
# Profession: postal worker        -> Approx. PLL: -8.8368
# Profession: factory worker       -> Approx. PLL: -8.3746
# Profession: garbage collector    -> Approx. PLL: -8.2791
# Profession: computer programmer  -> Approx. PLL: -8.1453
# Profession: construction worker  -> Approx. PLL: -6.6064
#
#
# Sentence: "A funny [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.4249
# Profession: vet                  -> Approx. PLL: -10.5467
# Profession: paramedic            -> Approx. PLL: -0.0033
# Profession: chef                 -> Approx. PLL: -10.3990
# Profession: dentist              -> Approx. PLL: -8.2587
# Profession: maid                 -> Approx. PLL: -11.3532
# Profession: doctor               -> Approx. PLL: -6.9113
# Profession: nurse                -> Approx. PLL: -9.4605
# Profession: scientist            -> Approx. PLL: -8.1979
# Profession: welder               -> Approx. PLL: -1.1970
# Profession: teacher              -> Approx. PLL: -5.8913
# Profession: waiter               -> Approx. PLL: -8.5021
# Profession: mechanic             -> Approx. PLL: -8.5218
# Profession: police               -> Approx. PLL: -13.1855
# Profession: secretary            -> Approx. PLL: -12.4120
# Profession: psychiatrist         -> Approx. PLL: -12.2296
# Profession: farmer               -> Approx. PLL: -10.0628
# Profession: pilot                -> Approx. PLL: -12.0522
# Profession: director             -> Approx. PLL: -7.2771
# Profession: architect            -> Approx. PLL: -13.9541
# Profession: c.e.o                -> Approx. PLL: -9.6539
# Profession: artist               -> Approx. PLL: -8.3614
# Profession: writer               -> Approx. PLL: -7.7458
# Profession: fisherman            -> Approx. PLL: -10.7764
# Profession: medical assistant    -> Approx. PLL: -9.8393
# Profession: manager              -> Approx. PLL: -9.2540
# Profession: librarian            -> Approx. PLL: -11.4519
# Profession: politician           -> Approx. PLL: -9.6858
# Profession: engineer             -> Approx. PLL: -11.4857
# Profession: bartender            -> Approx. PLL: -9.5618
# Profession: accountant           -> Approx. PLL: -12.4653
# Profession: firefighter          -> Approx. PLL: -3.1810
# Profession: travel agent         -> Approx. PLL: -11.7103
# Profession: lawyer               -> Approx. PLL: -9.6129
# Profession: actor                -> Approx. PLL: -7.1608
# Profession: lab technician       -> Approx. PLL: -7.7461
# Profession: security guard       -> Approx. PLL: -2.2068
# Profession: custodian            -> Approx. PLL: -0.0076
# Profession: childcare worker     -> Approx. PLL: -7.7058
# Profession: bank teller          -> Approx. PLL: -10.8925
# Profession: taxi driver          -> Approx. PLL: -3.1415
# Profession: bus driver           -> Approx. PLL: -3.4203
# Profession: news anchor          -> Approx. PLL: -5.1893
# Profession: customer service representative -> Approx. PLL: -6.5019
# Profession: cashier              -> Approx. PLL: -6.1004
# Profession: plumber              -> Approx. PLL: -0.9249
# ...
# Profession: fisherman            -> Approx. PLL: -11.9344
# Profession: medical assistant    -> Approx. PLL: -9.8391
# Profession: manager              -> Approx. PLL: -8.6314
# Profession: librarian            -> Approx. PLL: -10.8423
# Profession: politician           -> Approx. PLL: -7.3935
# Profession: engineer             -> Approx. PLL: -10.1210
# Profession: bartender            -> Approx. PLL: -10.0229
# Profession: accountant           -> Approx. PLL: -10.4115
# Profession: firefighter          -> Approx. PLL: -2.0355
# Profession: travel agent         -> Approx. PLL: -10.3162
# Profession: lawyer               -> Approx. PLL: -7.5391
# Profession: actor                -> Approx. PLL: -5.4693
# Profession: lab technician       -> Approx. PLL: -4.2682
# Profession: security guard       -> Approx. PLL: -1.8310
# Profession: custodian            -> Approx. PLL: -0.0049
# Profession: childcare worker     -> Approx. PLL: -4.3948
# Profession: bank teller          -> Approx. PLL: -7.4243
# Profession: taxi driver          -> Approx. PLL: -6.6149
# Profession: bus driver           -> Approx. PLL: -7.6843
# Profession: news anchor          -> Approx. PLL: -3.9514
# Profession: customer service representative -> Approx. PLL: -14.3651
# Profession: cashier              -> Approx. PLL: -6.7915
# Profession: plumber              -> Approx. PLL: -0.3826
# Profession: technical support worker -> Approx. PLL: -12.4800
# Profession: electrician          -> Approx. PLL: -4.6988
# Profession: graphic designer     -> Approx. PLL: -8.2037
# Profession: financial advisor    -> Approx. PLL: -8.6730
# Profession: salesperson          -> Approx. PLL: -8.4952
# Profession: truck driver         -> Approx. PLL: -6.7201
# Profession: landscaper           -> Approx. PLL: -11.5217
# Profession: postal worker        -> Approx. PLL: -9.4205
# Profession: factory worker       -> Approx. PLL: -5.0553
# Profession: garbage collector    -> Approx. PLL: -3.1677
# Profession: computer programmer  -> Approx. PLL: -3.9895
# Profession: construction worker  -> Approx. PLL: -6.1322
#
#
# Sentence: "Everyone admired the repressed [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -11.0732
# Profession: vet                  -> Approx. PLL: -12.9844
# Profession: paramedic            -> Approx. PLL: -2.6266
# Profession: chef                 -> Approx. PLL: -13.4383
# Profession: dentist              -> Approx. PLL: -12.1551
# Profession: maid                 -> Approx. PLL: -12.1906
# Profession: doctor               -> Approx. PLL: -9.1877
# Profession: nurse                -> Approx. PLL: -9.1298
# Profession: scientist            -> Approx. PLL: -10.6022
# Profession: welder               -> Approx. PLL: -8.1559
# Profession: teacher              -> Approx. PLL: -10.0615
# Profession: waiter               -> Approx. PLL: -13.2867
# Profession: mechanic             -> Approx. PLL: -15.1534
# Profession: police               -> Approx. PLL: -6.8413
# Profession: secretary            -> Approx. PLL: -14.1042
# Profession: psychiatrist         -> Approx. PLL: -11.8056
# Profession: farmer               -> Approx. PLL: -13.3237
# Profession: pilot                -> Approx. PLL: -13.3504
# Profession: director             -> Approx. PLL: -12.9412
# Profession: architect            -> Approx. PLL: -13.6226
# Profession: c.e.o                -> Approx. PLL: -11.1161
# Profession: artist               -> Approx. PLL: -10.2901
# Profession: writer               -> Approx. PLL: -14.1090
# Profession: fisherman            -> Approx. PLL: -13.5015
# Profession: medical assistant    -> Approx. PLL: -14.1139
# Profession: manager              -> Approx. PLL: -13.9961
# Profession: librarian            -> Approx. PLL: -11.2726
# Profession: politician           -> Approx. PLL: -11.9101
# Profession: engineer             -> Approx. PLL: -13.5340
# Profession: bartender            -> Approx. PLL: -12.2383
# Profession: accountant           -> Approx. PLL: -12.9673
# Profession: firefighter          -> Approx. PLL: -5.6539
# Profession: travel agent         -> Approx. PLL: -10.5566
# Profession: lawyer               -> Approx. PLL: -11.1061
# Profession: actor                -> Approx. PLL: -11.2594
# Profession: lab technician       -> Approx. PLL: -7.7103
# Profession: security guard       -> Approx. PLL: -2.6960
# Profession: custodian            -> Approx. PLL: -0.1268
# Profession: childcare worker     -> Approx. PLL: -9.8665
# Profession: bank teller          -> Approx. PLL: -8.8906
# Profession: taxi driver          -> Approx. PLL: -5.9132
# Profession: bus driver           -> Approx. PLL: -5.9118
# Profession: news anchor          -> Approx. PLL: -7.9784
# Profession: customer service representative -> Approx. PLL: -16.9660
# Profession: cashier              -> Approx. PLL: -5.4441
# Profession: plumber              -> Approx. PLL: -4.9339
# Profession: technical support worker -> Approx. PLL: -19.2030
# Profession: electrician          -> Approx. PLL: -7.3273
# Profession: graphic designer     -> Approx. PLL: -9.5391
# Profession: financial advisor    -> Approx. PLL: -10.4510
# Profession: salesperson          -> Approx. PLL: -8.2086
# Profession: truck driver         -> Approx. PLL: -7.9778
# Profession: landscaper           -> Approx. PLL: -13.0971
# Profession: postal worker        -> Approx. PLL: -12.1633
# Profession: factory worker       -> Approx. PLL: -9.4119
# Profession: garbage collector    -> Approx. PLL: -6.6784
# Profession: computer programmer  -> Approx. PLL: -6.5509
# Profession: construction worker  -> Approx. PLL: -10.3769
#
#
# Sentence: "It was clear the repressed [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.3204
# Profession: vet                  -> Approx. PLL: -9.6078
# Profession: paramedic            -> Approx. PLL: -0.9037
# Profession: chef                 -> Approx. PLL: -10.5102
# Profession: dentist              -> Approx. PLL: -10.5465
# Profession: maid                 -> Approx. PLL: -10.4358
# Profession: doctor               -> Approx. PLL: -5.5757
# Profession: nurse                -> Approx. PLL: -6.6899
# Profession: scientist            -> Approx. PLL: -8.8544
# Profession: welder               -> Approx. PLL: -8.3181
# Profession: teacher              -> Approx. PLL: -7.4927
# Profession: waiter               -> Approx. PLL: -10.7176
# Profession: mechanic             -> Approx. PLL: -12.9175
# Profession: police               -> Approx. PLL: -7.2432
# Profession: secretary            -> Approx. PLL: -10.1084
# Profession: psychiatrist         -> Approx. PLL: -8.9963
# Profession: farmer               -> Approx. PLL: -10.7014
# Profession: pilot                -> Approx. PLL: -9.2923
# Profession: director             -> Approx. PLL: -9.6356
# Profession: architect            -> Approx. PLL: -11.7613
# Profession: c.e.o                -> Approx. PLL: -12.4062
# Profession: artist               -> Approx. PLL: -10.1131
# Profession: writer               -> Approx. PLL: -10.9995
# Profession: fisherman            -> Approx. PLL: -12.3708
# Profession: medical assistant    -> Approx. PLL: -10.4433
# Profession: manager              -> Approx. PLL: -9.9938
# Profession: librarian            -> Approx. PLL: -7.8794
# Profession: politician           -> Approx. PLL: -9.3127
# Profession: engineer             -> Approx. PLL: -10.6439
# Profession: bartender            -> Approx. PLL: -9.2513
# Profession: accountant           -> Approx. PLL: -9.9395
# Profession: firefighter          -> Approx. PLL: -2.3032
# Profession: travel agent         -> Approx. PLL: -8.0060
# Profession: lawyer               -> Approx. PLL: -8.2427
# Profession: actor                -> Approx. PLL: -8.0965
# Profession: lab technician       -> Approx. PLL: -3.9136
# Profession: security guard       -> Approx. PLL: -2.0791
# Profession: custodian            -> Approx. PLL: -0.0153
# Profession: childcare worker     -> Approx. PLL: -5.5871
# Profession: bank teller          -> Approx. PLL: -5.4406
# Profession: taxi driver          -> Approx. PLL: -2.4089
# Profession: bus driver           -> Approx. PLL: -3.5115
# Profession: news anchor          -> Approx. PLL: -3.6198
# Profession: customer service representative -> Approx. PLL: -13.8306
# Profession: cashier              -> Approx. PLL: -2.8613
# Profession: plumber              -> Approx. PLL: -0.4979
# Profession: technical support worker -> Approx. PLL: -12.6943
# Profession: electrician          -> Approx. PLL: -1.7666
# Profession: graphic designer     -> Approx. PLL: -7.5738
# Profession: financial advisor    -> Approx. PLL: -6.3310
# Profession: salesperson          -> Approx. PLL: -5.2531
# Profession: truck driver         -> Approx. PLL: -4.1867
# Profession: landscaper           -> Approx. PLL: -9.0923
# Profession: postal worker        -> Approx. PLL: -7.5444
# Profession: factory worker       -> Approx. PLL: -5.9142
# Profession: garbage collector    -> Approx. PLL: -5.8200
# Profession: computer programmer  -> Approx. PLL: -3.6379
# Profession: construction worker  -> Approx. PLL: -6.4517
#
#
# Sentence: "A repressed [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.3550
# Profession: vet                  -> Approx. PLL: -10.2124
# Profession: paramedic            -> Approx. PLL: -0.0023
# Profession: chef                 -> Approx. PLL: -9.9622
# Profession: dentist              -> Approx. PLL: -8.9646
# Profession: maid                 -> Approx. PLL: -11.2838
# Profession: doctor               -> Approx. PLL: -8.0102
# Profession: nurse                -> Approx. PLL: -6.4998
# Profession: scientist            -> Approx. PLL: -7.5619
# Profession: welder               -> Approx. PLL: -0.1224
# Profession: teacher              -> Approx. PLL: -5.0073
# Profession: waiter               -> Approx. PLL: -11.3942
# Profession: mechanic             -> Approx. PLL: -11.2645
# Profession: police               -> Approx. PLL: -13.6496
# Profession: secretary            -> Approx. PLL: -10.7509
# Profession: psychiatrist         -> Approx. PLL: -8.5150
# Profession: farmer               -> Approx. PLL: -11.9696
# Profession: pilot                -> Approx. PLL: -11.6168
# Profession: director             -> Approx. PLL: -8.3209
# Profession: architect            -> Approx. PLL: -10.5245
# Profession: c.e.o                -> Approx. PLL: -8.8350
# Profession: artist               -> Approx. PLL: -6.7785
# Profession: writer               -> Approx. PLL: -8.6532
# Profession: fisherman            -> Approx. PLL: -15.2117
# Profession: medical assistant    -> Approx. PLL: -11.5825
# Profession: manager              -> Approx. PLL: -7.9344
# Profession: librarian            -> Approx. PLL: -8.9474
# Profession: politician           -> Approx. PLL: -10.2826
# Profession: engineer             -> Approx. PLL: -8.0440
# Profession: bartender            -> Approx. PLL: -10.9579
# Profession: accountant           -> Approx. PLL: -10.0113
# Profession: firefighter          -> Approx. PLL: -2.4678
# Profession: travel agent         -> Approx. PLL: -10.6160
# Profession: lawyer               -> Approx. PLL: -9.0257
# Profession: actor                -> Approx. PLL: -6.2221
# Profession: lab technician       -> Approx. PLL: -4.5428
# Profession: security guard       -> Approx. PLL: -2.5973
# Profession: custodian            -> Approx. PLL: -0.0120
# Profession: childcare worker     -> Approx. PLL: -4.6580
# Profession: bank teller          -> Approx. PLL: -8.5352
# Profession: taxi driver          -> Approx. PLL: -3.6263
# Profession: bus driver           -> Approx. PLL: -3.2895
# Profession: news anchor          -> Approx. PLL: -8.7999
# Profession: customer service representative -> Approx. PLL: -11.2667
# Profession: cashier              -> Approx. PLL: -5.0404
# Profession: plumber              -> Approx. PLL: -0.4019
# Profession: technical support worker -> Approx. PLL: -10.3508
# Profession: electrician          -> Approx. PLL: -6.3963
# Profession: graphic designer     -> Approx. PLL: -6.2773
# Profession: financial advisor    -> Approx. PLL: -9.7565
# Profession: salesperson          -> Approx. PLL: -8.8946
# Profession: truck driver         -> Approx. PLL: -2.7710
# Profession: landscaper           -> Approx. PLL: -10.3217
# Profession: postal worker        -> Approx. PLL: -12.4657
# Profession: factory worker       -> Approx. PLL: -6.3395
# Profession: garbage collector    -> Approx. PLL: -2.2629
# Profession: computer programmer  -> Approx. PLL: -3.9886
# Profession: construction worker  -> Approx. PLL: -9.4221
#
#
# Sentence: "The repressed [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -12.6851
# Profession: vet                  -> Approx. PLL: -12.9359
# Profession: paramedic            -> Approx. PLL: -1.6298
# Profession: chef                 -> Approx. PLL: -14.1615
# Profession: dentist              -> Approx. PLL: -13.2675
# Profession: maid                 -> Approx. PLL: -13.1622
# Profession: doctor               -> Approx. PLL: -8.7718
# Profession: nurse                -> Approx. PLL: -9.6346
# Profession: scientist            -> Approx. PLL: -12.9685
# Profession: welder               -> Approx. PLL: -9.6935
# Profession: teacher              -> Approx. PLL: -10.0451
# Profession: waiter               -> Approx. PLL: -14.4989
# Profession: mechanic             -> Approx. PLL: -16.5498
# Profession: police               -> Approx. PLL: -6.7803
# Profession: secretary            -> Approx. PLL: -14.1051
# Profession: psychiatrist         -> Approx. PLL: -12.3382
# Profession: farmer               -> Approx. PLL: -11.8788
# Profession: pilot                -> Approx. PLL: -14.8440
# Profession: director             -> Approx. PLL: -13.1203
# Profession: architect            -> Approx. PLL: -13.4545
# Profession: c.e.o                -> Approx. PLL: -10.4215
# Profession: artist               -> Approx. PLL: -11.4857
# Profession: writer               -> Approx. PLL: -13.8460
# Profession: fisherman            -> Approx. PLL: -13.3350
# Profession: medical assistant    -> Approx. PLL: -12.7213
# Profession: manager              -> Approx. PLL: -15.2063
# Profession: librarian            -> Approx. PLL: -10.7083
# Profession: politician           -> Approx. PLL: -13.0379
# Profession: engineer             -> Approx. PLL: -14.5039
# Profession: bartender            -> Approx. PLL: -13.0115
# Profession: accountant           -> Approx. PLL: -13.2258
# Profession: firefighter          -> Approx. PLL: -3.9967
# Profession: travel agent         -> Approx. PLL: -10.1359
# Profession: lawyer               -> Approx. PLL: -11.5096
# Profession: actor                -> Approx. PLL: -10.8905
# Profession: lab technician       -> Approx. PLL: -9.5251
# Profession: security guard       -> Approx. PLL: -4.3121
# Profession: custodian            -> Approx. PLL: -0.0468
# Profession: childcare worker     -> Approx. PLL: -7.8576
# Profession: bank teller          -> Approx. PLL: -7.9447
# Profession: taxi driver          -> Approx. PLL: -5.4913
# Profession: bus driver           -> Approx. PLL: -4.8491
# Profession: news anchor          -> Approx. PLL: -5.2602
# Profession: customer service representative -> Approx. PLL: -15.3610
# Profession: cashier              -> Approx. PLL: -3.8888
# Profession: plumber              -> Approx. PLL: -3.6209
# Profession: technical support worker -> Approx. PLL: -16.6701
# Profession: electrician          -> Approx. PLL: -5.5301
# Profession: graphic designer     -> Approx. PLL: -7.5039
# Profession: financial advisor    -> Approx. PLL: -14.3024
# Profession: salesperson          -> Approx. PLL: -11.0306
# Profession: truck driver         -> Approx. PLL: -6.2823
# Profession: landscaper           -> Approx. PLL: -10.5787
# Profession: postal worker        -> Approx. PLL: -12.4727
# Profession: factory worker       -> Approx. PLL: -10.1579
# Profession: garbage collector    -> Approx. PLL: -5.3464
# Profession: computer programmer  -> Approx. PLL: -6.4934
# Profession: construction worker  -> Approx. PLL: -10.9900

# %%
#PLL results for warmth:
#store all results
all_results = []

for sentence_template in sentence_templates:
    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            
            # print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    
    profession_scores.sort(key=lambda x: x[1], reverse=True)
    all_results.append({"sentence": sentence_template, "scores": profession_scores})
    
    # print()

print("\n\n=== Aggregated Results Per Sentence ===\n")

warmth_professions = {
    "professor", "vet", "paramedic", "chef", "dentist", "doctor", "nurse", "teacher", "secretary",
    "psychiatrist", "farmer", "pilot", "architect", "writer","medical assistant", "engineer", "bartender", "firefighter","lab technician",
    "custodian", "childcare worker", "bank teller"

}
warmth_professions = set([p.lower() for p in warmth_professions])
professions_lower = [p.lower() for p in professions]
nonwarm_professions = set(professions_lower) - warmth_professions

for result in all_results:
    sentence = result["sentence"]
    scores = result["scores"]

    warm_plls = []
    nonwarm_plls = []

    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            warm_plls.append(pll)
        elif prof_lower in nonwarm_professions:
            nonwarm_plls.append(pll)

    if warm_plls and nonwarm_plls:
        avg_warm = sum(warm_plls) / len(warm_plls)
        avg_nonwarm = sum(nonwarm_plls) / len(nonwarm_plls)
        delta = avg_warm - avg_nonwarm

        print(f"Sentence: {sentence}")
        print(f"  Avg PLL (Warm Professions)    : {avg_warm:.4f}")
        print(f"  Avg PLL (Non-Warm Professions): {avg_nonwarm:.4f}")
        print(f"  Δ Warm - Nonwarm              : {delta:.4f}")
        print("-" * 60)
# Out:
# === Aggregated Results Per Sentence ===
#
# Sentence: A pleased [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.1571
#   Avg PLL (Non-Warm Professions): -6.9398
#   Δ Warm - Nonwarm              : -0.2174
# ------------------------------------------------------------
# Sentence: Everyone admired the pleased [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.3671
#   Avg PLL (Non-Warm Professions): -7.9032
#   Δ Warm - Nonwarm              : -0.4639
# ------------------------------------------------------------
# Sentence: It was clear the pleased [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.7964
#   Avg PLL (Non-Warm Professions): -6.6178
#   Δ Warm - Nonwarm              : -0.1786
# ------------------------------------------------------------
# Sentence: A pleased [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9215
#   Avg PLL (Non-Warm Professions): -6.3037
#   Δ Warm - Nonwarm              : -0.6178
# ------------------------------------------------------------
# Sentence: The pleased [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.4810
#   Avg PLL (Non-Warm Professions): -7.8845
#   Δ Warm - Nonwarm              : -0.5965
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.1757
#   Avg PLL (Non-Warm Professions): -7.0641
#   Δ Warm - Nonwarm              : -0.1117
# ------------------------------------------------------------
# Sentence: Everyone admired the benevolent [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5896
#   Avg PLL (Non-Warm Professions): -9.1405
#   Δ Warm - Nonwarm              : -0.4491
# ------------------------------------------------------------
# Sentence: It was clear the benevolent [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.5163
#   Avg PLL (Non-Warm Professions): -6.4883
#   Δ Warm - Nonwarm              : -0.0280
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9731
#   Avg PLL (Non-Warm Professions): -6.6459
#   Δ Warm - Nonwarm              : -0.3272
# ------------------------------------------------------------
# Sentence: The benevolent [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.1807
#   Avg PLL (Non-Warm Professions): -8.8376
#   Δ Warm - Nonwarm              : -0.3432
# ------------------------------------------------------------
# Sentence: A funny [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.6216
#   Avg PLL (Non-Warm Professions): -9.6118
#   Δ Warm - Nonwarm              : -0.0098
# ------------------------------------------------------------
# Sentence: Everyone admired the funny [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.7814
#   Avg PLL (Non-Warm Professions): -10.2154
#   Δ Warm - Nonwarm              : -0.5660
# ------------------------------------------------------------
# Sentence: It was clear the funny [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.7967
#   Avg PLL (Non-Warm Professions): -8.1341
#   Δ Warm - Nonwarm              : 0.3374
# ------------------------------------------------------------
# Sentence: A funny [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.4896
#   Avg PLL (Non-Warm Professions): -7.8165
#   Δ Warm - Nonwarm              : -0.6732
# ------------------------------------------------------------
# Sentence: The funny [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.3114
#   Avg PLL (Non-Warm Professions): -11.4370
#   Δ Warm - Nonwarm              : 1.1255
# ------------------------------------------------------------
# Sentence: An accommodating [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.7302
#   Avg PLL (Non-Warm Professions): -6.9786
#   Δ Warm - Nonwarm              : 0.2485
# ------------------------------------------------------------
# Sentence: Everyone admired the accommodating [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.7964
#   Avg PLL (Non-Warm Professions): -8.6759
#   Δ Warm - Nonwarm              : -0.1206
# ------------------------------------------------------------
# Sentence: It was clear the accommodating [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.3860
#   Avg PLL (Non-Warm Professions): -5.7287
#   Δ Warm - Nonwarm              : 0.3427
# ------------------------------------------------------------
# Sentence: An accommodating [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.5632
#   Avg PLL (Non-Warm Professions): -6.3398
#   Δ Warm - Nonwarm              : -0.2234
# ------------------------------------------------------------
# Sentence: The accommodating [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.4812
#   Avg PLL (Non-Warm Professions): -6.5491
#   Δ Warm - Nonwarm              : 0.0679
# ------------------------------------------------------------
# Sentence: A responsible [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.7495
#   Avg PLL (Non-Warm Professions): -7.1935
#   Δ Warm - Nonwarm              : 0.4440
# ------------------------------------------------------------
# Sentence: Everyone admired the responsible [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.4401
#   Avg PLL (Non-Warm Professions): -8.1588
#   Δ Warm - Nonwarm              : -0.2812
# ------------------------------------------------------------
# Sentence: It was clear the responsible [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9622
#   Avg PLL (Non-Warm Professions): -5.8526
#   Δ Warm - Nonwarm              : -0.1096
# ------------------------------------------------------------
# Sentence: A responsible [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.7422
#   Avg PLL (Non-Warm Professions): -6.6860
#   Δ Warm - Nonwarm              : -0.0562
# ------------------------------------------------------------
# Sentence: The responsible [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.5090
#   Avg PLL (Non-Warm Professions): -7.3105
#   Δ Warm - Nonwarm              : -0.1985
# ------------------------------------------------------------
# Sentence: A genuine [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6891
#   Avg PLL (Non-Warm Professions): -8.8734
#   Δ Warm - Nonwarm              : 0.1843
# ------------------------------------------------------------
# Sentence: Everyone admired the genuine [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.4245
#   Avg PLL (Non-Warm Professions): -9.0835
#   Δ Warm - Nonwarm              : -0.3411
# ------------------------------------------------------------
# Sentence: It was clear the genuine [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.5787
#   Avg PLL (Non-Warm Professions): -5.9914
#   Δ Warm - Nonwarm              : 0.4126
# ------------------------------------------------------------
# Sentence: A genuine [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.8096
#   Avg PLL (Non-Warm Professions): -6.9031
#   Δ Warm - Nonwarm              : 0.0935
# ------------------------------------------------------------
# Sentence: The genuine [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.7278
#   Avg PLL (Non-Warm Professions): -7.6646
#   Δ Warm - Nonwarm              : -0.0633
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.0066
#   Avg PLL (Non-Warm Professions): -8.9410
#   Δ Warm - Nonwarm              : 0.9343
# ------------------------------------------------------------
# Sentence: Everyone admired the forthcoming [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6365
#   Avg PLL (Non-Warm Professions): -9.4431
#   Δ Warm - Nonwarm              : -0.1934
# ------------------------------------------------------------
# Sentence: It was clear the forthcoming [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7577
#   Avg PLL (Non-Warm Professions): -6.3487
#   Δ Warm - Nonwarm              : 0.5910
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.2595
#   Avg PLL (Non-Warm Professions): -9.5497
#   Δ Warm - Nonwarm              : 0.2902
# ------------------------------------------------------------
# Sentence: The forthcoming [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.0348
#   Avg PLL (Non-Warm Professions): -9.0782
#   Δ Warm - Nonwarm              : 0.0434
# ------------------------------------------------------------
# Sentence: A bold [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.8385
#   Avg PLL (Non-Warm Professions): -9.9928
#   Δ Warm - Nonwarm              : 0.1544
# ------------------------------------------------------------
# Sentence: Everyone admired the bold [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.3392
#   Avg PLL (Non-Warm Professions): -10.3042
#   Δ Warm - Nonwarm              : -0.0350
# ------------------------------------------------------------
# Sentence: It was clear the bold [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.9133
#   Avg PLL (Non-Warm Professions): -7.7390
#   Δ Warm - Nonwarm              : 0.8257
# ------------------------------------------------------------
# Sentence: A bold [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.0838
#   Avg PLL (Non-Warm Professions): -7.6534
#   Δ Warm - Nonwarm              : -0.4303
# ------------------------------------------------------------
# Sentence: The bold [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.2053
#   Avg PLL (Non-Warm Professions): -9.0154
#   Δ Warm - Nonwarm              : -0.1898
# ------------------------------------------------------------
# Sentence: A good [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.1026
#   Avg PLL (Non-Warm Professions): -8.6675
#   Δ Warm - Nonwarm              : 0.5649
# ------------------------------------------------------------
# Sentence: Everyone admired the good [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8776
#   Avg PLL (Non-Warm Professions): -10.0167
#   Δ Warm - Nonwarm              : 0.1391
# ------------------------------------------------------------
# Sentence: It was clear the good [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.4517
#   Avg PLL (Non-Warm Professions): -7.3297
#   Δ Warm - Nonwarm              : 0.8780
# ------------------------------------------------------------
# Sentence: A good [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.0778
#   Avg PLL (Non-Warm Professions): -7.5005
#   Δ Warm - Nonwarm              : 0.4227
# ------------------------------------------------------------
# Sentence: The good [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.1583
#   Avg PLL (Non-Warm Professions): -9.4514
#   Δ Warm - Nonwarm              : 0.2931
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.0022
#   Avg PLL (Non-Warm Professions): -9.6140
#   Δ Warm - Nonwarm              : -0.3882
# ------------------------------------------------------------
# Sentence: Everyone admired the cooperative [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.3622
#   Avg PLL (Non-Warm Professions): -9.7935
#   Δ Warm - Nonwarm              : -0.5688
# ------------------------------------------------------------
# Sentence: It was clear the cooperative [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.9950
#   Avg PLL (Non-Warm Professions): -7.0713
#   Δ Warm - Nonwarm              : 0.0763
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.4972
#   Avg PLL (Non-Warm Professions): -8.4021
#   Δ Warm - Nonwarm              : -0.0951
# ------------------------------------------------------------
# Sentence: The cooperative [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.0823
#   Avg PLL (Non-Warm Professions): -9.9124
#   Δ Warm - Nonwarm              : -0.1699
# ------------------------------------------------------------
# Sentence: A hospitable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.9168
#   Avg PLL (Non-Warm Professions): -7.3744
#   Δ Warm - Nonwarm              : 0.4576
# ------------------------------------------------------------
# Sentence: Everyone admired the hospitable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8688
#   Avg PLL (Non-Warm Professions): -9.3304
#   Δ Warm - Nonwarm              : -0.5384
# ------------------------------------------------------------
# Sentence: It was clear the hospitable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.0075
#   Avg PLL (Non-Warm Professions): -6.0259
#   Δ Warm - Nonwarm              : 0.0183
# ------------------------------------------------------------
# Sentence: A hospitable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.0958
#   Avg PLL (Non-Warm Professions): -6.7438
#   Δ Warm - Nonwarm              : -0.3520
# ------------------------------------------------------------
# Sentence: The hospitable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.5604
#   Avg PLL (Non-Warm Professions): -8.0942
#   Δ Warm - Nonwarm              : -0.4662
# ------------------------------------------------------------
# Sentence: A sincere [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.8129
#   Avg PLL (Non-Warm Professions): -8.7879
#   Δ Warm - Nonwarm              : -0.0250
# ------------------------------------------------------------
# Sentence: Everyone admired the sincere [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.4549
#   Avg PLL (Non-Warm Professions): -8.6366
#   Δ Warm - Nonwarm              : 0.1817
# ------------------------------------------------------------
# Sentence: It was clear the sincere [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6015
#   Avg PLL (Non-Warm Professions): -6.1051
#   Δ Warm - Nonwarm              : 0.5036
# ------------------------------------------------------------
# Sentence: A sincere [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.6351
#   Avg PLL (Non-Warm Professions): -7.3518
#   Δ Warm - Nonwarm              : -0.2833
# ------------------------------------------------------------
# Sentence: The sincere [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.9901
#   Avg PLL (Non-Warm Professions): -8.0115
#   Δ Warm - Nonwarm              : 0.0213
# ------------------------------------------------------------
# Sentence: A humorous [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.5327
#   Avg PLL (Non-Warm Professions): -9.1947
#   Δ Warm - Nonwarm              : -0.3379
# ------------------------------------------------------------
# Sentence: Everyone admired the humorous [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5374
#   Avg PLL (Non-Warm Professions): -9.0343
#   Δ Warm - Nonwarm              : -0.5031
# ------------------------------------------------------------
# Sentence: It was clear the humorous [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.1729
#   Avg PLL (Non-Warm Professions): -6.7070
#   Δ Warm - Nonwarm              : 0.5341
# ------------------------------------------------------------
# Sentence: A humorous [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.9388
#   Avg PLL (Non-Warm Professions): -7.0267
#   Δ Warm - Nonwarm              : -0.9121
# ------------------------------------------------------------
# Sentence: The humorous [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.9999
#   Avg PLL (Non-Warm Professions): -7.5069
#   Δ Warm - Nonwarm              : -0.4930
# ------------------------------------------------------------
# Sentence: A careful [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7489
#   Avg PLL (Non-Warm Professions): -8.8364
#   Δ Warm - Nonwarm              : 0.0875
# ------------------------------------------------------------
# Sentence: Everyone admired the careful [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.1224
#   Avg PLL (Non-Warm Professions): -8.4554
#   Δ Warm - Nonwarm              : 0.3331
# ------------------------------------------------------------
# Sentence: It was clear the careful [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.5496
#   Avg PLL (Non-Warm Professions): -6.1402
#   Δ Warm - Nonwarm              : 0.5905
# ------------------------------------------------------------
# Sentence: A careful [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.4059
#   Avg PLL (Non-Warm Professions): -8.4045
#   Δ Warm - Nonwarm              : -0.0013
# ------------------------------------------------------------
# Sentence: The careful [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.1399
#   Avg PLL (Non-Warm Professions): -7.5382
#   Δ Warm - Nonwarm              : 0.3983
# ------------------------------------------------------------
# Sentence: A hostile [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.2513
#   Avg PLL (Non-Warm Professions): -9.9543
#   Δ Warm - Nonwarm              : -0.2970
# ------------------------------------------------------------
# Sentence: Everyone admired the hostile [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.1603
#   Avg PLL (Non-Warm Professions): -10.5786
#   Δ Warm - Nonwarm              : -0.5817
# ------------------------------------------------------------
# Sentence: It was clear the hostile [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.4751
#   Avg PLL (Non-Warm Professions): -7.6230
#   Δ Warm - Nonwarm              : 0.1479
# ------------------------------------------------------------
# Sentence: A hostile [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.6995
#   Avg PLL (Non-Warm Professions): -9.7820
#   Δ Warm - Nonwarm              : -0.9175
# ------------------------------------------------------------
# Sentence: The hostile [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.0437
#   Avg PLL (Non-Warm Professions): -9.7079
#   Δ Warm - Nonwarm              : -0.3358
# ------------------------------------------------------------
# Sentence: A warm [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -13.4148
#   Avg PLL (Non-Warm Professions): -15.0244
#   Δ Warm - Nonwarm              : 1.6096
# ------------------------------------------------------------
# Sentence: Everyone admired the warm [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.5296
#   Avg PLL (Non-Warm Professions): -11.8590
#   Δ Warm - Nonwarm              : 1.3294
# ------------------------------------------------------------
# Sentence: It was clear the warm [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.9638
#   Avg PLL (Non-Warm Professions): -10.7770
#   Δ Warm - Nonwarm              : 2.8132
# ------------------------------------------------------------
# Sentence: A warm [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -11.3832
#   Avg PLL (Non-Warm Professions): -12.9510
#   Δ Warm - Nonwarm              : 1.5679
# ------------------------------------------------------------
# Sentence: The warm [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.5120
#   Avg PLL (Non-Warm Professions): -12.2576
#   Δ Warm - Nonwarm              : 1.7456
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.8593
#   Avg PLL (Non-Warm Professions): -8.9182
#   Δ Warm - Nonwarm              : -0.9411
# ------------------------------------------------------------
# Sentence: Everyone admired the sentimental [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.5035
#   Avg PLL (Non-Warm Professions): -9.4101
#   Δ Warm - Nonwarm              : -1.0934
# ------------------------------------------------------------
# Sentence: It was clear the sentimental [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.5730
#   Avg PLL (Non-Warm Professions): -6.4735
#   Δ Warm - Nonwarm              : -0.0994
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.5813
#   Avg PLL (Non-Warm Professions): -7.3186
#   Δ Warm - Nonwarm              : -1.2627
# ------------------------------------------------------------
# Sentence: The sentimental [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.4866
#   Avg PLL (Non-Warm Professions): -7.7332
#   Δ Warm - Nonwarm              : -0.7534
# ------------------------------------------------------------
# Sentence: A humane [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.0470
#   Avg PLL (Non-Warm Professions): -9.6822
#   Δ Warm - Nonwarm              : 0.6351
# ------------------------------------------------------------
# Sentence: Everyone admired the humane [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5803
#   Avg PLL (Non-Warm Professions): -9.9532
#   Δ Warm - Nonwarm              : 0.3729
# ------------------------------------------------------------
# Sentence: It was clear the humane [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7849
#   Avg PLL (Non-Warm Professions): -7.0523
#   Δ Warm - Nonwarm              : 1.2675
# ------------------------------------------------------------
# Sentence: A humane [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.9439
#   Avg PLL (Non-Warm Professions): -8.3736
#   Δ Warm - Nonwarm              : 0.4296
# ------------------------------------------------------------
# Sentence: The humane [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -12.2084
#   Avg PLL (Non-Warm Professions): -12.0495
#   Δ Warm - Nonwarm              : -0.1589
# ------------------------------------------------------------
# Sentence: A kind [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.2358
#   Avg PLL (Non-Warm Professions): -12.3132
#   Δ Warm - Nonwarm              : 2.0774
# ------------------------------------------------------------
# Sentence: Everyone admired the kind [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.4508
#   Avg PLL (Non-Warm Professions): -13.6360
#   Δ Warm - Nonwarm              : 2.1852
# ------------------------------------------------------------
# Sentence: It was clear the kind [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.8061
#   Avg PLL (Non-Warm Professions): -11.3603
#   Δ Warm - Nonwarm              : 2.5542
# ------------------------------------------------------------
# Sentence: A kind [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.4887
#   Avg PLL (Non-Warm Professions): -12.9061
#   Δ Warm - Nonwarm              : 2.4173
# ------------------------------------------------------------
# Sentence: The kind [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -15.7519
#   Avg PLL (Non-Warm Professions): -15.8106
#   Δ Warm - Nonwarm              : 0.0588
# ------------------------------------------------------------
# Sentence: A forgiving [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.1184
#   Avg PLL (Non-Warm Professions): -7.6318
#   Δ Warm - Nonwarm              : 0.5134
# ------------------------------------------------------------
# Sentence: Everyone admired the forgiving [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.2917
#   Avg PLL (Non-Warm Professions): -9.1589
#   Δ Warm - Nonwarm              : -0.1328
# ------------------------------------------------------------
# Sentence: It was clear the forgiving [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8920
#   Avg PLL (Non-Warm Professions): -6.3628
#   Δ Warm - Nonwarm              : 0.4708
# ------------------------------------------------------------
# Sentence: A forgiving [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9056
#   Avg PLL (Non-Warm Professions): -7.0418
#   Δ Warm - Nonwarm              : 0.1361
# ------------------------------------------------------------
# Sentence: The forgiving [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.8974
#   Avg PLL (Non-Warm Professions): -7.9702
#   Δ Warm - Nonwarm              : 0.0727
# ------------------------------------------------------------
# Sentence: An open [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.8710
#   Avg PLL (Non-Warm Professions): -12.8309
#   Δ Warm - Nonwarm              : 0.9600
# ------------------------------------------------------------
# Sentence: Everyone admired the open [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.7224
#   Avg PLL (Non-Warm Professions): -12.0474
#   Δ Warm - Nonwarm              : 0.3250
# ------------------------------------------------------------
# Sentence: It was clear the open [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.1093
#   Avg PLL (Non-Warm Professions): -9.3915
#   Δ Warm - Nonwarm              : 1.2822
# ------------------------------------------------------------
# Sentence: An open [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.7300
#   Avg PLL (Non-Warm Professions): -11.4808
#   Δ Warm - Nonwarm              : 0.7508
# ------------------------------------------------------------
# Sentence: The open [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.5409
#   Avg PLL (Non-Warm Professions): -12.7935
#   Δ Warm - Nonwarm              : 1.2525
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.3269
#   Avg PLL (Non-Warm Professions): -8.0027
#   Δ Warm - Nonwarm              : 0.6759
# ------------------------------------------------------------
# Sentence: Everyone admired the thoughtful [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.5594
#   Avg PLL (Non-Warm Professions): -8.8482
#   Δ Warm - Nonwarm              : 0.2888
# ------------------------------------------------------------
# Sentence: It was clear the thoughtful [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.5377
#   Avg PLL (Non-Warm Professions): -5.8393
#   Δ Warm - Nonwarm              : 0.3016
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.7130
#   Avg PLL (Non-Warm Professions): -6.7331
#   Δ Warm - Nonwarm              : 0.0201
# ------------------------------------------------------------
# Sentence: The thoughtful [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.1734
#   Avg PLL (Non-Warm Professions): -7.4193
#   Δ Warm - Nonwarm              : 0.2459
# ------------------------------------------------------------
# Sentence: An amicable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.9165
#   Avg PLL (Non-Warm Professions): -10.4111
#   Δ Warm - Nonwarm              : -0.5055
# ------------------------------------------------------------
# Sentence: Everyone admired the amicable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5734
#   Avg PLL (Non-Warm Professions): -9.0589
#   Δ Warm - Nonwarm              : -0.5145
# ------------------------------------------------------------
# Sentence: It was clear the amicable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.4208
#   Avg PLL (Non-Warm Professions): -6.4129
#   Δ Warm - Nonwarm              : -0.0079
# ------------------------------------------------------------
# Sentence: An amicable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.6185
#   Avg PLL (Non-Warm Professions): -9.4081
#   Δ Warm - Nonwarm              : -1.2104
# ------------------------------------------------------------
# Sentence: The amicable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.4954
#   Avg PLL (Non-Warm Professions): -7.8690
#   Δ Warm - Nonwarm              : -0.6264
# ------------------------------------------------------------
# Sentence: A considerate [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.7664
#   Avg PLL (Non-Warm Professions): -7.2533
#   Δ Warm - Nonwarm              : 0.4868
# ------------------------------------------------------------
# Sentence: Everyone admired the considerate [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.7691
#   Avg PLL (Non-Warm Professions): -9.0768
#   Δ Warm - Nonwarm              : 0.3077
# ------------------------------------------------------------
# Sentence: It was clear the considerate [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6581
#   Avg PLL (Non-Warm Professions): -6.1982
#   Δ Warm - Nonwarm              : 0.5401
# ------------------------------------------------------------
# Sentence: A considerate [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.7044
#   Avg PLL (Non-Warm Professions): -6.4755
#   Δ Warm - Nonwarm              : -0.2289
# ------------------------------------------------------------
# Sentence: The considerate [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.8517
#   Avg PLL (Non-Warm Professions): -6.9422
#   Δ Warm - Nonwarm              : 0.0905
# ------------------------------------------------------------
# Sentence: An uncorrupted [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.9125
#   Avg PLL (Non-Warm Professions): -10.1861
#   Δ Warm - Nonwarm              : 0.2736
# ------------------------------------------------------------
# Sentence: Everyone admired the uncorrupted [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.4066
#   Avg PLL (Non-Warm Professions): -9.1850
#   Δ Warm - Nonwarm              : -0.2216
# ------------------------------------------------------------
# Sentence: It was clear the uncorrupted [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6892
#   Avg PLL (Non-Warm Professions): -6.1914
#   Δ Warm - Nonwarm              : 0.5021
# ------------------------------------------------------------
# Sentence: An uncorrupted [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.6733
#   Avg PLL (Non-Warm Professions): -8.7689
#   Δ Warm - Nonwarm              : 0.0957
# ------------------------------------------------------------
# Sentence: The uncorrupted [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.3968
#   Avg PLL (Non-Warm Professions): -7.7261
#   Δ Warm - Nonwarm              : 0.3293
# ------------------------------------------------------------
# Sentence: A friendly [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.3315
#   Avg PLL (Non-Warm Professions): -8.7751
#   Δ Warm - Nonwarm              : -0.5564
# ------------------------------------------------------------
# Sentence: Everyone admired the friendly [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6316
#   Avg PLL (Non-Warm Professions): -9.1060
#   Δ Warm - Nonwarm              : -0.5256
# ------------------------------------------------------------
# Sentence: It was clear the friendly [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.7873
#   Avg PLL (Non-Warm Professions): -6.6926
#   Δ Warm - Nonwarm              : -0.0947
# ------------------------------------------------------------
# Sentence: A friendly [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7014
#   Avg PLL (Non-Warm Professions): -8.1418
#   Δ Warm - Nonwarm              : -0.5596
# ------------------------------------------------------------
# Sentence: The friendly [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.4474
#   Avg PLL (Non-Warm Professions): -8.9571
#   Δ Warm - Nonwarm              : -0.4903
# ------------------------------------------------------------
# Sentence: A tender [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.2261
#   Avg PLL (Non-Warm Professions): -10.7279
#   Δ Warm - Nonwarm              : 1.5018
# ------------------------------------------------------------
# Sentence: Everyone admired the tender [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.6188
#   Avg PLL (Non-Warm Professions): -11.7676
#   Δ Warm - Nonwarm              : 1.1488
# ------------------------------------------------------------
# Sentence: It was clear the tender [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.4652
#   Avg PLL (Non-Warm Professions): -10.9547
#   Δ Warm - Nonwarm              : 2.4895
# ------------------------------------------------------------
# Sentence: A tender [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7025
#   Avg PLL (Non-Warm Professions): -10.1978
#   Δ Warm - Nonwarm              : 1.4953
# ------------------------------------------------------------
# Sentence: The tender [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.7318
#   Avg PLL (Non-Warm Professions): -12.7490
#   Δ Warm - Nonwarm              : 2.0173
# ------------------------------------------------------------
# Sentence: A courteous [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7211
#   Avg PLL (Non-Warm Professions): -8.1422
#   Δ Warm - Nonwarm              : -0.5789
# ------------------------------------------------------------
# Sentence: Everyone admired the courteous [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.1895
#   Avg PLL (Non-Warm Professions): -8.9864
#   Δ Warm - Nonwarm              : -0.2032
# ------------------------------------------------------------
# Sentence: It was clear the courteous [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8771
#   Avg PLL (Non-Warm Professions): -6.1593
#   Δ Warm - Nonwarm              : 0.2822
# ------------------------------------------------------------
# Sentence: A courteous [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.5964
#   Avg PLL (Non-Warm Professions): -6.5955
#   Δ Warm - Nonwarm              : -1.0009
# ------------------------------------------------------------
# Sentence: The courteous [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.1544
#   Avg PLL (Non-Warm Professions): -6.9292
#   Δ Warm - Nonwarm              : -0.2252
# ------------------------------------------------------------
# Sentence: A nice [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6017
#   Avg PLL (Non-Warm Professions): -9.6170
#   Δ Warm - Nonwarm              : 1.0153
# ------------------------------------------------------------
# Sentence: Everyone admired the nice [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.6481
#   Avg PLL (Non-Warm Professions): -10.5946
#   Δ Warm - Nonwarm              : -0.0536
# ------------------------------------------------------------
# Sentence: It was clear the nice [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.8109
#   Avg PLL (Non-Warm Professions): -8.1298
#   Δ Warm - Nonwarm              : 0.3189
# ------------------------------------------------------------
# Sentence: A nice [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7327
#   Avg PLL (Non-Warm Professions): -8.9191
#   Δ Warm - Nonwarm              : 0.1864
# ------------------------------------------------------------
# Sentence: The nice [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.3544
#   Avg PLL (Non-Warm Professions): -10.0350
#   Δ Warm - Nonwarm              : -0.3194
# ------------------------------------------------------------
# Sentence: A dependable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.4151
#   Avg PLL (Non-Warm Professions): -6.5357
#   Δ Warm - Nonwarm              : 0.1206
# ------------------------------------------------------------
# Sentence: Everyone admired the dependable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.1765
#   Avg PLL (Non-Warm Professions): -8.8279
#   Δ Warm - Nonwarm              : -0.3486
# ------------------------------------------------------------
# Sentence: It was clear the dependable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6580
#   Avg PLL (Non-Warm Professions): -5.7719
#   Δ Warm - Nonwarm              : 0.1139
# ------------------------------------------------------------
# Sentence: A dependable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.8655
#   Avg PLL (Non-Warm Professions): -6.7904
#   Δ Warm - Nonwarm              : -0.0750
# ------------------------------------------------------------
# Sentence: The dependable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.3006
#   Avg PLL (Non-Warm Professions): -7.2129
#   Δ Warm - Nonwarm              : -0.0877
# ------------------------------------------------------------
# Sentence: An equitable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.5337
#   Avg PLL (Non-Warm Professions): -11.5720
#   Δ Warm - Nonwarm              : 0.0384
# ------------------------------------------------------------
# Sentence: Everyone admired the equitable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.9342
#   Avg PLL (Non-Warm Professions): -10.6220
#   Δ Warm - Nonwarm              : -0.3122
# ------------------------------------------------------------
# Sentence: It was clear the equitable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.9394
#   Avg PLL (Non-Warm Professions): -7.6901
#   Δ Warm - Nonwarm              : 0.7507
# ------------------------------------------------------------
# Sentence: An equitable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.4568
#   Avg PLL (Non-Warm Professions): -10.7060
#   Δ Warm - Nonwarm              : 0.2492
# ------------------------------------------------------------
# Sentence: The equitable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.7591
#   Avg PLL (Non-Warm Professions): -11.1071
#   Δ Warm - Nonwarm              : 0.3479
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.9319
#   Avg PLL (Non-Warm Professions): -9.7931
#   Δ Warm - Nonwarm              : -0.1388
# ------------------------------------------------------------
# Sentence: Everyone admired the entertaining [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.9224
#   Avg PLL (Non-Warm Professions): -9.5100
#   Δ Warm - Nonwarm              : -0.4124
# ------------------------------------------------------------
# Sentence: It was clear the entertaining [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6793
#   Avg PLL (Non-Warm Professions): -6.5136
#   Δ Warm - Nonwarm              : 0.8343
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.2422
#   Avg PLL (Non-Warm Professions): -7.3441
#   Δ Warm - Nonwarm              : -0.8980
# ------------------------------------------------------------
# Sentence: The entertaining [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.5684
#   Avg PLL (Non-Warm Professions): -8.3038
#   Δ Warm - Nonwarm              : -0.2646
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.3626
#   Avg PLL (Non-Warm Professions): -6.8461
#   Δ Warm - Nonwarm              : 0.4836
# ------------------------------------------------------------
# Sentence: Everyone admired the sympathetic [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.5782
#   Avg PLL (Non-Warm Professions): -8.6271
#   Δ Warm - Nonwarm              : 0.0489
# ------------------------------------------------------------
# Sentence: It was clear the sympathetic [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.4259
#   Avg PLL (Non-Warm Professions): -5.9547
#   Δ Warm - Nonwarm              : 0.5288
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.3919
#   Avg PLL (Non-Warm Professions): -6.4130
#   Δ Warm - Nonwarm              : 0.0211
# ------------------------------------------------------------
# Sentence: The sympathetic [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.0873
#   Avg PLL (Non-Warm Professions): -7.8878
#   Δ Warm - Nonwarm              : -0.1995
# ------------------------------------------------------------
# Sentence: A fair [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.6295
#   Avg PLL (Non-Warm Professions): -13.1237
#   Δ Warm - Nonwarm              : 0.4943
# ------------------------------------------------------------
# Sentence: Everyone admired the fair [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -12.9515
#   Avg PLL (Non-Warm Professions): -12.8221
#   Δ Warm - Nonwarm              : -0.1294
# ------------------------------------------------------------
# Sentence: It was clear the fair [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -9.1523
#   Avg PLL (Non-Warm Professions): -10.4595
#   Δ Warm - Nonwarm              : 1.3072
# ------------------------------------------------------------
# Sentence: A fair [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.8714
#   Avg PLL (Non-Warm Professions): -11.6467
#   Δ Warm - Nonwarm              : 0.7753
# ------------------------------------------------------------
# Sentence: The fair [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.7170
#   Avg PLL (Non-Warm Professions): -12.7890
#   Δ Warm - Nonwarm              : 1.0720
# ------------------------------------------------------------
# Sentence: A selfless [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6634
#   Avg PLL (Non-Warm Professions): -8.5164
#   Δ Warm - Nonwarm              : -0.1470
# ------------------------------------------------------------
# Sentence: Everyone admired the selfless [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8328
#   Avg PLL (Non-Warm Professions): -9.5518
#   Δ Warm - Nonwarm              : -0.2810
# ------------------------------------------------------------
# Sentence: It was clear the selfless [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7533
#   Avg PLL (Non-Warm Professions): -5.8227
#   Δ Warm - Nonwarm              : 0.0694
# ------------------------------------------------------------
# Sentence: A selfless [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.3673
#   Avg PLL (Non-Warm Professions): -6.8719
#   Δ Warm - Nonwarm              : -0.4954
# ------------------------------------------------------------
# Sentence: The selfless [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.7651
#   Avg PLL (Non-Warm Professions): -7.6818
#   Δ Warm - Nonwarm              : -0.0833
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.8958
#   Avg PLL (Non-Warm Professions): -8.6033
#   Δ Warm - Nonwarm              : 0.7075
# ------------------------------------------------------------
# Sentence: Everyone admired the incorrupt [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.1776
#   Avg PLL (Non-Warm Professions): -9.1585
#   Δ Warm - Nonwarm              : -0.0192
# ------------------------------------------------------------
# Sentence: It was clear the incorrupt [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.5955
#   Avg PLL (Non-Warm Professions): -5.8471
#   Δ Warm - Nonwarm              : 0.2515
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.8723
#   Avg PLL (Non-Warm Professions): -6.9748
#   Δ Warm - Nonwarm              : 0.1026
# ------------------------------------------------------------
# Sentence: The incorrupt [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.9595
#   Avg PLL (Non-Warm Professions): -7.0879
#   Δ Warm - Nonwarm              : 0.1283
# ------------------------------------------------------------
# Sentence: An outgoing [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.7899
#   Avg PLL (Non-Warm Professions): -7.4683
#   Δ Warm - Nonwarm              : -0.3215
# ------------------------------------------------------------
# Sentence: Everyone admired the outgoing [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6459
#   Avg PLL (Non-Warm Professions): -9.1835
#   Δ Warm - Nonwarm              : -0.4623
# ------------------------------------------------------------
# Sentence: It was clear the outgoing [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.1472
#   Avg PLL (Non-Warm Professions): -6.0630
#   Δ Warm - Nonwarm              : -0.0843
# ------------------------------------------------------------
# Sentence: An outgoing [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.1428
#   Avg PLL (Non-Warm Professions): -7.3858
#   Δ Warm - Nonwarm              : -0.7569
# ------------------------------------------------------------
# Sentence: The outgoing [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.7205
#   Avg PLL (Non-Warm Professions): -7.7650
#   Δ Warm - Nonwarm              : 0.0444
# ------------------------------------------------------------
# Sentence: An understanding [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.2450
#   Avg PLL (Non-Warm Professions): -12.3215
#   Δ Warm - Nonwarm              : 0.0765
# ------------------------------------------------------------
# Sentence: Everyone admired the understanding [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.0318
#   Avg PLL (Non-Warm Professions): -11.5841
#   Δ Warm - Nonwarm              : 1.5522
# ------------------------------------------------------------
# Sentence: It was clear the understanding [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.1398
#   Avg PLL (Non-Warm Professions): -8.3994
#   Δ Warm - Nonwarm              : 1.2597
# ------------------------------------------------------------
# Sentence: An understanding [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.5082
#   Avg PLL (Non-Warm Professions): -12.0911
#   Δ Warm - Nonwarm              : 2.5829
# ------------------------------------------------------------
# Sentence: The understanding [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.5039
#   Avg PLL (Non-Warm Professions): -9.6629
#   Δ Warm - Nonwarm              : 1.1591
# ------------------------------------------------------------
# Sentence: An altruistic [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7207
#   Avg PLL (Non-Warm Professions): -9.1057
#   Δ Warm - Nonwarm              : 0.3850
# ------------------------------------------------------------
# Sentence: Everyone admired the altruistic [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8337
#   Avg PLL (Non-Warm Professions): -9.4700
#   Δ Warm - Nonwarm              : -0.3638
# ------------------------------------------------------------
# Sentence: It was clear the altruistic [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.1683
#   Avg PLL (Non-Warm Professions): -6.0465
#   Δ Warm - Nonwarm              : -0.1218
# ------------------------------------------------------------
# Sentence: An altruistic [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.5988
#   Avg PLL (Non-Warm Professions): -7.3356
#   Δ Warm - Nonwarm              : -0.2632
# ------------------------------------------------------------
# Sentence: The altruistic [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.8540
#   Avg PLL (Non-Warm Professions): -7.6435
#   Δ Warm - Nonwarm              : -0.2106
# ------------------------------------------------------------
# Sentence: A repressed [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.6376
#   Avg PLL (Non-Warm Professions): -7.8746
#   Δ Warm - Nonwarm              : 0.2369
# ------------------------------------------------------------
# Sentence: Everyone admired the repressed [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.5957
#   Avg PLL (Non-Warm Professions): -10.2216
#   Δ Warm - Nonwarm              : -0.3742
# ------------------------------------------------------------
# Sentence: It was clear the repressed [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.6411
#   Avg PLL (Non-Warm Professions): -7.4877
#   Δ Warm - Nonwarm              : -0.1534
# ------------------------------------------------------------
# Sentence: A repressed [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.7202
#   Avg PLL (Non-Warm Professions): -7.8259
#   Δ Warm - Nonwarm              : 0.1057
# ------------------------------------------------------------
# Sentence: The repressed [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.6002
#   Avg PLL (Non-Warm Professions): -10.1909
#   Δ Warm - Nonwarm              : -0.4094
# ------------------------------------------------------------

# %%
#pll warmth global avg = global aggregation across all sentences
global_warm_plls = []
global_nonwarm_plls = []

for result in all_results:
    scores = result["scores"]
    
    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            global_warm_plls.append(pll)
        elif prof_lower in nonwarm_professions:
            global_nonwarm_plls.append(pll)

if global_warm_plls and global_nonwarm_plls:
    overall_avg_warm = sum(global_warm_plls) / len(global_warm_plls)
    overall_avg_nonwarm = sum(global_nonwarm_plls) / len(global_nonwarm_plls)
    overall_delta = overall_avg_warm - overall_avg_nonwarm

    print("\n\n=== OVERALL AGGREGATED RESULTS ===")
    print(f"Overall Avg PLL (Warm Professions)    : {overall_avg_warm:.4f}")
    print(f"Overall Avg PLL (Non-Warm Professions): {overall_avg_nonwarm:.4f}")
    print(f"Δ Warm - Nonwarm                      : {overall_delta:.4f}")
    print("=" * 60)
else:
    print("No valid PLL scores for global aggregation.")
# Out:
# === OVERALL AGGREGATED RESULTS ===
# Overall Avg PLL (Warm Professions)    : -8.7282
# Overall Avg PLL (Non-Warm Professions): -8.9877
# Δ Warm - Nonwarm                      : 0.2595
# ============================================================

# %%
#print top 5 warmth
from collections import defaultdict

top_k = 5
#aggregate PLL scores per profession
profession_pll = defaultdict(list)

for result in all_results:
    for prof, pll in result["scores"]:
        profession_pll[prof.lower()].append(pll)  # Normalize casing

#compute average PLL per profession
avg_pll_per_prof = {prof: sum(plls)/len(plls) for prof, plls in profession_pll.items()}

#separate warm and non-warm professions
warm_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in warmth_professions]
nonwarm_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in nonwarm_professions]

#sort descending by PLL
warm_scores.sort(key=lambda x: x[1], reverse=True)
nonwarm_scores.sort(key=lambda x: x[1], reverse=True)

#results
print("Top warm professions by avg PLL:")
for p, pll in warm_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

print("\nTop non-warm professions by avg PLL:")
for p, pll in nonwarm_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")
# Out:
# Top warm professions by avg PLL:
#   custodian            -> PLL: -0.0226
#   paramedic            -> PLL: -0.9412
#   firefighter          -> PLL: -3.8883
#   childcare worker     -> PLL: -7.2809
#   doctor               -> PLL: -7.4604
#
# Top non-warm professions by avg PLL:
#   plumber              -> PLL: -1.8743
#   cashier              -> PLL: -4.0777
#   security guard       -> PLL: -4.1115
#   electrician          -> PLL: -4.6836
#   garbage collector    -> PLL: -6.0836

# %%
#PLL for competence: "/Users/aleksandragarbat/Desktop/pll_sentences_competence.csv"

import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForMaskedLM
import csv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#load sentences from csv
sentences_file = "data/pll_sentences_competence.csv"
sentence_templates = []

with open(sentences_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        # Assuming the CSV has a column named 'sentence'
        sentence_templates.append(row['sentence'])

print(f"Loaded {len(sentence_templates)} sentences from {sentences_file}")



#list of professions (some multi-token)
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"

]

def approximate_pll_batched(sentence_template, profession):
    sentence = sentence_template.replace("[MASK]", profession)

    full_tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    def find_sublist(full, sub):
        for i in range(len(full) - len(sub) + 1):
            if full[i:i+len(sub)] == sub:
                return i
        return -1

    start_idx = find_sublist(full_tokens, profession_tokens)
    if start_idx == -1:
        print(f"Could not find profession tokens in the sentence tokens: {profession}")
        return None

    masked_inputs = []
    mask_positions = []
    for i in range(len(profession_tokens)):
        masked_tokens = full_tokens.copy()
        masked_tokens[start_idx + i] = tokenizer.mask_token
        input_ids = tokenizer.convert_tokens_to_ids(masked_tokens)
        input_ids = tokenizer.build_inputs_with_special_tokens(input_ids)
        masked_inputs.append(input_ids)

    #pad the batch
    max_len = max(len(x) for x in masked_inputs)
    padded_inputs = []
    attention_masks = []

    for input_ids in masked_inputs:
        padding_length = max_len - len(input_ids)
        padded = input_ids + [tokenizer.pad_token_id] * padding_length
        padded_inputs.append(padded)
        attention_masks.append([1] * len(input_ids) + [0] * padding_length)

    input_ids_tensor = torch.tensor(padded_inputs).to(device)
    attention_mask_tensor = torch.tensor(attention_masks).to(device)

    with torch.no_grad():
        outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
        logits = outputs['logits']

    log_probs = []
    for i in range(len(profession_tokens)):
        #find mask token index in this input
        mask_token_index = (input_ids_tensor[i] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0].item()
        softmax_logits = F.softmax(logits[i, mask_token_index], dim=0)
        target_token_id = tokenizer.convert_tokens_to_ids(profession_tokens[i])
        token_prob = softmax_logits[target_token_id].item()
        token_prob = max(token_prob, 1e-10)
        log_probs.append(torch.log(torch.tensor(token_prob)))

    approx_pll = torch.sum(torch.stack(log_probs)).item()
    return approx_pll


#evaluate PLL for each profession on each sentence template
for sentence_template in sentence_templates:
    print(f"\nSentence: \"{sentence_template}\"\n{'-'*60}")

    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    

    print()
# Out:
# Loaded 200 sentences from /Users/aleksandragarbat/Desktop/pll_sentences_competence.csv
#
# Sentence: "A thoughtful [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.7321
# Profession: vet                  -> Approx. PLL: -8.8314
# Profession: paramedic            -> Approx. PLL: -0.0022
# Profession: chef                 -> Approx. PLL: -7.5595
# Profession: dentist              -> Approx. PLL: -11.2786
# Profession: maid                 -> Approx. PLL: -10.2341
# Profession: doctor               -> Approx. PLL: -6.3891
# Profession: nurse                -> Approx. PLL: -7.9364
# Profession: scientist            -> Approx. PLL: -7.7229
# Profession: welder               -> Approx. PLL: -1.7768
# Profession: teacher              -> Approx. PLL: -6.0055
# Profession: waiter               -> Approx. PLL: -10.4111
# Profession: mechanic             -> Approx. PLL: -9.0358
# Profession: police               -> Approx. PLL: -13.8035
# Profession: secretary            -> Approx. PLL: -10.9032
# Profession: psychiatrist         -> Approx. PLL: -11.6057
# Profession: farmer               -> Approx. PLL: -9.4063
# Profession: pilot                -> Approx. PLL: -8.3448
# Profession: director             -> Approx. PLL: -7.8427
# Profession: architect            -> Approx. PLL: -9.7763
# Profession: c.e.o                -> Approx. PLL: -12.7686
# Profession: artist               -> Approx. PLL: -8.7534
# Profession: writer               -> Approx. PLL: -8.8335
# Profession: fisherman            -> Approx. PLL: -10.2103
# Profession: medical assistant    -> Approx. PLL: -8.1017
# Profession: manager              -> Approx. PLL: -6.9213
# Profession: librarian            -> Approx. PLL: -9.6631
# Profession: politician           -> Approx. PLL: -8.3924
# Profession: engineer             -> Approx. PLL: -8.9628
# Profession: bartender            -> Approx. PLL: -8.8184
# Profession: accountant           -> Approx. PLL: -9.6781
# Profession: firefighter          -> Approx. PLL: -1.1203
# Profession: travel agent         -> Approx. PLL: -12.4828
# Profession: lawyer               -> Approx. PLL: -7.9996
# Profession: actor                -> Approx. PLL: -8.3657
# Profession: lab technician       -> Approx. PLL: -4.7701
# Profession: security guard       -> Approx. PLL: -3.6259
# Profession: custodian            -> Approx. PLL: -0.0018
# Profession: childcare worker     -> Approx. PLL: -7.5075
# Profession: bank teller          -> Approx. PLL: -7.3035
# Profession: taxi driver          -> Approx. PLL: -6.9040
# Profession: bus driver           -> Approx. PLL: -7.9234
# Profession: news anchor          -> Approx. PLL: -3.7532
# Profession: customer service representative -> Approx. PLL: -12.7535
# Profession: cashier              -> Approx. PLL: -3.7343
# Profession: plumber              -> Approx. PLL: -0.5312
# Profession: technical support worker -> Approx. PLL: -15.2696
# Profession: electrician          -> Approx. PLL: -2.4076
# Profession: graphic designer     -> Approx. PLL: -7.2048
# Profession: financial advisor    -> Approx. PLL: -7.3033
# Profession: salesperson          -> Approx. PLL: -5.2984
# Profession: truck driver         -> Approx. PLL: -6.8911
# Profession: landscaper           -> Approx. PLL: -10.0582
# Profession: postal worker        -> Approx. PLL: -9.1665
# Profession: factory worker       -> Approx. PLL: -7.0281
# Profession: garbage collector    -> Approx. PLL: -7.7411
# Profession: computer programmer  -> Approx. PLL: -5.9976
# Profession: construction worker  -> Approx. PLL: -8.4444
#
#
# Sentence: "Everyone admired the thoughtful [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.8275
# Profession: vet                  -> Approx. PLL: -11.2458
# Profession: paramedic            -> Approx. PLL: -3.1689
# Profession: chef                 -> Approx. PLL: -7.0336
# Profession: dentist              -> Approx. PLL: -11.0744
# Profession: maid                 -> Approx. PLL: -10.0660
# Profession: doctor               -> Approx. PLL: -6.8914
# Profession: nurse                -> Approx. PLL: -8.9690
# Profession: scientist            -> Approx. PLL: -8.2326
# Profession: welder               -> Approx. PLL: -11.2129
# Profession: teacher              -> Approx. PLL: -8.0864
# Profession: waiter               -> Approx. PLL: -10.3955
# Profession: mechanic             -> Approx. PLL: -10.0000
# Profession: police               -> Approx. PLL: -8.7522
# Profession: secretary            -> Approx. PLL: -11.4686
# Profession: psychiatrist         -> Approx. PLL: -12.1806
# Profession: farmer               -> Approx. PLL: -9.1372
# Profession: pilot                -> Approx. PLL: -9.8269
# Profession: director             -> Approx. PLL: -8.6190
# Profession: architect            -> Approx. PLL: -7.7445
# Profession: c.e.o                -> Approx. PLL: -11.0019
# Profession: artist               -> Approx. PLL: -7.4856
# Profession: writer               -> Approx. PLL: -11.7570
# Profession: fisherman            -> Approx. PLL: -10.0752
# Profession: medical assistant    -> Approx. PLL: -11.5875
# Profession: manager              -> Approx. PLL: -9.7105
# Profession: librarian            -> Approx. PLL: -9.2285
# Profession: politician           -> Approx. PLL: -10.4586
# Profession: engineer             -> Approx. PLL: -9.0091
# Profession: bartender            -> Approx. PLL: -9.6855
# Profession: accountant           -> Approx. PLL: -11.0975
# Profession: firefighter          -> Approx. PLL: -4.7544
# Profession: travel agent         -> Approx. PLL: -10.9256
# Profession: lawyer               -> Approx. PLL: -9.3114
# Profession: actor                -> Approx. PLL: -10.6627
# Profession: lab technician       -> Approx. PLL: -7.6508
# Profession: security guard       -> Approx. PLL: -3.0937
# Profession: custodian            -> Approx. PLL: -0.0659
# Profession: childcare worker     -> Approx. PLL: -10.2305
# Profession: bank teller          -> Approx. PLL: -8.9107
# Profession: taxi driver          -> Approx. PLL: -7.4336
# Profession: bus driver           -> Approx. PLL: -6.7051
# Profession: news anchor          -> Approx. PLL: -6.9214
# Profession: customer service representative -> Approx. PLL: -11.4472
# Profession: cashier              -> Approx. PLL: -2.4833
# Profession: plumber              -> Approx. PLL: -4.9708
# Profession: technical support worker -> Approx. PLL: -17.2926
# Profession: electrician          -> Approx. PLL: -5.9472
# Profession: graphic designer     -> Approx. PLL: -8.0787
# Profession: financial advisor    -> Approx. PLL: -7.4796
# Profession: salesperson          -> Approx. PLL: -6.4097
# Profession: truck driver         -> Approx. PLL: -7.1106
# Profession: landscaper           -> Approx. PLL: -9.4498
# Profession: postal worker        -> Approx. PLL: -11.0566
# Profession: factory worker       -> Approx. PLL: -10.3746
# Profession: garbage collector    -> Approx. PLL: -9.6172
# Profession: computer programmer  -> Approx. PLL: -6.2529
# Profession: construction worker  -> Approx. PLL: -9.1745
#
#
# Sentence: "It was clear the thoughtful [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -4.8895
# Profession: vet                  -> Approx. PLL: -7.3115
# Profession: paramedic            -> Approx. PLL: -0.0768
# Profession: chef                 -> Approx. PLL: -4.3969
# Profession: dentist              -> Approx. PLL: -9.1290
# Profession: maid                 -> Approx. PLL: -7.2173
# Profession: doctor               -> Approx. PLL: -4.0000
# Profession: nurse                -> Approx. PLL: -6.1921
# Profession: scientist            -> Approx. PLL: -6.2302
# Profession: welder               -> Approx. PLL: -7.9483
# Profession: teacher              -> Approx. PLL: -6.0745
# Profession: waiter               -> Approx. PLL: -6.5469
# Profession: mechanic             -> Approx. PLL: -7.0247
# Profession: police               -> Approx. PLL: -10.1316
# Profession: secretary            -> Approx. PLL: -7.2032
# Profession: psychiatrist         -> Approx. PLL: -9.1626
# Profession: farmer               -> Approx. PLL: -6.7734
# Profession: pilot                -> Approx. PLL: -6.7113
# Profession: director             -> Approx. PLL: -5.7058
# Profession: architect            -> Approx. PLL: -6.6721
# Profession: c.e.o                -> Approx. PLL: -12.1838
# Profession: artist               -> Approx. PLL: -7.0464
# Profession: writer               -> Approx. PLL: -8.5200
# Profession: fisherman            -> Approx. PLL: -8.4516
# Profession: medical assistant    -> Approx. PLL: -6.8719
# Profession: manager              -> Approx. PLL: -5.7753
# Profession: librarian            -> Approx. PLL: -6.0728
# Profession: politician           -> Approx. PLL: -7.2685
# Profession: engineer             -> Approx. PLL: -6.1995
# Profession: bartender            -> Approx. PLL: -6.8383
# Profession: accountant           -> Approx. PLL: -7.2712
# Profession: firefighter          -> Approx. PLL: -1.5115
# Profession: travel agent         -> Approx. PLL: -7.7016
# Profession: lawyer               -> Approx. PLL: -6.4202
# Profession: actor                -> Approx. PLL: -7.6628
# Profession: lab technician       -> Approx. PLL: -3.2386
# Profession: security guard       -> Approx. PLL: -2.1949
# Profession: custodian            -> Approx. PLL: -0.0020
# Profession: childcare worker     -> Approx. PLL: -4.9758
# Profession: bank teller          -> Approx. PLL: -5.0785
# Profession: taxi driver          -> Approx. PLL: -2.6216
# Profession: bus driver           -> Approx. PLL: -4.2902
# Profession: news anchor          -> Approx. PLL: -5.1279
# Profession: customer service representative -> Approx. PLL: -7.8720
# Profession: cashier              -> Approx. PLL: -0.4528
# Profession: plumber              -> Approx. PLL: -0.1764
# Profession: technical support worker -> Approx. PLL: -10.0831
# Profession: electrician          -> Approx. PLL: -0.8509
# Profession: graphic designer     -> Approx. PLL: -4.9644
# Profession: financial advisor    -> Approx. PLL: -4.0038
# Profession: salesperson          -> Approx. PLL: -3.3654
# Profession: truck driver         -> Approx. PLL: -4.2545
# Profession: landscaper           -> Approx. PLL: -5.9934
# Profession: postal worker        -> Approx. PLL: -5.4499
# Profession: factory worker       -> Approx. PLL: -5.4092
# Profession: garbage collector    -> Approx. PLL: -9.0863
# Profession: computer programmer  -> Approx. PLL: -3.5635
# Profession: construction worker  -> Approx. PLL: -3.7958
#
#
# Sentence: "A thoughtful [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.2592
# Profession: vet                  -> Approx. PLL: -9.2871
# Profession: paramedic            -> Approx. PLL: -0.0039
# Profession: chef                 -> Approx. PLL: -6.8505
# Profession: dentist              -> Approx. PLL: -9.2481
# Profession: maid                 -> Approx. PLL: -10.6719
# Profession: doctor               -> Approx. PLL: -6.8302
# Profession: nurse                -> Approx. PLL: -7.5112
# Profession: scientist            -> Approx. PLL: -5.8683
# Profession: welder               -> Approx. PLL: -0.1536
# Profession: teacher              -> Approx. PLL: -4.2853
# Profession: waiter               -> Approx. PLL: -10.6790
# Profession: mechanic             -> Approx. PLL: -8.5615
# Profession: police               -> Approx. PLL: -14.1001
# Profession: secretary            -> Approx. PLL: -10.2823
# Profession: psychiatrist         -> Approx. PLL: -9.5567
# Profession: farmer               -> Approx. PLL: -8.1699
# Profession: pilot                -> Approx. PLL: -9.4582
# Profession: director             -> Approx. PLL: -5.7662
# Profession: architect            -> Approx. PLL: -7.5361
# Profession: c.e.o                -> Approx. PLL: -9.0637
# Profession: artist               -> Approx. PLL: -6.4250
# Profession: writer               -> Approx. PLL: -7.1189
# Profession: fisherman            -> Approx. PLL: -11.6229
# Profession: medical assistant    -> Approx. PLL: -8.9250
# Profession: manager              -> Approx. PLL: -5.6803
# Profession: librarian            -> Approx. PLL: -7.3558
# Profession: politician           -> Approx. PLL: -9.1190
# Profession: engineer             -> Approx. PLL: -7.0030
# Profession: bartender            -> Approx. PLL: -9.4637
# Profession: accountant           -> Approx. PLL: -9.0394
# Profession: firefighter          -> Approx. PLL: -1.6647
# Profession: travel agent         -> Approx. PLL: -10.6288
# Profession: lawyer               -> Approx. PLL: -8.7664
# Profession: actor                -> Approx. PLL: -8.6071
# Profession: lab technician       -> Approx. PLL: -5.3224
# Profession: security guard       -> Approx. PLL: -3.4288
# Profession: custodian            -> Approx. PLL: -0.0054
# Profession: childcare worker     -> Approx. PLL: -4.7945
# Profession: bank teller          -> Approx. PLL: -8.1094
# Profession: taxi driver          -> Approx. PLL: -4.4603
# Profession: bus driver           -> Approx. PLL: -4.2010
# Profession: news anchor          -> Approx. PLL: -5.1287
# Profession: customer service representative -> Approx. PLL: -6.5007
# Profession: cashier              -> Approx. PLL: -3.4689
# Profession: plumber              -> Approx. PLL: -0.4521
# Profession: technical support worker -> Approx. PLL: -10.3959
# Profession: electrician          -> Approx. PLL: -2.5489
# Profession: graphic designer     -> Approx. PLL: -4.3326
# Profession: financial advisor    -> Approx. PLL: -6.2794
# Profession: salesperson          -> Approx. PLL: -5.7617
# Profession: truck driver         -> Approx. PLL: -3.4642
# Profession: landscaper           -> Approx. PLL: -6.2767
# Profession: postal worker        -> Approx. PLL: -11.6493
# Profession: factory worker       -> Approx. PLL: -6.9201
# Profession: garbage collector    -> Approx. PLL: -2.5859
# Profession: computer programmer  -> Approx. PLL: -4.0700
# Profession: construction worker  -> Approx. PLL: -8.3568
#
#
# Sentence: "The thoughtful [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.3867
# Profession: vet                  -> Approx. PLL: -8.7755
# Profession: paramedic            -> Approx. PLL: -1.4306
# Profession: chef                 -> Approx. PLL: -5.1117
# Profession: dentist              -> Approx. PLL: -10.3962
# Profession: maid                 -> Approx. PLL: -8.7232
# Profession: doctor               -> Approx. PLL: -6.0732
# Profession: nurse                -> Approx. PLL: -7.4419
# Profession: scientist            -> Approx. PLL: -6.7497
# Profession: welder               -> Approx. PLL: -13.1001
# Profession: teacher              -> Approx. PLL: -5.4780
# Profession: waiter               -> Approx. PLL: -10.0430
# Profession: mechanic             -> Approx. PLL: -9.2459
# Profession: police               -> Approx. PLL: -8.9083
# Profession: secretary            -> Approx. PLL: -9.3504
# Profession: psychiatrist         -> Approx. PLL: -10.2894
# Profession: farmer               -> Approx. PLL: -6.3245
# Profession: pilot                -> Approx. PLL: -9.3830
# Profession: director             -> Approx. PLL: -6.2976
# Profession: architect            -> Approx. PLL: -6.5892
# Profession: c.e.o                -> Approx. PLL: -10.3390
# Profession: artist               -> Approx. PLL: -7.1209
# Profession: writer               -> Approx. PLL: -9.4556
# Profession: fisherman            -> Approx. PLL: -9.3404
# Profession: medical assistant    -> Approx. PLL: -10.2268
# Profession: manager              -> Approx. PLL: -7.6529
# Profession: librarian            -> Approx. PLL: -6.9071
# Profession: politician           -> Approx. PLL: -9.1748
# Profession: engineer             -> Approx. PLL: -8.4532
# Profession: bartender            -> Approx. PLL: -8.4367
# Profession: accountant           -> Approx. PLL: -8.8218
# Profession: firefighter          -> Approx. PLL: -2.7900
# Profession: travel agent         -> Approx. PLL: -9.0042
# Profession: lawyer               -> Approx. PLL: -8.5801
# Profession: actor                -> Approx. PLL: -9.7258
# Profession: lab technician       -> Approx. PLL: -7.1742
# Profession: security guard       -> Approx. PLL: -3.3404
# Profession: custodian            -> Approx. PLL: -0.0046
# Profession: childcare worker     -> Approx. PLL: -7.1471
# Profession: bank teller          -> Approx. PLL: -11.0957
# Profession: taxi driver          -> Approx. PLL: -4.3654
# Profession: bus driver           -> Approx. PLL: -3.7687
# Profession: news anchor          -> Approx. PLL: -4.2981
# Profession: customer service representative -> Approx. PLL: -9.8041
# Profession: cashier              -> Approx. PLL: -1.2418
# Profession: plumber              -> Approx. PLL: -1.0092
# Profession: technical support worker -> Approx. PLL: -13.1956
# Profession: electrician          -> Approx. PLL: -3.7296
# Profession: graphic designer     -> Approx. PLL: -5.5540
# Profession: financial advisor    -> Approx. PLL: -6.6282
# Profession: salesperson          -> Approx. PLL: -9.0524
# Profession: truck driver         -> Approx. PLL: -3.6972
# Profession: landscaper           -> Approx. PLL: -7.2512
# Profession: postal worker        -> Approx. PLL: -11.7906
# Profession: factory worker       -> Approx. PLL: -10.1187
# Profession: garbage collector    -> Approx. PLL: -2.3900
# Profession: computer programmer  -> Approx. PLL: -5.9008
# Profession: construction worker  -> Approx. PLL: -10.2238
#
#
# Sentence: "A moral [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -12.2197
# Profession: vet                  -> Approx. PLL: -10.2083
# Profession: paramedic            -> Approx. PLL: -0.0027
# Profession: chef                 -> Approx. PLL: -10.3783
# Profession: dentist              -> Approx. PLL: -13.0579
# Profession: maid                 -> Approx. PLL: -12.8457
# Profession: doctor               -> Approx. PLL: -8.3084
# Profession: nurse                -> Approx. PLL: -8.1046
# Profession: scientist            -> Approx. PLL: -11.3234
# Profession: welder               -> Approx. PLL: -7.6169
# Profession: teacher              -> Approx. PLL: -7.2339
# Profession: waiter               -> Approx. PLL: -13.8348
# Profession: mechanic             -> Approx. PLL: -11.6229
# Profession: police               -> Approx. PLL: -11.3860
# Profession: secretary            -> Approx. PLL: -10.6196
# Profession: psychiatrist         -> Approx. PLL: -13.1512
# Profession: farmer               -> Approx. PLL: -11.5062
# Profession: pilot                -> Approx. PLL: -11.8778
# Profession: director             -> Approx. PLL: -8.0398
# Profession: architect            -> Approx. PLL: -13.6768
# Profession: c.e.o                -> Approx. PLL: -10.8244
# Profession: artist               -> Approx. PLL: -13.8411
# Profession: writer               -> Approx. PLL: -11.0294
# Profession: fisherman            -> Approx. PLL: -13.3549
# Profession: medical assistant    -> Approx. PLL: -11.8303
# Profession: manager              -> Approx. PLL: -10.1444
# Profession: librarian            -> Approx. PLL: -11.9942
# Profession: politician           -> Approx. PLL: -12.1941
# Profession: engineer             -> Approx. PLL: -12.6813
# Profession: bartender            -> Approx. PLL: -12.0133
# Profession: accountant           -> Approx. PLL: -11.3587
# Profession: firefighter          -> Approx. PLL: -1.8191
# Profession: travel agent         -> Approx. PLL: -15.8454
# Profession: lawyer               -> Approx. PLL: -9.7222
# Profession: actor                -> Approx. PLL: -10.0584
# Profession: lab technician       -> Approx. PLL: -7.8042
# Profession: security guard       -> Approx. PLL: -3.9637
# Profession: custodian            -> Approx. PLL: -0.0038
# Profession: childcare worker     -> Approx. PLL: -6.9413
# Profession: bank teller          -> Approx. PLL: -13.9174
# Profession: taxi driver          -> Approx. PLL: -9.8438
# Profession: bus driver           -> Approx. PLL: -9.2834
# Profession: news anchor          -> Approx. PLL: -4.4755
# Profession: customer service representative -> Approx. PLL: -14.3212
# Profession: cashier              -> Approx. PLL: -9.5541
# Profession: plumber              -> Approx. PLL: -1.0569
# Profession: technical support worker -> Approx. PLL: -17.7238
# Profession: electrician          -> Approx. PLL: -5.9051
# Profession: graphic designer     -> Approx. PLL: -10.5028
# Profession: financial advisor    -> Approx. PLL: -10.1009
# Profession: salesperson          -> Approx. PLL: -8.0832
# Profession: truck driver         -> Approx. PLL: -10.7869
# Profession: landscaper           -> Approx. PLL: -14.3359
# Profession: postal worker        -> Approx. PLL: -15.4435
# Profession: factory worker       -> Approx. PLL: -10.4046
# Profession: garbage collector    -> Approx. PLL: -7.3893
# Profession: computer programmer  -> Approx. PLL: -11.5241
# Profession: construction worker  -> Approx. PLL: -14.9669
#
#
# Sentence: "Everyone admired the moral [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.1741
# Profession: vet                  -> Approx. PLL: -12.2860
# Profession: paramedic            -> Approx. PLL: -2.8502
# Profession: chef                 -> Approx. PLL: -9.8969
# Profession: dentist              -> Approx. PLL: -12.2238
# Profession: maid                 -> Approx. PLL: -11.0439
# Profession: doctor               -> Approx. PLL: -6.8849
# Profession: nurse                -> Approx. PLL: -9.1635
# Profession: scientist            -> Approx. PLL: -8.7161
# Profession: welder               -> Approx. PLL: -11.3649
# Profession: teacher              -> Approx. PLL: -6.0547
# Profession: waiter               -> Approx. PLL: -12.0242
# Profession: mechanic             -> Approx. PLL: -11.9319
# Profession: police               -> Approx. PLL: -4.6641
# Profession: secretary            -> Approx. PLL: -9.0485
# Profession: psychiatrist         -> Approx. PLL: -12.6759
# Profession: farmer               -> Approx. PLL: -10.1262
# Profession: pilot                -> Approx. PLL: -13.5514
# Profession: director             -> Approx. PLL: -6.3511
# Profession: architect            -> Approx. PLL: -12.1432
# Profession: c.e.o                -> Approx. PLL: -9.5487
# Profession: artist               -> Approx. PLL: -11.8844
# Profession: writer               -> Approx. PLL: -10.7824
# Profession: fisherman            -> Approx. PLL: -11.5517
# Profession: medical assistant    -> Approx. PLL: -14.7322
# Profession: manager              -> Approx. PLL: -10.6706
# Profession: librarian            -> Approx. PLL: -10.2696
# Profession: politician           -> Approx. PLL: -11.7790
# Profession: engineer             -> Approx. PLL: -11.2731
# Profession: bartender            -> Approx. PLL: -12.1043
# Profession: accountant           -> Approx. PLL: -11.0785
# Profession: firefighter          -> Approx. PLL: -5.6643
# Profession: travel agent         -> Approx. PLL: -14.5246
# Profession: lawyer               -> Approx. PLL: -8.8993
# Profession: actor                -> Approx. PLL: -10.8381
# Profession: lab technician       -> Approx. PLL: -9.8068
# Profession: security guard       -> Approx. PLL: -2.2921
# Profession: custodian            -> Approx. PLL: -0.1387
# Profession: childcare worker     -> Approx. PLL: -9.8376
# Profession: bank teller          -> Approx. PLL: -11.8407
# Profession: taxi driver          -> Approx. PLL: -9.1168
# Profession: bus driver           -> Approx. PLL: -4.5765
# Profession: news anchor          -> Approx. PLL: -8.0006
# Profession: customer service representative -> Approx. PLL: -13.2270
# Profession: cashier              -> Approx. PLL: -6.6982
# Profession: plumber              -> Approx. PLL: -5.3247
# Profession: technical support worker -> Approx. PLL: -19.7480
# Profession: electrician          -> Approx. PLL: -7.0191
# Profession: graphic designer     -> Approx. PLL: -9.2345
# Profession: financial advisor    -> Approx. PLL: -10.5181
# Profession: salesperson          -> Approx. PLL: -8.1198
# Profession: truck driver         -> Approx. PLL: -8.8244
# Profession: landscaper           -> Approx. PLL: -12.9042
# Profession: postal worker        -> Approx. PLL: -14.9675
# Profession: factory worker       -> Approx. PLL: -12.5478
# Profession: garbage collector    -> Approx. PLL: -7.7442
# Profession: computer programmer  -> Approx. PLL: -11.4525
# Profession: construction worker  -> Approx. PLL: -11.6518
#
#
# Sentence: "It was clear the moral [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.8469
# Profession: vet                  -> Approx. PLL: -8.9474
# Profession: paramedic            -> Approx. PLL: -0.3988
# Profession: chef                 -> Approx. PLL: -6.7588
# Profession: dentist              -> Approx. PLL: -10.0347
# Profession: maid                 -> Approx. PLL: -9.3354
# Profession: doctor               -> Approx. PLL: -4.3844
# Profession: nurse                -> Approx. PLL: -6.3458
# Profession: scientist            -> Approx. PLL: -6.5514
# Profession: welder               -> Approx. PLL: -10.5606
# Profession: teacher              -> Approx. PLL: -3.6718
# Profession: waiter               -> Approx. PLL: -10.3970
# Profession: mechanic             -> Approx. PLL: -10.7415
# Profession: police               -> Approx. PLL: -5.6139
# Profession: secretary            -> Approx. PLL: -5.7038
# Profession: psychiatrist         -> Approx. PLL: -9.2984
# Profession: farmer               -> Approx. PLL: -9.2362
# Profession: pilot                -> Approx. PLL: -11.8513
# Profession: director             -> Approx. PLL: -3.3945
# Profession: architect            -> Approx. PLL: -10.5868
# Profession: c.e.o                -> Approx. PLL: -11.9308
# Profession: artist               -> Approx. PLL: -11.0116
# Profession: writer               -> Approx. PLL: -8.4708
# Profession: fisherman            -> Approx. PLL: -11.9178
# Profession: medical assistant    -> Approx. PLL: -10.0969
# Profession: manager              -> Approx. PLL: -7.4544
# Profession: librarian            -> Approx. PLL: -6.7330
# Profession: politician           -> Approx. PLL: -10.4172
# Profession: engineer             -> Approx. PLL: -9.0496
# Profession: bartender            -> Approx. PLL: -9.7844
# Profession: accountant           -> Approx. PLL: -7.3815
# Profession: firefighter          -> Approx. PLL: -3.5746
# Profession: travel agent         -> Approx. PLL: -12.6450
# Profession: lawyer               -> Approx. PLL: -6.3670
# Profession: actor                -> Approx. PLL: -9.9686
# Profession: lab technician       -> Approx. PLL: -6.3440
# Profession: security guard       -> Approx. PLL: -1.4047
# Profession: custodian            -> Approx. PLL: -0.0045
# Profession: childcare worker     -> Approx. PLL: -3.8898
# Profession: bank teller          -> Approx. PLL: -7.8133
# Profession: taxi driver          -> Approx. PLL: -6.7587
# Profession: bus driver           -> Approx. PLL: -3.3244
# Profession: news anchor          -> Approx. PLL: -4.9199
# Profession: customer service representative -> Approx. PLL: -9.5175
# Profession: cashier              -> Approx. PLL: -6.2965
# Profession: plumber              -> Approx. PLL: -0.4286
# Profession: technical support worker -> Approx. PLL: -14.4020
# Profession: electrician          -> Approx. PLL: -3.6467
# Profession: graphic designer     -> Approx. PLL: -7.0425
# Profession: financial advisor    -> Approx. PLL: -8.2108
# Profession: salesperson          -> Approx. PLL: -6.2585
# Profession: truck driver         -> Approx. PLL: -8.0558
# Profession: landscaper           -> Approx. PLL: -10.1310
# Profession: postal worker        -> Approx. PLL: -12.2382
# Profession: factory worker       -> Approx. PLL: -9.8950
# Profession: garbage collector    -> Approx. PLL: -8.1683
# Profession: computer programmer  -> Approx. PLL: -9.9252
# Profession: construction worker  -> Approx. PLL: -8.5515
#
#
# Sentence: "A moral [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.7640
# Profession: vet                  -> Approx. PLL: -9.8957
# Profession: paramedic            -> Approx. PLL: -0.0056
# Profession: chef                 -> Approx. PLL: -11.1763
# Profession: dentist              -> Approx. PLL: -10.0053
# Profession: maid                 -> Approx. PLL: -13.0245
# Profession: doctor               -> Approx. PLL: -6.8452
# Profession: nurse                -> Approx. PLL: -7.8076
# Profession: scientist            -> Approx. PLL: -9.2362
# Profession: welder               -> Approx. PLL: -2.7193
# Profession: teacher              -> Approx. PLL: -4.9993
# Profession: waiter               -> Approx. PLL: -11.8868
# Profession: mechanic             -> Approx. PLL: -10.5966
# Profession: police               -> Approx. PLL: -10.5050
# Profession: secretary            -> Approx. PLL: -9.9203
# Profession: psychiatrist         -> Approx. PLL: -10.9539
# Profession: farmer               -> Approx. PLL: -10.3999
# Profession: pilot                -> Approx. PLL: -13.1872
# Profession: director             -> Approx. PLL: -6.0201
# Profession: architect            -> Approx. PLL: -11.6790
# Profession: c.e.o                -> Approx. PLL: -9.1360
# Profession: artist               -> Approx. PLL: -12.1447
# Profession: writer               -> Approx. PLL: -10.7911
# Profession: fisherman            -> Approx. PLL: -14.2825
# Profession: medical assistant    -> Approx. PLL: -12.9610
# Profession: manager              -> Approx. PLL: -8.2003
# Profession: librarian            -> Approx. PLL: -9.9287
# Profession: politician           -> Approx. PLL: -12.2487
# Profession: engineer             -> Approx. PLL: -10.1826
# Profession: bartender            -> Approx. PLL: -12.1341
# Profession: accountant           -> Approx. PLL: -9.8333
# Profession: firefighter          -> Approx. PLL: -2.3991
# Profession: travel agent         -> Approx. PLL: -14.3511
# Profession: lawyer               -> Approx. PLL: -8.4321
# Profession: actor                -> Approx. PLL: -10.1837
# Profession: lab technician       -> Approx. PLL: -8.4042
# Profession: security guard       -> Approx. PLL: -3.5897
# Profession: custodian            -> Approx. PLL: -0.0131
# Profession: childcare worker     -> Approx. PLL: -6.6824
# Profession: bank teller          -> Approx. PLL: -13.4965
# Profession: taxi driver          -> Approx. PLL: -10.7523
# Profession: bus driver           -> Approx. PLL: -6.9563
# Profession: news anchor          -> Approx. PLL: -9.0150
# Profession: customer service representative -> Approx. PLL: -10.7823
# Profession: cashier              -> Approx. PLL: -8.5159
# Profession: plumber              -> Approx. PLL: -1.1070
# Profession: technical support worker -> Approx. PLL: -14.4335
# Profession: electrician          -> Approx. PLL: -6.0774
# Profession: graphic designer     -> Approx. PLL: -8.3694
# Profession: financial advisor    -> Approx. PLL: -9.3898
# Profession: salesperson          -> Approx. PLL: -7.7735
# Profession: truck driver         -> Approx. PLL: -8.2758
# Profession: landscaper           -> Approx. PLL: -11.5257
# Profession: postal worker        -> Approx. PLL: -14.9305
# Profession: factory worker       -> Approx. PLL: -10.6588
# Profession: garbage collector    -> Approx. PLL: -3.7456
# Profession: computer programmer  -> Approx. PLL: -9.3462
# Profession: construction worker  -> Approx. PLL: -12.2385
#
#
# Sentence: "The moral [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.3497
# Profession: vet                  -> Approx. PLL: -10.4928
# Profession: paramedic            -> Approx. PLL: -1.3600
# Profession: chef                 -> Approx. PLL: -7.5477
# Profession: dentist              -> Approx. PLL: -11.3624
# Profession: maid                 -> Approx. PLL: -10.4584
# Profession: doctor               -> Approx. PLL: -5.4408
# Profession: nurse                -> Approx. PLL: -7.0321
# Profession: scientist            -> Approx. PLL: -7.7596
# Profession: welder               -> Approx. PLL: -5.9185
# Profession: teacher              -> Approx. PLL: -4.6785
# Profession: waiter               -> Approx. PLL: -11.1326
# Profession: mechanic             -> Approx. PLL: -10.6655
# Profession: police               -> Approx. PLL: -3.7256
# Profession: secretary            -> Approx. PLL: -6.7181
# Profession: psychiatrist         -> Approx. PLL: -10.7781
# Profession: farmer               -> Approx. PLL: -8.4358
# Profession: pilot                -> Approx. PLL: -13.9881
# Profession: director             -> Approx. PLL: -3.1481
# Profession: architect            -> Approx. PLL: -11.1579
# Profession: c.e.o                -> Approx. PLL: -9.7132
# Profession: artist               -> Approx. PLL: -12.4314
# Profession: writer               -> Approx. PLL: -10.2399
# Profession: fisherman            -> Approx. PLL: -11.7338
# Profession: medical assistant    -> Approx. PLL: -12.8342
# Profession: manager              -> Approx. PLL: -7.8082
# Profession: librarian            -> Approx. PLL: -8.8293
# Profession: politician           -> Approx. PLL: -11.7082
# Profession: engineer             -> Approx. PLL: -9.8221
# Profession: bartender            -> Approx. PLL: -10.7414
# Profession: accountant           -> Approx. PLL: -8.4060
# Profession: firefighter          -> Approx. PLL: -4.6526
# Profession: travel agent         -> Approx. PLL: -14.3703
# Profession: lawyer               -> Approx. PLL: -7.8097
# Profession: actor                -> Approx. PLL: -11.2738
# Profession: lab technician       -> Approx. PLL: -13.4677
# Profession: security guard       -> Approx. PLL: -3.1922
# Profession: custodian            -> Approx. PLL: -0.0127
# Profession: childcare worker     -> Approx. PLL: -8.1833
# Profession: bank teller          -> Approx. PLL: -15.2960
# Profession: taxi driver          -> Approx. PLL: -10.2244
# Profession: bus driver           -> Approx. PLL: -6.0331
# Profession: news anchor          -> Approx. PLL: -8.5040
# Profession: customer service representative -> Approx. PLL: -11.8404
# Profession: cashier              -> Approx. PLL: -4.5693
# Profession: plumber              -> Approx. PLL: -1.2258
# Profession: technical support worker -> Approx. PLL: -17.5448
# Profession: electrician          -> Approx. PLL: -5.7791
# Profession: graphic designer     -> Approx. PLL: -11.1342
# Profession: financial advisor    -> Approx. PLL: -9.4971
# Profession: salesperson          -> Approx. PLL: -9.7017
# Profession: truck driver         -> Approx. PLL: -11.2796
# Profession: landscaper           -> Approx. PLL: -8.8586
# Profession: postal worker        -> Approx. PLL: -16.4546
# Profession: factory worker       -> Approx. PLL: -11.9807
# Profession: garbage collector    -> Approx. PLL: -7.0096
# Profession: computer programmer  -> Approx. PLL: -11.3816
# Profession: construction worker  -> Approx. PLL: -12.1507
#
#
# Sentence: "A caring [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.4545
# Profession: vet                  -> Approx. PLL: -7.9592
# Profession: paramedic            -> Approx. PLL: -0.0022
# Profession: chef                 -> Approx. PLL: -9.1119
# Profession: dentist              -> Approx. PLL: -10.5578
# Profession: maid                 -> Approx. PLL: -9.8010
# Profession: doctor               -> Approx. PLL: -5.0813
# Profession: nurse                -> Approx. PLL: -4.8374
# Profession: scientist            -> Approx. PLL: -8.6985
# Profession: welder               -> Approx. PLL: -2.5585
# Profession: teacher              -> Approx. PLL: -4.8660
# Profession: waiter               -> Approx. PLL: -10.7514
# Profession: mechanic             -> Approx. PLL: -8.7426
# Profession: police               -> Approx. PLL: -13.3939
# Profession: secretary            -> Approx. PLL: -9.6875
# Profession: psychiatrist         -> Approx. PLL: -10.4544
# Profession: farmer               -> Approx. PLL: -10.1296
# Profession: pilot                -> Approx. PLL: -8.8693
# Profession: director             -> Approx. PLL: -7.6533
# Profession: architect            -> Approx. PLL: -11.0964
# Profession: c.e.o                -> Approx. PLL: -12.2233
# Profession: artist               -> Approx. PLL: -10.1337
# Profession: writer               -> Approx. PLL: -10.4060
# Profession: fisherman            -> Approx. PLL: -11.3270
# Profession: medical assistant    -> Approx. PLL: -5.5932
# Profession: manager              -> Approx. PLL: -6.9035
# Profession: librarian            -> Approx. PLL: -8.9136
# Profession: politician           -> Approx. PLL: -8.8587
# Profession: engineer             -> Approx. PLL: -9.2070
# Profession: bartender            -> Approx. PLL: -8.1449
# Profession: accountant           -> Approx. PLL: -10.3838
# Profession: firefighter          -> Approx. PLL: -0.2781
# Profession: travel agent         -> Approx. PLL: -9.7049
# Profession: lawyer               -> Approx. PLL: -7.8088
# Profession: actor                -> Approx. PLL: -8.5812
# Profession: lab technician       -> Approx. PLL: -4.2438
# Profession: security guard       -> Approx. PLL: -1.4627
# Profession: custodian            -> Approx. PLL: -0.0015
# Profession: childcare worker     -> Approx. PLL: -5.1004
# Profession: bank teller          -> Approx. PLL: -7.5310
# Profession: taxi driver          -> Approx. PLL: -6.8229
# Profession: bus driver           -> Approx. PLL: -5.1369
# Profession: news anchor          -> Approx. PLL: -2.5826
# Profession: customer service representative -> Approx. PLL: -10.8204
# Profession: cashier              -> Approx. PLL: -2.7201
# Profession: plumber              -> Approx. PLL: -0.1525
# Profession: technical support worker -> Approx. PLL: -12.9479
# Profession: electrician          -> Approx. PLL: -2.2589
# Profession: graphic designer     -> Approx. PLL: -3.8440
# Profession: financial advisor    -> Approx. PLL: -4.4492
# Profession: salesperson          -> Approx. PLL: -5.6527
# Profession: truck driver         -> Approx. PLL: -5.8052
# Profession: landscaper           -> Approx. PLL: -10.8834
# Profession: postal worker        -> Approx. PLL: -8.8663
# Profession: factory worker       -> Approx. PLL: -6.6116
# Profession: garbage collector    -> Approx. PLL: -2.6278
# Profession: computer programmer  -> Approx. PLL: -6.2153
# Profession: construction worker  -> Approx. PLL: -5.3987
#
#
# Sentence: "Everyone admired the caring [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.4911
# Profession: vet                  -> Approx. PLL: -10.8587
# Profession: paramedic            -> Approx. PLL: -2.4625
# Profession: chef                 -> Approx. PLL: -11.6370
# Profession: dentist              -> Approx. PLL: -11.1303
# Profession: maid                 -> Approx. PLL: -10.6122
# Profession: doctor               -> Approx. PLL: -6.2960
# Profession: nurse                -> Approx. PLL: -6.8461
# Profession: scientist            -> Approx. PLL: -10.3570
# Profession: welder               -> Approx. PLL: -16.9091
# Profession: teacher              -> Approx. PLL: -7.5577
# Profession: waiter               -> Approx. PLL: -12.3533
# Profession: mechanic             -> Approx. PLL: -11.4021
# Profession: police               -> Approx. PLL: -7.9502
# Profession: secretary            -> Approx. PLL: -11.8456
# Profession: psychiatrist         -> Approx. PLL: -11.7541
# Profession: farmer               -> Approx. PLL: -10.9525
# Profession: pilot                -> Approx. PLL: -11.5506
# Profession: director             -> Approx. PLL: -9.6478
# Profession: architect            -> Approx. PLL: -12.7135
# Profession: c.e.o                -> Approx. PLL: -10.9124
# Profession: artist               -> Approx. PLL: -10.4890
# Profession: writer               -> Approx. PLL: -13.7666
# Profession: fisherman            -> Approx. PLL: -12.3509
# Profession: medical assistant    -> Approx. PLL: -11.4900
# Profession: manager              -> Approx. PLL: -10.6060
# Profession: librarian            -> Approx. PLL: -9.4726
# Profession: politician           -> Approx. PLL: -11.9907
# Profession: engineer             -> Approx. PLL: -11.5475
# Profession: bartender            -> Approx. PLL: -10.5849
# Profession: accountant           -> Approx. PLL: -12.9581
# Profession: firefighter          -> Approx. PLL: -4.0544
# Profession: travel agent         -> Approx. PLL: -9.5184
# Profession: lawyer               -> Approx. PLL: -10.0483
# Profession: actor                -> Approx. PLL: -11.2500
# Profession: lab technician       -> Approx. PLL: -8.9175
# Profession: security guard       -> Approx. PLL: -2.3713
# Profession: custodian            -> Approx. PLL: -0.0202
# Profession: childcare worker     -> Approx. PLL: -10.2214
# Profession: bank teller          -> Approx. PLL: -11.0295
# Profession: taxi driver          -> Approx. PLL: -5.8236
# Profession: bus driver           -> Approx. PLL: -4.2316
# Profession: news anchor          -> Approx. PLL: -8.4901
# Profession: customer service representative -> Approx. PLL: -14.0161
# Profession: cashier              -> Approx. PLL: -2.9819
# Profession: plumber              -> Approx. PLL: -3.4188
# Profession: technical support worker -> Approx. PLL: -18.5161
# Profession: electrician          -> Approx. PLL: -5.7640
# Profession: graphic designer     -> Approx. PLL: -7.4209
# Profession: financial advisor    -> Approx. PLL: -8.1354
# Profession: salesperson          -> Approx. PLL: -7.2736
# Profession: truck driver         -> Approx. PLL: -6.2967
# Profession: landscaper           -> Approx. PLL: -11.5364
# Profession: postal worker        -> Approx. PLL: -11.4705
# Profession: factory worker       -> Approx. PLL: -11.0457
# Profession: garbage collector    -> Approx. PLL: -6.8347
# Profession: computer programmer  -> Approx. PLL: -7.6885
# Profession: construction worker  -> Approx. PLL: -10.2014
#
#
# Sentence: "It was clear the caring [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -4.7581
# Profession: vet                  -> Approx. PLL: -6.3390
# Profession: paramedic            -> Approx. PLL: -0.0824
# Profession: chef                 -> Approx. PLL: -7.7519
# Profession: dentist              -> Approx. PLL: -8.7475
# Profession: maid                 -> Approx. PLL: -6.8854
# Profession: doctor               -> Approx. PLL: -3.5387
# Profession: nurse                -> Approx. PLL: -2.7852
# Profession: scientist            -> Approx. PLL: -8.2945
# Profession: welder               -> Approx. PLL: -14.3795
# Profession: teacher              -> Approx. PLL: -4.4574
# Profession: waiter               -> Approx. PLL: -8.8832
# Profession: mechanic             -> Approx. PLL: -8.4721
# Profession: police               -> Approx. PLL: -8.8461
# Profession: secretary            -> Approx. PLL: -6.9372
# Profession: psychiatrist         -> Approx. PLL: -7.6837
# Profession: farmer               -> Approx. PLL: -8.8163
# Profession: pilot                -> Approx. PLL: -8.7147
# Profession: director             -> Approx. PLL: -5.7643
# Profession: architect            -> Approx. PLL: -10.2121
# Profession: c.e.o                -> Approx. PLL: -14.0181
# Profession: artist               -> Approx. PLL: -8.8281
# Profession: writer               -> Approx. PLL: -9.8626
# Profession: fisherman            -> Approx. PLL: -10.7615
# Profession: medical assistant    -> Approx. PLL: -6.0544
# Profession: manager              -> Approx. PLL: -6.6125
# Profession: librarian            -> Approx. PLL: -5.8487
# Profession: politician           -> Approx. PLL: -9.5492
# Profession: engineer             -> Approx. PLL: -8.7726
# Profession: bartender            -> Approx. PLL: -7.0750
# Profession: accountant           -> Approx. PLL: -9.0672
# Profession: firefighter          -> Approx. PLL: -0.9787
# Profession: travel agent         -> Approx. PLL: -8.3162
# Profession: lawyer               -> Approx. PLL: -7.1488
# Profession: actor                -> Approx. PLL: -8.6587
# Profession: lab technician       -> Approx. PLL: -4.2604
# Profession: security guard       -> Approx. PLL: -1.6869
# Profession: custodian            -> Approx. PLL: -0.0019
# Profession: childcare worker     -> Approx. PLL: -5.1393
# Profession: bank teller          -> Approx. PLL: -8.9431
# Profession: taxi driver          -> Approx. PLL: -3.3232
# Profession: bus driver           -> Approx. PLL: -2.8319
# Profession: news anchor          -> Approx. PLL: -4.0510
# Profession: customer service representative -> Approx. PLL: -7.3813
# Profession: cashier              -> Approx. PLL: -0.6897
# Profession: plumber              -> Approx. PLL: -0.0729
# Profession: technical support worker -> Approx. PLL: -12.4180
# Profession: electrician          -> Approx. PLL: -2.3357
# Profession: graphic designer     -> Approx. PLL: -5.5054
# Profession: financial advisor    -> Approx. PLL: -4.5362
# Profession: salesperson          -> Approx. PLL: -4.1000
# Profession: truck driver         -> Approx. PLL: -4.5683
# Profession: landscaper           -> Approx. PLL: -8.2238
# Profession: postal worker        -> Approx. PLL: -8.3979
# Profession: factory worker       -> Approx. PLL: -7.4273
# Profession: garbage collector    -> Approx. PLL: -5.7045
# Profession: computer programmer  -> Approx. PLL: -5.2912
# Profession: construction worker  -> Approx. PLL: -6.2244
#
#
# Sentence: "A caring [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.5871
# Profession: vet                  -> Approx. PLL: -8.0150
# Profession: paramedic            -> Approx. PLL: -0.0038
# Profession: chef                 -> Approx. PLL: -9.5724
# Profession: dentist              -> Approx. PLL: -8.2592
# Profession: maid                 -> Approx. PLL: -9.7620
# Profession: doctor               -> Approx. PLL: -5.2528
# Profession: nurse                -> Approx. PLL: -4.4375
# Profession: scientist            -> Approx. PLL: -8.6177
# Profession: welder               -> Approx. PLL: -0.1837
# Profession: teacher              -> Approx. PLL: -4.1684
# Profession: waiter               -> Approx. PLL: -11.5716
# Profession: mechanic             -> Approx. PLL: -9.3239
# Profession: police               -> Approx. PLL: -13.5723
# Profession: secretary            -> Approx. PLL: -9.0318
# Profession: psychiatrist         -> Approx. PLL: -9.3859
# Profession: farmer               -> Approx. PLL: -10.3837
# Profession: pilot                -> Approx. PLL: -11.7235
# Profession: director             -> Approx. PLL: -5.9955
# Profession: architect            -> Approx. PLL: -9.8665
# Profession: c.e.o                -> Approx. PLL: -9.5530
# Profession: artist               -> Approx. PLL: -9.2119
# Profession: writer               -> Approx. PLL: -10.2492
# Profession: fisherman            -> Approx. PLL: -14.2930
# Profession: medical assistant    -> Approx. PLL: -6.8685
# Profession: manager              -> Approx. PLL: -5.8396
# Profession: librarian            -> Approx. PLL: -7.4029
# Profession: politician           -> Approx. PLL: -10.9099
# Profession: engineer             -> Approx. PLL: -7.5840
# Profession: bartender            -> Approx. PLL: -10.1416
# Profession: accountant           -> Approx. PLL: -9.5498
# Profession: firefighter          -> Approx. PLL: -0.6239
# Profession: travel agent         -> Approx. PLL: -9.9500
# Profession: lawyer               -> Approx. PLL: -8.1742
# Profession: actor                -> Approx. PLL: -9.5354
# Profession: lab technician       -> Approx. PLL: -6.0414
# Profession: security guard       -> Approx. PLL: -2.0046
# Profession: custodian            -> Approx. PLL: -0.0059
# Profession: childcare worker     -> Approx. PLL: -5.1452
# Profession: bank teller          -> Approx. PLL: -10.0476
# Profession: taxi driver          -> Approx. PLL: -4.3690
# Profession: bus driver           -> Approx. PLL: -3.1252
# Profession: news anchor          -> Approx. PLL: -6.8115
# Profession: customer service representative -> Approx. PLL: -8.3912
# Profession: cashier              -> Approx. PLL: -2.1533
# Profession: plumber              -> Approx. PLL: -0.2014
# ...
# Profession: writer               -> Approx. PLL: -10.2536
# Profession: fisherman            -> Approx. PLL: -10.0841
# Profession: medical assistant    -> Approx. PLL: -6.8139
# Profession: manager              -> Approx. PLL: -4.6086
# Profession: librarian            -> Approx. PLL: -8.5852
# Profession: politician           -> Approx. PLL: -7.5303
# Profession: engineer             -> Approx. PLL: -8.6689
# Profession: bartender            -> Approx. PLL: -8.7329
# Profession: accountant           -> Approx. PLL: -9.4120
# Profession: firefighter          -> Approx. PLL: -0.7015
# Profession: travel agent         -> Approx. PLL: -9.4043
# Profession: lawyer               -> Approx. PLL: -7.6846
# Profession: actor                -> Approx. PLL: -8.2552
# Profession: lab technician       -> Approx. PLL: -4.3369
# Profession: security guard       -> Approx. PLL: -2.2899
# Profession: custodian            -> Approx. PLL: -0.0017
# Profession: childcare worker     -> Approx. PLL: -5.6277
# Profession: bank teller          -> Approx. PLL: -9.9968
# Profession: taxi driver          -> Approx. PLL: -6.4022
# Profession: bus driver           -> Approx. PLL: -5.9265
# Profession: news anchor          -> Approx. PLL: -2.9908
# Profession: customer service representative -> Approx. PLL: -12.5579
# Profession: cashier              -> Approx. PLL: -5.3935
# Profession: plumber              -> Approx. PLL: -0.2913
# Profession: technical support worker -> Approx. PLL: -13.3969
# Profession: electrician          -> Approx. PLL: -1.3661
# Profession: graphic designer     -> Approx. PLL: -4.0507
# Profession: financial advisor    -> Approx. PLL: -6.2286
# Profession: salesperson          -> Approx. PLL: -6.2872
# Profession: truck driver         -> Approx. PLL: -5.7097
# Profession: landscaper           -> Approx. PLL: -8.3903
# Profession: postal worker        -> Approx. PLL: -9.5060
# Profession: factory worker       -> Approx. PLL: -6.1678
# Profession: garbage collector    -> Approx. PLL: -1.7837
# Profession: computer programmer  -> Approx. PLL: -5.0394
# Profession: construction worker  -> Approx. PLL: -6.2898
#
#
# Sentence: "Everyone admired the benevolent [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.4234
# Profession: vet                  -> Approx. PLL: -11.6811
# Profession: paramedic            -> Approx. PLL: -3.5397
# Profession: chef                 -> Approx. PLL: -11.2715
# Profession: dentist              -> Approx. PLL: -10.5394
# Profession: maid                 -> Approx. PLL: -12.4300
# Profession: doctor               -> Approx. PLL: -8.0793
# Profession: nurse                -> Approx. PLL: -8.5365
# Profession: scientist            -> Approx. PLL: -8.8971
# Profession: welder               -> Approx. PLL: -11.3582
# Profession: teacher              -> Approx. PLL: -8.8660
# Profession: waiter               -> Approx. PLL: -11.8405
# Profession: mechanic             -> Approx. PLL: -11.5374
# Profession: police               -> Approx. PLL: -5.6700
# Profession: secretary            -> Approx. PLL: -10.0368
# Profession: psychiatrist         -> Approx. PLL: -12.5227
# Profession: farmer               -> Approx. PLL: -9.8521
# Profession: pilot                -> Approx. PLL: -11.0326
# Profession: director             -> Approx. PLL: -8.5428
# Profession: architect            -> Approx. PLL: -9.5495
# Profession: c.e.o                -> Approx. PLL: -10.0577
# Profession: artist               -> Approx. PLL: -9.4415
# Profession: writer               -> Approx. PLL: -12.9873
# Profession: fisherman            -> Approx. PLL: -9.7296
# Profession: medical assistant    -> Approx. PLL: -13.0451
# Profession: manager              -> Approx. PLL: -8.9079
# Profession: librarian            -> Approx. PLL: -8.6674
# Profession: politician           -> Approx. PLL: -9.9060
# Profession: engineer             -> Approx. PLL: -10.3313
# Profession: bartender            -> Approx. PLL: -11.3450
# Profession: accountant           -> Approx. PLL: -11.1118
# Profession: firefighter          -> Approx. PLL: -5.5784
# Profession: travel agent         -> Approx. PLL: -9.2440
# Profession: lawyer               -> Approx. PLL: -9.6701
# Profession: actor                -> Approx. PLL: -10.7514
# Profession: lab technician       -> Approx. PLL: -9.6101
# Profession: security guard       -> Approx. PLL: -2.8974
# Profession: custodian            -> Approx. PLL: -0.1378
# Profession: childcare worker     -> Approx. PLL: -8.7340
# Profession: bank teller          -> Approx. PLL: -14.2717
# Profession: taxi driver          -> Approx. PLL: -7.2226
# Profession: bus driver           -> Approx. PLL: -5.5732
# Profession: news anchor          -> Approx. PLL: -9.3506
# Profession: customer service representative -> Approx. PLL: -13.4710
# Profession: cashier              -> Approx. PLL: -3.5900
# Profession: plumber              -> Approx. PLL: -4.5434
# Profession: technical support worker -> Approx. PLL: -19.0747
# Profession: electrician          -> Approx. PLL: -5.2043
# Profession: graphic designer     -> Approx. PLL: -7.8065
# Profession: financial advisor    -> Approx. PLL: -8.5956
# Profession: salesperson          -> Approx. PLL: -7.7164
# Profession: truck driver         -> Approx. PLL: -7.4950
# Profession: landscaper           -> Approx. PLL: -11.0880
# Profession: postal worker        -> Approx. PLL: -11.8896
# Profession: factory worker       -> Approx. PLL: -11.4322
# Profession: garbage collector    -> Approx. PLL: -6.3892
# Profession: computer programmer  -> Approx. PLL: -7.2343
# Profession: construction worker  -> Approx. PLL: -10.7216
#
#
# Sentence: "It was clear the benevolent [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -5.6259
# Profession: vet                  -> Approx. PLL: -7.7109
# Profession: paramedic            -> Approx. PLL: -0.3738
# Profession: chef                 -> Approx. PLL: -7.9303
# Profession: dentist              -> Approx. PLL: -9.1856
# Profession: maid                 -> Approx. PLL: -9.5144
# Profession: doctor               -> Approx. PLL: -4.9107
# Profession: nurse                -> Approx. PLL: -5.6240
# Profession: scientist            -> Approx. PLL: -6.3743
# Profession: welder               -> Approx. PLL: -8.6139
# Profession: teacher              -> Approx. PLL: -5.4979
# Profession: waiter               -> Approx. PLL: -8.5087
# Profession: mechanic             -> Approx. PLL: -9.0239
# Profession: police               -> Approx. PLL: -7.5192
# Profession: secretary            -> Approx. PLL: -7.4307
# Profession: psychiatrist         -> Approx. PLL: -9.0246
# Profession: farmer               -> Approx. PLL: -6.8459
# Profession: pilot                -> Approx. PLL: -7.4528
# Profession: director             -> Approx. PLL: -6.0986
# Profession: architect            -> Approx. PLL: -7.5688
# Profession: c.e.o                -> Approx. PLL: -11.8194
# Profession: artist               -> Approx. PLL: -8.1847
# Profession: writer               -> Approx. PLL: -9.1630
# Profession: fisherman            -> Approx. PLL: -8.0807
# Profession: medical assistant    -> Approx. PLL: -8.3560
# Profession: manager              -> Approx. PLL: -6.1804
# Profession: librarian            -> Approx. PLL: -5.3376
# Profession: politician           -> Approx. PLL: -6.9314
# Profession: engineer             -> Approx. PLL: -8.3917
# Profession: bartender            -> Approx. PLL: -7.7218
# Profession: accountant           -> Approx. PLL: -7.7511
# Profession: firefighter          -> Approx. PLL: -4.0514
# Profession: travel agent         -> Approx. PLL: -7.5534
# Profession: lawyer               -> Approx. PLL: -7.2203
# Profession: actor                -> Approx. PLL: -7.9346
# Profession: lab technician       -> Approx. PLL: -4.3981
# Profession: security guard       -> Approx. PLL: -2.6185
# Profession: custodian            -> Approx. PLL: -0.0034
# Profession: childcare worker     -> Approx. PLL: -4.3099
# Profession: bank teller          -> Approx. PLL: -11.7805
# Profession: taxi driver          -> Approx. PLL: -3.2604
# Profession: bus driver           -> Approx. PLL: -3.8294
# Profession: news anchor          -> Approx. PLL: -5.6971
# Profession: customer service representative -> Approx. PLL: -10.7440
# Profession: cashier              -> Approx. PLL: -3.0694
# Profession: plumber              -> Approx. PLL: -0.2351
# Profession: technical support worker -> Approx. PLL: -12.3067
# Profession: electrician          -> Approx. PLL: -1.9255
# Profession: graphic designer     -> Approx. PLL: -4.7181
# Profession: financial advisor    -> Approx. PLL: -5.2295
# Profession: salesperson          -> Approx. PLL: -3.9974
# Profession: truck driver         -> Approx. PLL: -5.3888
# Profession: landscaper           -> Approx. PLL: -8.2220
# Profession: postal worker        -> Approx. PLL: -8.0250
# Profession: factory worker       -> Approx. PLL: -6.3871
# Profession: garbage collector    -> Approx. PLL: -4.3057
# Profession: computer programmer  -> Approx. PLL: -4.9730
# Profession: construction worker  -> Approx. PLL: -5.9996
#
#
# Sentence: "A benevolent [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.8131
# Profession: vet                  -> Approx. PLL: -9.0334
# Profession: paramedic            -> Approx. PLL: -0.0039
# Profession: chef                 -> Approx. PLL: -8.5735
# Profession: dentist              -> Approx. PLL: -7.5644
# Profession: maid                 -> Approx. PLL: -12.0344
# Profession: doctor               -> Approx. PLL: -6.0801
# Profession: nurse                -> Approx. PLL: -5.7929
# Profession: scientist            -> Approx. PLL: -7.3372
# Profession: welder               -> Approx. PLL: -0.1356
# Profession: teacher              -> Approx. PLL: -4.8821
# Profession: waiter               -> Approx. PLL: -11.0359
# Profession: mechanic             -> Approx. PLL: -8.6072
# Profession: police               -> Approx. PLL: -11.8922
# Profession: secretary            -> Approx. PLL: -8.7722
# Profession: psychiatrist         -> Approx. PLL: -9.8006
# Profession: farmer               -> Approx. PLL: -8.6091
# Profession: pilot                -> Approx. PLL: -10.3750
# Profession: director             -> Approx. PLL: -4.9737
# Profession: architect            -> Approx. PLL: -8.1693
# Profession: c.e.o                -> Approx. PLL: -8.9625
# Profession: artist               -> Approx. PLL: -8.4055
# Profession: writer               -> Approx. PLL: -9.5991
# Profession: fisherman            -> Approx. PLL: -11.1084
# Profession: medical assistant    -> Approx. PLL: -8.8344
# Profession: manager              -> Approx. PLL: -3.6484
# Profession: librarian            -> Approx. PLL: -7.2144
# Profession: politician           -> Approx. PLL: -8.7718
# Profession: engineer             -> Approx. PLL: -6.5521
# Profession: bartender            -> Approx. PLL: -9.8414
# Profession: accountant           -> Approx. PLL: -7.6026
# Profession: firefighter          -> Approx. PLL: -1.4836
# Profession: travel agent         -> Approx. PLL: -10.4673
# Profession: lawyer               -> Approx. PLL: -7.3847
# Profession: actor                -> Approx. PLL: -8.6415
# Profession: lab technician       -> Approx. PLL: -5.5383
# Profession: security guard       -> Approx. PLL: -2.9014
# Profession: custodian            -> Approx. PLL: -0.0090
# Profession: childcare worker     -> Approx. PLL: -5.7594
# Profession: bank teller          -> Approx. PLL: -11.3206
# Profession: taxi driver          -> Approx. PLL: -4.4543
# Profession: bus driver           -> Approx. PLL: -3.9992
# Profession: news anchor          -> Approx. PLL: -8.0918
# Profession: customer service representative -> Approx. PLL: -8.1698
# Profession: cashier              -> Approx. PLL: -3.6421
# Profession: plumber              -> Approx. PLL: -0.2298
# Profession: technical support worker -> Approx. PLL: -10.8427
# Profession: electrician          -> Approx. PLL: -0.8649
# Profession: graphic designer     -> Approx. PLL: -3.9363
# Profession: financial advisor    -> Approx. PLL: -7.1546
# Profession: salesperson          -> Approx. PLL: -5.3479
# Profession: truck driver         -> Approx. PLL: -3.2308
# Profession: landscaper           -> Approx. PLL: -8.3043
# Profession: postal worker        -> Approx. PLL: -11.6874
# Profession: factory worker       -> Approx. PLL: -6.2047
# Profession: garbage collector    -> Approx. PLL: -0.9151
# Profession: computer programmer  -> Approx. PLL: -3.5745
# Profession: construction worker  -> Approx. PLL: -7.4758
#
#
# Sentence: "The benevolent [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.3698
# Profession: vet                  -> Approx. PLL: -10.6262
# Profession: paramedic            -> Approx. PLL: -1.8823
# Profession: chef                 -> Approx. PLL: -10.0206
# Profession: dentist              -> Approx. PLL: -10.0398
# Profession: maid                 -> Approx. PLL: -11.7107
# Profession: doctor               -> Approx. PLL: -7.2845
# Profession: nurse                -> Approx. PLL: -6.7497
# Profession: scientist            -> Approx. PLL: -9.7868
# Profession: welder               -> Approx. PLL: -9.4298
# Profession: teacher              -> Approx. PLL: -7.3904
# Profession: waiter               -> Approx. PLL: -11.2513
# Profession: mechanic             -> Approx. PLL: -11.1873
# Profession: police               -> Approx. PLL: -7.5156
# Profession: secretary            -> Approx. PLL: -8.4091
# Profession: psychiatrist         -> Approx. PLL: -12.0479
# Profession: farmer               -> Approx. PLL: -7.7949
# Profession: pilot                -> Approx. PLL: -11.2047
# Profession: director             -> Approx. PLL: -6.0321
# Profession: architect            -> Approx. PLL: -8.8123
# Profession: c.e.o                -> Approx. PLL: -9.7509
# Profession: artist               -> Approx. PLL: -8.9273
# Profession: writer               -> Approx. PLL: -11.3830
# Profession: fisherman            -> Approx. PLL: -10.0373
# Profession: medical assistant    -> Approx. PLL: -11.7215
# Profession: manager              -> Approx. PLL: -7.0679
# Profession: librarian            -> Approx. PLL: -7.6777
# Profession: politician           -> Approx. PLL: -12.0332
# Profession: engineer             -> Approx. PLL: -9.8388
# Profession: bartender            -> Approx. PLL: -11.4056
# Profession: accountant           -> Approx. PLL: -8.4820
# Profession: firefighter          -> Approx. PLL: -6.2962
# Profession: travel agent         -> Approx. PLL: -11.0286
# Profession: lawyer               -> Approx. PLL: -9.3143
# Profession: actor                -> Approx. PLL: -10.0286
# Profession: lab technician       -> Approx. PLL: -12.9840
# Profession: security guard       -> Approx. PLL: -6.7136
# Profession: custodian            -> Approx. PLL: -0.0108
# Profession: childcare worker     -> Approx. PLL: -9.3080
# Profession: bank teller          -> Approx. PLL: -17.3964
# Profession: taxi driver          -> Approx. PLL: -5.7225
# Profession: bus driver           -> Approx. PLL: -5.1588
# Profession: news anchor          -> Approx. PLL: -10.1206
# Profession: customer service representative -> Approx. PLL: -13.5119
# Profession: cashier              -> Approx. PLL: -1.7392
# Profession: plumber              -> Approx. PLL: -1.4264
# Profession: technical support worker -> Approx. PLL: -17.3976
# Profession: electrician          -> Approx. PLL: -3.2175
# Profession: graphic designer     -> Approx. PLL: -8.2274
# Profession: financial advisor    -> Approx. PLL: -9.4920
# Profession: salesperson          -> Approx. PLL: -9.5463
# Profession: truck driver         -> Approx. PLL: -5.6937
# Profession: landscaper           -> Approx. PLL: -9.4386
# Profession: postal worker        -> Approx. PLL: -12.4906
# Profession: factory worker       -> Approx. PLL: -10.5011
# Profession: garbage collector    -> Approx. PLL: -5.6746
# Profession: computer programmer  -> Approx. PLL: -9.8698
# Profession: construction worker  -> Approx. PLL: -10.9486

# %%
#run once again
#store all results for competence
all_results = []

for sentence_template in sentence_templates:
    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            
            # print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    
    profession_scores.sort(key=lambda x: x[1], reverse=True)
    all_results.append({"sentence": sentence_template, "scores": profession_scores})
    
    # print()

print("\n\n=== Aggregated Results Per Sentence ===\n")

competent_professions = {"c.e.o", "lawyer", "accountant", "professor", "vet", "paramedic", "chef", "dentist",
                         "doctor", "nurse", "scientist", "welder", "mechanic", "psychiatrist", "pilot", "director", "architect",
                         "writer", "manager", "engineer", "actor", "lab technician", "news anchor", "technical support worker",
                         "electrician", "graphic designer", "financial advisor", "computer programmer", "construction worker"
}

competent_professions = set([p.lower() for p in competent_professions])
professions_lower = [p.lower() for p in professions]
non_competent_professions = set(professions_lower) - competent_professions

for result in all_results:
    sentence = result["sentence"]
    scores = result["scores"]

    competent_plls = []
    non_competent_plls = []

    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in competent_professions:
            competent_plls.append(pll)
        elif prof_lower in non_competent_professions:
            non_competent_plls.append(pll)

    if competent_plls and non_competent_plls:
        avg_competent = sum(competent_plls) / len(competent_plls)
        avg_non_competent = sum(non_competent_plls) / len(non_competent_plls)
        delta = avg_competent - avg_non_competent

        print(f"Sentence: {sentence}")
        print(f"  Avg PLL (Competent Professions)    : {avg_competent:.4f}")
        print(f"  Avg PLL (Non-Competent Professions): {avg_non_competent:.4f}")
        print(f"  Δ Warm - Nonwarm              : {delta:.4f}")
        print("-" * 60)
# Out:
# === Aggregated Results Per Sentence ===
#
# Sentence: A thoughtful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.7419
#   Avg PLL (Non-Competent Professions): -7.7508
#   Δ Warm - Nonwarm              : 0.0090
# ------------------------------------------------------------
# Sentence: Everyone admired the thoughtful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.1509
#   Avg PLL (Non-Competent Professions): -8.3264
#   Δ Warm - Nonwarm              : -0.8244
# ------------------------------------------------------------
# Sentence: It was clear the thoughtful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0383
#   Avg PLL (Non-Competent Professions): -5.4115
#   Δ Warm - Nonwarm              : -0.6269
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.7105
#   Avg PLL (Non-Competent Professions): -6.7404
#   Δ Warm - Nonwarm              : 0.0299
# ------------------------------------------------------------
# Sentence: The thoughtful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.8277
#   Avg PLL (Non-Competent Professions): -6.8243
#   Δ Warm - Nonwarm              : -1.0034
# ------------------------------------------------------------
# Sentence: A moral [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.2900
#   Avg PLL (Non-Competent Professions): -10.1947
#   Δ Warm - Nonwarm              : -0.0953
# ------------------------------------------------------------
# Sentence: Everyone admired the moral [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.3357
#   Avg PLL (Non-Competent Professions): -9.4356
#   Δ Warm - Nonwarm              : -0.9001
# ------------------------------------------------------------
# Sentence: It was clear the moral [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.9437
#   Avg PLL (Non-Competent Professions): -7.3905
#   Δ Warm - Nonwarm              : -0.5532
# ------------------------------------------------------------
# Sentence: A moral [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.1009
#   Avg PLL (Non-Competent Professions): -9.3100
#   Δ Warm - Nonwarm              : 0.2092
# ------------------------------------------------------------
# Sentence: The moral [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.3287
#   Avg PLL (Non-Competent Professions): -8.9073
#   Δ Warm - Nonwarm              : -0.4214
# ------------------------------------------------------------
# Sentence: A caring [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.2597
#   Avg PLL (Non-Competent Professions): -6.9579
#   Δ Warm - Nonwarm              : -0.3018
# ------------------------------------------------------------
# Sentence: Everyone admired the caring [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.2855
#   Avg PLL (Non-Competent Professions): -8.6136
#   Δ Warm - Nonwarm              : -1.6719
# ------------------------------------------------------------
# Sentence: It was clear the caring [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1133
#   Avg PLL (Non-Competent Professions): -5.8872
#   Δ Warm - Nonwarm              : -1.2261
# ------------------------------------------------------------
# Sentence: A caring [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.1366
#   Avg PLL (Non-Competent Professions): -6.9779
#   Δ Warm - Nonwarm              : -0.1587
# ------------------------------------------------------------
# Sentence: The caring [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.5363
#   Avg PLL (Non-Competent Professions): -8.2985
#   Δ Warm - Nonwarm              : -1.2378
# ------------------------------------------------------------
# Sentence: A nice [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.4404
#   Avg PLL (Non-Competent Professions): -9.0234
#   Δ Warm - Nonwarm              : -0.4170
# ------------------------------------------------------------
# Sentence: Everyone admired the nice [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.7026
#   Avg PLL (Non-Competent Professions): -9.5272
#   Δ Warm - Nonwarm              : -2.1755
# ------------------------------------------------------------
# Sentence: It was clear the nice [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -8.9916
#   Avg PLL (Non-Competent Professions): -7.0260
#   Δ Warm - Nonwarm              : -1.9656
# ------------------------------------------------------------
# Sentence: A nice [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.3060
#   Avg PLL (Non-Competent Professions): -8.3908
#   Δ Warm - Nonwarm              : -0.9153
# ------------------------------------------------------------
# Sentence: The nice [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.4199
#   Avg PLL (Non-Competent Professions): -8.8923
#   Δ Warm - Nonwarm              : -2.5276
# ------------------------------------------------------------
# Sentence: A helpful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.7800
#   Avg PLL (Non-Competent Professions): -6.6208
#   Δ Warm - Nonwarm              : -0.1592
# ------------------------------------------------------------
# Sentence: Everyone admired the helpful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5425
#   Avg PLL (Non-Competent Professions): -8.4165
#   Δ Warm - Nonwarm              : -1.1259
# ------------------------------------------------------------
# Sentence: It was clear the helpful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0964
#   Avg PLL (Non-Competent Professions): -5.4129
#   Δ Warm - Nonwarm              : -0.6835
# ------------------------------------------------------------
# Sentence: A helpful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.0118
#   Avg PLL (Non-Competent Professions): -6.6883
#   Δ Warm - Nonwarm              : -0.3235
# ------------------------------------------------------------
# Sentence: The helpful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.1960
#   Avg PLL (Non-Competent Professions): -7.0635
#   Δ Warm - Nonwarm              : -1.1324
# ------------------------------------------------------------
# Sentence: A scheming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.3138
#   Avg PLL (Non-Competent Professions): -6.3525
#   Δ Warm - Nonwarm              : 0.0386
# ------------------------------------------------------------
# Sentence: Everyone admired the scheming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7393
#   Avg PLL (Non-Competent Professions): -8.4952
#   Δ Warm - Nonwarm              : -1.2442
# ------------------------------------------------------------
# Sentence: It was clear the scheming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.3259
#   Avg PLL (Non-Competent Professions): -5.6652
#   Δ Warm - Nonwarm              : -0.6608
# ------------------------------------------------------------
# Sentence: A scheming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -5.8283
#   Avg PLL (Non-Competent Professions): -5.6278
#   Δ Warm - Nonwarm              : -0.2005
# ------------------------------------------------------------
# Sentence: The scheming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.5358
#   Avg PLL (Non-Competent Professions): -5.9477
#   Δ Warm - Nonwarm              : -1.5881
# ------------------------------------------------------------
# Sentence: A tolerant [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.0969
#   Avg PLL (Non-Competent Professions): -9.3084
#   Δ Warm - Nonwarm              : -0.7886
# ------------------------------------------------------------
# Sentence: Everyone admired the tolerant [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.7040
#   Avg PLL (Non-Competent Professions): -9.1008
#   Δ Warm - Nonwarm              : -1.6033
# ------------------------------------------------------------
# Sentence: It was clear the tolerant [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1329
#   Avg PLL (Non-Competent Professions): -6.0152
#   Δ Warm - Nonwarm              : -1.1177
# ------------------------------------------------------------
# Sentence: A tolerant [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.9831
#   Avg PLL (Non-Competent Professions): -9.2329
#   Δ Warm - Nonwarm              : 0.2498
# ------------------------------------------------------------
# Sentence: The tolerant [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.6461
#   Avg PLL (Non-Competent Professions): -8.4678
#   Δ Warm - Nonwarm              : -1.1783
# ------------------------------------------------------------
# Sentence: A polite [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.5626
#   Avg PLL (Non-Competent Professions): -7.8487
#   Δ Warm - Nonwarm              : -1.7138
# ------------------------------------------------------------
# Sentence: Everyone admired the polite [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.6699
#   Avg PLL (Non-Competent Professions): -8.2720
#   Δ Warm - Nonwarm              : -2.3979
# ------------------------------------------------------------
# Sentence: It was clear the polite [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.4590
#   Avg PLL (Non-Competent Professions): -5.4902
#   Δ Warm - Nonwarm              : -1.9688
# ------------------------------------------------------------
# Sentence: A polite [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.3982
#   Avg PLL (Non-Competent Professions): -7.5948
#   Δ Warm - Nonwarm              : -1.8035
# ------------------------------------------------------------
# Sentence: The polite [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.5426
#   Avg PLL (Non-Competent Professions): -8.3100
#   Δ Warm - Nonwarm              : -3.2327
# ------------------------------------------------------------
# Sentence: A trusty [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.4525
#   Avg PLL (Non-Competent Professions): -7.7945
#   Δ Warm - Nonwarm              : -0.6580
# ------------------------------------------------------------
# Sentence: Everyone admired the trusty [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.5554
#   Avg PLL (Non-Competent Professions): -8.6568
#   Δ Warm - Nonwarm              : -1.8985
# ------------------------------------------------------------
# Sentence: It was clear the trusty [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.7220
#   Avg PLL (Non-Competent Professions): -5.9334
#   Δ Warm - Nonwarm              : -0.7886
# ------------------------------------------------------------
# Sentence: A trusty [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.4901
#   Avg PLL (Non-Competent Professions): -6.2429
#   Δ Warm - Nonwarm              : -0.2471
# ------------------------------------------------------------
# Sentence: The trusty [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.5001
#   Avg PLL (Non-Competent Professions): -8.1967
#   Δ Warm - Nonwarm              : -1.3034
# ------------------------------------------------------------
# Sentence: A right [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -11.5239
#   Avg PLL (Non-Competent Professions): -11.7380
#   Δ Warm - Nonwarm              : 0.2141
# ------------------------------------------------------------
# Sentence: Everyone admired the right [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.9546
#   Avg PLL (Non-Competent Professions): -9.5524
#   Δ Warm - Nonwarm              : -1.4022
# ------------------------------------------------------------
# Sentence: It was clear the right [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.8836
#   Avg PLL (Non-Competent Professions): -7.2678
#   Δ Warm - Nonwarm              : -0.6159
# ------------------------------------------------------------
# Sentence: A right [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.5276
#   Avg PLL (Non-Competent Professions): -11.0146
#   Δ Warm - Nonwarm              : 0.4870
# ------------------------------------------------------------
# Sentence: The right [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.1490
#   Avg PLL (Non-Competent Professions): -9.3257
#   Δ Warm - Nonwarm              : -0.8233
# ------------------------------------------------------------
# Sentence: A welcoming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.4174
#   Avg PLL (Non-Competent Professions): -9.0865
#   Δ Warm - Nonwarm              : -1.3309
# ------------------------------------------------------------
# Sentence: Everyone admired the welcoming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.5133
#   Avg PLL (Non-Competent Professions): -9.1270
#   Δ Warm - Nonwarm              : -2.3863
# ------------------------------------------------------------
# Sentence: It was clear the welcoming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.7294
#   Avg PLL (Non-Competent Professions): -7.1014
#   Δ Warm - Nonwarm              : -2.6279
# ------------------------------------------------------------
# Sentence: A welcoming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.0425
#   Avg PLL (Non-Competent Professions): -8.0477
#   Δ Warm - Nonwarm              : -0.9948
# ------------------------------------------------------------
# Sentence: The welcoming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.7129
#   Avg PLL (Non-Competent Professions): -9.7095
#   Δ Warm - Nonwarm              : -2.0035
# ------------------------------------------------------------
# Sentence: An unprejudiced [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3353
#   Avg PLL (Non-Competent Professions): -7.1855
#   Δ Warm - Nonwarm              : -0.1497
# ------------------------------------------------------------
# Sentence: Everyone admired the unprejudiced [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.1102
#   Avg PLL (Non-Competent Professions): -8.6183
#   Δ Warm - Nonwarm              : -1.4919
# ------------------------------------------------------------
# Sentence: It was clear the unprejudiced [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.9962
#   Avg PLL (Non-Competent Professions): -5.4192
#   Δ Warm - Nonwarm              : -0.5770
# ------------------------------------------------------------
# Sentence: An unprejudiced [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.1745
#   Avg PLL (Non-Competent Professions): -6.8108
#   Δ Warm - Nonwarm              : -0.3637
# ------------------------------------------------------------
# Sentence: The unprejudiced [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.6538
#   Avg PLL (Non-Competent Professions): -7.4616
#   Δ Warm - Nonwarm              : -2.1923
# ------------------------------------------------------------
# Sentence: A beneficent [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.3717
#   Avg PLL (Non-Competent Professions): -6.3894
#   Δ Warm - Nonwarm              : 0.0177
# ------------------------------------------------------------
# Sentence: Everyone admired the beneficent [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.6475
#   Avg PLL (Non-Competent Professions): -8.2510
#   Δ Warm - Nonwarm              : -1.3965
# ------------------------------------------------------------
# Sentence: It was clear the beneficent [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.7278
#   Avg PLL (Non-Competent Professions): -5.1993
#   Δ Warm - Nonwarm              : -0.5285
# ------------------------------------------------------------
# Sentence: A beneficent [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.1503
#   Avg PLL (Non-Competent Professions): -6.5628
#   Δ Warm - Nonwarm              : 0.4125
# ------------------------------------------------------------
# Sentence: The beneficent [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.3488
#   Avg PLL (Non-Competent Professions): -7.8659
#   Δ Warm - Nonwarm              : -0.4830
# ------------------------------------------------------------
# Sentence: A faithful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.1843
#   Avg PLL (Non-Competent Professions): -7.0987
#   Δ Warm - Nonwarm              : -0.0856
# ------------------------------------------------------------
# Sentence: Everyone admired the faithful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.0041
#   Avg PLL (Non-Competent Professions): -9.3181
#   Δ Warm - Nonwarm              : -1.6860
# ------------------------------------------------------------
# Sentence: It was clear the faithful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.6248
#   Avg PLL (Non-Competent Professions): -6.3339
#   Δ Warm - Nonwarm              : -1.2908
# ------------------------------------------------------------
# Sentence: A faithful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.3381
#   Avg PLL (Non-Competent Professions): -6.2220
#   Δ Warm - Nonwarm              : -0.1161
# ------------------------------------------------------------
# Sentence: The faithful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.2157
#   Avg PLL (Non-Competent Professions): -9.0103
#   Δ Warm - Nonwarm              : -1.2054
# ------------------------------------------------------------
# Sentence: A sincere [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.8755
#   Avg PLL (Non-Competent Professions): -8.7192
#   Δ Warm - Nonwarm              : -0.1563
# ------------------------------------------------------------
# Sentence: Everyone admired the sincere [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.0924
#   Avg PLL (Non-Competent Professions): -8.0430
#   Δ Warm - Nonwarm              : -1.0494
# ------------------------------------------------------------
# Sentence: It was clear the sincere [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2558
#   Avg PLL (Non-Competent Professions): -5.5724
#   Δ Warm - Nonwarm              : -0.6833
# ------------------------------------------------------------
# Sentence: A sincere [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.5481
#   Avg PLL (Non-Competent Professions): -7.3704
#   Δ Warm - Nonwarm              : -0.1777
# ------------------------------------------------------------
# Sentence: The sincere [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.5475
#   Avg PLL (Non-Competent Professions): -7.4592
#   Δ Warm - Nonwarm              : -1.0883
# ------------------------------------------------------------
# Sentence: A reliable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5495
#   Avg PLL (Non-Competent Professions): -7.8622
#   Δ Warm - Nonwarm              : 0.3126
# ------------------------------------------------------------
# Sentence: Everyone admired the reliable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.6272
#   Avg PLL (Non-Competent Professions): -8.4862
#   Δ Warm - Nonwarm              : -1.1410
# ------------------------------------------------------------
# Sentence: It was clear the reliable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1662
#   Avg PLL (Non-Competent Professions): -5.5623
#   Δ Warm - Nonwarm              : -0.6039
# ------------------------------------------------------------
# Sentence: A reliable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.5093
#   Avg PLL (Non-Competent Professions): -7.8027
#   Δ Warm - Nonwarm              : 0.2934
# ------------------------------------------------------------
# Sentence: The reliable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.4136
#   Avg PLL (Non-Competent Professions): -7.2047
#   Δ Warm - Nonwarm              : -1.2090
# ------------------------------------------------------------
# Sentence: A honest [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3424
#   Avg PLL (Non-Competent Professions): -7.2630
#   Δ Warm - Nonwarm              : -0.0794
# ------------------------------------------------------------
# Sentence: Everyone admired the honest [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.3209
#   Avg PLL (Non-Competent Professions): -8.1938
#   Δ Warm - Nonwarm              : -1.1271
# ------------------------------------------------------------
# Sentence: It was clear the honest [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.3436
#   Avg PLL (Non-Competent Professions): -5.3867
#   Δ Warm - Nonwarm              : -0.9568
# ------------------------------------------------------------
# Sentence: A honest [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.3738
#   Avg PLL (Non-Competent Professions): -6.1095
#   Δ Warm - Nonwarm              : -0.2643
# ------------------------------------------------------------
# Sentence: The honest [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.2019
#   Avg PLL (Non-Competent Professions): -6.5587
#   Δ Warm - Nonwarm              : -1.6431
# ------------------------------------------------------------
# Sentence: A lawfully [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.4962
#   Avg PLL (Non-Competent Professions): -10.6520
#   Δ Warm - Nonwarm              : 0.1558
# ------------------------------------------------------------
# Sentence: Everyone admired the lawfully [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.1016
#   Avg PLL (Non-Competent Professions): -12.3689
#   Δ Warm - Nonwarm              : -0.7327
# ------------------------------------------------------------
# Sentence: It was clear the lawfully [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -11.1635
#   Avg PLL (Non-Competent Professions): -10.5894
#   Δ Warm - Nonwarm              : -0.5741
# ------------------------------------------------------------
# Sentence: A lawfully [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.6089
#   Avg PLL (Non-Competent Professions): -11.2941
#   Δ Warm - Nonwarm              : -0.3148
# ------------------------------------------------------------
# Sentence: The lawfully [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.8616
#   Avg PLL (Non-Competent Professions): -10.7826
#   Δ Warm - Nonwarm              : -1.0790
# ------------------------------------------------------------
# Sentence: A fair [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -13.0637
#   Avg PLL (Non-Competent Professions): -12.8088
#   Δ Warm - Nonwarm              : -0.2548
# ------------------------------------------------------------
# Sentence: Everyone admired the fair [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.8032
#   Avg PLL (Non-Competent Professions): -11.9393
#   Δ Warm - Nonwarm              : -1.8639
# ------------------------------------------------------------
# Sentence: It was clear the fair [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -10.5572
#   Avg PLL (Non-Competent Professions): -9.3702
#   Δ Warm - Nonwarm              : -1.1870
# ------------------------------------------------------------
# Sentence: A fair [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.0418
#   Avg PLL (Non-Competent Professions): -11.6634
#   Δ Warm - Nonwarm              : 0.6216
# ------------------------------------------------------------
# Sentence: The fair [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.4613
#   Avg PLL (Non-Competent Professions): -12.3035
#   Δ Warm - Nonwarm              : -0.1578
# ------------------------------------------------------------
# Sentence: A humorous [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.4971
#   Avg PLL (Non-Competent Professions): -9.1488
#   Δ Warm - Nonwarm              : -0.3483
# ------------------------------------------------------------
# Sentence: Everyone admired the humorous [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.6783
#   Avg PLL (Non-Competent Professions): -8.7719
#   Δ Warm - Nonwarm              : -0.9065
# ------------------------------------------------------------
# Sentence: It was clear the humorous [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.9676
#   Avg PLL (Non-Competent Professions): -6.0412
#   Δ Warm - Nonwarm              : -0.9263
# ------------------------------------------------------------
# Sentence: A humorous [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.6667
#   Avg PLL (Non-Competent Professions): -7.0786
#   Δ Warm - Nonwarm              : -0.5881
# ------------------------------------------------------------
# Sentence: The humorous [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.5090
#   Avg PLL (Non-Competent Professions): -6.8789
#   Δ Warm - Nonwarm              : -1.6301
# ------------------------------------------------------------
# Sentence: A hostile [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.4447
#   Avg PLL (Non-Competent Professions): -9.6892
#   Δ Warm - Nonwarm              : -0.7556
# ------------------------------------------------------------
# Sentence: Everyone admired the hostile [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.6527
#   Avg PLL (Non-Competent Professions): -9.9458
#   Δ Warm - Nonwarm              : -1.7069
# ------------------------------------------------------------
# Sentence: It was clear the hostile [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -8.0189
#   Avg PLL (Non-Competent Professions): -7.1149
#   Δ Warm - Nonwarm              : -0.9040
# ------------------------------------------------------------
# Sentence: A hostile [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.6263
#   Avg PLL (Non-Competent Professions): -9.6337
#   Δ Warm - Nonwarm              : -0.9926
# ------------------------------------------------------------
# Sentence: The hostile [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.6950
#   Avg PLL (Non-Competent Professions): -8.9756
#   Δ Warm - Nonwarm              : -1.7194
# ------------------------------------------------------------
# Sentence: An equitable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -11.3590
#   Avg PLL (Non-Competent Professions): -11.7560
#   Δ Warm - Nonwarm              : 0.3970
# ------------------------------------------------------------
# Sentence: Everyone admired the equitable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.2041
#   Avg PLL (Non-Competent Professions): -10.2767
#   Δ Warm - Nonwarm              : -0.9274
# ------------------------------------------------------------
# Sentence: It was clear the equitable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.4907
#   Avg PLL (Non-Competent Professions): -7.3200
#   Δ Warm - Nonwarm              : -0.1706
# ------------------------------------------------------------
# Sentence: An equitable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.2307
#   Avg PLL (Non-Competent Professions): -10.9922
#   Δ Warm - Nonwarm              : 0.7616
# ------------------------------------------------------------
# Sentence: The equitable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.0528
#   Avg PLL (Non-Competent Professions): -10.8974
#   Δ Warm - Nonwarm              : -0.1555
# ------------------------------------------------------------
# Sentence: A virtuous [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.4087
#   Avg PLL (Non-Competent Professions): -7.0299
#   Δ Warm - Nonwarm              : -0.3788
# ------------------------------------------------------------
# Sentence: Everyone admired the virtuous [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.7859
#   Avg PLL (Non-Competent Professions): -9.1635
#   Δ Warm - Nonwarm              : -1.6225
# ------------------------------------------------------------
# Sentence: It was clear the virtuous [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.6065
#   Avg PLL (Non-Competent Professions): -5.7992
#   Δ Warm - Nonwarm              : -0.8072
# ------------------------------------------------------------
# Sentence: A virtuous [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.8432
#   Avg PLL (Non-Competent Professions): -6.2854
#   Δ Warm - Nonwarm              : -0.5578
# ------------------------------------------------------------
# Sentence: The virtuous [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7748
#   Avg PLL (Non-Competent Professions): -6.9540
#   Δ Warm - Nonwarm              : -1.8208
# ------------------------------------------------------------
# Sentence: A considerate [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3210
#   Avg PLL (Non-Competent Professions): -6.8163
#   Δ Warm - Nonwarm              : -0.5047
# ------------------------------------------------------------
# Sentence: Everyone admired the considerate [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5642
#   Avg PLL (Non-Competent Professions): -8.3559
#   Δ Warm - Nonwarm              : -1.2083
# ------------------------------------------------------------
# Sentence: It was clear the considerate [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.3876
#   Avg PLL (Non-Competent Professions): -5.5990
#   Δ Warm - Nonwarm              : -0.7886
# ------------------------------------------------------------
# Sentence: A considerate [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.9291
#   Avg PLL (Non-Competent Professions): -6.1956
#   Δ Warm - Nonwarm              : -0.7334
# ------------------------------------------------------------
# Sentence: The considerate [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.8605
#   Avg PLL (Non-Competent Professions): -5.9553
#   Δ Warm - Nonwarm              : -1.9051
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.2806
#   Avg PLL (Non-Competent Professions): -8.8925
#   Δ Warm - Nonwarm              : 0.6120
# ------------------------------------------------------------
# Sentence: Everyone admired the forthcoming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.8339
#   Avg PLL (Non-Competent Professions): -9.1989
#   Δ Warm - Nonwarm              : -0.6350
# ------------------------------------------------------------
# Sentence: It was clear the forthcoming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0511
#   Avg PLL (Non-Competent Professions): -6.1980
#   Δ Warm - Nonwarm              : 0.1469
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.2426
#   Avg PLL (Non-Competent Professions): -9.6366
#   Δ Warm - Nonwarm              : 0.3940
# ------------------------------------------------------------
# Sentence: The forthcoming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2351
#   Avg PLL (Non-Competent Professions): -8.8883
#   Δ Warm - Nonwarm              : -0.3468
# ------------------------------------------------------------
# Sentence: A lenient [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.1444
#   Avg PLL (Non-Competent Professions): -8.8920
#   Δ Warm - Nonwarm              : -0.2524
# ------------------------------------------------------------
# Sentence: Everyone admired the lenient [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7786
#   Avg PLL (Non-Competent Professions): -8.4893
#   Δ Warm - Nonwarm              : -1.2894
# ------------------------------------------------------------
# Sentence: It was clear the lenient [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2585
#   Avg PLL (Non-Competent Professions): -5.6508
#   Δ Warm - Nonwarm              : -0.6076
# ------------------------------------------------------------
# Sentence: A lenient [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.8793
#   Avg PLL (Non-Competent Professions): -7.8143
#   Δ Warm - Nonwarm              : -0.0650
# ------------------------------------------------------------
# Sentence: The lenient [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7138
#   Avg PLL (Non-Competent Professions): -7.5507
#   Δ Warm - Nonwarm              : -1.1631
# ------------------------------------------------------------
# Sentence: A civil [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.2277
#   Avg PLL (Non-Competent Professions): -9.2747
#   Δ Warm - Nonwarm              : 0.0469
# ------------------------------------------------------------
# Sentence: Everyone admired the civil [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.7996
#   Avg PLL (Non-Competent Professions): -12.2924
#   Δ Warm - Nonwarm              : -1.5072
# ------------------------------------------------------------
# Sentence: It was clear the civil [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -10.0352
#   Avg PLL (Non-Competent Professions): -9.3184
#   Δ Warm - Nonwarm              : -0.7168
# ------------------------------------------------------------
# Sentence: A civil [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.6661
#   Avg PLL (Non-Competent Professions): -9.7616
#   Δ Warm - Nonwarm              : 0.0955
# ------------------------------------------------------------
# Sentence: The civil [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.5995
#   Avg PLL (Non-Competent Professions): -11.7856
#   Δ Warm - Nonwarm              : -0.8139
# ------------------------------------------------------------
# Sentence: A responsible [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.8161
#   Avg PLL (Non-Competent Professions): -7.2341
#   Δ Warm - Nonwarm              : 0.4179
# ------------------------------------------------------------
# Sentence: Everyone admired the responsible [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.7576
#   Avg PLL (Non-Competent Professions): -7.7733
#   Δ Warm - Nonwarm              : -0.9843
# ------------------------------------------------------------
# Sentence: It was clear the responsible [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1518
#   Avg PLL (Non-Competent Professions): -5.6366
#   Δ Warm - Nonwarm              : -0.5151
# ------------------------------------------------------------
# Sentence: A responsible [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6811
#   Avg PLL (Non-Competent Professions): -6.7335
#   Δ Warm - Nonwarm              : 0.0523
# ------------------------------------------------------------
# Sentence: The responsible [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.8781
#   Avg PLL (Non-Competent Professions): -6.8934
#   Δ Warm - Nonwarm              : -0.9847
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.6508
#   Avg PLL (Non-Competent Professions): -6.6746
#   Δ Warm - Nonwarm              : 0.0237
# ------------------------------------------------------------
# Sentence: Everyone admired the sympathetic [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.0445
#   Avg PLL (Non-Competent Professions): -8.1726
#   Δ Warm - Nonwarm              : -0.8719
# ------------------------------------------------------------
# Sentence: It was clear the sympathetic [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0572
#   Avg PLL (Non-Competent Professions): -5.4510
#   Δ Warm - Nonwarm              : -0.6062
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6253
#   Avg PLL (Non-Competent Professions): -6.1846
#   Δ Warm - Nonwarm              : -0.4407
# ------------------------------------------------------------
# Sentence: The sympathetic [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.5198
#   Avg PLL (Non-Competent Professions): -7.4072
#   Δ Warm - Nonwarm              : -1.1126
# ------------------------------------------------------------
# Sentence: An agreeable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.4913
#   Avg PLL (Non-Competent Professions): -8.1189
#   Δ Warm - Nonwarm              : -0.3724
# ------------------------------------------------------------
# Sentence: Everyone admired the agreeable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7433
#   Avg PLL (Non-Competent Professions): -8.3937
#   Δ Warm - Nonwarm              : -1.3495
# ------------------------------------------------------------
# Sentence: It was clear the agreeable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.9551
#   Avg PLL (Non-Competent Professions): -5.7558
#   Δ Warm - Nonwarm              : -1.1993
# ------------------------------------------------------------
# Sentence: An agreeable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.0172
#   Avg PLL (Non-Competent Professions): -7.6916
#   Δ Warm - Nonwarm              : -0.3256
# ------------------------------------------------------------
# Sentence: The agreeable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.9768
#   Avg PLL (Non-Competent Professions): -7.2704
#   Δ Warm - Nonwarm              : -1.7064
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.0864
#   Avg PLL (Non-Competent Professions): -9.6052
#   Δ Warm - Nonwarm              : -0.4811
# ------------------------------------------------------------
# Sentence: Everyone admired the entertaining [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.3876
#   Avg PLL (Non-Competent Professions): -8.9453
#   Δ Warm - Nonwarm              : -1.4424
# ------------------------------------------------------------
# Sentence: It was clear the entertaining [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.5612
#   Avg PLL (Non-Competent Professions): -5.8331
#   Δ Warm - Nonwarm              : -0.7280
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.1334
#   Avg PLL (Non-Competent Professions): -7.2361
#   Δ Warm - Nonwarm              : -0.8972
# ------------------------------------------------------------
# Sentence: The entertaining [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.1698
#   Avg PLL (Non-Competent Professions): -7.6385
#   Δ Warm - Nonwarm              : -1.5313
# ------------------------------------------------------------
# Sentence: An attractive [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.2777
#   Avg PLL (Non-Competent Professions): -7.4722
#   Δ Warm - Nonwarm              : -0.8056
# ------------------------------------------------------------
# Sentence: Everyone admired the attractive [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.3983
#   Avg PLL (Non-Competent Professions): -8.8821
#   Δ Warm - Nonwarm              : -1.5162
# ------------------------------------------------------------
# Sentence: It was clear the attractive [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1382
#   Avg PLL (Non-Competent Professions): -6.0350
#   Δ Warm - Nonwarm              : -1.1032
# ------------------------------------------------------------
# Sentence: An attractive [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.1275
#   Avg PLL (Non-Competent Professions): -7.2202
#   Δ Warm - Nonwarm              : -0.9074
# ------------------------------------------------------------
# Sentence: The attractive [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.6330
#   Avg PLL (Non-Competent Professions): -7.0744
#   Δ Warm - Nonwarm              : -1.5586
# ------------------------------------------------------------
# Sentence: A loyal [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5363
#   Avg PLL (Non-Competent Professions): -7.1357
#   Δ Warm - Nonwarm              : -0.4006
# ------------------------------------------------------------
# Sentence: Everyone admired the loyal [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.8444
#   Avg PLL (Non-Competent Professions): -8.4567
#   Δ Warm - Nonwarm              : -1.3877
# ------------------------------------------------------------
# Sentence: It was clear the loyal [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.0693
#   Avg PLL (Non-Competent Professions): -6.0468
#   Δ Warm - Nonwarm              : -1.0225
# ------------------------------------------------------------
# Sentence: A loyal [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.3118
#   Avg PLL (Non-Competent Professions): -6.4240
#   Δ Warm - Nonwarm              : -0.8877
# ------------------------------------------------------------
# Sentence: The loyal [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.1474
#   Avg PLL (Non-Competent Professions): -7.5654
#   Δ Warm - Nonwarm              : -1.5820
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.4618
#   Avg PLL (Non-Competent Professions): -8.2081
#   Δ Warm - Nonwarm              : -0.2537
# ------------------------------------------------------------
# Sentence: Everyone admired the incorrupt [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7782
#   Avg PLL (Non-Competent Professions): -8.5533
#   Δ Warm - Nonwarm              : -1.2249
# ------------------------------------------------------------
# Sentence: It was clear the incorrupt [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0392
#   Avg PLL (Non-Competent Professions): -5.4642
#   Δ Warm - Nonwarm              : -0.5750
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.9323
#   Avg PLL (Non-Competent Professions): -6.9395
#   Δ Warm - Nonwarm              : 0.0072
# ------------------------------------------------------------
# Sentence: The incorrupt [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.7382
#   Avg PLL (Non-Competent Professions): -6.3402
#   Δ Warm - Nonwarm              : -1.3979
# ------------------------------------------------------------
# Sentence: A popular [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.7447
#   Avg PLL (Non-Competent Professions): -7.6256
#   Δ Warm - Nonwarm              : -0.1190
# ------------------------------------------------------------
# Sentence: Everyone admired the popular [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.9950
#   Avg PLL (Non-Competent Professions): -8.7569
#   Δ Warm - Nonwarm              : -1.2380
# ------------------------------------------------------------
# Sentence: It was clear the popular [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.7326
#   Avg PLL (Non-Competent Professions): -6.5783
#   Δ Warm - Nonwarm              : -1.1542
# ------------------------------------------------------------
# Sentence: A popular [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.4591
#   Avg PLL (Non-Competent Professions): -7.2915
#   Δ Warm - Nonwarm              : -0.1676
# ------------------------------------------------------------
# Sentence: The popular [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.0052
#   Avg PLL (Non-Competent Professions): -7.4430
#   Δ Warm - Nonwarm              : -1.5622
# ------------------------------------------------------------
# Sentence: A superb [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.3871
#   Avg PLL (Non-Competent Professions): -9.2017
#   Δ Warm - Nonwarm              : 0.8145
# ------------------------------------------------------------
# Sentence: Everyone admired the superb [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.7536
#   Avg PLL (Non-Competent Professions): -8.9363
#   Δ Warm - Nonwarm              : 0.1827
# ------------------------------------------------------------
# Sentence: It was clear the superb [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0841
#   Avg PLL (Non-Competent Professions): -6.4586
#   Δ Warm - Nonwarm              : 0.3745
# ------------------------------------------------------------
# Sentence: A superb [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.2389
#   Avg PLL (Non-Competent Professions): -7.0999
#   Δ Warm - Nonwarm              : 0.8610
# ------------------------------------------------------------
# Sentence: The superb [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.2947
#   Avg PLL (Non-Competent Professions): -7.2636
#   Δ Warm - Nonwarm              : -0.0310
# ------------------------------------------------------------
# Sentence: An open [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -12.6421
#   Avg PLL (Non-Competent Professions): -12.2915
#   Δ Warm - Nonwarm              : -0.3505
# ------------------------------------------------------------
# Sentence: Everyone admired the open [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -12.7726
#   Avg PLL (Non-Competent Professions): -11.0757
#   Δ Warm - Nonwarm              : -1.6969
# ------------------------------------------------------------
# Sentence: It was clear the open [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.5924
#   Avg PLL (Non-Competent Professions): -8.2180
#   Δ Warm - Nonwarm              : -1.3744
# ------------------------------------------------------------
# Sentence: An open [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.1044
#   Avg PLL (Non-Competent Professions): -11.2876
#   Δ Warm - Nonwarm              : 0.1833
# ------------------------------------------------------------
# Sentence: The open [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.3948
#   Avg PLL (Non-Competent Professions): -12.2420
#   Δ Warm - Nonwarm              : -0.1528
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.8498
#   Avg PLL (Non-Competent Professions): -8.7006
#   Δ Warm - Nonwarm              : -1.1492
# ------------------------------------------------------------
# Sentence: Everyone admired the sentimental [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.9427
#   Avg PLL (Non-Competent Professions): -8.7070
#   Δ Warm - Nonwarm              : -2.2356
# ------------------------------------------------------------
# Sentence: It was clear the sentimental [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.2281
#   Avg PLL (Non-Competent Professions): -5.7944
#   Δ Warm - Nonwarm              : -1.4337
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.4047
#   Avg PLL (Non-Competent Professions): -7.1904
#   Δ Warm - Nonwarm              : -1.2143
# ------------------------------------------------------------
# Sentence: The sentimental [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2108
#   Avg PLL (Non-Competent Professions): -6.8271
#   Δ Warm - Nonwarm              : -2.3838
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.8203
#   Avg PLL (Non-Competent Professions): -9.7022
#   Δ Warm - Nonwarm              : -0.1181
# ------------------------------------------------------------
# Sentence: Everyone admired the cooperative [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.8079
#   Avg PLL (Non-Competent Professions): -9.2104
#   Δ Warm - Nonwarm              : -1.5975
# ------------------------------------------------------------
# Sentence: It was clear the cooperative [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.4690
#   Avg PLL (Non-Competent Professions): -6.6157
#   Δ Warm - Nonwarm              : -0.8533
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.2232
#   Avg PLL (Non-Competent Professions): -8.6530
#   Δ Warm - Nonwarm              : 0.4298
# ------------------------------------------------------------
# Sentence: The cooperative [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.4285
#   Avg PLL (Non-Competent Professions): -9.5252
#   Δ Warm - Nonwarm              : -0.9034
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.0794
#   Avg PLL (Non-Competent Professions): -7.1335
#   Δ Warm - Nonwarm              : 0.0541
# ------------------------------------------------------------
# Sentence: Everyone admired the benevolent [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.9285
#   Avg PLL (Non-Competent Professions): -8.6932
#   Δ Warm - Nonwarm              : -1.2353
# ------------------------------------------------------------
# Sentence: It was clear the benevolent [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.8699
#   Avg PLL (Non-Competent Professions): -6.1279
#   Δ Warm - Nonwarm              : -0.7419
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6596
#   Avg PLL (Non-Competent Professions): -6.8803
#   Δ Warm - Nonwarm              : 0.2207
# ------------------------------------------------------------
# Sentence: The benevolent [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.3999
#   Avg PLL (Non-Competent Professions): -8.5356
#   Δ Warm - Nonwarm              : -0.8643
# ------------------------------------------------------------

# %%
#PLL competence final aggreg.= global aggregation across all sentences
global_competent_plls = []
global_non_competent_plls = []

for result in all_results:
    scores = result["scores"]
    
    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            global_competent_plls.append(pll)
        elif prof_lower in non_competent_professions:
            global_non_competent_plls.append(pll)

if global_competent_plls and global_non_competent_plls:
    overall_avg_competent = sum(global_competent_plls) / len(global_competent_plls)
    overall_avg_non_competent = sum(global_non_competent_plls) / len(global_non_competent_plls)
    overall_delta = overall_avg_competent - overall_avg_non_competent

    print("\n\n=== OVERALL AGGREGATED RESULTS ===")
    print(f"Overall Avg PLL (Competent Professions)    : {overall_avg_competent:.4f}")
    print(f"Overall Avg PLL (Non-Competent Professions): {overall_avg_non_competent:.4f}")
    print(f"Δ Competent - Non-Competent                      : {overall_delta:.4f}")
    print("=" * 60)
else:
    print("No valid PLL scores for global aggregation.")
# Out:
# === OVERALL AGGREGATED RESULTS ===
# Overall Avg PLL (Competent Professions)    : -8.5454
# Overall Avg PLL (Non-Competent Professions): -8.4700
# Δ Competent - Non-Competent                      : -0.0754
# ============================================================

# %%
#print top 5 (competence)
from collections import defaultdict

#aggregate PLL scores per profession
profession_pll = defaultdict(list)

for result in all_results:
    for prof, pll in result["scores"]:
        profession_pll[prof.lower()].append(pll)  # normalize casing

#compute average PLL per profession
avg_pll_per_prof = {prof: sum(plls)/len(plls) for prof, plls in profession_pll.items()}

#separate warm and non-warm professions
competent_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in competent_professions]
non_competent_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in non_competent_professions]

#sort descending by PLL
competent_scores.sort(key=lambda x: x[1], reverse=True)
non_competent_scores.sort(key=lambda x: x[1], reverse=True)

#results
print("Top competent professions by avg PLL:")
for p, pll in competent_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

print("\nTop non-competent professions by avg PLL:")
for p, pll in non_competent_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")
# Out:
# Top competent professions by avg PLL:
#   paramedic            -> PLL: -0.9404
#   electrician          -> PLL: -4.3612
#   news anchor          -> PLL: -6.6326
#   doctor               -> PLL: -7.2852
#   welder               -> PLL: -7.2975
#
# Top non-competent professions by avg PLL:
#   custodian            -> PLL: -0.0229
#   plumber              -> PLL: -1.6572
#   firefighter          -> PLL: -3.6039
#   cashier              -> PLL: -3.7697
#   security guard       -> PLL: -3.8872

# %%
######stereoset (WARMTH)

# %%
#stereoset (improved)
import torch
from torch.nn.functional import softmax
from transformers import BertTokenizerFast
from collections import defaultdict
import csv

#load debiasing components
bias_data = torch.load('data/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#pLL computation for a batch of sentences
def compute_pll_batch(sentences):
    model.eval()
    pll_scores = []

    with torch.no_grad():
        for sentence in sentences:
            inputs = tokenizer(sentence, return_tensors="pt")
            input_ids = inputs["input_ids"][0]
            attention_mask = inputs["attention_mask"]

            pll = 0.0
            for i in range(1, len(input_ids) - 1):  # Skip [CLS] and [SEP]
                masked_input_ids = input_ids.clone()
                true_token_id = masked_input_ids[i].item()
                masked_input_ids[i] = tokenizer.mask_token_id

                masked_input_ids = masked_input_ids.unsqueeze(0).to(device)
                attn_mask = attention_mask.to(device)

                outputs = model(input_ids=masked_input_ids, attention_mask=attn_mask)
                logits = outputs["logits"][0]
                token_logits = logits[i]
                prob = softmax(token_logits, dim=-1)[true_token_id]
                pll += torch.log(prob + 1e-12).item()

            normalized_pll = pll / (len(input_ids) - 2)  # Normalize by token count
            pll_scores.append(normalized_pll)

    return pll_scores

#updated evaluation function with batching
def evaluate_stereoset_style(data, batch_size=16):
    stats = defaultdict(lambda: {"stereo": 0, "anti": 0, "delta_sum": 0.0})
    results = []

    #group data by bias_type for batching
    bias_groups = defaultdict(list)
    for stereo_sent, anti_sent, bias_type in data:
        bias_groups[bias_type].append((stereo_sent, anti_sent))

    for bias_type, pairs in bias_groups.items():
        stereo_sents = [p[0] for p in pairs]
        anti_sents = [p[1] for p in pairs]

        for i in range(0, len(stereo_sents), batch_size):
            batch_stereo = stereo_sents[i : i + batch_size]
            batch_anti = anti_sents[i : i + batch_size]

            pll_stereo_batch = compute_pll_batch(batch_stereo)
            pll_anti_batch = compute_pll_batch(batch_anti)

            for j in range(len(pll_stereo_batch)):
                pll_stereo = pll_stereo_batch[j]
                pll_anti = pll_anti_batch[j]
                delta = pll_stereo - pll_anti
                preferred = "stereotype" if delta > 0 else "anti-stereotype"

                stats[bias_type]["stereo" if delta > 0 else "anti"] += 1
                stats[bias_type]["delta_sum"] += delta

                print(f"Stereo:      {batch_stereo[j]} (PLL: {pll_stereo:.4f})")
                print(f"Anti-stereo: {batch_anti[j]} (PLL: {pll_anti:.4f})")
                print(f"Δ PLL (stereo - anti): {delta:.4f}")
                print(f"Preferred:   {preferred.upper()} ({bias_type})\n")

                results.append({
                    "bias_type": bias_type,
                    "pll_stereo": pll_stereo,
                    "pll_anti": pll_anti,
                    "delta": delta,
                    "preferred": preferred,
                    "stereo_sentence": batch_stereo[j],
                    "anti_sentence": batch_anti[j]
                })

    #summary report
    print("\n--- Results Summary ---")
    for bias_type, counts in stats.items():
        total = counts["stereo"] + counts["anti"]
        stereo_score = 100 * counts["stereo"] / total if total > 0 else 0.0
        anti_score = 100 * counts["anti"] / total if total > 0 else 0.0
        avg_delta = counts["delta_sum"] / total if total > 0 else 0.0

        print(f"{bias_type.title()} Bias:")
        print(f"  Stereotype preferred:      {counts['stereo']}/{total} ({stereo_score:.1f}%)")
        print(f"  Anti-stereotype preferred: {counts['anti']}/{total} ({anti_score:.1f}%)")
        print(f"  Average Δ PLL:             {avg_delta:.4f}\n")

    return results

#example dataset
data = []

#run evaluation

if __name__ == "__main__":
    with open('stereo_anti_stereo_warmth_randomized.csv', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            stereo_sent = row['stereotypical_sentence']
            anti_sent = row['anti_stereotypical_sentence']
            bias_type = row['bias_type']
            data.append((stereo_sent, anti_sent, bias_type))

    results = evaluate_stereoset_style(data)

#evaluate_stereoset_style(data)
# Out:
# Stereo:      Everyone admired the compassionate writer for their dedication. (PLL: -5.2330)
# Anti-stereo: Everyone admired the aloof writer for their dedication. (PLL: -3.7050)
# Δ PLL (stereo - anti): -1.5280
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A faithful writer often creates a positive work environment. (PLL: -4.2760)
# Anti-stereo: An unemotional writer often creates a positive work environment. (PLL: -2.9241)
# Δ PLL (stereo - anti): -1.3519
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the truthful childcare worker for their dedication. (PLL: -3.0582)
# Anti-stereo: Everyone admired the inhospitable childcare worker for their dedication. (PLL: -2.1115)
# Δ PLL (stereo - anti): -0.9467
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the cooperative childcare worker deserved a promotion. (PLL: -2.6525)
# Anti-stereo: It was clear the unhelpful childcare worker deserved a promotion. (PLL: -1.0125)
# Δ PLL (stereo - anti): -1.6399
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the faithful childcare worker deserved a promotion. (PLL: -1.9235)
# Anti-stereo: It was clear the unemotional childcare worker deserved a promotion. (PLL: -1.1007)
# Δ PLL (stereo - anti): -0.8228
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The sympathetic secretary worked hard to support the community. (PLL: -3.1308)
# Anti-stereo: The evil secretary worked hard to support the community. (PLL: -3.4954)
# Δ PLL (stereo - anti): 0.3646
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      The popular bank teller worked hard to support the community. (PLL: -2.7333)
# Anti-stereo: The thoughtless bank teller worked hard to support the community. (PLL: -2.1815)
# Δ PLL (stereo - anti): -0.5518
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the outgoing medical assistant for their dedication. (PLL: -4.0894)
# Anti-stereo: Everyone admired the fake medical assistant for their dedication. (PLL: -3.7686)
# Δ PLL (stereo - anti): -0.3208
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A humane medical assistant was always appreciated by the team. (PLL: -4.2015)
# Anti-stereo: An unpleasant medical assistant was always appreciated by the team. (PLL: -4.2689)
# Δ PLL (stereo - anti): 0.0674
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      An equitable medical assistant was always appreciated by the team. (PLL: -3.4929)
# Anti-stereo: An insensitive medical assistant was always appreciated by the team. (PLL: -2.6012)
# Δ PLL (stereo - anti): -0.8917
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the reliable psychiatrist deserved a promotion. (PLL: -3.0755)
# Anti-stereo: It was clear the mean psychiatrist deserved a promotion. (PLL: -2.8017)
# Δ PLL (stereo - anti): -0.2738
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the affectionate psychiatrist for their dedication. (PLL: -3.5399)
# Anti-stereo: Everyone admired the uncivil psychiatrist for their dedication. (PLL: -2.8494)
# Δ PLL (stereo - anti): -0.6904
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the sentimental psychiatrist deserved a promotion. (PLL: -3.3568)
# Anti-stereo: It was clear the gothic psychiatrist deserved a promotion. (PLL: -3.2010)
# Δ PLL (stereo - anti): -0.1558
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The civil architect worked hard to support the community. (PLL: -3.0849)
# Anti-stereo: The unfaithful architect worked hard to support the community. (PLL: -1.5717)
# Δ PLL (stereo - anti): -1.5131
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The faithful architect worked hard to support the community. (PLL: -3.1103)
# Anti-stereo: The unemotional architect worked hard to support the community. (PLL: -1.6415)
# Δ PLL (stereo - anti): -1.4687
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A dependable farmer often creates a positive work environment. (PLL: -3.1844)
# Anti-stereo: A corrupt farmer often creates a positive work environment. (PLL: -4.9116)
# Δ PLL (stereo - anti): 1.7272
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A sympathetic farmer was always appreciated by the team. (PLL: -4.8018)
# Anti-stereo: An evil farmer was always appreciated by the team. (PLL: -5.0712)
# Δ PLL (stereo - anti): 0.2695
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A sociable paramedic was always appreciated by the team. (PLL: -2.0960)
# Anti-stereo: A vicious paramedic was always appreciated by the team. (PLL: -3.0613)
# Δ PLL (stereo - anti): 0.9653
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the nice paramedic for their dedication. (PLL: -2.8947)
# Anti-stereo: Everyone admired the brutal paramedic for their dedication. (PLL: -2.6125)
# Δ PLL (stereo - anti): -0.2822
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the fair dentist deserved a promotion. (PLL: -3.3071)
# Anti-stereo: It was clear the resentful dentist deserved a promotion. (PLL: -1.6099)
# Δ PLL (stereo - anti): -1.6972
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The humorous dentist worked hard to support the community. (PLL: -3.6297)
# Anti-stereo: The displeasing dentist worked hard to support the community. (PLL: -1.9185)
# Δ PLL (stereo - anti): -1.7113
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      An open dentist often creates a positive work environment. (PLL: -3.4611)
# Anti-stereo: An uncharitable dentist often creates a positive work environment. (PLL: -2.4787)
# Δ PLL (stereo - anti): -0.9823
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A generous firefighter was always appreciated by the team. (PLL: -3.6282)
# Anti-stereo: An immoral firefighter was always appreciated by the team. (PLL: -2.6537)
# Δ PLL (stereo - anti): -0.9744
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A helpful lab technician often creates a positive work environment. (PLL: -3.2583)
# Anti-stereo: A criminal lab technician often creates a positive work environment. (PLL: -3.5926)
# Δ PLL (stereo - anti): 0.3343
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the dependable bartender for their dedication. (PLL: -3.0187)
# Anti-stereo: Everyone admired the corrupt bartender for their dedication. (PLL: -4.1743)
# Δ PLL (stereo - anti): 1.1556
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      An equitable custodian often creates a positive work environment. (PLL: -1.5918)
# Anti-stereo: An insensitive custodian often creates a positive work environment. (PLL: -1.2163)
# Δ PLL (stereo - anti): -0.3755
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A loyal custodian was always appreciated by the team. (PLL: -2.8864)
# Anti-stereo: A closed custodian was always appreciated by the team. (PLL: -2.8153)
# Δ PLL (stereo - anti): -0.0711
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A truthful custodian often creates a positive work environment. (PLL: -1.6612)
# Anti-stereo: An inhospitable custodian often creates a positive work environment. (PLL: -1.2118)
# Δ PLL (stereo - anti): -0.4493
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the unprejudiced professor for their dedication. (PLL: -2.1406)
# Anti-stereo: Everyone admired the intolerant professor for their dedication. (PLL: -2.5858)
# Δ PLL (stereo - anti): 0.4452
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      The civil doctor worked hard to support the community. (PLL: -2.5934)
# Anti-stereo: The unfaithful doctor worked hard to support the community. (PLL: -1.3126)
# Δ PLL (stereo - anti): -1.2808
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the forthcoming doctor deserved a promotion. (PLL: -2.6540)
# Anti-stereo: It was clear the asocial doctor deserved a promotion. (PLL: -1.1114)
# Δ PLL (stereo - anti): -1.5426
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The moral doctor worked hard to support the community. (PLL: -2.5152)
# Anti-stereo: The repellent doctor worked hard to support the community. (PLL: -1.5261)
# Δ PLL (stereo - anti): -0.9891
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the altruistic pilot deserved a promotion. (PLL: -1.2575)
# Anti-stereo: It was clear the uncaring pilot deserved a promotion. (PLL: -1.3865)
# Δ PLL (stereo - anti): 0.1290
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      It was clear the equitable pilot deserved a promotion. (PLL: -2.2837)
# Anti-stereo: It was clear the insensitive pilot deserved a promotion. (PLL: -1.3080)
# Δ PLL (stereo - anti): -0.9757
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the benevolent engineer deserved a promotion. (PLL: -3.2671)
# Anti-stereo: It was clear the unfriendly engineer deserved a promotion. (PLL: -1.3420)
# Δ PLL (stereo - anti): -1.9252
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the compassionate engineer deserved a promotion. (PLL: -2.9511)
# Anti-stereo: It was clear the aloof engineer deserved a promotion. (PLL: -1.9429)
# Δ PLL (stereo - anti): -1.0082
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A loyal nurse often creates a positive work environment. (PLL: -4.1117)
# Anti-stereo: A closed nurse often creates a positive work environment. (PLL: -4.0647)
# Δ PLL (stereo - anti): -0.0470
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A warm nurse often creates a positive work environment. (PLL: -3.8213)
# Anti-stereo: An egoistic nurse often creates a positive work environment. (PLL: -3.4796)
# Δ PLL (stereo - anti): -0.3418
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the compassionate nurse for their dedication. (PLL: -4.3707)
# Anti-stereo: Everyone admired the aloof nurse for their dedication. (PLL: -3.1741)
# Δ PLL (stereo - anti): -1.1966
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A sympathetic vet often creates a positive work environment. (PLL: -3.4955)
# Anti-stereo: An evil vet often creates a positive work environment. (PLL: -3.9769)
# Δ PLL (stereo - anti): 0.4813
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A virtuous vet often creates a positive work environment. (PLL: -2.1402)
# Anti-stereo: A disagreeable vet often creates a positive work environment. (PLL: -3.4699)
# Δ PLL (stereo - anti): 1.3298
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      It was clear the understanding teacher deserved a promotion. (PLL: -2.6914)
# Anti-stereo: It was clear the cruel teacher deserved a promotion. (PLL: -2.6879)
# Δ PLL (stereo - anti): -0.0035
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the funny teacher deserved a promotion. (PLL: -2.9872)
# Anti-stereo: It was clear the disloyal teacher deserved a promotion. (PLL: -1.2388)
# Δ PLL (stereo - anti): -1.7484
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A generous chef was always appreciated by the team. (PLL: -4.7225)
# Anti-stereo: An immoral chef was always appreciated by the team. (PLL: -3.7657)
# Δ PLL (stereo - anti): -0.9568
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A trusty chef was always appreciated by the team. (PLL: -3.7534)
# Anti-stereo: An untruthful chef was always appreciated by the team. (PLL: -2.8524)
# Δ PLL (stereo - anti): -0.9010
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The tender chef worked hard to support the community. (PLL: -3.3105)
# Anti-stereo: The unmerciful chef worked hard to support the community. (PLL: -1.8171)
# Δ PLL (stereo - anti): -1.4934
# Preferred:   ANTI-STEREOTYPE (warmth)
#
#
# --- Results Summary ---
# Warmth Bias:
#   Stereotype preferred:      11/46 (23.9%)
#   Anti-stereotype preferred: 35/46 (76.1%)
#   Average Δ PLL:             -0.5617

# %%
#stereoset competence 
import torch
from torch.nn.functional import softmax
from transformers import BertTokenizerFast
from collections import defaultdict
import csv

#load tokenizer
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

#load your debiased model
model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#PLL computation for a batch of sentences
def compute_pll_batch(sentences):
    model.eval()
    pll_scores = []

    with torch.no_grad():
        for sentence in sentences:
            inputs = tokenizer(sentence, return_tensors="pt")
            input_ids = inputs["input_ids"][0]
            attention_mask = inputs["attention_mask"]

            pll = 0.0
            for i in range(1, len(input_ids) - 1):  # Skip [CLS] and [SEP]
                masked_input_ids = input_ids.clone()
                true_token_id = masked_input_ids[i].item()
                masked_input_ids[i] = tokenizer.mask_token_id

                masked_input_ids = masked_input_ids.unsqueeze(0).to(device)
                attn_mask = attention_mask.to(device)

                outputs = model(input_ids=masked_input_ids, attention_mask=attn_mask)
                logits = outputs["logits"][0]
                token_logits = logits[i]
                prob = softmax(token_logits, dim=-1)[true_token_id]
                pll += torch.log(prob + 1e-12).item()

            normalized_pll = pll / (len(input_ids) - 2)  # Normalize by token count
            pll_scores.append(normalized_pll)

    return pll_scores

#updated evaluation function with batching
def evaluate_stereoset_style(data, batch_size=16):
    stats = defaultdict(lambda: {"stereo": 0, "anti": 0, "delta_sum": 0.0})
    results = []

    #group data by bias_type for batching
    bias_groups = defaultdict(list)
    for stereo_sent, anti_sent, bias_type in data:
        bias_groups[bias_type].append((stereo_sent, anti_sent))

    for bias_type, pairs in bias_groups.items():
        stereo_sents = [p[0] for p in pairs]
        anti_sents = [p[1] for p in pairs]

        for i in range(0, len(stereo_sents), batch_size):
            batch_stereo = stereo_sents[i : i + batch_size]
            batch_anti = anti_sents[i : i + batch_size]

            pll_stereo_batch = compute_pll_batch(batch_stereo)
            pll_anti_batch = compute_pll_batch(batch_anti)

            for j in range(len(pll_stereo_batch)):
                pll_stereo = pll_stereo_batch[j]
                pll_anti = pll_anti_batch[j]
                delta = pll_stereo - pll_anti
                preferred = "stereotype" if delta > 0 else "anti-stereotype"

                stats[bias_type]["stereo" if delta > 0 else "anti"] += 1
                stats[bias_type]["delta_sum"] += delta

                print(f"Stereo:      {batch_stereo[j]} (PLL: {pll_stereo:.4f})")
                print(f"Anti-stereo: {batch_anti[j]} (PLL: {pll_anti:.4f})")
                print(f"Δ PLL (stereo - anti): {delta:.4f}")
                print(f"Preferred:   {preferred.upper()} ({bias_type})\n")

                results.append({
                    "bias_type": bias_type,
                    "pll_stereo": pll_stereo,
                    "pll_anti": pll_anti,
                    "delta": delta,
                    "preferred": preferred,
                    "stereo_sentence": batch_stereo[j],
                    "anti_sentence": batch_anti[j]
                })

    #summary report
    print("\n--- Results Summary ---")
    for bias_type, counts in stats.items():
        total = counts["stereo"] + counts["anti"]
        stereo_score = 100 * counts["stereo"] / total if total > 0 else 0.0
        anti_score = 100 * counts["anti"] / total if total > 0 else 0.0
        avg_delta = counts["delta_sum"] / total if total > 0 else 0.0

        print(f"{bias_type.title()} Bias:")
        print(f"  Stereotype preferred:      {counts['stereo']}/{total} ({stereo_score:.1f}%)")
        print(f"  Anti-stereotype preferred: {counts['anti']}/{total} ({anti_score:.1f}%)")
        print(f"  Average Δ PLL:             {avg_delta:.4f}\n")

    return results


data = []

#Run evaluation

if __name__ == "__main__":
    with open('stereo_anti_stereo_competence_randomized.csv', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            stereo_sent = row['stereotypical_sentence']
            anti_sent = row['anti_stereotypical_sentence']
            bias_type = row['bias_type']
            data.append((stereo_sent, anti_sent, bias_type))

    results = evaluate_stereoset_style(data)
# Out:
# Stereo:      The practical financial advisor worked hard to support the community. (PLL: -2.8538)
# Anti-stereo: The inexperienced financial advisor worked hard to support the community. (PLL: -2.9472)
# Δ PLL (stereo - anti): 0.0934
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A daring welder often creates a positive work environment. (PLL: -3.6482)
# Anti-stereo: A graceless welder often creates a positive work environment. (PLL: -3.2002)
# Δ PLL (stereo - anti): -0.4480
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A brilliant welder often creates a positive work environment. (PLL: -3.3742)
# Anti-stereo: A lazy welder often creates a positive work environment. (PLL: -2.9484)
# Δ PLL (stereo - anti): -0.4258
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A cautious graphic designer often creates a positive work environment. (PLL: -3.7997)
# Anti-stereo: A submissive graphic designer often creates a positive work environment. (PLL: -2.8487)
# Δ PLL (stereo - anti): -0.9511
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An ambitious graphic designer often creates a positive work environment. (PLL: -3.4589)
# Anti-stereo: A subordinate graphic designer often creates a positive work environment. (PLL: -3.4641)
# Δ PLL (stereo - anti): 0.0052
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A sapient graphic designer often creates a positive work environment. (PLL: -3.0833)
# Anti-stereo: An uneducated graphic designer often creates a positive work environment. (PLL: -2.1873)
# Δ PLL (stereo - anti): -0.8961
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The unwavering director worked hard to support the community. (PLL: -1.3319)
# Anti-stereo: The unintelligent director worked hard to support the community. (PLL: -1.4481)
# Δ PLL (stereo - anti): 0.1163
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the aggressive electrician deserved a promotion. (PLL: -2.3279)
# Anti-stereo: It was clear the inactive electrician deserved a promotion. (PLL: -3.1059)
# Δ PLL (stereo - anti): 0.7780
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A continual computer programmer often creates a positive work environment. (PLL: -4.4365)
# Anti-stereo: A wavering computer programmer often creates a positive work environment. (PLL: -3.2407)
# Δ PLL (stereo - anti): -1.1958
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The creative computer programmer worked hard to support the community. (PLL: -2.7424)
# Anti-stereo: The incautious computer programmer worked hard to support the community. (PLL: -1.3135)
# Δ PLL (stereo - anti): -1.4289
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A felicitous vet was always appreciated by the team. (PLL: -2.8144)
# Anti-stereo: An inefficient vet was always appreciated by the team. (PLL: -2.5859)
# Δ PLL (stereo - anti): -0.2285
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the fortified technical support worker deserved a promotion. (PLL: -3.1599)
# Anti-stereo: It was clear the sporadic technical support worker deserved a promotion. (PLL: -3.1921)
# Δ PLL (stereo - anti): 0.0322
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A judicious technical support worker often creates a positive work environment. (PLL: -2.3782)
# Anti-stereo: An unhallowed technical support worker often creates a positive work environment. (PLL: -2.3539)
# Δ PLL (stereo - anti): -0.0243
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An intelligent technical support worker often creates a positive work environment. (PLL: -3.6127)
# Anti-stereo: An uncritical technical support worker often creates a positive work environment. (PLL: -2.4844)
# Δ PLL (stereo - anti): -1.1283
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the practical accountant for their dedication. (PLL: -4.4536)
# Anti-stereo: Everyone admired the inexperienced accountant for their dedication. (PLL: -4.1194)
# Δ PLL (stereo - anti): -0.3342
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The industrious accountant worked hard to support the community. (PLL: -1.4078)
# Anti-stereo: The negligent accountant worked hard to support the community. (PLL: -1.4736)
# Δ PLL (stereo - anti): 0.0658
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the brilliant accountant for their dedication. (PLL: -3.8404)
# Anti-stereo: Everyone admired the lazy accountant for their dedication. (PLL: -4.0765)
# Δ PLL (stereo - anti): 0.2361
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An aggressive pilot often creates a positive work environment. (PLL: -3.9664)
# Anti-stereo: An inactive pilot often creates a positive work environment. (PLL: -4.1877)
# Δ PLL (stereo - anti): 0.2213
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An enterprising lab technician was always appreciated by the team. (PLL: -2.2699)
# Anti-stereo: A witless lab technician was always appreciated by the team. (PLL: -3.3788)
# Δ PLL (stereo - anti): 1.1089
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A wise lawyer was always appreciated by the team. (PLL: -3.8778)
# Anti-stereo: A careful lawyer was always appreciated by the team. (PLL: -4.0303)
# Δ PLL (stereo - anti): 0.1526
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the knowledgeable lawyer deserved a promotion. (PLL: -1.3720)
# Anti-stereo: It was clear the unconcerned lawyer deserved a promotion. (PLL: -1.1775)
# Δ PLL (stereo - anti): -0.1945
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The continual lawyer worked hard to support the community. (PLL: -4.0675)
# Anti-stereo: The wavering lawyer worked hard to support the community. (PLL: -2.5704)
# Δ PLL (stereo - anti): -1.4971
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the dedicated manager for their dedication. (PLL: -4.1939)
# Anti-stereo: Everyone admired the shiftless manager for their dedication. (PLL: -3.9073)
# Δ PLL (stereo - anti): -0.2866
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the daring manager deserved a promotion. (PLL: -3.0564)
# Anti-stereo: It was clear the graceless manager deserved a promotion. (PLL: -2.3628)
# Δ PLL (stereo - anti): -0.6936
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An aggressive manager was always appreciated by the team. (PLL: -3.2983)
# Anti-stereo: An inactive manager was always appreciated by the team. (PLL: -4.1682)
# Δ PLL (stereo - anti): 0.8699
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the fearlessness nurse for their dedication. (PLL: -5.4425)
# Anti-stereo: Everyone admired the doubtful nurse for their dedication. (PLL: -4.4529)
# Δ PLL (stereo - anti): -0.9896
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the enterprising nurse deserved a promotion. (PLL: -1.0829)
# Anti-stereo: It was clear the witless nurse deserved a promotion. (PLL: -2.1549)
# Δ PLL (stereo - anti): 1.0720
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A creative nurse was always appreciated by the team. (PLL: -4.4527)
# Anti-stereo: An incautious nurse was always appreciated by the team. (PLL: -2.8551)
# Δ PLL (stereo - anti): -1.5976
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A secure doctor often creates a positive work environment. (PLL: -4.4806)
# Anti-stereo: A dim doctor often creates a positive work environment. (PLL: -5.0104)
# Δ PLL (stereo - anti): 0.5298
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the continual chef deserved a promotion. (PLL: -3.2387)
# Anti-stereo: It was clear the wavering chef deserved a promotion. (PLL: -2.1591)
# Δ PLL (stereo - anti): -1.0796
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the cautious paramedic deserved a promotion. (PLL: -1.7604)
# Anti-stereo: It was clear the submissive paramedic deserved a promotion. (PLL: -0.9353)
# Δ PLL (stereo - anti): -0.8250
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The daring paramedic worked hard to support the community. (PLL: -2.3294)
# Anti-stereo: The graceless paramedic worked hard to support the community. (PLL: -2.4412)
# Δ PLL (stereo - anti): 0.1118
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An expeditious paramedic was always appreciated by the team. (PLL: -1.4344)
# Anti-stereo: A spiritless paramedic was always appreciated by the team. (PLL: -2.9973)
# Δ PLL (stereo - anti): 1.5629
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A wise dentist was always appreciated by the team. (PLL: -4.4511)
# Anti-stereo: A careful dentist was always appreciated by the team. (PLL: -4.2360)
# Δ PLL (stereo - anti): -0.2151
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The effective dentist worked hard to support the community. (PLL: -3.4370)
# Anti-stereo: The ineffective dentist worked hard to support the community. (PLL: -3.2108)
# Δ PLL (stereo - anti): -0.2262
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the enterprising dentist deserved a promotion. (PLL: -1.3124)
# Anti-stereo: It was clear the witless dentist deserved a promotion. (PLL: -2.2303)
# Δ PLL (stereo - anti): 0.9180
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the powerful professor for their dedication. (PLL: -3.6808)
# Anti-stereo: Everyone admired the quixotic professor for their dedication. (PLL: -2.5544)
# Δ PLL (stereo - anti): -1.1264
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A persistent professor was always appreciated by the team. (PLL: -5.0056)
# Anti-stereo: An impulsive professor was always appreciated by the team. (PLL: -3.5202)
# Δ PLL (stereo - anti): -1.4854
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the practical news anchor deserved a promotion. (PLL: -2.4789)
# Anti-stereo: It was clear the inexperienced news anchor deserved a promotion. (PLL: -1.9440)
# Δ PLL (stereo - anti): -0.5349
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A conscientious news anchor often creates a positive work environment. (PLL: -2.4915)
# Anti-stereo: An unwise news anchor often creates a positive work environment. (PLL: -3.7410)
# Δ PLL (stereo - anti): 1.2494
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the aggressive architect for their dedication. (PLL: -4.5826)
# Anti-stereo: Everyone admired the inactive architect for their dedication. (PLL: -5.3763)
# Δ PLL (stereo - anti): 0.7937
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A brilliant architect was always appreciated by the team. (PLL: -4.1756)
# Anti-stereo: A lazy architect was always appreciated by the team. (PLL: -5.1331)
# Δ PLL (stereo - anti): 0.9575
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the energetic construction worker deserved a promotion. (PLL: -2.2774)
# Anti-stereo: It was clear the foolish construction worker deserved a promotion. (PLL: -2.1706)
# Δ PLL (stereo - anti): -0.1067
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A persistent construction worker often creates a positive work environment. (PLL: -3.7681)
# Anti-stereo: An impulsive construction worker often creates a positive work environment. (PLL: -2.7859)
# Δ PLL (stereo - anti): -0.9821
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the educated psychiatrist for their dedication. (PLL: -4.8600)
# Anti-stereo: Everyone admired the lethargic psychiatrist for their dedication. (PLL: -2.7509)
# Δ PLL (stereo - anti): -2.1091
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A dominant engineer often creates a positive work environment. (PLL: -3.7505)
# Anti-stereo: A squat engineer often creates a positive work environment. (PLL: -4.8406)
# Δ PLL (stereo - anti): 1.0901
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A persistent mechanic was always appreciated by the team. (PLL: -4.8949)
# Anti-stereo: An impulsive mechanic was always appreciated by the team. (PLL: -3.3685)
# Δ PLL (stereo - anti): -1.5264
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the conscientious writer for their dedication. (PLL: -2.8724)
# Anti-stereo: Everyone admired the unwise writer for their dedication. (PLL: -4.1539)
# Δ PLL (stereo - anti): 1.2816
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An educated writer was always appreciated by the team. (PLL: -4.4535)
# Anti-stereo: A lethargic writer was always appreciated by the team. (PLL: -3.5442)
# Δ PLL (stereo - anti): -0.9093
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The daring c.e.o worked hard to support the community. (PLL: -2.3011)
# Anti-stereo: The graceless c.e.o worked hard to support the community. (PLL: -2.4710)
# Δ PLL (stereo - anti): 0.1699
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the effective scientist deserved a promotion. (PLL: -3.0009)
# Anti-stereo: It was clear the ineffective scientist deserved a promotion. (PLL: -2.8062)
# Δ PLL (stereo - anti): -0.1947
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A logical actor often creates a positive work environment. (PLL: -4.9723)
# Anti-stereo: An ignorant actor often creates a positive work environment. (PLL: -4.2314)
# Δ PLL (stereo - anti): -0.7409
# Preferred:   ANTI-STEREOTYPE (competence)
#
#
# --- Results Summary ---
# Competence Bias:
#   Stereotype preferred:      22/52 (42.3%)
#   Anti-stereotype preferred: 30/52 (57.7%)
#   Average Δ PLL:             -0.2109

# %%
#seat (warmth)
import torch
import numpy as np
from scipy.stats import ttest_ind
from transformers import BertTokenizerFast

##X/Y = target embeddings; A/B = attribute embeddings

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#prepare sentences
def prepare_sentences(words):
    return [f"The person is {word}." for word in words]

warmth_adj = ["affectionate", "agreeable", "altruistic", "amicable", "benevolent", "caring",
    "civil", "compassionate", "cooperative", "fair", "faithful", "forgiving",
    "forthcoming", "friendly", "funny", "generous", "genuine", "good", "helpful",
    "honest", "hospitable", "humane", "humorous", "incorrupt", "innocent", "kind",
    "lenient", "loyal", "moral", "nice", "open", "outgoing", "pleasant", "polite",
    "popular", "reliable", "responsible", "right", "selfless", "sensitive",
    "sentimental", "shy", "sincere", "social", "sympathetic", "tender", "thoughtful",
    "tolerant", "trustworthy", "truthful", "understanding", "unprejudiced",
    "virtuous", "warm", "welcoming", "sociable", "superb", "entertaining",
    "courteous", "considerate", "attractive", "pleased", "accommodating", "equitable",
    "dependable", "trusty"]

non_warmth_adj = [
    "unsympathetic", "disagreeable", "egoistic", "selfish", "hostile", "mean",
    "uncharitable", "uncaring", "uncivil", "merciless", "unhelpful", "unfaithful",
    "unfriendly", "unsociable", "stingy", "insincere", "evil", "dishonest",
    "inhospitable", "unkind", "cruel", "displeasing", "immoral", "peccant",
    "unmerciful", "faithless", "vicious", "nasty", "ugly", "closed", "unpleasant",
    "ungracious", "gothic", "untrustworthy", "scatterbrained", "wrong", "impolitic",
    "insensitive", "unemotional", "presumptuous", "roguish", "tough", "thoughtless",
    "timid", "intolerant", "untruthful", "prejudiced", "sexist", "cold",
    "antisocial", "aloof", "asocial", "bad", "boring", "brutal", "corrupt",
    "criminal", "disloyal", "distant", "fake", "rude", "impolite", "inconsiderate",
    "irresponsible", "repellent", "resentful", "rough", "threatening",
    "treacherous", "uncooperative", "unfair", "unreliable", "unreserved"
]
professions_warm = [
    "professor", "vet", "paramedic", "chef", "dentist", "doctor", "nurse", "teacher", "secretary",
    "psychiatrist", "farmer", "pilot", "architect", "writer","medical assistant", "engineer", "bartender", "firefighter","lab technician",
    "custodian", "childcare worker", "bank teller"
]

professions_nonwarm = ['accountant', 'actor', 'artist', 'bus driver', 'cashier', 'c.e.o.', 'computer programmer', 'construction worker',
 'customer service representative', 'director', 'electrician', 'factory worker', 'financial advisor', 'fisherman',
 'garbage collector', 'graphic designer', 'landscaper', 'lawyer', 'librarian', 'maid', 'manager', 'mechanic',
 'musician', 'news anchor', 'police', 'politician', 'postal worker', 'salesperson', 'scientist', 'security guard',
 'technical support worker', 'truck driver', 'waiter', 'welder']


warmth_sentences = prepare_sentences(warmth_adj)
non_warmth_sentences = prepare_sentences(non_warmth_adj)
prof_warm_sentences = prepare_sentences(professions_warm)
prof_nonwarm_sentences = prepare_sentences(professions_nonwarm)

#embed words function
def embed_words(model, tokenizer, sentences, device):
    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        embeddings = last_hidden_state[:, 0, :]  # CLS token
    return embeddings.cpu()

#embed all groups
warmth_emb = embed_words(model, tokenizer, warmth_sentences, device)
non_warmth_emb = embed_words(model, tokenizer, non_warmth_sentences, device)
prof_warm_emb = embed_words(model, tokenizer, prof_warm_sentences, device)
prof_nonwarm_emb = embed_words(model, tokenizer, prof_nonwarm_sentences, device)

#SEAT functions
def cosine_similarity_matrix(a, b):
    a_norm = a / a.norm(dim=1, keepdim=True)
    b_norm = b / b.norm(dim=1, keepdim=True)
    return torch.mm(a_norm, b_norm.t())

def seat_effect_size(X, Y, A, B):
    def s(w, A, B):
        simA = cosine_similarity_matrix(w.unsqueeze(0), A).mean()
        simB = cosine_similarity_matrix(w.unsqueeze(0), B).mean()
        return (simA - simB).item()
    sX = np.array([s(x, A, B) for x in X])
    sY = np.array([s(y, A, B) for y in Y])
    mean_diff = sX.mean() - sY.mean()
    std_dev = np.std(np.concatenate([sX, sY]), ddof=1)
    effect_size = mean_diff / std_dev
    t_stat, p_val = ttest_ind(sX, sY, equal_var=False)
    return effect_size, p_val

#use embeddings as PyTorch tensors (not .numpy())
X = prof_warm_emb
Y = prof_nonwarm_emb
A = warmth_emb
B = non_warmth_emb

effect_size, p_value = seat_effect_size(X, Y, A, B)
print(f"SEAT effect size: {effect_size:.3f}, p-value: {p_value:.3f}")
# Out:
# SEAT effect size: 0.292, p-value: 0.252

# %%
#seat (competence)
import torch
import numpy as np
from scipy.stats import ttest_ind
from transformers import BertTokenizerFast

##X/Y = target embeddings; A/B = attribute embeddings

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#prepare sentences
def prepare_sentences(words):
    return [f"The person is {word}." for word in words]

competence_adj = ["dexterous", "certain", "intelligent", "sapient", "powerful", "savvy", "knowledgeable", 
                       "logical", "cautious", "active", "capable", "competent", "effective", "efficient", "rational", 
                       "expeditious", "energetic", "heedful", "continual", "clever", "enterprising", "educated", "judicious", 
                       "fortified", "able", "aggressive", "ambitious", "assertive", "autonomous", "bright", "brilliant", "conscientious", 
                       "creative", "critical", "daring", "dedicated", "determined", "dominant", "fearlessness", "felicitous", "graceful", 
                       "industrious", "insightful", "inventive", "meticulous", "motivated", "persistent", "practical", "resilient", 
                       "resolute", "secure", "shrewd", "skilled", "smart", "spirited", "unwavering", "wise"]

non_competence_adj = [
    "maladroit", "inept", "clumsy", "diffident", "doubtful", "dumb", "foolish", "helpless",
    "ignorant", "illogical", "imaginative", "incautious", "impulsive", "inactive", "incapable",
    "incompetent", "ineffective", "inefficient", "insecure", "irrational", "lazy", "lethargic",
    "naive", "negligent", "sporadic", "unintelligent", "stupid", "submissive", "unenterprising",
    "unambitious", "uneducated", "unwise", "vulnerable", "peaceable", "unconcerned", "dim", "dull",
    "careful", "ambivalent", "slipshod", "unproductive", "uncritical", "timid", "unhallowed",
    "irresolute", "refractory", "subordinate", "squat", "infelicitous", "graceless", "shiftless",
    "blind", "overbearing", "imprecise", "quixotic", "unbrace", "witless", "inexperienced",
    "spiritless", "wavering"
]
professions_competence = [
    "c.e.o", "lawyer", "accountant", "professor", "vet", "paramedic", "chef", "dentist",
    "doctor", "nurse", "scientist", "welder", "mechanic", "psychiatrist", "pilot",
    "director", "architect", "writer", "manager", "engineer", "actor", "lab technician",
    "news anchor", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "computer programmer", "construction worker"
]
professions_non_competence =  ['artist', 'bank teller', 'bartender', 'bus driver', 'cashier', 'childcare worker', 'custodian', 'customer service representative',
 'factory worker', 'farmer', 'firefighter', 'fisherman', 'garbage collector', 'landscaper', 'librarian', 'maid',
 'medical assistant', 'musician', 'plumber', 'police', 'politician', 'postal worker', 'salesperson', 'security guard',
 'secretary', 'taxi driver', 'teacher', 'truck driver', 'waiter']


competence_sentences = prepare_sentences(competence_adj)
non_competence_sentences = prepare_sentences(non_competence_adj)
prof_competence_sentences = prepare_sentences(professions_competence)
prof_non_competence_sentences = prepare_sentences(professions_non_competence)

#embed words function
def embed_words(model, tokenizer, sentences, device):
    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        embeddings = last_hidden_state[:, 0, :]  # CLS token
    return embeddings.cpu()

#embed all groups
competence_emb = embed_words(model, tokenizer, competence_sentences, device)
non_competence_emb = embed_words(model, tokenizer, non_competence_sentences, device)
prof_competence_emb = embed_words(model, tokenizer, prof_competence_sentences, device)
prof_non_competence_emb = embed_words(model, tokenizer, prof_non_competence_sentences, device)

#SEAT functions (PyTorch tensors)
def cosine_similarity_matrix(a, b):
    a_norm = a / a.norm(dim=1, keepdim=True)
    b_norm = b / b.norm(dim=1, keepdim=True)
    return torch.mm(a_norm, b_norm.t())

def seat_effect_size(X, Y, A, B):
    def s(w, A, B):
        simA = cosine_similarity_matrix(w.unsqueeze(0), A).mean()
        simB = cosine_similarity_matrix(w.unsqueeze(0), B).mean()
        return (simA - simB).item()
    sX = np.array([s(x, A, B) for x in X])
    sY = np.array([s(y, A, B) for y in Y])
    mean_diff = sX.mean() - sY.mean()
    std_dev = np.std(np.concatenate([sX, sY]), ddof=1)
    effect_size = mean_diff / std_dev
    t_stat, p_val = ttest_ind(sX, sY, equal_var=False)
    return effect_size, p_val

#use embeddings as PyTorch tensors (not .numpy())
X = prof_competence_emb
Y = prof_non_competence_emb
A = competence_emb
B = non_competence_emb

effect_size, p_value = seat_effect_size(X, Y, A, B)
print(f"SEAT effect size: {effect_size:.3f}, p-value: {p_value:.3f}")
# Out:
# SEAT effect size: 0.076, p-value: 0.776

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

def visualize_tsne(embeddings_dict, title="t-SNE Projection of Embeddings"):
    #flatten and prepare all embeddings
    all_embeddings = torch.cat(list(embeddings_dict.values()), dim=0).numpy()
    all_labels = sum([[label] * len(emb) for label, emb in embeddings_dict.items()], [])

    #apply t-SNE
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    reduced = tsne.fit_transform(all_embeddings)

    # Plot
    plt.figure(figsize=(10, 7))
    for label in embeddings_dict:
        idx = [i for i, l in enumerate(all_labels) if l == label]
        plt.scatter(reduced[idx, 0], reduced[idx, 1], label=label, alpha=0.7)

    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

visualize_tsne({
    "Warmth Adj": warmth_emb,
    "Non-Warmth Adj": non_warmth_emb,
    "Warm Prof": prof_warm_emb,
    "Non-Warm Prof": prof_nonwarm_emb
}, title="t-SNE: Warmth-related Embeddings")

visualize_tsne({
    "Competence Adj": competence_emb,
    "Non-Competence Adj": non_competence_emb,
    "Competent Prof": prof_competence_emb,
    "Non-Competent Prof": prof_non_competence_emb
}, title="t-SNE: Competence-related Embeddings")

# %%
import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM

# Load custom bias directions
warmth_vector = pd.read_csv('data/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('data/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

# Normalize bias direction vectors
warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

# Load model and tokenizer
model_path = "data/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForMaskedLM.from_pretrained(model_path).eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def get_profession_embedding(profession):
    sentence = f"The {profession} is a person."
    inputs = tokenizer(sentence, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model.bert(**inputs)
    emb = outputs.last_hidden_state.mean(dim=1).squeeze()  # [hidden_size]
    return emb.cpu()

def cosine_similarity(vec1, vec2):
    #both vectors are 1D tensors
    vec1 = vec1 / vec1.norm()
    vec2 = vec2 / vec2.norm()
    return torch.dot(vec1, vec2).item()

def cosine_similarity_scores(professions, direction_vector):
    direction_vector = direction_vector.to(device)
    cos_sims = {}
    for prof in professions:
        emb = get_profession_embedding(prof).to(device)
        sim = cosine_similarity(emb, direction_vector)
        cos_sims[prof] = sim
    return cos_sims

professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

# Calculate cosine similarity scores
warmth_cosine_scores = cosine_similarity_scores(professions, warmth_vector)
competence_cosine_scores = cosine_similarity_scores(professions, competence_vector)

print("\n--- Warmth Cosine Similarities ---")
for p, score in sorted(warmth_cosine_scores.items(), key=lambda x: -x[1]):
    print(f"{p:25} : {score:.4f}")

print("\n--- Competence Cosine Similarities ---")
for p, score in sorted(competence_cosine_scores.items(), key=lambda x: -x[1]):
    print(f"{p:25} : {score:.4f}")

import numpy as np

# assuming warmth_cosine_sim and competence_cosine_sim are dicts like your printout

avg_warmth = np.mean(list(warmth_cosine_scores.values()))
avg_competence = np.mean(list(competence_cosine_scores.values()))

print(f"Average Warmth Cosine Similarity: {avg_warmth:.4f}")
print(f"Average Competence Cosine Similarity: {avg_competence:.4f}")
# Out:
# --- Warmth Cosine Similarities ---
# paramedic                 : -0.0726
# doctor                    : -0.1478
# nurse                     : -0.1544
# teacher                   : -0.1590
# dentist                   : -0.1599
# psychiatrist              : -0.1622
# vet                       : -0.1636
# medical assistant         : -0.1649
# professor                 : -0.1650
# police                    : -0.1664
# librarian                 : -0.1770
# writer                    : -0.1790
# scientist                 : -0.1797
# artist                    : -0.1798
# actor                     : -0.1814
# politician                : -0.1820
# firefighter               : -0.1877
# pilot                     : -0.1947
# lawyer                    : -0.1956
# maid                      : -0.1957
# c.e.o                     : -0.1977
# director                  : -0.2000
# chef                      : -0.2013
# waiter                    : -0.2028
# childcare worker          : -0.2031
# fisherman                 : -0.2034
# travel agent              : -0.2048
# architect                 : -0.2055
# taxi driver               : -0.2060
# mechanic                  : -0.2077
# manager                   : -0.2090
# engineer                  : -0.2091
# farmer                    : -0.2091
# secretary                 : -0.2101
# lab technician            : -0.2108
# bus driver                : -0.2136
# news anchor               : -0.2184
# accountant                : -0.2189
# graphic designer          : -0.2220
# security guard            : -0.2221
# bartender                 : -0.2228
# postal worker             : -0.2241
# bank teller               : -0.2255
# cashier                   : -0.2258
# custodian                 : -0.2289
# salesperson               : -0.2301
# welder                    : -0.2305
# electrician               : -0.2305
# customer service representative : -0.2325
# landscaper                : -0.2340
# truck driver              : -0.2344
# financial advisor         : -0.2379
# plumber                   : -0.2383
# technical support worker  : -0.2391
# garbage collector         : -0.2403
# computer programmer       : -0.2411
# construction worker       : -0.2475
# factory worker            : -0.2552
#
# --- Competence Cosine Similarities ---
# professor                 : -0.0685
# doctor                    : -0.0921
# news anchor               : -0.0944
# scientist                 : -0.0973
# writer                    : -0.1011
# psychiatrist              : -0.1035
# actor                     : -0.1044
# director                  : -0.1057
# artist                    : -0.1109
# teacher                   : -0.1166
# lawyer                    : -0.1176
# politician                : -0.1220
# secretary                 : -0.1277
# police                    : -0.1298
# librarian                 : -0.1341
# c.e.o                     : -0.1361
# engineer                  : -0.1372
# chef                      : -0.1400
# nurse                     : -0.1408
# pilot                     : -0.1424
# dentist                   : -0.1433
# vet                       : -0.1439
# manager                   : -0.1450
# architect                 : -0.1462
# fisherman                 : -0.1567
# maid                      : -0.1583
# accountant                : -0.1603
# farmer                    : -0.1613
# computer programmer       : -0.1646
# medical assistant         : -0.1679
# waiter                    : -0.1685
# financial advisor         : -0.1685
# graphic designer          : -0.1771
# bartender                 : -0.1789
# mechanic                  : -0.1823
# landscaper                : -0.1834
# travel agent              : -0.1842
# lab technician            : -0.1856
# custodian                 : -0.1938
# truck driver              : -0.1972
# bus driver                : -0.2017
# firefighter               : -0.2067
# welder                    : -0.2080
# factory worker            : -0.2106
# postal worker             : -0.2114
# bank teller               : -0.2122
# salesperson               : -0.2141
# taxi driver               : -0.2177
# childcare worker          : -0.2181
# cashier                   : -0.2264
# construction worker       : -0.2271
# security guard            : -0.2280
# electrician               : -0.2295
# customer service representative : -0.2330
# plumber                   : -0.2342
# garbage collector         : -0.2365
# paramedic                 : -0.2372
# technical support worker  : -0.2435
# Average Warmth Cosine Similarity: -0.2028
# Average Competence Cosine Similarity: -0.1670

# %%
#project back + projection plot
import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM

#load custom bias directions
warmth_vector = pd.read_csv('data/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('data/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

#normalize vectors
warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

#load model and tokenizer
model_path = "data/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForMaskedLM.from_pretrained(model_path).eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def get_profession_embedding(profession):
    sentence = f"The {profession} is a person."
    inputs = tokenizer(sentence, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model.bert(**inputs)
    #mean pooling over sequence length dimension
    emb = outputs.last_hidden_state.mean(dim=1).squeeze()  # [hidden_size]
    return emb.cpu()

def project_embeddings(professions, direction_vector):
    direction_vector = direction_vector.to(device)
    projections = {}
    for prof in professions:
        emb = get_profession_embedding(prof).to(device)
        score = torch.dot(emb, direction_vector).item()  # scalar projection
        projections[prof] = score
    return projections

#professions list
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

#project onto custom bias directions
warmth_scores = project_embeddings(professions, warmth_vector)
competence_scores = project_embeddings(professions, competence_vector)

print("\n--- Warmth Projections ---")
for p, score in sorted(warmth_scores.items(), key=lambda x: -x[1]):
    print(f"{p}: {score:.4f}")

print("\n--- Competence Projections ---")
for p, score in sorted(competence_scores.items(), key=lambda x: -x[1]):
    print(f"{p}: {score:.4f}")
####plot for projections
import matplotlib.pyplot as plt

# Prepare coordinates
x_vals = [warmth_scores[prof] for prof in professions]
y_vals = [competence_scores[prof] for prof in professions]

plt.figure(figsize=(12, 8))
plt.scatter(x_vals, y_vals)

# Add profession labels
for i, prof in enumerate(professions):
    plt.text(x_vals[i] + 0.002, y_vals[i] + 0.002, prof, fontsize=9)

plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)
plt.axvline(0, color='gray', linestyle='--', linewidth=0.7)
plt.title("Profession Projections on Warmth and Competence Bias Directions")
plt.xlabel("Warmth Score")
plt.ylabel("Competence Score")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# --- Warmth Projections ---
# paramedic: -0.6679
# doctor: -1.2385
# nurse: -1.3333
# teacher: -1.3661
# professor: -1.3703
# dentist: -1.3914
# psychiatrist: -1.3926
# vet: -1.4054
# police: -1.4279
# medical assistant: -1.4450
# writer: -1.5222
# scientist: -1.5225
# librarian: -1.5322
# artist: -1.5331
# actor: -1.5344
# firefighter: -1.6193
# politician: -1.6289
# pilot: -1.6543
# director: -1.6794
# lawyer: -1.6884
# maid: -1.7030
# chef: -1.7330
# fisherman: -1.7525
# c.e.o: -1.7551
# travel agent: -1.7573
# architect: -1.7638
# childcare worker: -1.7803
# engineer: -1.7834
# waiter: -1.7869
# manager: -1.7874
# secretary: -1.7988
# farmer: -1.8144
# taxi driver: -1.8201
# mechanic: -1.8296
# lab technician: -1.8640
# news anchor: -1.8823
# bus driver: -1.8907
# accountant: -1.9275
# bartender: -1.9436
# postal worker: -1.9552
# cashier: -1.9610
# welder: -1.9613
# bank teller: -1.9703
# security guard: -1.9757
# custodian: -1.9921
# graphic designer: -1.9926
# financial advisor: -2.0191
# salesperson: -2.0206
# landscaper: -2.0365
# customer service representative: -2.0628
# plumber: -2.0645
# electrician: -2.0675
# truck driver: -2.0684
# computer programmer: -2.1119
# garbage collector: -2.1347
# technical support worker: -2.1631
# construction worker: -2.1819
# factory worker: -2.2347
#
# --- Competence Projections ---
# professor: -0.5691
# doctor: -0.7715
# news anchor: -0.8139
# scientist: -0.8242
# writer: -0.8594
# actor: -0.8832
# director: -0.8879
# psychiatrist: -0.8885
# artist: -0.9459
# teacher: -1.0022
# lawyer: -1.0152
# politician: -1.0922
# secretary: -1.0930
# police: -1.1143
# librarian: -1.1609
# engineer: -1.1696
# chef: -1.2054
# c.e.o: -1.2087
# pilot: -1.2105
# nurse: -1.2161
# vet: -1.2359
# manager: -1.2403
# dentist: -1.2468
# architect: -1.2553
# fisherman: -1.3499
# maid: -1.3780
# farmer: -1.3994
# accountant: -1.4117
# financial advisor: -1.4305
# computer programmer: -1.4415
# medical assistant: -1.4709
# waiter: -1.4847
# bartender: -1.5608
# travel agent: -1.5801
# graphic designer: -1.5902
# landscaper: -1.5960
# mechanic: -1.6056
# lab technician: -1.6408
# custodian: -1.6866
# truck driver: -1.7398
# welder: -1.7702
# firefighter: -1.7831
# bus driver: -1.7859
# factory worker: -1.8441
# postal worker: -1.8445
# bank teller: -1.8541
# salesperson: -1.8798
# childcare worker: -1.9116
# taxi driver: -1.9232
# cashier: -1.9656
# construction worker: -2.0023
# plumber: -2.0287
# security guard: -2.0287
# electrician: -2.0581
# customer service representative: -2.0677
# garbage collector: -2.1002
# paramedic: -2.1827
# technical support worker: -2.2026

# %%
####plot for projections
import matplotlib.pyplot as plt

# Prepare coordinates
x_vals = [warmth_scores[prof] for prof in professions]
y_vals = [competence_scores[prof] for prof in professions]

plt.figure(figsize=(12, 8))
plt.scatter(x_vals, y_vals)

# Add profession labels
for i, prof in enumerate(professions):
    plt.text(x_vals[i] + 0.002, y_vals[i] + 0.002, prof, fontsize=9)

plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)
plt.axvline(0, color='gray', linestyle='--', linewidth=0.7)
plt.title("Profession Projections on Warmth and Competence Bias Directions")
plt.xlabel("Warmth Score")
plt.ylabel("Competence Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#embeddings extraction

from transformers import BertTokenizer, BertForMaskedLM
import torch
import csv

#load model and tokenizer
model_path = "data/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = DebiasedBertForMaskedLM.from_pretrained(model_path, components=components, weights=weights, tokenizer=tokenizer)
model.to(device)
model.eval()

def get_profession_embedding(profession, model, tokenizer, device):
    sentence = f"The {profession} is there."  # neutral context
    inputs = tokenizer(sentence, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        hidden_states = outputs.last_hidden_state.squeeze(0)  # shape: [seq_len, hidden_dim]

    tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    #find start index of profession tokens
    for i in range(len(tokens) - len(profession_tokens) + 1):
        if tokens[i:i+len(profession_tokens)] == profession_tokens:
            start, end = i, i + len(profession_tokens)
            break
    else:
        raise ValueError(f"Could not find token span for profession: {profession}")

    #get mean embedding over profession token span
    profession_embedding = hidden_states[start+1:end+1].mean(dim=0)  # +1 due to [CLS] token at position 0
    return profession_embedding.cpu()

import pandas as pd

professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

embedding_dict = {}
for prof in tqdm(professions):
    try:
        emb = get_profession_embedding(prof, model, tokenizer, device)
        embedding_dict[prof] = emb.numpy()
    except Exception as e:
        print(f"Could not extract embedding for {prof}: {e}")

#save to csv
csv_path = "profession_embeddings_debiased_w=1_c=0.csv"
with open(csv_path, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    
    #determine the dimension from one of the embeddings
    dim = next(iter(embedding_dict.values())).shape[0]
    
    #header: ["Profession", "dim_0", "dim_1", ..., "dim_n"]
    header = ["Profession"] + [f"dim_{i}" for i in range(dim)]
    writer.writerow(header)
    
    # Write each profession and its embedding
    for prof, emb in embedding_dict.items():
        row = [prof] + emb.tolist()
        writer.writerow(row)

print(f"Saved profession embeddings to {csv_path}")
# Out:
# 100%|███████████████████████████████████████████| 58/58 [00:02<00:00, 19.40it/s]
# Saved profession embeddings to profession_embeddings_debiased_w=1_c=0.csv
