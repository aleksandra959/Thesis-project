# %%
#MODEL WITH DEBIASING (w=0; c=0)

# %%
#w=0, c=0
import torch
from transformers import BertTokenizer, BertForMaskedLM
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from tqdm import tqdm
import torch.nn.functional as F
from contextlib import contextmanager
import os
import copy

#load and normalize warmth/competence vectors
warmth_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

def gram_schmidt(vectors):
    ortho = []
    for v in vectors:
        for u in ortho:
            v = v - torch.dot(v, u) * u
        v = v / torch.norm(v)
        ortho.append(v)
    return ortho

g0, g1 = gram_schmidt([warmth_vector, competence_vector])
components = [g0, g1]
weights = [0.0, 0.0]

def debias_custom(h, components, weights, n_mask=None):
    debiased = h.clone()
    for i, g in enumerate(components):
        weight = weights[i]
        n = n_mask[i] if n_mask is not None else 1
        debiased -= weight * n * torch.dot(h, g) * g
    return debiased

class MLM_Dataset(Dataset):
    def __init__(self, texts, tokenizer, max_len=128, mask_prob=0.15):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.mask_prob = mask_prob
        self.mask_token_id = tokenizer.mask_token_id

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        text = self.texts[item]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].flatten()
        attention_mask = encoding["attention_mask"].flatten()

        labels = input_ids.clone()

        # Identify manually placed [MASK] tokens
        manual_mask_positions = (input_ids == self.mask_token_id)

        # Create random mask with 15% probability
        rand = torch.rand(input_ids.shape)
        special_tokens = torch.tensor([
            self.tokenizer.cls_token_id,
            self.tokenizer.sep_token_id,
            self.tokenizer.pad_token_id
        ])
        is_special_token = input_ids.unsqueeze(-1).eq(special_tokens).any(dim=-1)

        #random mask (excluding special tokens and manually masked tokens)
        random_mask_positions = (rand < self.mask_prob) & (~is_special_token) & (~manual_mask_positions)

        #final mask = manual [MASK] + random 15%
        final_mask = manual_mask_positions | random_mask_positions

        labels[~final_mask] = -100  # Only compute loss on these
        input_ids[random_mask_positions] = self.mask_token_id  # Replace only random ones with [MASK]

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels
        }


class DebiasedBertForMaskedLM(BertForMaskedLM):
    def __init__(self, config, components, weights, tokenizer, debias_all_tokens=True):
        super().__init__(config)
        self.components = components
        self.weights = weights
        self.tokenizer = tokenizer
        self.debias_all_tokens = debias_all_tokens

    def forward(self, input_ids, attention_mask=None, token_type_ids=None, labels=None):
        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            return_dict=True
        )
        sequence_output = outputs.last_hidden_state
        debiased_sequence_output = sequence_output.clone()
        if self.debias_all_tokens:
            for batch_idx in range(input_ids.size(0)):
                for token_idx in range(input_ids.size(1)):
                    h = sequence_output[batch_idx, token_idx]
                    debiased_sequence_output[batch_idx, token_idx] = debias_custom(h, self.components, self.weights)
        else:
            mask_token_index = (input_ids == self.tokenizer.mask_token_id)
            for batch_idx in range(input_ids.size(0)):
                for token_idx in torch.where(mask_token_index[batch_idx])[0]:
                    h = sequence_output[batch_idx, token_idx]
                    debiased_sequence_output[batch_idx, token_idx] = debias_custom(h, self.components, self.weights)

        prediction_scores = self.cls(debiased_sequence_output)
        loss = None
        if labels is not None:
            loss_fct = torch.nn.CrossEntropyLoss()
            loss = loss_fct(prediction_scores.view(-1, self.config.vocab_size), labels.view(-1))
        return {"loss": loss, "logits": prediction_scores}

#setup device and AMP support
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_amp = torch.cuda.is_available()

if use_amp:
    from torch.cuda.amp import autocast, GradScaler
    scaler = GradScaler()
else:
    @contextmanager
    def autocast():
        yield
    scaler = None

def train_finetune(model, train_loader, val_loader, epochs=7, learning_rate=5e-6, weight_decay=0.01):
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    model.train()

    for epoch in range(epochs):
        epoch_loss = 0
        loop = tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{epochs}")
        for batch in loop:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            optimizer.zero_grad()
            with autocast():
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs['loss']

            if use_amp:
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                optimizer.step()

            epoch_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = epoch_loss / len(train_loader)

        #validation step
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                val_loss += outputs['loss'].item()
        avg_val_loss = val_loss / len(val_loader)
        model.train()

        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

def print_masked_predictions(model, tokenizer, sentences, top_k=5):
    model.eval()
    for sent in sentences:
        encoding = tokenizer.encode_plus(
            sent,
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].to(device)
        attention_mask = encoding["attention_mask"].to(device)

        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs["logits"]

        mask_token_index = (input_ids == tokenizer.mask_token_id)[0].nonzero(as_tuple=True)[0]
        probs = F.softmax(logits[0, mask_token_index, :], dim=-1)
        top_probs, top_indices = probs.topk(top_k, dim=-1)

        print(f"\nInput: {sent}")
        print("Top predictions for [MASK]:")
        for prob, idx in zip(top_probs[0], top_indices[0]):
            token = tokenizer.decode([idx.item()])
            print(f"  {token.strip()} (prob={prob.item():.4f})")

#setup tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

#load csv with sentences (using only 2nd column)
df = pd.read_csv('/Users/aleksandragarbat/Desktop/cleaned_one_masked_sentence_per_job.csv', header=None)
all_sentences = df.iloc[:, 1].dropna().tolist()  # Use second column

#split dataset 80/20 train/val
train_size = int(0.8 * len(all_sentences))
val_size = len(all_sentences) - train_size

train_texts = all_sentences[:train_size]
val_texts = all_sentences[train_size:]

train_dataset = MLM_Dataset(train_texts, tokenizer)
val_dataset = MLM_Dataset(val_texts, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0, pin_memory=(device.type=="cuda"))
val_loader = DataLoader(val_dataset, batch_size=16, num_workers=0, pin_memory=(device.type=="cuda"))

debias_model = DebiasedBertForMaskedLM.from_pretrained(
    "bert-base-uncased",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

debias_model.to(device)

#train with a lower learning rate and add gradient clipping for stability
def train_finetune_stable(
    model, train_loader, val_loader,
    epochs=7, learning_rate=5e-6,
    max_grad_norm=1.0, weight_decay=0.01,
    patience=2,
    save_dir="/Users/aleksandragarbat/Desktop/BERT_finetuned"
):
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    best_val_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    os.makedirs(save_dir, exist_ok=True)

    for epoch in range(epochs):
        epoch_loss = 0
        model.train()
        loop = tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{epochs}")
        for batch in loop:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            optimizer.zero_grad()
            with autocast():
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs['loss']

            if use_amp:
                scaler.scale(loss).backward()
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                optimizer.step()

            epoch_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = epoch_loss / len(train_loader)

        #validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                val_loss += outputs['loss'].item()
        avg_val_loss = val_loss / len(val_loader)

        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

        # Early stopping check
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print("Validation loss improved. Saving model...")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    #restore best model weights
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    #save final model and tokenizer
    model.save_pretrained(save_dir)
    tokenizer.save_pretrained(save_dir)

    torch.save({
        'components': components,
        'weights': weights
    }, os.path.join(save_dir, 'bias_vectors.pt'))

    print(f"Model saved to: {save_dir}")

# Run training with weight decay
train_finetune_stable(
    debias_model,
    train_loader,
    val_loader,
    epochs=7,
    learning_rate=5e-6,
    patience=2,
    save_dir="/Users/aleksandragarbat/Desktop/BERT_finetuned"
)
# Out:
# Training Epoch 1/7: 100%|████████████| 51/51 [07:09<00:00,  8.41s/it, loss=3.73]
# Epoch 1, Train Loss: 4.6295, Val Loss: 3.7860
# Validation loss improved. Saving model...
# Training Epoch 2/7: 100%|████████████| 51/51 [06:59<00:00,  8.22s/it, loss=1.64]
# Epoch 2, Train Loss: 3.0911, Val Loss: 2.5775
# Validation loss improved. Saving model...
# Training Epoch 3/7: 100%|████████████| 51/51 [07:15<00:00,  8.54s/it, loss=2.13]
# Epoch 3, Train Loss: 2.0736, Val Loss: 2.0418
# Validation loss improved. Saving model...
# Training Epoch 4/7: 100%|████████████| 51/51 [07:02<00:00,  8.29s/it, loss=1.38]
# Epoch 4, Train Loss: 1.7871, Val Loss: 2.0314
# Validation loss improved. Saving model...
# Training Epoch 5/7: 100%|████████████| 51/51 [07:12<00:00,  8.49s/it, loss=1.08]
# Epoch 5, Train Loss: 1.6113, Val Loss: 1.8081
# Validation loss improved. Saving model...
# Training Epoch 6/7: 100%|████████████| 51/51 [07:11<00:00,  8.46s/it, loss=1.76]
# Epoch 6, Train Loss: 1.7049, Val Loss: 1.7910
# Validation loss improved. Saving model...
# Training Epoch 7/7: 100%|████████████| 51/51 [07:09<00:00,  8.42s/it, loss=1.43]
# Epoch 7, Train Loss: 1.6473, Val Loss: 1.6617
# Validation loss improved. Saving model...
# Model saved to: /Users/aleksandragarbat/Desktop/BERT_finetuned

# %%
##### access model
#load debiasing components (bias directions)
bias_data = torch.load('/Users/aleksandragarbat/Desktop/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer
tokenizer = BertTokenizer.from_pretrained("/Users/aleksandragarbat/Desktop/BERT_finetuned")

#load model (custom class)
model = DebiasedBertForMaskedLM.from_pretrained(
    "/Users/aleksandragarbat/Desktop/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True 
)
###access model
bias_data = torch.load('/Users/aleksandragarbat/Desktop/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer and model
tokenizer = BertTokenizer.from_pretrained("/Users/aleksandragarbat/Desktop/BERT_finetuned")
model = DebiasedBertForMaskedLM.from_pretrained(
    "/Users/aleksandragarbat/Desktop/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True 
)

# %%
#batched pll (warmth)
import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForMaskedLM
import csv


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()


#load sentences from csv file
sentences_file = "/Users/aleksandragarbat/Desktop/pll_sentences_warmth.csv"
sentence_templates = []

with open(sentences_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        # Assuming the CSV has a column named 'sentence'
        sentence_templates.append(row['sentence'])

print(f"Loaded {len(sentence_templates)} sentences from {sentences_file}")



#list of professions (some multi-token)
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"

]

def approximate_pll_batched(sentence_template, profession):
    sentence = sentence_template.replace("[MASK]", profession)

    full_tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    def find_sublist(full, sub):
        for i in range(len(full) - len(sub) + 1):
            if full[i:i+len(sub)] == sub:
                return i
        return -1

    start_idx = find_sublist(full_tokens, profession_tokens)
    if start_idx == -1:
        print(f"Could not find profession tokens in the sentence tokens: {profession}")
        return None

    masked_inputs = []
    mask_positions = []
    for i in range(len(profession_tokens)):
        masked_tokens = full_tokens.copy()
        masked_tokens[start_idx + i] = tokenizer.mask_token
        input_ids = tokenizer.convert_tokens_to_ids(masked_tokens)
        input_ids = tokenizer.build_inputs_with_special_tokens(input_ids)
        masked_inputs.append(input_ids)

    #pad the batch
    max_len = max(len(x) for x in masked_inputs)
    padded_inputs = []
    attention_masks = []

    for input_ids in masked_inputs:
        padding_length = max_len - len(input_ids)
        padded = input_ids + [tokenizer.pad_token_id] * padding_length
        padded_inputs.append(padded)
        attention_masks.append([1] * len(input_ids) + [0] * padding_length)

    input_ids_tensor = torch.tensor(padded_inputs).to(device)
    attention_mask_tensor = torch.tensor(attention_masks).to(device)

    with torch.no_grad():
        outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
        logits = outputs['logits']

    log_probs = []
    for i in range(len(profession_tokens)):
        #find mask token index in this input
        mask_token_index = (input_ids_tensor[i] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0].item()
        softmax_logits = F.softmax(logits[i, mask_token_index], dim=0)
        target_token_id = tokenizer.convert_tokens_to_ids(profession_tokens[i])
        token_prob = softmax_logits[target_token_id].item()
        token_prob = max(token_prob, 1e-10)
        log_probs.append(torch.log(torch.tensor(token_prob)))

    approx_pll = torch.sum(torch.stack(log_probs)).item()
    return approx_pll


#evaluate PLL for each profession on each sentence template
for sentence_template in sentence_templates:
    print(f"\nSentence: \"{sentence_template}\"\n{'-'*60}")

    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")

    print()
# Out:
# Loaded 200 sentences from /Users/aleksandragarbat/Desktop/pll_sentences_warmth.csv
#
# Sentence: "A pleased [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.6977
# Profession: vet                  -> Approx. PLL: -10.4821
# Profession: paramedic            -> Approx. PLL: -0.0022
# Profession: chef                 -> Approx. PLL: -8.6349
# Profession: dentist              -> Approx. PLL: -10.6927
# Profession: maid                 -> Approx. PLL: -11.0087
# Profession: doctor               -> Approx. PLL: -7.3043
# Profession: nurse                -> Approx. PLL: -8.8288
# Profession: scientist            -> Approx. PLL: -7.2841
# Profession: welder               -> Approx. PLL: -1.4605
# Profession: teacher              -> Approx. PLL: -6.7293
# Profession: waiter               -> Approx. PLL: -9.2366
# Profession: mechanic             -> Approx. PLL: -9.4204
# Profession: police               -> Approx. PLL: -14.3973
# Profession: secretary            -> Approx. PLL: -10.5162
# Profession: psychiatrist         -> Approx. PLL: -13.4356
# Profession: farmer               -> Approx. PLL: -9.4398
# Profession: pilot                -> Approx. PLL: -7.5510
# Profession: director             -> Approx. PLL: -8.1570
# Profession: architect            -> Approx. PLL: -11.2628
# Profession: c.e.o                -> Approx. PLL: -10.8322
# Profession: artist               -> Approx. PLL: -8.8813
# Profession: writer               -> Approx. PLL: -9.0932
# Profession: fisherman            -> Approx. PLL: -10.7243
# Profession: medical assistant    -> Approx. PLL: -8.3972
# Profession: manager              -> Approx. PLL: -5.5081
# Profession: librarian            -> Approx. PLL: -11.8611
# Profession: politician           -> Approx. PLL: -7.3107
# Profession: engineer             -> Approx. PLL: -9.0539
# Profession: bartender            -> Approx. PLL: -9.1073
# Profession: accountant           -> Approx. PLL: -11.0603
# Profession: firefighter          -> Approx. PLL: -0.6162
# Profession: travel agent         -> Approx. PLL: -8.0165
# Profession: lawyer               -> Approx. PLL: -8.3723
# Profession: actor                -> Approx. PLL: -6.6539
# Profession: lab technician       -> Approx. PLL: -3.8750
# Profession: security guard       -> Approx. PLL: -1.3110
# Profession: custodian            -> Approx. PLL: -0.0006
# Profession: childcare worker     -> Approx. PLL: -3.6379
# Profession: bank teller          -> Approx. PLL: -3.7644
# Profession: taxi driver          -> Approx. PLL: -7.0431
# Profession: bus driver           -> Approx. PLL: -6.6584
# Profession: news anchor          -> Approx. PLL: -3.8607
# Profession: customer service representative -> Approx. PLL: -8.7854
# Profession: cashier              -> Approx. PLL: -0.7641
# Profession: plumber              -> Approx. PLL: -0.5246
# Profession: technical support worker -> Approx. PLL: -9.7521
# Profession: electrician          -> Approx. PLL: -1.1541
# Profession: graphic designer     -> Approx. PLL: -3.9861
# Profession: financial advisor    -> Approx. PLL: -6.2302
# Profession: salesperson          -> Approx. PLL: -3.0563
# Profession: truck driver         -> Approx. PLL: -6.5049
# Profession: landscaper           -> Approx. PLL: -7.5512
# Profession: postal worker        -> Approx. PLL: -7.7516
# Profession: factory worker       -> Approx. PLL: -5.1151
# Profession: garbage collector    -> Approx. PLL: -5.2482
# Profession: computer programmer  -> Approx. PLL: -4.7681
# Profession: construction worker  -> Approx. PLL: -3.2170
#
#
# Sentence: "Everyone admired the pleased [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.1083
# Profession: vet                  -> Approx. PLL: -12.5364
# Profession: paramedic            -> Approx. PLL: -2.2937
# Profession: chef                 -> Approx. PLL: -8.3374
# Profession: dentist              -> Approx. PLL: -10.5991
# Profession: maid                 -> Approx. PLL: -10.0347
# Profession: doctor               -> Approx. PLL: -6.8260
# Profession: nurse                -> Approx. PLL: -8.9265
# Profession: scientist            -> Approx. PLL: -7.1045
# Profession: welder               -> Approx. PLL: -13.2655
# Profession: teacher              -> Approx. PLL: -7.6210
# Profession: waiter               -> Approx. PLL: -8.2379
# Profession: mechanic             -> Approx. PLL: -9.7441
# Profession: police               -> Approx. PLL: -8.1093
# Profession: secretary            -> Approx. PLL: -10.4434
# Profession: psychiatrist         -> Approx. PLL: -13.2754
# Profession: farmer               -> Approx. PLL: -8.2866
# Profession: pilot                -> Approx. PLL: -9.4441
# Profession: director             -> Approx. PLL: -8.6193
# Profession: architect            -> Approx. PLL: -9.4870
# Profession: c.e.o                -> Approx. PLL: -10.4151
# Profession: artist               -> Approx. PLL: -6.3023
# Profession: writer               -> Approx. PLL: -11.0938
# Profession: fisherman            -> Approx. PLL: -10.4142
# Profession: medical assistant    -> Approx. PLL: -12.6511
# Profession: manager              -> Approx. PLL: -7.5176
# Profession: librarian            -> Approx. PLL: -9.6616
# Profession: politician           -> Approx. PLL: -7.5974
# Profession: engineer             -> Approx. PLL: -8.5561
# Profession: bartender            -> Approx. PLL: -8.2349
# Profession: accountant           -> Approx. PLL: -10.4502
# Profession: firefighter          -> Approx. PLL: -3.9741
# Profession: travel agent         -> Approx. PLL: -7.5463
# Profession: lawyer               -> Approx. PLL: -8.3730
# Profession: actor                -> Approx. PLL: -8.0967
# Profession: lab technician       -> Approx. PLL: -6.6539
# Profession: security guard       -> Approx. PLL: -2.4807
# Profession: custodian            -> Approx. PLL: -0.0052
# Profession: childcare worker     -> Approx. PLL: -8.2172
# Profession: bank teller          -> Approx. PLL: -7.9023
# Profession: taxi driver          -> Approx. PLL: -4.8668
# Profession: bus driver           -> Approx. PLL: -5.0410
# Profession: news anchor          -> Approx. PLL: -6.8056
# Profession: customer service representative -> Approx. PLL: -12.0472
# Profession: cashier              -> Approx. PLL: -1.0242
# Profession: plumber              -> Approx. PLL: -3.4986
# Profession: technical support worker -> Approx. PLL: -15.3525
# Profession: electrician          -> Approx. PLL: -3.8777
# Profession: graphic designer     -> Approx. PLL: -5.9454
# Profession: financial advisor    -> Approx. PLL: -5.7299
# Profession: salesperson          -> Approx. PLL: -2.9129
# Profession: truck driver         -> Approx. PLL: -6.5202
# Profession: landscaper           -> Approx. PLL: -9.5505
# Profession: postal worker        -> Approx. PLL: -8.7462
# Profession: factory worker       -> Approx. PLL: -7.8306
# Profession: garbage collector    -> Approx. PLL: -8.3951
# Profession: computer programmer  -> Approx. PLL: -5.5877
# Profession: construction worker  -> Approx. PLL: -6.6108
#
#
# Sentence: "It was clear the pleased [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.8208
# Profession: vet                  -> Approx. PLL: -10.1766
# Profession: paramedic            -> Approx. PLL: -0.1676
# Profession: chef                 -> Approx. PLL: -6.9980
# Profession: dentist              -> Approx. PLL: -9.5277
# Profession: maid                 -> Approx. PLL: -8.3566
# Profession: doctor               -> Approx. PLL: -6.1495
# Profession: nurse                -> Approx. PLL: -6.6622
# Profession: scientist            -> Approx. PLL: -7.0546
# Profession: welder               -> Approx. PLL: -10.9857
# Profession: teacher              -> Approx. PLL: -7.4713
# Profession: waiter               -> Approx. PLL: -6.9310
# Profession: mechanic             -> Approx. PLL: -8.8995
# Profession: police               -> Approx. PLL: -9.2730
# Profession: secretary            -> Approx. PLL: -8.8958
# Profession: psychiatrist         -> Approx. PLL: -12.2825
# Profession: farmer               -> Approx. PLL: -6.8912
# Profession: pilot                -> Approx. PLL: -7.4865
# Profession: director             -> Approx. PLL: -7.6620
# Profession: architect            -> Approx. PLL: -9.9597
# Profession: c.e.o                -> Approx. PLL: -12.3670
# Profession: artist               -> Approx. PLL: -7.6083
# Profession: writer               -> Approx. PLL: -9.3540
# Profession: fisherman            -> Approx. PLL: -9.8492
# Profession: medical assistant    -> Approx. PLL: -10.7760
# Profession: manager              -> Approx. PLL: -5.3462
# Profession: librarian            -> Approx. PLL: -9.3624
# Profession: politician           -> Approx. PLL: -6.0887
# Profession: engineer             -> Approx. PLL: -8.1808
# Profession: bartender            -> Approx. PLL: -7.2795
# Profession: accountant           -> Approx. PLL: -9.9840
# Profession: firefighter          -> Approx. PLL: -2.7175
# Profession: travel agent         -> Approx. PLL: -6.6909
# Profession: lawyer               -> Approx. PLL: -7.3672
# Profession: actor                -> Approx. PLL: -7.2338
# Profession: lab technician       -> Approx. PLL: -3.9904
# Profession: security guard       -> Approx. PLL: -2.3336
# Profession: custodian            -> Approx. PLL: -0.0008
# Profession: childcare worker     -> Approx. PLL: -4.3012
# Profession: bank teller          -> Approx. PLL: -5.4156
# Profession: taxi driver          -> Approx. PLL: -2.8596
# Profession: bus driver           -> Approx. PLL: -4.0767
# Profession: news anchor          -> Approx. PLL: -8.6583
# Profession: customer service representative -> Approx. PLL: -8.4656
# Profession: cashier              -> Approx. PLL: -0.4800
# Profession: plumber              -> Approx. PLL: -0.5017
# Profession: technical support worker -> Approx. PLL: -10.4671
# Profession: electrician          -> Approx. PLL: -1.8614
# Profession: graphic designer     -> Approx. PLL: -4.4939
# Profession: financial advisor    -> Approx. PLL: -4.8549
# Profession: salesperson          -> Approx. PLL: -1.6036
# Profession: truck driver         -> Approx. PLL: -5.0976
# Profession: landscaper           -> Approx. PLL: -7.9857
# Profession: postal worker        -> Approx. PLL: -6.0664
# Profession: factory worker       -> Approx. PLL: -4.5087
# Profession: garbage collector    -> Approx. PLL: -7.7115
# Profession: computer programmer  -> Approx. PLL: -3.9540
# Profession: construction worker  -> Approx. PLL: -3.7322
#
#
# Sentence: "A pleased [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.2548
# Profession: vet                  -> Approx. PLL: -12.1405
# Profession: paramedic            -> Approx. PLL: -0.0025
# Profession: chef                 -> Approx. PLL: -8.6236
# Profession: dentist              -> Approx. PLL: -10.2395
# Profession: maid                 -> Approx. PLL: -10.6092
# Profession: doctor               -> Approx. PLL: -7.7812
# Profession: nurse                -> Approx. PLL: -8.2342
# Profession: scientist            -> Approx. PLL: -6.6138
# Profession: welder               -> Approx. PLL: -1.3227
# Profession: teacher              -> Approx. PLL: -5.0680
# Profession: waiter               -> Approx. PLL: -7.8795
# Profession: mechanic             -> Approx. PLL: -9.2339
# Profession: police               -> Approx. PLL: -14.5929
# Profession: secretary            -> Approx. PLL: -9.2316
# Profession: psychiatrist         -> Approx. PLL: -12.7553
# Profession: farmer               -> Approx. PLL: -9.5309
# Profession: pilot                -> Approx. PLL: -9.3379
# Profession: director             -> Approx. PLL: -6.6588
# Profession: architect            -> Approx. PLL: -10.6461
# Profession: c.e.o                -> Approx. PLL: -9.5010
# Profession: artist               -> Approx. PLL: -7.0320
# Profession: writer               -> Approx. PLL: -8.0411
# Profession: fisherman            -> Approx. PLL: -13.0026
# Profession: medical assistant    -> Approx. PLL: -9.0681
# Profession: manager              -> Approx. PLL: -5.0362
# Profession: librarian            -> Approx. PLL: -10.8147
# Profession: politician           -> Approx. PLL: -8.1807
# Profession: engineer             -> Approx. PLL: -7.6851
# Profession: bartender            -> Approx. PLL: -8.8390
# Profession: accountant           -> Approx. PLL: -10.3477
# Profession: firefighter          -> Approx. PLL: -0.8674
# Profession: travel agent         -> Approx. PLL: -8.0867
# Profession: lawyer               -> Approx. PLL: -9.1738
# Profession: actor                -> Approx. PLL: -6.7050
# Profession: lab technician       -> Approx. PLL: -5.1998
# Profession: security guard       -> Approx. PLL: -0.8725
# Profession: custodian            -> Approx. PLL: -0.0029
# Profession: childcare worker     -> Approx. PLL: -3.9403
# Profession: bank teller          -> Approx. PLL: -3.8453
# Profession: taxi driver          -> Approx. PLL: -3.1310
# Profession: bus driver           -> Approx. PLL: -2.0691
# Profession: news anchor          -> Approx. PLL: -4.6886
# Profession: customer service representative -> Approx. PLL: -8.5714
# Profession: cashier              -> Approx. PLL: -0.6333
# Profession: plumber              -> Approx. PLL: -0.4084
# Profession: technical support worker -> Approx. PLL: -9.4434
# Profession: electrician          -> Approx. PLL: -0.8303
# Profession: graphic designer     -> Approx. PLL: -3.8589
# Profession: financial advisor    -> Approx. PLL: -6.1159
# Profession: salesperson          -> Approx. PLL: -2.2015
# Profession: truck driver         -> Approx. PLL: -3.2981
# Profession: landscaper           -> Approx. PLL: -7.5917
# Profession: postal worker        -> Approx. PLL: -9.1387
# Profession: factory worker       -> Approx. PLL: -4.5965
# Profession: garbage collector    -> Approx. PLL: -2.7436
# Profession: computer programmer  -> Approx. PLL: -4.8965
# Profession: construction worker  -> Approx. PLL: -5.2605
#
#
# Sentence: "The pleased [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.1744
# Profession: vet                  -> Approx. PLL: -12.8975
# Profession: paramedic            -> Approx. PLL: -2.0326
# Profession: chef                 -> Approx. PLL: -9.1649
# Profession: dentist              -> Approx. PLL: -11.3947
# Profession: maid                 -> Approx. PLL: -9.8520
# Profession: doctor               -> Approx. PLL: -7.8451
# Profession: nurse                -> Approx. PLL: -9.0552
# Profession: scientist            -> Approx. PLL: -8.4695
# Profession: welder               -> Approx. PLL: -14.6285
# Profession: teacher              -> Approx. PLL: -7.6772
# Profession: waiter               -> Approx. PLL: -9.1441
# Profession: mechanic             -> Approx. PLL: -11.1035
# Profession: police               -> Approx. PLL: -8.4729
# Profession: secretary            -> Approx. PLL: -10.9184
# Profession: psychiatrist         -> Approx. PLL: -13.9779
# Profession: farmer               -> Approx. PLL: -7.4649
# Profession: pilot                -> Approx. PLL: -11.0221
# Profession: director             -> Approx. PLL: -9.2529
# Profession: architect            -> Approx. PLL: -10.0632
# Profession: c.e.o                -> Approx. PLL: -9.8790
# Profession: artist               -> Approx. PLL: -7.5797
# Profession: writer               -> Approx. PLL: -11.0243
# Profession: fisherman            -> Approx. PLL: -9.5213
# Profession: medical assistant    -> Approx. PLL: -13.8897
# Profession: manager              -> Approx. PLL: -7.1394
# Profession: librarian            -> Approx. PLL: -9.8967
# Profession: politician           -> Approx. PLL: -8.0937
# Profession: engineer             -> Approx. PLL: -10.5778
# Profession: bartender            -> Approx. PLL: -8.1177
# Profession: accountant           -> Approx. PLL: -10.0821
# Profession: firefighter          -> Approx. PLL: -4.1622
# Profession: travel agent         -> Approx. PLL: -6.8108
# Profession: lawyer               -> Approx. PLL: -9.1461
# Profession: actor                -> Approx. PLL: -8.5493
# Profession: lab technician       -> Approx. PLL: -7.9371
# Profession: security guard       -> Approx. PLL: -3.2686
# Profession: custodian            -> Approx. PLL: -0.0031
# Profession: childcare worker     -> Approx. PLL: -6.4908
# Profession: bank teller          -> Approx. PLL: -5.4183
# Profession: taxi driver          -> Approx. PLL: -3.8189
# Profession: bus driver           -> Approx. PLL: -3.6318
# Profession: news anchor          -> Approx. PLL: -6.3163
# Profession: customer service representative -> Approx. PLL: -10.0279
# Profession: cashier              -> Approx. PLL: -1.2326
# Profession: plumber              -> Approx. PLL: -1.6466
# Profession: technical support worker -> Approx. PLL: -15.5499
# Profession: electrician          -> Approx. PLL: -3.3248
# Profession: graphic designer     -> Approx. PLL: -5.0717
# Profession: financial advisor    -> Approx. PLL: -7.8607
# Profession: salesperson          -> Approx. PLL: -5.5978
# Profession: truck driver         -> Approx. PLL: -6.4720
# Profession: landscaper           -> Approx. PLL: -7.9859
# Profession: postal worker        -> Approx. PLL: -10.2299
# Profession: factory worker       -> Approx. PLL: -9.8963
# Profession: garbage collector    -> Approx. PLL: -4.6581
# Profession: computer programmer  -> Approx. PLL: -6.0105
# Profession: construction worker  -> Approx. PLL: -9.6125
#
#
# Sentence: "A benevolent [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.3042
# Profession: vet                  -> Approx. PLL: -10.9368
# Profession: paramedic            -> Approx. PLL: -0.0034
# Profession: chef                 -> Approx. PLL: -9.3472
# Profession: dentist              -> Approx. PLL: -10.7765
# Profession: maid                 -> Approx. PLL: -11.3431
# Profession: doctor               -> Approx. PLL: -6.9895
# Profession: nurse                -> Approx. PLL: -7.0367
# Profession: scientist            -> Approx. PLL: -9.2531
# Profession: welder               -> Approx. PLL: -0.4040
# Profession: teacher              -> Approx. PLL: -6.0588
# Profession: waiter               -> Approx. PLL: -10.4080
# Profession: mechanic             -> Approx. PLL: -8.5743
# Profession: police               -> Approx. PLL: -12.5010
# Profession: secretary            -> Approx. PLL: -9.4164
# Profession: psychiatrist         -> Approx. PLL: -11.8330
# Profession: farmer               -> Approx. PLL: -9.7809
# Profession: pilot                -> Approx. PLL: -8.3991
# Profession: director             -> Approx. PLL: -6.7458
# Profession: architect            -> Approx. PLL: -9.7448
# Profession: c.e.o                -> Approx. PLL: -10.2344
# Profession: artist               -> Approx. PLL: -9.6578
# Profession: writer               -> Approx. PLL: -10.1481
# Profession: fisherman            -> Approx. PLL: -9.8218
# Profession: medical assistant    -> Approx. PLL: -7.7911
# Profession: manager              -> Approx. PLL: -4.2365
# Profession: librarian            -> Approx. PLL: -9.4338
# Profession: politician           -> Approx. PLL: -7.6703
# Profession: engineer             -> Approx. PLL: -8.6466
# Profession: bartender            -> Approx. PLL: -8.5334
# Profession: accountant           -> Approx. PLL: -9.5371
# Profession: firefighter          -> Approx. PLL: -0.5793
# Profession: travel agent         -> Approx. PLL: -9.3143
# Profession: lawyer               -> Approx. PLL: -8.0842
# Profession: actor                -> Approx. PLL: -8.0767
# Profession: lab technician       -> Approx. PLL: -4.9060
# Profession: security guard       -> Approx. PLL: -2.8609
# Profession: custodian            -> Approx. PLL: -0.0009
# Profession: childcare worker     -> Approx. PLL: -5.6227
# Profession: bank teller          -> Approx. PLL: -8.9389
# Profession: taxi driver          -> Approx. PLL: -6.1241
# Profession: bus driver           -> Approx. PLL: -5.6617
# Profession: news anchor          -> Approx. PLL: -3.8200
# Profession: customer service representative -> Approx. PLL: -11.8323
# Profession: cashier              -> Approx. PLL: -4.0803
# Profession: plumber              -> Approx. PLL: -0.4864
# Profession: technical support worker -> Approx. PLL: -12.8170
# Profession: electrician          -> Approx. PLL: -0.7617
# Profession: graphic designer     -> Approx. PLL: -3.1462
# Profession: financial advisor    -> Approx. PLL: -6.2073
# Profession: salesperson          -> Approx. PLL: -5.6558
# Profession: truck driver         -> Approx. PLL: -4.9204
# Profession: landscaper           -> Approx. PLL: -8.0105
# Profession: postal worker        -> Approx. PLL: -9.8313
# Profession: factory worker       -> Approx. PLL: -5.8308
# Profession: garbage collector    -> Approx. PLL: -1.9550
# Profession: computer programmer  -> Approx. PLL: -4.5199
# Profession: construction worker  -> Approx. PLL: -6.0974
#
#
# Sentence: "Everyone admired the benevolent [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.9815
# Profession: vet                  -> Approx. PLL: -12.9716
# Profession: paramedic            -> Approx. PLL: -3.9938
# Profession: chef                 -> Approx. PLL: -11.2481
# Profession: dentist              -> Approx. PLL: -10.7851
# Profession: maid                 -> Approx. PLL: -12.1301
# Profession: doctor               -> Approx. PLL: -8.9960
# Profession: nurse                -> Approx. PLL: -8.9473
# Profession: scientist            -> Approx. PLL: -8.9641
# Profession: welder               -> Approx. PLL: -10.6714
# Profession: teacher              -> Approx. PLL: -8.7060
# Profession: waiter               -> Approx. PLL: -11.5606
# Profession: mechanic             -> Approx. PLL: -10.9029
# Profession: police               -> Approx. PLL: -5.8050
# Profession: secretary            -> Approx. PLL: -9.6715
# Profession: psychiatrist         -> Approx. PLL: -12.6487
# Profession: farmer               -> Approx. PLL: -9.5353
# Profession: pilot                -> Approx. PLL: -10.4061
# Profession: director             -> Approx. PLL: -8.4335
# Profession: architect            -> Approx. PLL: -8.9610
# Profession: c.e.o                -> Approx. PLL: -10.3364
# Profession: artist               -> Approx. PLL: -8.9335
# Profession: writer               -> Approx. PLL: -12.3818
# Profession: fisherman            -> Approx. PLL: -9.1876
# Profession: medical assistant    -> Approx. PLL: -13.7677
# Profession: manager              -> Approx. PLL: -8.0746
# Profession: librarian            -> Approx. PLL: -9.1277
# Profession: politician           -> Approx. PLL: -9.8628
# Profession: engineer             -> Approx. PLL: -9.8261
# Profession: bartender            -> Approx. PLL: -11.0584
# Profession: accountant           -> Approx. PLL: -10.7401
# Profession: firefighter          -> Approx. PLL: -5.2718
# Profession: travel agent         -> Approx. PLL: -9.2522
# Profession: lawyer               -> Approx. PLL: -9.4115
# Profession: actor                -> Approx. PLL: -10.3870
# Profession: lab technician       -> Approx. PLL: -10.5187
# Profession: security guard       -> Approx. PLL: -3.7759
# Profession: custodian            -> Approx. PLL: -0.0659
# Profession: childcare worker     -> Approx. PLL: -8.6030
# Profession: bank teller          -> Approx. PLL: -13.8184
# Profession: taxi driver          -> Approx. PLL: -7.3313
# Profession: bus driver           -> Approx. PLL: -5.8140
# Profession: news anchor          -> Approx. PLL: -9.7359
# Profession: customer service representative -> Approx. PLL: -13.2131
# Profession: cashier              -> Approx. PLL: -2.6331
# Profession: plumber              -> Approx. PLL: -5.4153
# Profession: technical support worker -> Approx. PLL: -18.5952
# Profession: electrician          -> Approx. PLL: -4.7229
# Profession: graphic designer     -> Approx. PLL: -6.8282
# Profession: financial advisor    -> Approx. PLL: -8.2430
# Profession: salesperson          -> Approx. PLL: -7.2604
# Profession: truck driver         -> Approx. PLL: -7.1056
# Profession: landscaper           -> Approx. PLL: -10.9971
# Profession: postal worker        -> Approx. PLL: -12.1982
# Profession: factory worker       -> Approx. PLL: -11.5748
# Profession: garbage collector    -> Approx. PLL: -6.7598
# Profession: computer programmer  -> Approx. PLL: -6.8326
# Profession: construction worker  -> Approx. PLL: -10.8698
#
#
# Sentence: "It was clear the benevolent [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -5.9342
# Profession: vet                  -> Approx. PLL: -8.9662
# Profession: paramedic            -> Approx. PLL: -0.5800
# Profession: chef                 -> Approx. PLL: -7.7537
# Profession: dentist              -> Approx. PLL: -9.3703
# Profession: maid                 -> Approx. PLL: -9.0603
# Profession: doctor               -> Approx. PLL: -5.6718
# Profession: nurse                -> Approx. PLL: -5.9846
# Profession: scientist            -> Approx. PLL: -6.3830
# Profession: welder               -> Approx. PLL: -8.2530
# Profession: teacher              -> Approx. PLL: -5.2510
# Profession: waiter               -> Approx. PLL: -8.0385
# Profession: mechanic             -> Approx. PLL: -8.1236
# Profession: police               -> Approx. PLL: -7.5987
# Profession: secretary            -> Approx. PLL: -6.9977
# Profession: psychiatrist         -> Approx. PLL: -9.0743
# Profession: farmer               -> Approx. PLL: -6.3125
# Profession: pilot                -> Approx. PLL: -6.9270
# Profession: director             -> Approx. PLL: -5.9052
# Profession: architect            -> Approx. PLL: -7.1301
# Profession: c.e.o                -> Approx. PLL: -11.4145
# Profession: artist               -> Approx. PLL: -7.6296
# Profession: writer               -> Approx. PLL: -8.5818
# Profession: fisherman            -> Approx. PLL: -7.3917
# Profession: medical assistant    -> Approx. PLL: -9.1369
# Profession: manager              -> Approx. PLL: -5.2189
# Profession: librarian            -> Approx. PLL: -5.7992
# Profession: politician           -> Approx. PLL: -6.7138
# Profession: engineer             -> Approx. PLL: -7.7812
# Profession: bartender            -> Approx. PLL: -7.0203
# Profession: accountant           -> Approx. PLL: -7.1715
# Profession: firefighter          -> Approx. PLL: -3.6005
# Profession: travel agent         -> Approx. PLL: -7.5736
# Profession: lawyer               -> Approx. PLL: -6.8528
# Profession: actor                -> Approx. PLL: -7.5191
# Profession: lab technician       -> Approx. PLL: -4.8213
# Profession: security guard       -> Approx. PLL: -3.3789
# Profession: custodian            -> Approx. PLL: -0.0012
# Profession: childcare worker     -> Approx. PLL: -4.3648
# Profession: bank teller          -> Approx. PLL: -11.5194
# Profession: taxi driver          -> Approx. PLL: -3.3138
# Profession: bus driver           -> Approx. PLL: -3.7177
# Profession: news anchor          -> Approx. PLL: -6.6726
# Profession: customer service representative -> Approx. PLL: -10.9229
# Profession: cashier              -> Approx. PLL: -2.0448
# Profession: plumber              -> Approx. PLL: -0.3761
# Profession: technical support worker -> Approx. PLL: -12.0483
# Profession: electrician          -> Approx. PLL: -1.4631
# Profession: graphic designer     -> Approx. PLL: -3.6837
# Profession: financial advisor    -> Approx. PLL: -4.9777
# Profession: salesperson          -> Approx. PLL: -3.6867
# Profession: truck driver         -> Approx. PLL: -4.7449
# Profession: landscaper           -> Approx. PLL: -8.1281
# Profession: postal worker        -> Approx. PLL: -8.1989
# Profession: factory worker       -> Approx. PLL: -6.1886
# Profession: garbage collector    -> Approx. PLL: -4.7404
# Profession: computer programmer  -> Approx. PLL: -4.3904
# Profession: construction worker  -> Approx. PLL: -5.7378
#
#
# Sentence: "A benevolent [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.3569
# Profession: vet                  -> Approx. PLL: -10.4093
# Profession: paramedic            -> Approx. PLL: -0.0045
# Profession: chef                 -> Approx. PLL: -8.7421
# Profession: dentist              -> Approx. PLL: -8.1158
# Profession: maid                 -> Approx. PLL: -11.6699
# Profession: doctor               -> Approx. PLL: -7.0714
# Profession: nurse                -> Approx. PLL: -6.5691
# Profession: scientist            -> Approx. PLL: -7.7535
# Profession: welder               -> Approx. PLL: -0.1218
# Profession: teacher              -> Approx. PLL: -5.0302
# Profession: waiter               -> Approx. PLL: -10.6791
# Profession: mechanic             -> Approx. PLL: -8.2499
# Profession: police               -> Approx. PLL: -11.8918
# Profession: secretary            -> Approx. PLL: -8.7585
# Profession: psychiatrist         -> Approx. PLL: -10.2568
# Profession: farmer               -> Approx. PLL: -8.6465
# Profession: pilot                -> Approx. PLL: -9.6671
# Profession: director             -> Approx. PLL: -5.0320
# Profession: architect            -> Approx. PLL: -7.9482
# Profession: c.e.o                -> Approx. PLL: -8.8891
# Profession: artist               -> Approx. PLL: -8.1300
# Profession: writer               -> Approx. PLL: -9.3264
# Profession: fisherman            -> Approx. PLL: -10.6486
# Profession: medical assistant    -> Approx. PLL: -9.8217
# Profession: manager              -> Approx. PLL: -3.2747
# Profession: librarian            -> Approx. PLL: -7.9580
# Profession: politician           -> Approx. PLL: -8.8484
# Profession: engineer             -> Approx. PLL: -6.3699
# Profession: bartender            -> Approx. PLL: -9.5017
# Profession: accountant           -> Approx. PLL: -7.4616
# Profession: firefighter          -> Approx. PLL: -1.1766
# Profession: travel agent         -> Approx. PLL: -10.2188
# Profession: lawyer               -> Approx. PLL: -7.2753
# Profession: actor                -> Approx. PLL: -8.2080
# Profession: lab technician       -> Approx. PLL: -6.5588
# Profession: security guard       -> Approx. PLL: -3.8792
# Profession: custodian            -> Approx. PLL: -0.0056
# Profession: childcare worker     -> Approx. PLL: -5.9731
# Profession: bank teller          -> Approx. PLL: -11.0891
# Profession: taxi driver          -> Approx. PLL: -4.1808
# Profession: bus driver           -> Approx. PLL: -4.4791
# Profession: news anchor          -> Approx. PLL: -8.6304
# Profession: customer service representative -> Approx. PLL: -8.5130
# Profession: cashier              -> Approx. PLL: -2.3987
# Profession: plumber              -> Approx. PLL: -0.3566
# Profession: technical support worker -> Approx. PLL: -11.0495
# Profession: electrician          -> Approx. PLL: -0.4547
# Profession: salesperson          -> Approx. PLL: -9.2843
# Profession: truck driver         -> Approx. PLL: -5.7011
# Profession: landscaper           -> Approx. PLL: -9.3914
# Profession: postal worker        -> Approx. PLL: -12.5055
# Profession: factory worker       -> Approx. PLL: -10.8691
# Profession: garbage collector    -> Approx. PLL: -5.8198
# Profession: computer programmer  -> Approx. PLL: -10.3358
# Profession: construction worker  -> Approx. PLL: -11.2661
#
#
# Sentence: "A funny [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.6222
# Profession: vet                  -> Approx. PLL: -11.9577
# Profession: paramedic            -> Approx. PLL: -0.0024
# Profession: chef                 -> Approx. PLL: -11.5444
# Profession: dentist              -> Approx. PLL: -11.2661
# Profession: maid                 -> Approx. PLL: -12.1288
# Profession: doctor               -> Approx. PLL: -9.1286
# Profession: nurse                -> Approx. PLL: -10.7247
# Profession: scientist            -> Approx. PLL: -9.5468
# Profession: welder               -> Approx. PLL: -2.3665
# Profession: teacher              -> Approx. PLL: -7.4726
# Profession: waiter               -> Approx. PLL: -10.5511
# Profession: mechanic             -> Approx. PLL: -9.0250
# Profession: police               -> Approx. PLL: -14.0479
# Profession: secretary            -> Approx. PLL: -13.6888
# Profession: psychiatrist         -> Approx. PLL: -13.7586
# Profession: farmer               -> Approx. PLL: -11.5936
# Profession: pilot                -> Approx. PLL: -10.9986
# Profession: director             -> Approx. PLL: -9.2808
# Profession: architect            -> Approx. PLL: -14.8358
# Profession: c.e.o                -> Approx. PLL: -11.8503
# Profession: artist               -> Approx. PLL: -10.3968
# Profession: writer               -> Approx. PLL: -8.7989
# Profession: fisherman            -> Approx. PLL: -10.6046
# Profession: medical assistant    -> Approx. PLL: -11.7845
# Profession: manager              -> Approx. PLL: -9.9909
# Profession: librarian            -> Approx. PLL: -13.6221
# Profession: politician           -> Approx. PLL: -9.9182
# Profession: engineer             -> Approx. PLL: -12.9264
# Profession: bartender            -> Approx. PLL: -10.3003
# Profession: accountant           -> Approx. PLL: -13.2808
# Profession: firefighter          -> Approx. PLL: -3.5096
# Profession: travel agent         -> Approx. PLL: -13.0688
# Profession: lawyer               -> Approx. PLL: -10.1318
# Profession: actor                -> Approx. PLL: -7.2795
# Profession: lab technician       -> Approx. PLL: -8.2943
# Profession: security guard       -> Approx. PLL: -6.3637
# Profession: custodian            -> Approx. PLL: -0.0016
# Profession: childcare worker     -> Approx. PLL: -8.4223
# Profession: bank teller          -> Approx. PLL: -10.3359
# Profession: taxi driver          -> Approx. PLL: -7.0542
# Profession: bus driver           -> Approx. PLL: -7.4770
# Profession: news anchor          -> Approx. PLL: -5.9848
# Profession: customer service representative -> Approx. PLL: -9.6854
# Profession: cashier              -> Approx. PLL: -6.6680
# Profession: plumber              -> Approx. PLL: -0.9569
# Profession: technical support worker -> Approx. PLL: -13.9229
# Profession: electrician          -> Approx. PLL: -5.4238
# Profession: graphic designer     -> Approx. PLL: -9.0142
# Profession: financial advisor    -> Approx. PLL: -10.7176
# Profession: salesperson          -> Approx. PLL: -6.5121
# Profession: truck driver         -> Approx. PLL: -6.2103
# Profession: landscaper           -> Approx. PLL: -16.1960
# Profession: postal worker        -> Approx. PLL: -10.4279
# Profession: factory worker       -> Approx. PLL: -9.4479
# Profession: garbage collector    -> Approx. PLL: -5.6376
# Profession: computer programmer  -> Approx. PLL: -7.8931
# Profession: construction worker  -> Approx. PLL: -8.4906
#
#
# Sentence: "Everyone admired the funny [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.8502
# Profession: vet                  -> Approx. PLL: -13.7979
# Profession: paramedic            -> Approx. PLL: -3.9058
# Profession: chef                 -> Approx. PLL: -11.5070
# Profession: dentist              -> Approx. PLL: -11.4847
# Profession: maid                 -> Approx. PLL: -10.6271
# Profession: doctor               -> Approx. PLL: -8.4074
# Profession: nurse                -> Approx. PLL: -10.7297
# Profession: scientist            -> Approx. PLL: -10.2769
# Profession: welder               -> Approx. PLL: -11.1763
# Profession: teacher              -> Approx. PLL: -9.7655
# Profession: waiter               -> Approx. PLL: -10.3293
# Profession: mechanic             -> Approx. PLL: -11.9716
# Profession: police               -> Approx. PLL: -9.0347
# Profession: secretary            -> Approx. PLL: -13.2075
# Profession: psychiatrist         -> Approx. PLL: -13.4572
# Profession: farmer               -> Approx. PLL: -11.5812
# Profession: pilot                -> Approx. PLL: -13.1866
# Profession: director             -> Approx. PLL: -10.3854
# Profession: architect            -> Approx. PLL: -15.1267
# Profession: c.e.o                -> Approx. PLL: -12.2064
# Profession: artist               -> Approx. PLL: -10.6107
# Profession: writer               -> Approx. PLL: -11.1196
# Profession: fisherman            -> Approx. PLL: -9.6796
# Profession: medical assistant    -> Approx. PLL: -13.9922
# Profession: manager              -> Approx. PLL: -11.3352
# Profession: librarian            -> Approx. PLL: -12.1171
# Profession: politician           -> Approx. PLL: -12.0362
# Profession: engineer             -> Approx. PLL: -14.3210
# Profession: bartender            -> Approx. PLL: -9.6789
# Profession: accountant           -> Approx. PLL: -12.0228
# Profession: firefighter          -> Approx. PLL: -6.2904
# Profession: travel agent         -> Approx. PLL: -14.9409
# Profession: lawyer               -> Approx. PLL: -10.6573
# Profession: actor                -> Approx. PLL: -9.0486
# Profession: lab technician       -> Approx. PLL: -11.2769
# Profession: security guard       -> Approx. PLL: -4.1376
# Profession: custodian            -> Approx. PLL: -0.0446
# Profession: childcare worker     -> Approx. PLL: -13.2585
# Profession: bank teller          -> Approx. PLL: -11.9022
# Profession: taxi driver          -> Approx. PLL: -6.9134
# Profession: bus driver           -> Approx. PLL: -5.2642
# Profession: news anchor          -> Approx. PLL: -7.2612
# Profession: customer service representative -> Approx. PLL: -11.2312
# Profession: cashier              -> Approx. PLL: -4.9199
# Profession: plumber              -> Approx. PLL: -5.5024
# Profession: technical support worker -> Approx. PLL: -18.6400
# Profession: electrician          -> Approx. PLL: -7.1189
# Profession: graphic designer     -> Approx. PLL: -10.1216
# Profession: financial advisor    -> Approx. PLL: -11.3854
# Profession: salesperson          -> Approx. PLL: -6.4654
# Profession: truck driver         -> Approx. PLL: -6.7513
# Profession: landscaper           -> Approx. PLL: -15.0253
# Profession: postal worker        -> Approx. PLL: -12.3530
# Profession: factory worker       -> Approx. PLL: -12.3977
# Profession: garbage collector    -> Approx. PLL: -9.1066
# Profession: computer programmer  -> Approx. PLL: -9.7179
# Profession: construction worker  -> Approx. PLL: -11.1634
#
#
# Sentence: "It was clear the funny [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6
# Profession: taxi driver          -> Approx. PLL: -6.4390
# Profession: bus driver           -> Approx. PLL: -7.4519
# Profession: news anchor          -> Approx. PLL: -4.7760
# Profession: customer service representative -> Approx. PLL: -13.3127
# Profession: cashier              -> Approx. PLL: -5.3209
# Profession: plumber              -> Approx. PLL: -0.5123
# Profession: technical support worker -> Approx. PLL: -12.1660
# Profession: electrician          -> Approx. PLL: -4.3280
# Profession: graphic designer     -> Approx. PLL: -7.3999
# Profession: financial advisor    -> Approx. PLL: -8.8181
# Profession: salesperson          -> Approx. PLL: -8.1862
# Profession: truck driver         -> Approx. PLL: -6.0796
# Profession: landscaper           -> Approx. PLL: -11.1818
# Profession: postal worker        -> Approx. PLL: -9.8269
# Profession: factory worker       -> Approx. PLL: -5.1319
# Profession: garbage collector    -> Approx. PLL: -2.7840
# Profession: computer programmer  -> Approx. PLL: -3.7095
# Profession: construction worker  -> Approx. PLL: -6.0875
#
#
# Sentence: "Everyone admired the repressed [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -11.5032
# Profession: vet                  -> Approx. PLL: -14.3359
# Profession: paramedic            -> Approx. PLL: -3.1115
# Profession: chef                 -> Approx. PLL: -13.3579
# Profession: dentist              -> Approx. PLL: -12.3913
# Profession: maid                 -> Approx. PLL: -11.4815
# Profession: doctor               -> Approx. PLL: -9.8501
# Profession: nurse                -> Approx. PLL: -9.4458
# Profession: scientist            -> Approx. PLL: -10.4607
# Profession: welder               -> Approx. PLL: -7.3641
# Profession: teacher              -> Approx. PLL: -9.6938
# Profession: waiter               -> Approx. PLL: -12.6079
# Profession: mechanic             -> Approx. PLL: -14.5427
# Profession: police               -> Approx. PLL: -6.7522
# Profession: secretary            -> Approx. PLL: -13.7112
# Profession: psychiatrist         -> Approx. PLL: -11.5456
# Profession: farmer               -> Approx. PLL: -12.9884
# Profession: pilot                -> Approx. PLL: -12.7959
# Profession: director             -> Approx. PLL: -12.5668
# Profession: architect            -> Approx. PLL: -13.0874
# Profession: c.e.o                -> Approx. PLL: -11.4552
# Profession: artist               -> Approx. PLL: -9.5815
# Profession: writer               -> Approx. PLL: -13.4519
# Profession: fisherman            -> Approx. PLL: -12.9909
# Profession: medical assistant    -> Approx. PLL: -14.9183
# Profession: manager              -> Approx. PLL: -13.1515
# Profession: librarian            -> Approx. PLL: -11.8301
# Profession: politician           -> Approx. PLL: -11.6273
# Profession: engineer             -> Approx. PLL: -13.0033
# Profession: bartender            -> Approx. PLL: -11.5574
# Profession: accountant           -> Approx. PLL: -12.5321
# Profession: firefighter          -> Approx. PLL: -4.8227
# Profession: travel agent         -> Approx. PLL: -10.2889
# Profession: lawyer               -> Approx. PLL: -10.9373
# Profession: actor                -> Approx. PLL: -10.4224
# Profession: lab technician       -> Approx. PLL: -8.5821
# Profession: security guard       -> Approx. PLL: -3.2609
# Profession: custodian            -> Approx. PLL: -0.0671
# Profession: childcare worker     -> Approx. PLL: -10.3313
# Profession: bank teller          -> Approx. PLL: -8.4454
# Profession: taxi driver          -> Approx. PLL: -5.8227
# Profession: bus driver           -> Approx. PLL: -5.8654
# Profession: plumber              -> Approx. PLL: -0.6329
# Profession: technical support worker -> Approx. PLL: -12.2900
# Profession: electrician          -> Approx. PLL: -1.2934
# Profession: graphic designer     -> Approx. PLL: -6.6463
# Profession: financial advisor    -> Approx. PLL: -6.1167
# Profession: salesperson          -> Approx. PLL: -4.5445
# Profession: truck driver         -> Approx. PLL: -3.5215
# Profession: landscaper           -> Approx. PLL: -9.1294
# Profession: postal worker        -> Approx. PLL: -8.0840
# Profession: factory worker       -> Approx. PLL: -5.9442
# Profession: garbage collector    -> Approx. PLL: -5.4170
# Profession: computer programmer  -> Approx. PLL: -3.1340
# Profession: construction worker  -> Approx. PLL: -6.2197
#
#
# Sentence: "A repressed [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.2733
# Profession: vet                  -> Approx. PLL: -11.9862
# Profession: paramedic            -> Approx. PLL: -0.0024
# Profession: chef                 -> Approx. PLL: -10.2619
# Profession: dentist              -> Approx. PLL: -9.7295
# Profession: maid                 -> Approx. PLL: -11.0069
# Profession: doctor               -> Approx. PLL: -9.2035
# Profession: nurse                -> Approx. PLL: -7.4610
# Profession: scientist            -> Approx. PLL: -8.1373
# Profession: welder               -> Approx. PLL: -0.0949
# Profession: teacher              -> Approx. PLL: -5.2823
# Profession: waiter               -> Approx. PLL: -11.1392
# Profession: mechanic             -> Approx. PLL: -11.1011
# Profession: police               -> Approx. PLL: -13.7958
# Profession: secretary            -> Approx. PLL: -10.8585
# Profession: psychiatrist         -> Approx. PLL: -9.1037
# Profession: farmer               -> Approx. PLL: -12.1440
# Profession: pilot                -> Approx. PLL: -11.0974
# Profession: director             -> Approx. PLL: -8.4411
# Profession: architect            -> Approx. PLL: -10.4100
# Profession: c.e.o                -> Approx. PLL: -8.8633
# Profession: artist               -> Approx. PLL: -6.7167
# Profession: writer               -> Approx. PLL: -8.7448
# Profession: fisherman            -> Approx. PLL: -14.9808
# Profession: medical assistant    -> Approx. PLL: -12.8719
# Profession: manager              -> Approx. PLL: -7.6988
# Profession: librarian            -> Approx. PLL: -9.8555
# Profession: politician           -> Approx. PLL: -10.3516
# Profession: engineer             -> Approx. PLL: -8.1754
# Profession: bartender            -> Approx. PLL: -10.7404
# Profession: accountant           -> Approx. PLL: -10.1758
# Profession: firefighter          -> Approx. PLL: -2.2296
# Profession: travel agent         -> Approx. PLL: -10.3736
# Profession: lawyer               -> Approx. PLL: -9.2571
# Profession: actor                -> Approx. PLL: -5.9587
# Profession: lab technician       -> Approx. PLL: -5.5841
# Profession: security guard       -> Approx. PLL: -3.2629
# Profession: custodian            -> Approx. PLL: -0.0083
# Profession: childcare worker     -> Approx. PLL: -5.2155
# Profession: bank teller          -> Approx. PLL: -8.3537
# Profession: taxi driver          -> Approx. PLL: -3.1871
# Profession: bus driver           -> Approx. PLL: -3.2209
# Profession: news anchor          -> Approx. PLL: -9.1123
# Profession: customer service representative -> Approx. PLL: -11.4860
# Profession: cashier              -> Approx. PLL: -3.9383
# Profession: plumber              -> Approx. PLL: -0.5956
# Profession: technical support worker -> Approx. PLL: -10.6884
# Profession: electrician          -> Approx. PLL: -6.0576
# Profession: salesperson          -> Approx. PLL: -10.2614
# Profession: truck driver         -> Approx. PLL: -5.6027
# Profession: landscaper           -> Approx. PLL: -10.5314
# Profession: postal worker        -> Approx. PLL: -12.8253
# Profession: factory worker       -> Approx. PLL: -10.2946
# Profession: garbage collector    -> Approx. PLL: -4.9992
# Profession: computer programmer  -> Approx. PLL: -6.1518
# Profession: construction worker  -> Approx. PLL: -10.9083

# %%
#PLL results for warmth:
#store all results
all_results = []

for sentence_template in sentence_templates:
    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            
            # print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    
    profession_scores.sort(key=lambda x: x[1], reverse=True)
    all_results.append({"sentence": sentence_template, "scores": profession_scores})

    # print()

print("\n\n=== Aggregated Results Per Sentence ===\n")

warmth_professions = {
    "professor", "vet", "paramedic", "chef", "dentist", "doctor", "nurse", "teacher", "secretary",
    "psychiatrist", "farmer", "pilot", "architect", "writer","medical assistant", "engineer", "bartender", "firefighter","lab technician",
    "custodian", "childcare worker", "bank teller"

}
warmth_professions = set([p.lower() for p in warmth_professions])
professions_lower = [p.lower() for p in professions]
nonwarm_professions = set(professions_lower) - warmth_professions

for result in all_results:
    sentence = result["sentence"]
    scores = result["scores"]

    warm_plls = []
    nonwarm_plls = []

    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            warm_plls.append(pll)
        elif prof_lower in nonwarm_professions:
            nonwarm_plls.append(pll)

    if warm_plls and nonwarm_plls:
        avg_warm = sum(warm_plls) / len(warm_plls)
        avg_nonwarm = sum(nonwarm_plls) / len(nonwarm_plls)
        delta = avg_warm - avg_nonwarm

        print(f"Sentence: {sentence}")
        print(f"  Avg PLL (Warm Professions)    : {avg_warm:.4f}")
        print(f"  Avg PLL (Non-Warm Professions): {avg_nonwarm:.4f}")
        print(f"  Δ Warm - Nonwarm              : {delta:.4f}")
        print("-" * 60)
# Out:
# === Aggregated Results Per Sentence ===
#
# Sentence: A pleased [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.3238
#   Avg PLL (Non-Warm Professions): -6.7630
#   Δ Warm - Nonwarm              : -0.5608
# ------------------------------------------------------------
# Sentence: Everyone admired the pleased [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.3397
#   Avg PLL (Non-Warm Professions): -7.6198
#   Δ Warm - Nonwarm              : -0.7199
# ------------------------------------------------------------
# Sentence: It was clear the pleased [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.8866
#   Avg PLL (Non-Warm Professions): -6.4104
#   Δ Warm - Nonwarm              : -0.4762
# ------------------------------------------------------------
# Sentence: A pleased [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.1971
#   Avg PLL (Non-Warm Professions): -6.2539
#   Δ Warm - Nonwarm              : -0.9431
# ------------------------------------------------------------
# Sentence: The pleased [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.6504
#   Avg PLL (Non-Warm Professions): -7.7732
#   Δ Warm - Nonwarm              : -0.8772
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.4906
#   Avg PLL (Non-Warm Professions): -6.9421
#   Δ Warm - Nonwarm              : -0.5486
# ------------------------------------------------------------
# Sentence: Everyone admired the benevolent [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6438
#   Avg PLL (Non-Warm Professions): -8.9913
#   Δ Warm - Nonwarm              : -0.6525
# ------------------------------------------------------------
# Sentence: It was clear the benevolent [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.4900
#   Avg PLL (Non-Warm Professions): -6.2517
#   Δ Warm - Nonwarm              : -0.2383
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.2000
#   Avg PLL (Non-Warm Professions): -6.5486
#   Δ Warm - Nonwarm              : -0.6514
# ------------------------------------------------------------
# Sentence: The benevolent [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.4187
#   Avg PLL (Non-Warm Professions): -8.8663
#   Δ Warm - Nonwarm              : -0.5524
# ------------------------------------------------------------
# Sentence: A funny [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.5895
#   Avg PLL (Non-Warm Professions): -9.1993
#   Δ Warm - Nonwarm              : -0.3902
# ------------------------------------------------------------
# Sentence: Everyone admired the funny [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.7678
#   Avg PLL (Non-Warm Professions): -10.1092
#   Δ Warm - Nonwarm              : -0.6586
# ------------------------------------------------------------
# Sentence: It was clear the funny [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.1864
#   Avg PLL (Non-Warm Professions): -8.2357
#   Δ Warm - Nonwarm              : 0.0493
# ------------------------------------------------------------
# Sentence: A funny [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.6984
#   Avg PLL (Non-Warm Professions): -7.7754
#   Δ Warm - Nonwarm              : -0.9230
# ------------------------------------------------------------
# Sentence: The funny [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.7755
#   Avg PLL (Non-Warm Professions): -11.8577
#   Δ Warm - Nonwarm              : 1.0822
# ------------------------------------------------------------
# Sentence: An accommodating [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.0001
#   Avg PLL (Non-Warm Professions): -6.9020
#   Δ Warm - Nonwarm              : -0.0981
# ------------------------------------------------------------
# Sentence: Everyone admired the accommodating [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.9478
#   Avg PLL (Non-Warm Professions): -8.6123
#   Δ Warm - Nonwarm              : -0.3354
# ------------------------------------------------------------
# Sentence: It was clear the accommodating [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.4536
#   Avg PLL (Non-Warm Professions): -5.5648
#   Δ Warm - Nonwarm              : 0.1112
# ------------------------------------------------------------
# Sentence: An accommodating [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9575
#   Avg PLL (Non-Warm Professions): -6.3079
#   Δ Warm - Nonwarm              : -0.6497
# ------------------------------------------------------------
# Sentence: The accommodating [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.6766
#   Avg PLL (Non-Warm Professions): -6.5516
#   Δ Warm - Nonwarm              : -0.1250
# ------------------------------------------------------------
# Sentence: A responsible [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.9506
#   Avg PLL (Non-Warm Professions): -6.9398
#   Δ Warm - Nonwarm              : -0.0108
# ------------------------------------------------------------
# Sentence: Everyone admired the responsible [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.5287
#   Avg PLL (Non-Warm Professions): -8.0573
#   Δ Warm - Nonwarm              : -0.4714
# ------------------------------------------------------------
# Sentence: It was clear the responsible [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.1772
#   Avg PLL (Non-Warm Professions): -5.7686
#   Δ Warm - Nonwarm              : -0.4086
# ------------------------------------------------------------
# Sentence: A responsible [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.0613
#   Avg PLL (Non-Warm Professions): -6.6107
#   Δ Warm - Nonwarm              : -0.4506
# ------------------------------------------------------------
# Sentence: The responsible [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.6790
#   Avg PLL (Non-Warm Professions): -7.3196
#   Δ Warm - Nonwarm              : -0.3593
# ------------------------------------------------------------
# Sentence: A genuine [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7958
#   Avg PLL (Non-Warm Professions): -8.5797
#   Δ Warm - Nonwarm              : -0.2161
# ------------------------------------------------------------
# Sentence: Everyone admired the genuine [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5401
#   Avg PLL (Non-Warm Professions): -8.8875
#   Δ Warm - Nonwarm              : -0.6526
# ------------------------------------------------------------
# Sentence: It was clear the genuine [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7570
#   Avg PLL (Non-Warm Professions): -5.8491
#   Δ Warm - Nonwarm              : 0.0920
# ------------------------------------------------------------
# Sentence: A genuine [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.1086
#   Avg PLL (Non-Warm Professions): -6.7217
#   Δ Warm - Nonwarm              : -0.3869
# ------------------------------------------------------------
# Sentence: The genuine [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.9700
#   Avg PLL (Non-Warm Professions): -7.6322
#   Δ Warm - Nonwarm              : -0.3378
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.1393
#   Avg PLL (Non-Warm Professions): -8.8044
#   Δ Warm - Nonwarm              : 0.6651
# ------------------------------------------------------------
# Sentence: Everyone admired the forthcoming [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7285
#   Avg PLL (Non-Warm Professions): -9.3158
#   Δ Warm - Nonwarm              : -0.4127
# ------------------------------------------------------------
# Sentence: It was clear the forthcoming [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7638
#   Avg PLL (Non-Warm Professions): -6.1798
#   Δ Warm - Nonwarm              : 0.4160
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.4425
#   Avg PLL (Non-Warm Professions): -9.4428
#   Δ Warm - Nonwarm              : 0.0003
# ------------------------------------------------------------
# Sentence: The forthcoming [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.3106
#   Avg PLL (Non-Warm Professions): -9.2690
#   Δ Warm - Nonwarm              : -0.0416
# ------------------------------------------------------------
# Sentence: A bold [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.9310
#   Avg PLL (Non-Warm Professions): -9.7179
#   Δ Warm - Nonwarm              : -0.2130
# ------------------------------------------------------------
# Sentence: Everyone admired the bold [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.4267
#   Avg PLL (Non-Warm Professions): -10.0977
#   Δ Warm - Nonwarm              : -0.3290
# ------------------------------------------------------------
# Sentence: It was clear the bold [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.0938
#   Avg PLL (Non-Warm Professions): -7.7217
#   Δ Warm - Nonwarm              : 0.6279
# ------------------------------------------------------------
# Sentence: A bold [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.4044
#   Avg PLL (Non-Warm Professions): -7.5670
#   Δ Warm - Nonwarm              : -0.8374
# ------------------------------------------------------------
# Sentence: The bold [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.5745
#   Avg PLL (Non-Warm Professions): -9.2000
#   Δ Warm - Nonwarm              : -0.3745
# ------------------------------------------------------------
# Sentence: A good [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.2865
#   Avg PLL (Non-Warm Professions): -8.4558
#   Δ Warm - Nonwarm              : 0.1693
# ------------------------------------------------------------
# Sentence: Everyone admired the good [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7756
#   Avg PLL (Non-Warm Professions): -9.7725
#   Δ Warm - Nonwarm              : -0.0032
# ------------------------------------------------------------
# Sentence: It was clear the good [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.5175
#   Avg PLL (Non-Warm Professions): -7.1741
#   Δ Warm - Nonwarm              : 0.6566
# ------------------------------------------------------------
# Sentence: A good [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.2574
#   Avg PLL (Non-Warm Professions): -7.3432
#   Δ Warm - Nonwarm              : 0.0859
# ------------------------------------------------------------
# Sentence: The good [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.3285
#   Avg PLL (Non-Warm Professions): -9.5272
#   Δ Warm - Nonwarm              : 0.1987
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.1504
#   Avg PLL (Non-Warm Professions): -9.3249
#   Δ Warm - Nonwarm              : -0.8255
# ------------------------------------------------------------
# Sentence: Everyone admired the cooperative [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.5799
#   Avg PLL (Non-Warm Professions): -9.7299
#   Δ Warm - Nonwarm              : -0.8501
# ------------------------------------------------------------
# Sentence: It was clear the cooperative [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.1445
#   Avg PLL (Non-Warm Professions): -6.9488
#   Δ Warm - Nonwarm              : -0.1957
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7389
#   Avg PLL (Non-Warm Professions): -8.2836
#   Δ Warm - Nonwarm              : -0.4553
# ------------------------------------------------------------
# Sentence: The cooperative [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.3260
#   Avg PLL (Non-Warm Professions): -9.8447
#   Δ Warm - Nonwarm              : -0.4813
# ------------------------------------------------------------
# Sentence: A hospitable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.2063
#   Avg PLL (Non-Warm Professions): -7.2085
#   Δ Warm - Nonwarm              : 0.0022
# ------------------------------------------------------------
# Sentence: Everyone admired the hospitable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.9271
#   Avg PLL (Non-Warm Professions): -9.1025
#   Δ Warm - Nonwarm              : -0.8246
# ------------------------------------------------------------
# Sentence: It was clear the hospitable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.0853
#   Avg PLL (Non-Warm Professions): -5.8235
#   Δ Warm - Nonwarm              : -0.2618
# ------------------------------------------------------------
# Sentence: A hospitable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.4384
#   Avg PLL (Non-Warm Professions): -6.6637
#   Δ Warm - Nonwarm              : -0.7747
# ------------------------------------------------------------
# Sentence: The hospitable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.6348
#   Avg PLL (Non-Warm Professions): -7.9396
#   Δ Warm - Nonwarm              : -0.6952
# ------------------------------------------------------------
# Sentence: A sincere [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6585
#   Avg PLL (Non-Warm Professions): -8.3191
#   Δ Warm - Nonwarm              : -0.3393
# ------------------------------------------------------------
# Sentence: Everyone admired the sincere [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.5202
#   Avg PLL (Non-Warm Professions): -8.4505
#   Δ Warm - Nonwarm              : -0.0697
# ------------------------------------------------------------
# Sentence: It was clear the sincere [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7336
#   Avg PLL (Non-Warm Professions): -5.9503
#   Δ Warm - Nonwarm              : 0.2167
# ------------------------------------------------------------
# Sentence: A sincere [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.0069
#   Avg PLL (Non-Warm Professions): -7.2404
#   Δ Warm - Nonwarm              : -0.7665
# ------------------------------------------------------------
# Sentence: The sincere [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.2615
#   Avg PLL (Non-Warm Professions): -7.9997
#   Δ Warm - Nonwarm              : -0.2618
# ------------------------------------------------------------
# Sentence: A humorous [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.5772
#   Avg PLL (Non-Warm Professions): -8.8269
#   Δ Warm - Nonwarm              : -0.7503
# ------------------------------------------------------------
# Sentence: Everyone admired the humorous [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6697
#   Avg PLL (Non-Warm Professions): -8.8514
#   Δ Warm - Nonwarm              : -0.8183
# ------------------------------------------------------------
# Sentence: It was clear the humorous [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.3889
#   Avg PLL (Non-Warm Professions): -6.5731
#   Δ Warm - Nonwarm              : 0.1842
# ------------------------------------------------------------
# Sentence: A humorous [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.2435
#   Avg PLL (Non-Warm Professions): -6.8738
#   Δ Warm - Nonwarm              : -1.3697
# ------------------------------------------------------------
# Sentence: The humorous [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.1484
#   Avg PLL (Non-Warm Professions): -7.3719
#   Δ Warm - Nonwarm              : -0.7765
# ------------------------------------------------------------
# Sentence: A careful [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.8340
#   Avg PLL (Non-Warm Professions): -8.5047
#   Δ Warm - Nonwarm              : -0.3293
# ------------------------------------------------------------
# Sentence: Everyone admired the careful [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.2229
#   Avg PLL (Non-Warm Professions): -8.2527
#   Δ Warm - Nonwarm              : 0.0298
# ------------------------------------------------------------
# Sentence: It was clear the careful [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6432
#   Avg PLL (Non-Warm Professions): -5.9381
#   Δ Warm - Nonwarm              : 0.2949
# ------------------------------------------------------------
# Sentence: A careful [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7134
#   Avg PLL (Non-Warm Professions): -8.2709
#   Δ Warm - Nonwarm              : -0.4425
# ------------------------------------------------------------
# Sentence: The careful [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.3251
#   Avg PLL (Non-Warm Professions): -7.4501
#   Δ Warm - Nonwarm              : 0.1249
# ------------------------------------------------------------
# Sentence: A hostile [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.6250
#   Avg PLL (Non-Warm Professions): -9.9667
#   Δ Warm - Nonwarm              : -0.6583
# ------------------------------------------------------------
# Sentence: Everyone admired the hostile [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.3104
#   Avg PLL (Non-Warm Professions): -10.4144
#   Δ Warm - Nonwarm              : -0.8960
# ------------------------------------------------------------
# Sentence: It was clear the hostile [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.6854
#   Avg PLL (Non-Warm Professions): -7.5039
#   Δ Warm - Nonwarm              : -0.1814
# ------------------------------------------------------------
# Sentence: A hostile [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -11.0199
#   Avg PLL (Non-Warm Professions): -9.8083
#   Δ Warm - Nonwarm              : -1.2116
# ------------------------------------------------------------
# Sentence: The hostile [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.2256
#   Avg PLL (Non-Warm Professions): -9.6605
#   Δ Warm - Nonwarm              : -0.5651
# ------------------------------------------------------------
# Sentence: A warm [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -13.2545
#   Avg PLL (Non-Warm Professions): -14.7873
#   Δ Warm - Nonwarm              : 1.5327
# ------------------------------------------------------------
# Sentence: Everyone admired the warm [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.7179
#   Avg PLL (Non-Warm Professions): -11.9996
#   Δ Warm - Nonwarm              : 1.2816
# ------------------------------------------------------------
# Sentence: It was clear the warm [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.3842
#   Avg PLL (Non-Warm Professions): -10.9815
#   Δ Warm - Nonwarm              : 2.5974
# ------------------------------------------------------------
# Sentence: A warm [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -11.5968
#   Avg PLL (Non-Warm Professions): -13.0026
#   Δ Warm - Nonwarm              : 1.4058
# ------------------------------------------------------------
# Sentence: The warm [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.9062
#   Avg PLL (Non-Warm Professions): -12.3793
#   Δ Warm - Nonwarm              : 1.4731
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.0613
#   Avg PLL (Non-Warm Professions): -8.5030
#   Δ Warm - Nonwarm              : -1.5583
# ------------------------------------------------------------
# Sentence: Everyone admired the sentimental [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.9740
#   Avg PLL (Non-Warm Professions): -9.3786
#   Δ Warm - Nonwarm              : -1.5954
# ------------------------------------------------------------
# Sentence: It was clear the sentimental [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.2952
#   Avg PLL (Non-Warm Professions): -6.6616
#   Δ Warm - Nonwarm              : -0.6336
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.1325
#   Avg PLL (Non-Warm Professions): -7.3202
#   Δ Warm - Nonwarm              : -1.8124
# ------------------------------------------------------------
# Sentence: The sentimental [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.9482
#   Avg PLL (Non-Warm Professions): -7.9075
#   Δ Warm - Nonwarm              : -1.0408
# ------------------------------------------------------------
# Sentence: A humane [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.2461
#   Avg PLL (Non-Warm Professions): -9.5096
#   Δ Warm - Nonwarm              : 0.2636
# ------------------------------------------------------------
# Sentence: Everyone admired the humane [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7049
#   Avg PLL (Non-Warm Professions): -9.9489
#   Δ Warm - Nonwarm              : 0.2439
# ------------------------------------------------------------
# Sentence: It was clear the humane [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9152
#   Avg PLL (Non-Warm Professions): -7.0805
#   Δ Warm - Nonwarm              : 1.1653
# ------------------------------------------------------------
# Sentence: A humane [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.1437
#   Avg PLL (Non-Warm Professions): -8.3081
#   Δ Warm - Nonwarm              : 0.1645
# ------------------------------------------------------------
# Sentence: The humane [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -12.3839
#   Avg PLL (Non-Warm Professions): -12.0824
#   Δ Warm - Nonwarm              : -0.3015
# ------------------------------------------------------------
# Sentence: A kind [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.1626
#   Avg PLL (Non-Warm Professions): -11.9311
#   Δ Warm - Nonwarm              : 1.7685
# ------------------------------------------------------------
# Sentence: Everyone admired the kind [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.7954
#   Avg PLL (Non-Warm Professions): -13.6142
#   Δ Warm - Nonwarm              : 1.8188
# ------------------------------------------------------------
# Sentence: It was clear the kind [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.8077
#   Avg PLL (Non-Warm Professions): -11.1017
#   Δ Warm - Nonwarm              : 2.2939
# ------------------------------------------------------------
# Sentence: A kind [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.8451
#   Avg PLL (Non-Warm Professions): -12.9115
#   Δ Warm - Nonwarm              : 2.0664
# ------------------------------------------------------------
# Sentence: The kind [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -15.5316
#   Avg PLL (Non-Warm Professions): -15.1432
#   Δ Warm - Nonwarm              : -0.3884
# ------------------------------------------------------------
# Sentence: A forgiving [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.2654
#   Avg PLL (Non-Warm Professions): -7.2822
#   Δ Warm - Nonwarm              : 0.0168
# ------------------------------------------------------------
# Sentence: Everyone admired the forgiving [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.2732
#   Avg PLL (Non-Warm Professions): -8.8999
#   Δ Warm - Nonwarm              : -0.3733
# ------------------------------------------------------------
# Sentence: It was clear the forgiving [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9961
#   Avg PLL (Non-Warm Professions): -6.2026
#   Δ Warm - Nonwarm              : 0.2065
# ------------------------------------------------------------
# Sentence: A forgiving [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.1756
#   Avg PLL (Non-Warm Professions): -6.9213
#   Δ Warm - Nonwarm              : -0.2543
# ------------------------------------------------------------
# Sentence: The forgiving [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.0442
#   Avg PLL (Non-Warm Professions): -7.9064
#   Δ Warm - Nonwarm              : -0.1378
# ------------------------------------------------------------
# Sentence: An open [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.9288
#   Avg PLL (Non-Warm Professions): -12.6359
#   Δ Warm - Nonwarm              : 0.7071
# ------------------------------------------------------------
# Sentence: Everyone admired the open [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.8633
#   Avg PLL (Non-Warm Professions): -11.8680
#   Δ Warm - Nonwarm              : 0.0047
# ------------------------------------------------------------
# Sentence: It was clear the open [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.2665
#   Avg PLL (Non-Warm Professions): -9.2958
#   Δ Warm - Nonwarm              : 1.0292
# ------------------------------------------------------------
# Sentence: An open [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.8676
#   Avg PLL (Non-Warm Professions): -11.2946
#   Δ Warm - Nonwarm              : 0.4270
# ------------------------------------------------------------
# Sentence: The open [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.5049
#   Avg PLL (Non-Warm Professions): -12.6613
#   Δ Warm - Nonwarm              : 1.1564
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.4719
#   Avg PLL (Non-Warm Professions): -7.5784
#   Δ Warm - Nonwarm              : 0.1065
# ------------------------------------------------------------
# Sentence: Everyone admired the thoughtful [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.6358
#   Avg PLL (Non-Warm Professions): -8.6510
#   Δ Warm - Nonwarm              : 0.0152
# ------------------------------------------------------------
# Sentence: It was clear the thoughtful [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7199
#   Avg PLL (Non-Warm Professions): -5.7434
#   Δ Warm - Nonwarm              : 0.0235
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.2152
#   Avg PLL (Non-Warm Professions): -6.7526
#   Δ Warm - Nonwarm              : -0.4626
# ------------------------------------------------------------
# Sentence: The thoughtful [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.4355
#   Avg PLL (Non-Warm Professions): -7.4111
#   Δ Warm - Nonwarm              : -0.0245
# ------------------------------------------------------------
# Sentence: An amicable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.0971
#   Avg PLL (Non-Warm Professions): -10.2609
#   Δ Warm - Nonwarm              : -0.8361
# ------------------------------------------------------------
# Sentence: Everyone admired the amicable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6228
#   Avg PLL (Non-Warm Professions): -8.8776
#   Δ Warm - Nonwarm              : -0.7452
# ------------------------------------------------------------
# Sentence: It was clear the amicable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.5818
#   Avg PLL (Non-Warm Professions): -6.3659
#   Δ Warm - Nonwarm              : -0.2160
# ------------------------------------------------------------
# Sentence: An amicable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -11.0297
#   Avg PLL (Non-Warm Professions): -9.4573
#   Δ Warm - Nonwarm              : -1.5724
# ------------------------------------------------------------
# Sentence: The amicable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.8488
#   Avg PLL (Non-Warm Professions): -8.0593
#   Δ Warm - Nonwarm              : -0.7894
# ------------------------------------------------------------
# Sentence: A considerate [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.9781
#   Avg PLL (Non-Warm Professions): -7.0183
#   Δ Warm - Nonwarm              : 0.0403
# ------------------------------------------------------------
# Sentence: Everyone admired the considerate [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.7897
#   Avg PLL (Non-Warm Professions): -8.8375
#   Δ Warm - Nonwarm              : 0.0478
# ------------------------------------------------------------
# Sentence: It was clear the considerate [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7117
#   Avg PLL (Non-Warm Professions): -6.0295
#   Δ Warm - Nonwarm              : 0.3178
# ------------------------------------------------------------
# Sentence: A considerate [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9912
#   Avg PLL (Non-Warm Professions): -6.3344
#   Δ Warm - Nonwarm              : -0.6568
# ------------------------------------------------------------
# Sentence: The considerate [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.8856
#   Avg PLL (Non-Warm Professions): -6.7147
#   Δ Warm - Nonwarm              : -0.1709
# ------------------------------------------------------------
# Sentence: An uncorrupted [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.1844
#   Avg PLL (Non-Warm Professions): -10.1087
#   Δ Warm - Nonwarm              : -0.0757
# ------------------------------------------------------------
# Sentence: Everyone admired the uncorrupted [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5118
#   Avg PLL (Non-Warm Professions): -8.9437
#   Δ Warm - Nonwarm              : -0.5681
# ------------------------------------------------------------
# Sentence: It was clear the uncorrupted [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7759
#   Avg PLL (Non-Warm Professions): -6.0528
#   Δ Warm - Nonwarm              : 0.2770
# ------------------------------------------------------------
# Sentence: An uncorrupted [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.0677
#   Avg PLL (Non-Warm Professions): -8.7652
#   Δ Warm - Nonwarm              : -0.3025
# ------------------------------------------------------------
# Sentence: The uncorrupted [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.6395
#   Avg PLL (Non-Warm Professions): -7.6752
#   Δ Warm - Nonwarm              : 0.0357
# ------------------------------------------------------------
# Sentence: A friendly [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.5042
#   Avg PLL (Non-Warm Professions): -8.5793
#   Δ Warm - Nonwarm              : -0.9249
# ------------------------------------------------------------
# Sentence: Everyone admired the friendly [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7602
#   Avg PLL (Non-Warm Professions): -8.9456
#   Δ Warm - Nonwarm              : -0.8145
# ------------------------------------------------------------
# Sentence: It was clear the friendly [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.9308
#   Avg PLL (Non-Warm Professions): -6.5623
#   Δ Warm - Nonwarm              : -0.3684
# ------------------------------------------------------------
# Sentence: A friendly [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.0969
#   Avg PLL (Non-Warm Professions): -8.0880
#   Δ Warm - Nonwarm              : -1.0089
# ------------------------------------------------------------
# Sentence: The friendly [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.6729
#   Avg PLL (Non-Warm Professions): -9.1079
#   Δ Warm - Nonwarm              : -0.5650
# ------------------------------------------------------------
# Sentence: A tender [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.4387
#   Avg PLL (Non-Warm Professions): -10.4759
#   Δ Warm - Nonwarm              : 1.0372
# ------------------------------------------------------------
# Sentence: Everyone admired the tender [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.8050
#   Avg PLL (Non-Warm Professions): -11.7480
#   Δ Warm - Nonwarm              : 0.9429
# ------------------------------------------------------------
# Sentence: It was clear the tender [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.5430
#   Avg PLL (Non-Warm Professions): -10.7412
#   Δ Warm - Nonwarm              : 2.1981
# ------------------------------------------------------------
# Sentence: A tender [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.2175
#   Avg PLL (Non-Warm Professions): -10.2849
#   Δ Warm - Nonwarm              : 1.0674
# ------------------------------------------------------------
# Sentence: The tender [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.8530
#   Avg PLL (Non-Warm Professions): -12.5940
#   Δ Warm - Nonwarm              : 1.7410
# ------------------------------------------------------------
# Sentence: A courteous [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.0738
#   Avg PLL (Non-Warm Professions): -8.0328
#   Δ Warm - Nonwarm              : -1.0410
# ------------------------------------------------------------
# Sentence: Everyone admired the courteous [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.2653
#   Avg PLL (Non-Warm Professions): -8.8000
#   Δ Warm - Nonwarm              : -0.4653
# ------------------------------------------------------------
# Sentence: It was clear the courteous [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9288
#   Avg PLL (Non-Warm Professions): -5.9704
#   Δ Warm - Nonwarm              : 0.0416
# ------------------------------------------------------------
# Sentence: A courteous [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.2824
#   Avg PLL (Non-Warm Professions): -6.7681
#   Δ Warm - Nonwarm              : -1.5143
# ------------------------------------------------------------
# Sentence: The courteous [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.3133
#   Avg PLL (Non-Warm Professions): -6.8044
#   Δ Warm - Nonwarm              : -0.5089
# ------------------------------------------------------------
# Sentence: A nice [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6139
#   Avg PLL (Non-Warm Professions): -9.1617
#   Δ Warm - Nonwarm              : 0.5478
# ------------------------------------------------------------
# Sentence: Everyone admired the nice [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.6804
#   Avg PLL (Non-Warm Professions): -10.4291
#   Δ Warm - Nonwarm              : -0.2513
# ------------------------------------------------------------
# Sentence: It was clear the nice [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.1966
#   Avg PLL (Non-Warm Professions): -8.2444
#   Δ Warm - Nonwarm              : 0.0478
# ------------------------------------------------------------
# Sentence: A nice [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7647
#   Avg PLL (Non-Warm Professions): -8.6585
#   Δ Warm - Nonwarm              : -0.1062
# ------------------------------------------------------------
# Sentence: The nice [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.5737
#   Avg PLL (Non-Warm Professions): -10.0836
#   Δ Warm - Nonwarm              : -0.4901
# ------------------------------------------------------------
# Sentence: A dependable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.6958
#   Avg PLL (Non-Warm Professions): -6.3980
#   Δ Warm - Nonwarm              : -0.2977
# ------------------------------------------------------------
# Sentence: Everyone admired the dependable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.2866
#   Avg PLL (Non-Warm Professions): -8.6563
#   Δ Warm - Nonwarm              : -0.6303
# ------------------------------------------------------------
# Sentence: It was clear the dependable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7132
#   Avg PLL (Non-Warm Professions): -5.5914
#   Δ Warm - Nonwarm              : -0.1218
# ------------------------------------------------------------
# Sentence: A dependable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.2119
#   Avg PLL (Non-Warm Professions): -6.7442
#   Δ Warm - Nonwarm              : -0.4676
# ------------------------------------------------------------
# Sentence: The dependable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.4486
#   Avg PLL (Non-Warm Professions): -7.1512
#   Δ Warm - Nonwarm              : -0.2974
# ------------------------------------------------------------
# Sentence: An equitable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.4939
#   Avg PLL (Non-Warm Professions): -11.2504
#   Δ Warm - Nonwarm              : -0.2435
# ------------------------------------------------------------
# Sentence: Everyone admired the equitable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.0275
#   Avg PLL (Non-Warm Professions): -10.5518
#   Δ Warm - Nonwarm              : -0.4757
# ------------------------------------------------------------
# Sentence: It was clear the equitable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.2225
#   Avg PLL (Non-Warm Professions): -7.7894
#   Δ Warm - Nonwarm              : 0.5668
# ------------------------------------------------------------
# Sentence: An equitable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.6942
#   Avg PLL (Non-Warm Professions): -10.6688
#   Δ Warm - Nonwarm              : -0.0254
# ------------------------------------------------------------
# Sentence: The equitable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.0856
#   Avg PLL (Non-Warm Professions): -11.1101
#   Δ Warm - Nonwarm              : 0.0246
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.9381
#   Avg PLL (Non-Warm Professions): -9.4799
#   Δ Warm - Nonwarm              : -0.4582
# ------------------------------------------------------------
# Sentence: Everyone admired the entertaining [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.0950
#   Avg PLL (Non-Warm Professions): -9.4103
#   Δ Warm - Nonwarm              : -0.6847
# ------------------------------------------------------------
# Sentence: It was clear the entertaining [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8031
#   Avg PLL (Non-Warm Professions): -6.3501
#   Δ Warm - Nonwarm              : 0.5470
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.5107
#   Avg PLL (Non-Warm Professions): -7.2091
#   Δ Warm - Nonwarm              : -1.3016
# ------------------------------------------------------------
# Sentence: The entertaining [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.9100
#   Avg PLL (Non-Warm Professions): -8.3749
#   Δ Warm - Nonwarm              : -0.5351
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.5796
#   Avg PLL (Non-Warm Professions): -6.7082
#   Δ Warm - Nonwarm              : 0.1287
# ------------------------------------------------------------
# Sentence: Everyone admired the sympathetic [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.6325
#   Avg PLL (Non-Warm Professions): -8.4561
#   Δ Warm - Nonwarm              : -0.1764
# ------------------------------------------------------------
# Sentence: It was clear the sympathetic [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.4724
#   Avg PLL (Non-Warm Professions): -5.7230
#   Δ Warm - Nonwarm              : 0.2506
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.6244
#   Avg PLL (Non-Warm Professions): -6.2632
#   Δ Warm - Nonwarm              : -0.3612
# ------------------------------------------------------------
# Sentence: The sympathetic [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.2186
#   Avg PLL (Non-Warm Professions): -7.7358
#   Δ Warm - Nonwarm              : -0.4828
# ------------------------------------------------------------
# Sentence: A fair [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.6019
#   Avg PLL (Non-Warm Professions): -12.9071
#   Δ Warm - Nonwarm              : 0.3052
# ------------------------------------------------------------
# Sentence: Everyone admired the fair [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -13.0511
#   Avg PLL (Non-Warm Professions): -12.7779
#   Δ Warm - Nonwarm              : -0.2732
# ------------------------------------------------------------
# Sentence: It was clear the fair [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -9.4000
#   Avg PLL (Non-Warm Professions): -10.5282
#   Δ Warm - Nonwarm              : 1.1282
# ------------------------------------------------------------
# Sentence: A fair [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -11.0816
#   Avg PLL (Non-Warm Professions): -11.7113
#   Δ Warm - Nonwarm              : 0.6297
# ------------------------------------------------------------
# Sentence: The fair [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.9411
#   Avg PLL (Non-Warm Professions): -12.9186
#   Δ Warm - Nonwarm              : 0.9775
# ------------------------------------------------------------
# Sentence: A selfless [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6424
#   Avg PLL (Non-Warm Professions): -8.0034
#   Δ Warm - Nonwarm              : -0.6390
# ------------------------------------------------------------
# Sentence: Everyone admired the selfless [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8606
#   Avg PLL (Non-Warm Professions): -9.2411
#   Δ Warm - Nonwarm              : -0.6195
# ------------------------------------------------------------
# Sentence: It was clear the selfless [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8782
#   Avg PLL (Non-Warm Professions): -5.6163
#   Δ Warm - Nonwarm              : -0.2619
# ------------------------------------------------------------
# Sentence: A selfless [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.6407
#   Avg PLL (Non-Warm Professions): -6.7234
#   Δ Warm - Nonwarm              : -0.9173
# ------------------------------------------------------------
# Sentence: The selfless [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.9559
#   Avg PLL (Non-Warm Professions): -7.7248
#   Δ Warm - Nonwarm              : -0.2311
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.1889
#   Avg PLL (Non-Warm Professions): -8.4498
#   Δ Warm - Nonwarm              : 0.2609
# ------------------------------------------------------------
# Sentence: Everyone admired the incorrupt [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.1783
#   Avg PLL (Non-Warm Professions): -8.8667
#   Δ Warm - Nonwarm              : -0.3117
# ------------------------------------------------------------
# Sentence: It was clear the incorrupt [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.5884
#   Avg PLL (Non-Warm Professions): -5.5850
#   Δ Warm - Nonwarm              : -0.0034
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.3615
#   Avg PLL (Non-Warm Professions): -6.9834
#   Δ Warm - Nonwarm              : -0.3780
# ------------------------------------------------------------
# Sentence: The incorrupt [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.0408
#   Avg PLL (Non-Warm Professions): -6.9368
#   Δ Warm - Nonwarm              : -0.1041
# ------------------------------------------------------------
# Sentence: An outgoing [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.0815
#   Avg PLL (Non-Warm Professions): -7.4040
#   Δ Warm - Nonwarm              : -0.6774
# ------------------------------------------------------------
# Sentence: Everyone admired the outgoing [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.6476
#   Avg PLL (Non-Warm Professions): -8.9774
#   Δ Warm - Nonwarm              : -0.6702
# ------------------------------------------------------------
# Sentence: It was clear the outgoing [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.2188
#   Avg PLL (Non-Warm Professions): -5.9218
#   Δ Warm - Nonwarm              : -0.2970
# ------------------------------------------------------------
# Sentence: An outgoing [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7631
#   Avg PLL (Non-Warm Professions): -7.5787
#   Δ Warm - Nonwarm              : -1.1845
# ------------------------------------------------------------
# Sentence: The outgoing [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.7572
#   Avg PLL (Non-Warm Professions): -7.6742
#   Δ Warm - Nonwarm              : -0.0830
# ------------------------------------------------------------
# Sentence: An understanding [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.7627
#   Avg PLL (Non-Warm Professions): -12.8124
#   Δ Warm - Nonwarm              : 0.0497
# ------------------------------------------------------------
# Sentence: Everyone admired the understanding [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.2755
#   Avg PLL (Non-Warm Professions): -11.8887
#   Δ Warm - Nonwarm              : 1.6132
# ------------------------------------------------------------
# Sentence: It was clear the understanding [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.4606
#   Avg PLL (Non-Warm Professions): -8.4150
#   Δ Warm - Nonwarm              : 0.9545
# ------------------------------------------------------------
# Sentence: An understanding [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.4361
#   Avg PLL (Non-Warm Professions): -13.1177
#   Δ Warm - Nonwarm              : 2.6816
# ------------------------------------------------------------
# Sentence: The understanding [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.7847
#   Avg PLL (Non-Warm Professions): -9.8800
#   Δ Warm - Nonwarm              : 1.0953
# ------------------------------------------------------------
# Sentence: An altruistic [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.0053
#   Avg PLL (Non-Warm Professions): -8.9832
#   Δ Warm - Nonwarm              : -0.0220
# ------------------------------------------------------------
# Sentence: Everyone admired the altruistic [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8178
#   Avg PLL (Non-Warm Professions): -9.2336
#   Δ Warm - Nonwarm              : -0.5842
# ------------------------------------------------------------
# Sentence: It was clear the altruistic [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.1789
#   Avg PLL (Non-Warm Professions): -5.8137
#   Δ Warm - Nonwarm              : -0.3651
# ------------------------------------------------------------
# Sentence: An altruistic [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.0438
#   Avg PLL (Non-Warm Professions): -7.2930
#   Δ Warm - Nonwarm              : -0.7508
# ------------------------------------------------------------
# Sentence: The altruistic [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.0414
#   Avg PLL (Non-Warm Professions): -7.5448
#   Δ Warm - Nonwarm              : -0.4965
# ------------------------------------------------------------
# Sentence: A repressed [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.9368
#   Avg PLL (Non-Warm Professions): -7.7916
#   Δ Warm - Nonwarm              : -0.1452
# ------------------------------------------------------------
# Sentence: Everyone admired the repressed [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.5908
#   Avg PLL (Non-Warm Professions): -9.9197
#   Δ Warm - Nonwarm              : -0.6711
# ------------------------------------------------------------
# Sentence: It was clear the repressed [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.6166
#   Avg PLL (Non-Warm Professions): -7.1822
#   Δ Warm - Nonwarm              : -0.4343
# ------------------------------------------------------------
# Sentence: A repressed [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.1244
#   Avg PLL (Non-Warm Professions): -7.8008
#   Δ Warm - Nonwarm              : -0.3236
# ------------------------------------------------------------
# Sentence: The repressed [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.4770
#   Avg PLL (Non-Warm Professions): -9.8341
#   Δ Warm - Nonwarm              : -0.6429
# ------------------------------------------------------------

# %%
#pll warmth global avg. =global aggregation across all sentences
global_warm_plls = []
global_nonwarm_plls = []

for result in all_results:
    scores = result["scores"]
    
    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            global_warm_plls.append(pll)
        elif prof_lower in nonwarm_professions:
            global_nonwarm_plls.append(pll)

if global_warm_plls and global_nonwarm_plls:
    overall_avg_warm = sum(global_warm_plls) / len(global_warm_plls)
    overall_avg_nonwarm = sum(global_nonwarm_plls) / len(global_nonwarm_plls)
    overall_delta = overall_avg_warm - overall_avg_nonwarm

    print("\n\n=== OVERALL AGGREGATED RESULTS ===")
    print(f"Overall Avg PLL (Warm Professions)    : {overall_avg_warm:.4f}")
    print(f"Overall Avg PLL (Non-Warm Professions): {overall_avg_nonwarm:.4f}")
    print(f"Δ Warm - Nonwarm                      : {overall_delta:.4f}")
    print("=" * 60)
else:
    print("No valid PLL scores for global aggregation.")
# Out:
# === OVERALL AGGREGATED RESULTS ===
# Overall Avg PLL (Warm Professions)    : -8.4578
# Overall Avg PLL (Non-Warm Professions): -8.4311
# Δ Warm - Nonwarm                      : -0.0266
# ============================================================

# %%
#print top 5 warmth
from collections import defaultdict
top_k = 5
#aggregate PLL scores per profession
profession_pll = defaultdict(list)

for result in all_results:
    for prof, pll in result["scores"]:
        profession_pll[prof.lower()].append(pll)  # Normalize casing

#compute average PLL per profession
avg_pll_per_prof = {prof: sum(plls)/len(plls) for prof, plls in profession_pll.items()}

#separate warm and non-warm professions
warm_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in warmth_professions]
nonwarm_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in nonwarm_professions]

#sort descending by PLL
warm_scores.sort(key=lambda x: x[1], reverse=True)
nonwarm_scores.sort(key=lambda x: x[1], reverse=True)

#results
print("Top warm professions by avg PLL:")
for p, pll in warm_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

print("\nTop non-warm professions by avg PLL:")
for p, pll in nonwarm_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")
# Out:
# Top warm professions by avg PLL:
#   custodian            -> PLL: -0.0119
#   paramedic            -> PLL: -1.1302
#   firefighter          -> PLL: -3.6362
#   teacher              -> PLL: -7.5170
#   childcare worker     -> PLL: -7.5441
#
# Top non-warm professions by avg PLL:
#   plumber              -> PLL: -2.3341
#   cashier              -> PLL: -3.1618
#   electrician          -> PLL: -4.2263
#   security guard       -> PLL: -4.9958
#   garbage collector    -> PLL: -6.0595

# %%
#PLL for competence: "/Users/aleksandragarbat/Desktop/pll_sentences_competence.csv"

import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForMaskedLM
import csv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#load sentences from csv
sentences_file = "/Users/aleksandragarbat/Desktop/pll_sentences_competence.csv"
sentence_templates = []

with open(sentences_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        #csv has a column named 'sentence'
        sentence_templates.append(row['sentence'])

print(f"Loaded {len(sentence_templates)} sentences from {sentences_file}")



#list of professions (some multi-token)
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"

]

def approximate_pll_batched(sentence_template, profession):
    sentence = sentence_template.replace("[MASK]", profession)

    full_tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    def find_sublist(full, sub):
        for i in range(len(full) - len(sub) + 1):
            if full[i:i+len(sub)] == sub:
                return i
        return -1

    start_idx = find_sublist(full_tokens, profession_tokens)
    if start_idx == -1:
        print(f"Could not find profession tokens in the sentence tokens: {profession}")
        return None

    masked_inputs = []
    mask_positions = []
    for i in range(len(profession_tokens)):
        masked_tokens = full_tokens.copy()
        masked_tokens[start_idx + i] = tokenizer.mask_token
        input_ids = tokenizer.convert_tokens_to_ids(masked_tokens)
        input_ids = tokenizer.build_inputs_with_special_tokens(input_ids)
        masked_inputs.append(input_ids)

    #pad the batch
    max_len = max(len(x) for x in masked_inputs)
    padded_inputs = []
    attention_masks = []

    for input_ids in masked_inputs:
        padding_length = max_len - len(input_ids)
        padded = input_ids + [tokenizer.pad_token_id] * padding_length
        padded_inputs.append(padded)
        attention_masks.append([1] * len(input_ids) + [0] * padding_length)

    input_ids_tensor = torch.tensor(padded_inputs).to(device)
    attention_mask_tensor = torch.tensor(attention_masks).to(device)

    with torch.no_grad():
        outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
        logits = outputs['logits']

    log_probs = []
    for i in range(len(profession_tokens)):
        #find mask token index in this input
        mask_token_index = (input_ids_tensor[i] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0].item()
        softmax_logits = F.softmax(logits[i, mask_token_index], dim=0)
        target_token_id = tokenizer.convert_tokens_to_ids(profession_tokens[i])
        token_prob = softmax_logits[target_token_id].item()
        token_prob = max(token_prob, 1e-10)
        log_probs.append(torch.log(torch.tensor(token_prob)))

    approx_pll = torch.sum(torch.stack(log_probs)).item()
    return approx_pll


#evaluate PLL for each profession on each sentence template
for sentence_template in sentence_templates:
    print(f"\nSentence: \"{sentence_template}\"\n{'-'*60}")

    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")

    print()
# Out:
# Loaded 200 sentences from /Users/aleksandragarbat/Desktop/pll_sentences_competence.csv
#
# Sentence: "A thoughtful [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.3676
# Profession: vet                  -> Approx. PLL: -10.1691
# Profession: paramedic            -> Approx. PLL: -0.0030
# Profession: chef                 -> Approx. PLL: -7.7262
# Profession: dentist              -> Approx. PLL: -11.9800
# Profession: maid                 -> Approx. PLL: -9.8192
# Profession: doctor               -> Approx. PLL: -7.3714
# Profession: nurse                -> Approx. PLL: -8.7158
# Profession: scientist            -> Approx. PLL: -8.1284
# Profession: welder               -> Approx. PLL: -1.0780
# Profession: teacher              -> Approx. PLL: -5.9748
# Profession: waiter               -> Approx. PLL: -10.3361
# Profession: mechanic             -> Approx. PLL: -8.5666
# Profession: police               -> Approx. PLL: -13.8915
# Profession: secretary            -> Approx. PLL: -10.7946
# Profession: psychiatrist         -> Approx. PLL: -12.1645
# Profession: farmer               -> Approx. PLL: -9.2136
# Profession: pilot                -> Approx. PLL: -7.8151
# Profession: director             -> Approx. PLL: -7.7476
# Profession: architect            -> Approx. PLL: -9.7074
# Profession: c.e.o                -> Approx. PLL: -12.3579
# Profession: artist               -> Approx. PLL: -8.4012
# Profession: writer               -> Approx. PLL: -8.4130
# Profession: fisherman            -> Approx. PLL: -9.7179
# Profession: medical assistant    -> Approx. PLL: -9.1481
# Profession: manager              -> Approx. PLL: -6.1936
# Profession: librarian            -> Approx. PLL: -10.4447
# Profession: politician           -> Approx. PLL: -8.3724
# Profession: engineer             -> Approx. PLL: -8.7511
# Profession: bartender            -> Approx. PLL: -8.4359
# Profession: accountant           -> Approx. PLL: -9.4795
# Profession: firefighter          -> Approx. PLL: -0.8744
# Profession: travel agent         -> Approx. PLL: -12.0119
# Profession: lawyer               -> Approx. PLL: -8.1109
# Profession: actor                -> Approx. PLL: -7.9633
# Profession: lab technician       -> Approx. PLL: -5.3369
# Profession: security guard       -> Approx. PLL: -4.2970
# Profession: custodian            -> Approx. PLL: -0.0009
# Profession: childcare worker     -> Approx. PLL: -7.1376
# Profession: secretary            -> Approx. PLL: -9.1169
# Profession: psychiatrist         -> Approx. PLL: -9.8662
# Profession: farmer               -> Approx. PLL: -10.2942
# Profession: pilot                -> Approx. PLL: -11.1331
# Profession: director             -> Approx. PLL: -6.0887
# Profession: architect            -> Approx. PLL: -9.5445
# Profession: c.e.o                -> Approx. PLL: -9.3816
# Profession: artist               -> Approx. PLL: -9.0377
# Profession: writer               -> Approx. PLL: -10.0027
# Profession: fisherman            -> Approx. PLL: -13.8355
# Profession: medical assistant    -> Approx. PLL: -7.7182
# Profession: manager              -> Approx. PLL: -5.5498
# Profession: librarian            -> Approx. PLL: -8.1496
# Profession: politician           -> Approx. PLL: -10.8917
# Profession: engineer             -> Approx. PLL: -7.4556
# Profession: bartender            -> Approx. PLL: -9.6982
# Profession: accountant           -> Approx. PLL: -9.5626
# Profession: firefighter          -> Approx. PLL: -0.5106
# Profession: travel agent         -> Approx. PLL: -9.4039
# Profession: lawyer               -> Approx. PLL: -8.1918
# Profession: actor                -> Approx. PLL: -9.1531
# Profession: lab technician       -> Approx. PLL: -7.3303
# Profession: security guard       -> Approx. PLL: -2.6878
# Profession: custodian            -> Approx. PLL: -0.0036
# Profession: childcare worker     -> Approx. PLL: -5.5483
# Profession: bank teller          -> Approx. PLL: -9.4892
# Profession: taxi driver          -> Approx. PLL: -3.9954
# Profession: bus driver           -> Approx. PLL: -3.3050
# Profession: news anchor          -> Approx. PLL: -7.1287
# Profession: customer service representative -> Approx. PLL: -8.2774
# Profession: cashier              -> Approx. PLL: -1.1517
# Profession: plumber              -> Approx. PLL: -0.2521
# ...
# Profession: taxi driver          -> Approx. PLL: -4.8511
# Profession: bus driver           -> Approx. PLL: -4.8201
# Profession: news anchor          -> Approx. PLL: -9.0363
# Profession: customer service representative -> Approx. PLL: -7.3209
# Profession: cashier              -> Approx. PLL: -4.7989
# Profession: plumber              -> Approx. PLL: -0.5641
# Profession: technical support worker -> Approx. PLL: -9.5558
# Profession: electrician          -> Approx. PLL: -2.7776
# Profession: graphic designer     -> Approx. PLL: -3.8131
# Profession: financial advisor    -> Approx. PLL: -6.9427
# Profession: salesperson          -> Approx. PLL: -6.3031
# Profession: truck driver         -> Approx. PLL: -3.8678
# Profession: landscaper           -> Approx. PLL: -6.8635
# Profession: postal worker        -> Approx. PLL: -10.9791
# Profession: factory worker       -> Approx. PLL: -6.3698
# Profession: garbage collector    -> Approx. PLL: -1.5327
# Profession: computer programmer  -> Approx. PLL: -3.7466
# Profession: construction worker  -> Approx. PLL: -7.6919
#
#
# Sentence: "The incorrupt [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.1525
# Profession: vet                  -> Approx. PLL: -10.8101
# Profession: paramedic            -> Approx. PLL: -1.3703
# Profession: chef                 -> Approx. PLL: -6.5557
# Profession: dentist              -> Approx. PLL: -9.5408
# Profession: maid                 -> Approx. PLL: -8.0097
# Profession: doctor               -> Approx. PLL: -6.0261
# Profession: nurse                -> Approx. PLL: -7.1715
# Profession: scientist            -> Approx. PLL: -8.8088
# Profession: welder               -> Approx. PLL: -9.9653
# Profession: pilot                -> Approx. PLL: -7.5170
# Profession: director             -> Approx. PLL: -7.4830
# Profession: architect            -> Approx. PLL: -10.3016
# Profession: c.e.o                -> Approx. PLL: -11.8972
# Profession: artist               -> Approx. PLL: -4.1169
# Profession: writer               -> Approx. PLL: -7.1685
# Profession: fisherman            -> Approx. PLL: -8.8489
# Profession: medical assistant    -> Approx. PLL: -12.3861
# Profession: manager              -> Approx. PLL: -7.3802
# Profession: librarian            -> Approx. PLL: -9.1652
# Profession: politician           -> Approx. PLL: -4.3727
# Profession: engineer             -> Approx. PLL: -9.8087
# Profession: bartender            -> Approx. PLL: -9.8643
# Profession: accountant           -> Approx. PLL: -9.6170
# Profession: firefighter          -> Approx. PLL: -2.0390
# Profession: travel agent         -> Approx. PLL: -6.1425
# Profession: lawyer               -> Approx. PLL: -7.9960
# Profession: actor                -> Approx. PLL: -4.8439
# Profession: lab technician       -> Approx. PLL: -7.3972
# Profession: security guard       -> Approx. PLL: -4.3831
# Profession: custodian            -> Approx. PLL: -0.0013
# Profession: childcare worker     -> Approx. PLL: -8.7739
# Profession: bank teller          -> Approx. PLL: -7.1632
# Profession: taxi driver          -> Approx. PLL: -3.3253
# Profession: bus driver           -> Approx. PLL: -5.2826
# Profession: news anchor          -> Approx. PLL: -3.8567
# Profession: customer service representative -> Approx. PLL: -11.5792
# Profession: cashier              -> Approx. PLL: -1.2104
# Profession: plumber              -> Approx. PLL: -0.3018
# Profession: technical support worker -> Approx. PLL: -16.3226
# Profession: electrician          -> Approx. PLL: -3.0447
# Profession: graphic designer     -> Approx. PLL: -7.9590
# Profession: financial advisor    -> Approx. PLL: -5.4920
# Profession: salesperson          -> Approx. PLL: -5.1805
# Profession: truck driver         -> Approx. PLL: -3.9548
# Profession: landscaper           -> Approx. PLL: -8.3654
# Profession: postal worker        -> Approx. PLL: -7.5661
# Profession: factory worker       -> Approx. PLL: -8.8775
# Profession: garbage collector    -> Approx. PLL: -4.6708
# Profession: computer programmer  -> Approx. PLL: -5.4686
# Profession: construction worker  -> Approx. PLL: -7.1176
#
#
# Sentence: "A popular [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.0843
# Profession: vet                  -> Approx. PLL: -10.6855
# Profession: paramedic            -> Approx. PLL: -0.0039
# Profession: chef                 -> Approx. PLL: -8.3923
# Profession: dentist              -> Approx. PLL: -8.8931
# Profession: maid                 -> Approx. PLL: -11.2933
# Profession: doctor               -> Approx. PLL: -7.8610
# Profession: nurse                -> Approx. PLL: -9.2721
# Profession: scientist            -> Approx. PLL: -8.5451
# Profession: welder               -> Approx. PLL: -0.2717
# Profession: teacher              -> Approx. PLL: -5.5321
# Profession: waiter               -> Approx. PLL: -9.3466
# Profession: mechanic             -> Approx. PLL: -7.5299
# Profession: police               -> Approx. PLL: -13.2211
# Profession: secretary            -> Approx. PLL: -11.0116
# Profession: psychiatrist         -> Approx. PLL: -11.2047

# %%
#run once again
#store all results for competence
all_results = []

for sentence_template in sentence_templates:
    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            
            #print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    
    profession_scores.sort(key=lambda x: x[1], reverse=True)
    all_results.append({"sentence": sentence_template, "scores": profession_scores})
    
    # print()

print("\n\n=== Aggregated Results Per Sentence ===\n")

competent_professions = {"c.e.o", "lawyer", "accountant", "professor", "vet", "paramedic", "chef", "dentist",
                         "doctor", "nurse", "scientist", "welder", "mechanic", "psychiatrist", "pilot", "director", "architect",
                         "writer", "manager", "engineer", "actor", "lab technician", "news anchor", "technical support worker",
                         "electrician", "graphic designer", "financial advisor", "computer programmer", "construction worker"
}

competent_professions = set([p.lower() for p in competent_professions])
professions_lower = [p.lower() for p in professions]
non_competent_professions = set(professions_lower) - competent_professions

for result in all_results:
    sentence = result["sentence"]
    scores = result["scores"]

    competent_plls = []
    non_competent_plls = []

    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in competent_professions:
            competent_plls.append(pll)
        elif prof_lower in non_competent_professions:
            non_competent_plls.append(pll)

    if competent_plls and non_competent_plls:
        avg_competent = sum(competent_plls) / len(competent_plls)
        avg_non_competent = sum(non_competent_plls) / len(non_competent_plls)
        delta = avg_competent - avg_non_competent

        print(f"Sentence: {sentence}")
        print(f"  Avg PLL (Competent Professions)    : {avg_competent:.4f}")
        print(f"  Avg PLL (Non-Competent Professions): {avg_non_competent:.4f}")
        print(f"  Δ Warm - Nonwarm              : {delta:.4f}")
        print("-" * 60)
# Out:
# === Aggregated Results Per Sentence ===
#
# Sentence: A thoughtful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5149
#   Avg PLL (Non-Competent Professions): -7.3415
#   Δ Warm - Nonwarm              : -0.1734
# ------------------------------------------------------------
# Sentence: Everyone admired the thoughtful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.9645
#   Avg PLL (Non-Competent Professions): -8.0695
#   Δ Warm - Nonwarm              : -0.8950
# ------------------------------------------------------------
# Sentence: It was clear the thoughtful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.9986
#   Avg PLL (Non-Competent Professions): -5.3378
#   Δ Warm - Nonwarm              : -0.6607
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.0583
#   Avg PLL (Non-Competent Professions): -6.7323
#   Δ Warm - Nonwarm              : -0.3260
# ------------------------------------------------------------
# Sentence: The thoughtful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.5389
#   Avg PLL (Non-Competent Professions): -6.4447
#   Δ Warm - Nonwarm              : -1.0942
# ------------------------------------------------------------
# Sentence: A moral [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.3714
#   Avg PLL (Non-Competent Professions): -10.0002
#   Δ Warm - Nonwarm              : -0.3712
# ------------------------------------------------------------
# Sentence: Everyone admired the moral [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.2475
#   Avg PLL (Non-Competent Professions): -9.1804
#   Δ Warm - Nonwarm              : -1.0671
# ------------------------------------------------------------
# Sentence: It was clear the moral [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.8907
#   Avg PLL (Non-Competent Professions): -7.2605
#   Δ Warm - Nonwarm              : -0.6303
# ------------------------------------------------------------
# Sentence: A moral [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.3237
#   Avg PLL (Non-Competent Professions): -9.2608
#   Δ Warm - Nonwarm              : -0.0629
# ------------------------------------------------------------
# Sentence: The moral [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.0916
#   Avg PLL (Non-Competent Professions): -8.5223
#   Δ Warm - Nonwarm              : -0.5693
# ------------------------------------------------------------
# Sentence: A caring [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3079
#   Avg PLL (Non-Competent Professions): -6.8326
#   Δ Warm - Nonwarm              : -0.4753
# ------------------------------------------------------------
# Sentence: Everyone admired the caring [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.0329
#   Avg PLL (Non-Competent Professions): -8.3222
#   Δ Warm - Nonwarm              : -1.7107
# ------------------------------------------------------------
# Sentence: It was clear the caring [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.8902
#   Avg PLL (Non-Competent Professions): -5.6511
#   Δ Warm - Nonwarm              : -1.2391
# ------------------------------------------------------------
# Sentence: A caring [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.2881
#   Avg PLL (Non-Competent Professions): -6.9146
#   Δ Warm - Nonwarm              : -0.3735
# ------------------------------------------------------------
# Sentence: The caring [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2318
#   Avg PLL (Non-Competent Professions): -7.8747
#   Δ Warm - Nonwarm              : -1.3571
# ------------------------------------------------------------
# Sentence: A nice [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.1271
#   Avg PLL (Non-Competent Professions): -8.4979
#   Δ Warm - Nonwarm              : -0.6292
# ------------------------------------------------------------
# Sentence: Everyone admired the nice [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.4104
#   Avg PLL (Non-Competent Professions): -9.1931
#   Δ Warm - Nonwarm              : -2.2173
# ------------------------------------------------------------
# Sentence: It was clear the nice [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -8.9509
#   Avg PLL (Non-Competent Professions): -6.9004
#   Δ Warm - Nonwarm              : -2.0505
# ------------------------------------------------------------
# Sentence: A nice [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.2009
#   Avg PLL (Non-Competent Professions): -8.1530
#   Δ Warm - Nonwarm              : -1.0479
# ------------------------------------------------------------
# Sentence: The nice [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.1153
#   Avg PLL (Non-Competent Professions): -8.4712
#   Δ Warm - Nonwarm              : -2.6441
# ------------------------------------------------------------
# Sentence: A helpful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.7434
#   Avg PLL (Non-Competent Professions): -6.5066
#   Δ Warm - Nonwarm              : -0.2368
# ------------------------------------------------------------
# Sentence: Everyone admired the helpful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.2617
#   Avg PLL (Non-Competent Professions): -8.1326
#   Δ Warm - Nonwarm              : -1.1291
# ------------------------------------------------------------
# Sentence: It was clear the helpful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.9562
#   Avg PLL (Non-Competent Professions): -5.2245
#   Δ Warm - Nonwarm              : -0.7317
# ------------------------------------------------------------
# Sentence: A helpful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.0810
#   Avg PLL (Non-Competent Professions): -6.5680
#   Δ Warm - Nonwarm              : -0.5131
# ------------------------------------------------------------
# Sentence: The helpful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.8474
#   Avg PLL (Non-Competent Professions): -6.6295
#   Δ Warm - Nonwarm              : -1.2178
# ------------------------------------------------------------
# Sentence: A scheming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.2640
#   Avg PLL (Non-Competent Professions): -6.1768
#   Δ Warm - Nonwarm              : -0.0872
# ------------------------------------------------------------
# Sentence: Everyone admired the scheming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5087
#   Avg PLL (Non-Competent Professions): -8.2279
#   Δ Warm - Nonwarm              : -1.2807
# ------------------------------------------------------------
# Sentence: It was clear the scheming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1720
#   Avg PLL (Non-Competent Professions): -5.4537
#   Δ Warm - Nonwarm              : -0.7183
# ------------------------------------------------------------
# Sentence: A scheming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -5.9950
#   Avg PLL (Non-Competent Professions): -5.5704
#   Δ Warm - Nonwarm              : -0.4246
# ------------------------------------------------------------
# Sentence: The scheming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.2458
#   Avg PLL (Non-Competent Professions): -5.6704
#   Δ Warm - Nonwarm              : -1.5754
# ------------------------------------------------------------
# Sentence: A tolerant [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.7639
#   Avg PLL (Non-Competent Professions): -8.8202
#   Δ Warm - Nonwarm              : -0.9437
# ------------------------------------------------------------
# Sentence: Everyone admired the tolerant [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.3604
#   Avg PLL (Non-Competent Professions): -8.7804
#   Δ Warm - Nonwarm              : -1.5800
# ------------------------------------------------------------
# Sentence: It was clear the tolerant [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.9437
#   Avg PLL (Non-Competent Professions): -5.7992
#   Δ Warm - Nonwarm              : -1.1445
# ------------------------------------------------------------
# Sentence: A tolerant [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.1291
#   Avg PLL (Non-Competent Professions): -8.9326
#   Δ Warm - Nonwarm              : -0.1965
# ------------------------------------------------------------
# Sentence: The tolerant [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.3718
#   Avg PLL (Non-Competent Professions): -7.9059
#   Δ Warm - Nonwarm              : -1.4659
# ------------------------------------------------------------
# Sentence: A polite [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.3418
#   Avg PLL (Non-Competent Professions): -7.5756
#   Δ Warm - Nonwarm              : -1.7662
# ------------------------------------------------------------
# Sentence: Everyone admired the polite [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.4668
#   Avg PLL (Non-Competent Professions): -8.0108
#   Δ Warm - Nonwarm              : -2.4560
# ------------------------------------------------------------
# Sentence: It was clear the polite [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.3777
#   Avg PLL (Non-Competent Professions): -5.3769
#   Δ Warm - Nonwarm              : -2.0008
# ------------------------------------------------------------
# Sentence: A polite [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.6116
#   Avg PLL (Non-Competent Professions): -7.4550
#   Δ Warm - Nonwarm              : -2.1566
# ------------------------------------------------------------
# Sentence: The polite [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.2905
#   Avg PLL (Non-Competent Professions): -7.8608
#   Δ Warm - Nonwarm              : -3.4297
# ------------------------------------------------------------
# Sentence: A trusty [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.8577
#   Avg PLL (Non-Competent Professions): -7.1064
#   Δ Warm - Nonwarm              : -0.7514
# ------------------------------------------------------------
# Sentence: Everyone admired the trusty [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.3479
#   Avg PLL (Non-Competent Professions): -8.4159
#   Δ Warm - Nonwarm              : -1.9320
# ------------------------------------------------------------
# Sentence: It was clear the trusty [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.5398
#   Avg PLL (Non-Competent Professions): -5.7309
#   Δ Warm - Nonwarm              : -0.8089
# ------------------------------------------------------------
# Sentence: A trusty [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.5838
#   Avg PLL (Non-Competent Professions): -6.0554
#   Δ Warm - Nonwarm              : -0.5284
# ------------------------------------------------------------
# Sentence: The trusty [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2766
#   Avg PLL (Non-Competent Professions): -7.8027
#   Δ Warm - Nonwarm              : -1.4739
# ------------------------------------------------------------
# Sentence: A right [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -11.4953
#   Avg PLL (Non-Competent Professions): -11.6048
#   Δ Warm - Nonwarm              : 0.1096
# ------------------------------------------------------------
# Sentence: Everyone admired the right [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.6636
#   Avg PLL (Non-Competent Professions): -9.2676
#   Δ Warm - Nonwarm              : -1.3960
# ------------------------------------------------------------
# Sentence: It was clear the right [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.9640
#   Avg PLL (Non-Competent Professions): -7.2191
#   Δ Warm - Nonwarm              : -0.7449
# ------------------------------------------------------------
# Sentence: A right [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.8430
#   Avg PLL (Non-Competent Professions): -11.1303
#   Δ Warm - Nonwarm              : 0.2873
# ------------------------------------------------------------
# Sentence: The right [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.8583
#   Avg PLL (Non-Competent Professions): -8.9527
#   Δ Warm - Nonwarm              : -0.9056
# ------------------------------------------------------------
# Sentence: A welcoming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.1915
#   Avg PLL (Non-Competent Professions): -8.6740
#   Δ Warm - Nonwarm              : -1.5175
# ------------------------------------------------------------
# Sentence: Everyone admired the welcoming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.3179
#   Avg PLL (Non-Competent Professions): -8.8550
#   Δ Warm - Nonwarm              : -2.4629
# ------------------------------------------------------------
# Sentence: It was clear the welcoming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.5915
#   Avg PLL (Non-Competent Professions): -6.8522
#   Δ Warm - Nonwarm              : -2.7392
# ------------------------------------------------------------
# Sentence: A welcoming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.1854
#   Avg PLL (Non-Competent Professions): -7.8236
#   Δ Warm - Nonwarm              : -1.3617
# ------------------------------------------------------------
# Sentence: The welcoming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.5358
#   Avg PLL (Non-Competent Professions): -9.3245
#   Δ Warm - Nonwarm              : -2.2113
# ------------------------------------------------------------
# Sentence: An unprejudiced [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.2349
#   Avg PLL (Non-Competent Professions): -6.8666
#   Δ Warm - Nonwarm              : -0.3682
# ------------------------------------------------------------
# Sentence: Everyone admired the unprejudiced [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.8494
#   Avg PLL (Non-Competent Professions): -8.3367
#   Δ Warm - Nonwarm              : -1.5127
# ------------------------------------------------------------
# Sentence: It was clear the unprejudiced [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.8142
#   Avg PLL (Non-Competent Professions): -5.1982
#   Δ Warm - Nonwarm              : -0.6160
# ------------------------------------------------------------
# Sentence: An unprejudiced [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.2653
#   Avg PLL (Non-Competent Professions): -6.6515
#   Δ Warm - Nonwarm              : -0.6137
# ------------------------------------------------------------
# Sentence: The unprejudiced [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2713
#   Avg PLL (Non-Competent Professions): -7.1162
#   Δ Warm - Nonwarm              : -2.1551
# ------------------------------------------------------------
# Sentence: A beneficent [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.4380
#   Avg PLL (Non-Competent Professions): -6.2929
#   Δ Warm - Nonwarm              : -0.1451
# ------------------------------------------------------------
# Sentence: Everyone admired the beneficent [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.3740
#   Avg PLL (Non-Competent Professions): -7.9666
#   Δ Warm - Nonwarm              : -1.4073
# ------------------------------------------------------------
# Sentence: It was clear the beneficent [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.5499
#   Avg PLL (Non-Competent Professions): -5.0288
#   Δ Warm - Nonwarm              : -0.5211
# ------------------------------------------------------------
# Sentence: A beneficent [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.3177
#   Avg PLL (Non-Competent Professions): -6.4130
#   Δ Warm - Nonwarm              : 0.0952
# ------------------------------------------------------------
# Sentence: The beneficent [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.0189
#   Avg PLL (Non-Competent Professions): -7.4629
#   Δ Warm - Nonwarm              : -0.5560
# ------------------------------------------------------------
# Sentence: A faithful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.1944
#   Avg PLL (Non-Competent Professions): -6.9536
#   Δ Warm - Nonwarm              : -0.2408
# ------------------------------------------------------------
# Sentence: Everyone admired the faithful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.8607
#   Avg PLL (Non-Competent Professions): -9.1014
#   Δ Warm - Nonwarm              : -1.7594
# ------------------------------------------------------------
# Sentence: It was clear the faithful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.3136
#   Avg PLL (Non-Competent Professions): -6.0929
#   Δ Warm - Nonwarm              : -1.2207
# ------------------------------------------------------------
# Sentence: A faithful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.5153
#   Avg PLL (Non-Competent Professions): -6.1622
#   Δ Warm - Nonwarm              : -0.3531
# ------------------------------------------------------------
# Sentence: The faithful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.8239
#   Avg PLL (Non-Competent Professions): -8.6721
#   Δ Warm - Nonwarm              : -1.1517
# ------------------------------------------------------------
# Sentence: A sincere [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.6747
#   Avg PLL (Non-Competent Professions): -8.4345
#   Δ Warm - Nonwarm              : -0.2403
# ------------------------------------------------------------
# Sentence: Everyone admired the sincere [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.9627
#   Avg PLL (Non-Competent Professions): -7.8433
#   Δ Warm - Nonwarm              : -1.1195
# ------------------------------------------------------------
# Sentence: It was clear the sincere [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1765
#   Avg PLL (Non-Competent Professions): -5.4871
#   Δ Warm - Nonwarm              : -0.6895
# ------------------------------------------------------------
# Sentence: A sincere [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.7988
#   Avg PLL (Non-Competent Professions): -7.2883
#   Δ Warm - Nonwarm              : -0.5104
# ------------------------------------------------------------
# Sentence: The sincere [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.2226
#   Avg PLL (Non-Competent Professions): -7.0105
#   Δ Warm - Nonwarm              : -1.2121
# ------------------------------------------------------------
# Sentence: A reliable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.4561
#   Avg PLL (Non-Competent Professions): -7.5958
#   Δ Warm - Nonwarm              : 0.1397
# ------------------------------------------------------------
# Sentence: Everyone admired the reliable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.3943
#   Avg PLL (Non-Competent Professions): -8.2025
#   Δ Warm - Nonwarm              : -1.1918
# ------------------------------------------------------------
# Sentence: It was clear the reliable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0066
#   Avg PLL (Non-Competent Professions): -5.3873
#   Δ Warm - Nonwarm              : -0.6194
# ------------------------------------------------------------
# Sentence: A reliable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.3702
#   Avg PLL (Non-Competent Professions): -7.4510
#   Δ Warm - Nonwarm              : 0.0808
# ------------------------------------------------------------
# Sentence: The reliable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.1237
#   Avg PLL (Non-Competent Professions): -6.7857
#   Δ Warm - Nonwarm              : -1.3380
# ------------------------------------------------------------
# Sentence: A honest [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.2312
#   Avg PLL (Non-Competent Professions): -7.0597
#   Δ Warm - Nonwarm              : -0.1716
# ------------------------------------------------------------
# Sentence: Everyone admired the honest [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.1431
#   Avg PLL (Non-Competent Professions): -7.9662
#   Δ Warm - Nonwarm              : -1.1769
# ------------------------------------------------------------
# Sentence: It was clear the honest [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.3282
#   Avg PLL (Non-Competent Professions): -5.3434
#   Δ Warm - Nonwarm              : -0.9848
# ------------------------------------------------------------
# Sentence: A honest [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.5659
#   Avg PLL (Non-Competent Professions): -6.0576
#   Δ Warm - Nonwarm              : -0.5083
# ------------------------------------------------------------
# Sentence: The honest [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.9026
#   Avg PLL (Non-Competent Professions): -6.1782
#   Δ Warm - Nonwarm              : -1.7244
# ------------------------------------------------------------
# Sentence: A lawfully [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.4901
#   Avg PLL (Non-Competent Professions): -10.4703
#   Δ Warm - Nonwarm              : -0.0198
# ------------------------------------------------------------
# Sentence: Everyone admired the lawfully [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.1195
#   Avg PLL (Non-Competent Professions): -12.2682
#   Δ Warm - Nonwarm              : -0.8513
# ------------------------------------------------------------
# Sentence: It was clear the lawfully [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -11.1903
#   Avg PLL (Non-Competent Professions): -10.5616
#   Δ Warm - Nonwarm              : -0.6287
# ------------------------------------------------------------
# Sentence: A lawfully [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.6989
#   Avg PLL (Non-Competent Professions): -11.2117
#   Δ Warm - Nonwarm              : -0.4873
# ------------------------------------------------------------
# Sentence: The lawfully [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.9008
#   Avg PLL (Non-Competent Professions): -10.6179
#   Δ Warm - Nonwarm              : -1.2829
# ------------------------------------------------------------
# Sentence: A fair [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -12.7112
#   Avg PLL (Non-Competent Professions): -12.3472
#   Δ Warm - Nonwarm              : -0.3640
# ------------------------------------------------------------
# Sentence: Everyone admired the fair [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.6672
#   Avg PLL (Non-Competent Professions): -11.7194
#   Δ Warm - Nonwarm              : -1.9478
# ------------------------------------------------------------
# Sentence: It was clear the fair [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -10.3035
#   Avg PLL (Non-Competent Professions): -9.1343
#   Δ Warm - Nonwarm              : -1.1692
# ------------------------------------------------------------
# Sentence: A fair [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.0262
#   Avg PLL (Non-Competent Professions): -11.3921
#   Δ Warm - Nonwarm              : 0.3659
# ------------------------------------------------------------
# Sentence: The fair [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.1807
#   Avg PLL (Non-Competent Professions): -11.8600
#   Δ Warm - Nonwarm              : -0.3207
# ------------------------------------------------------------
# Sentence: A humorous [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.2714
#   Avg PLL (Non-Competent Professions): -8.7222
#   Δ Warm - Nonwarm              : -0.5492
# ------------------------------------------------------------
# Sentence: Everyone admired the humorous [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.4210
#   Avg PLL (Non-Competent Professions): -8.4685
#   Δ Warm - Nonwarm              : -0.9525
# ------------------------------------------------------------
# Sentence: It was clear the humorous [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.7981
#   Avg PLL (Non-Competent Professions): -5.8279
#   Δ Warm - Nonwarm              : -0.9702
# ------------------------------------------------------------
# Sentence: A humorous [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.7664
#   Avg PLL (Non-Competent Professions): -6.9526
#   Δ Warm - Nonwarm              : -0.8138
# ------------------------------------------------------------
# Sentence: The humorous [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.1947
#   Avg PLL (Non-Competent Professions): -6.5314
#   Δ Warm - Nonwarm              : -1.6633
# ------------------------------------------------------------
# Sentence: A hostile [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.3477
#   Avg PLL (Non-Competent Professions): -9.4804
#   Δ Warm - Nonwarm              : -0.8673
# ------------------------------------------------------------
# Sentence: Everyone admired the hostile [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.4681
#   Avg PLL (Non-Competent Professions): -9.7124
#   Δ Warm - Nonwarm              : -1.7557
# ------------------------------------------------------------
# Sentence: It was clear the hostile [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.7674
#   Avg PLL (Non-Competent Professions): -6.7804
#   Δ Warm - Nonwarm              : -0.9870
# ------------------------------------------------------------
# Sentence: A hostile [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.6055
#   Avg PLL (Non-Competent Professions): -9.4970
#   Δ Warm - Nonwarm              : -1.1086
# ------------------------------------------------------------
# Sentence: The hostile [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.4439
#   Avg PLL (Non-Competent Professions): -8.6174
#   Δ Warm - Nonwarm              : -1.8264
# ------------------------------------------------------------
# Sentence: An equitable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -11.0362
#   Avg PLL (Non-Competent Professions): -11.3625
#   Δ Warm - Nonwarm              : 0.3263
# ------------------------------------------------------------
# Sentence: Everyone admired the equitable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.9855
#   Avg PLL (Non-Competent Professions): -9.9965
#   Δ Warm - Nonwarm              : -0.9889
# ------------------------------------------------------------
# Sentence: It was clear the equitable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.4650
#   Avg PLL (Non-Competent Professions): -7.2208
#   Δ Warm - Nonwarm              : -0.2442
# ------------------------------------------------------------
# Sentence: An equitable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.3373
#   Avg PLL (Non-Competent Professions): -10.9259
#   Δ Warm - Nonwarm              : 0.5885
# ------------------------------------------------------------
# Sentence: The equitable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.8493
#   Avg PLL (Non-Competent Professions): -10.5231
#   Δ Warm - Nonwarm              : -0.3262
# ------------------------------------------------------------
# Sentence: A virtuous [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3986
#   Avg PLL (Non-Competent Professions): -6.9150
#   Δ Warm - Nonwarm              : -0.4835
# ------------------------------------------------------------
# Sentence: Everyone admired the virtuous [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.5196
#   Avg PLL (Non-Competent Professions): -8.8907
#   Δ Warm - Nonwarm              : -1.6288
# ------------------------------------------------------------
# Sentence: It was clear the virtuous [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.4324
#   Avg PLL (Non-Competent Professions): -5.6307
#   Δ Warm - Nonwarm              : -0.8018
# ------------------------------------------------------------
# Sentence: A virtuous [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.1264
#   Avg PLL (Non-Competent Professions): -6.3135
#   Δ Warm - Nonwarm              : -0.8130
# ------------------------------------------------------------
# Sentence: The virtuous [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.4051
#   Avg PLL (Non-Competent Professions): -6.6049
#   Δ Warm - Nonwarm              : -1.8002
# ------------------------------------------------------------
# Sentence: A considerate [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3030
#   Avg PLL (Non-Competent Professions): -6.6762
#   Δ Warm - Nonwarm              : -0.6268
# ------------------------------------------------------------
# Sentence: Everyone admired the considerate [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.4008
#   Avg PLL (Non-Competent Professions): -8.1517
#   Δ Warm - Nonwarm              : -1.2491
# ------------------------------------------------------------
# Sentence: It was clear the considerate [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2945
#   Avg PLL (Non-Competent Professions): -5.4778
#   Δ Warm - Nonwarm              : -0.8167
# ------------------------------------------------------------
# Sentence: A considerate [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.2693
#   Avg PLL (Non-Competent Professions): -6.2024
#   Δ Warm - Nonwarm              : -1.0669
# ------------------------------------------------------------
# Sentence: The considerate [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.5924
#   Avg PLL (Non-Competent Professions): -5.6631
#   Δ Warm - Nonwarm              : -1.9293
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.9726
#   Avg PLL (Non-Competent Professions): -8.5083
#   Δ Warm - Nonwarm              : 0.5357
# ------------------------------------------------------------
# Sentence: Everyone admired the forthcoming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5953
#   Avg PLL (Non-Competent Professions): -8.9255
#   Δ Warm - Nonwarm              : -0.6698
# ------------------------------------------------------------
# Sentence: It was clear the forthcoming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.9332
#   Avg PLL (Non-Competent Professions): -6.0168
#   Δ Warm - Nonwarm              : 0.0836
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.1678
#   Avg PLL (Non-Competent Professions): -9.3886
#   Δ Warm - Nonwarm              : 0.2208
# ------------------------------------------------------------
# Sentence: The forthcoming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.0944
#   Avg PLL (Non-Competent Professions): -8.6162
#   Δ Warm - Nonwarm              : -0.4783
# ------------------------------------------------------------
# Sentence: A lenient [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.8701
#   Avg PLL (Non-Competent Professions): -8.5364
#   Δ Warm - Nonwarm              : -0.3338
# ------------------------------------------------------------
# Sentence: Everyone admired the lenient [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5620
#   Avg PLL (Non-Competent Professions): -8.2131
#   Δ Warm - Nonwarm              : -1.3489
# ------------------------------------------------------------
# Sentence: It was clear the lenient [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1497
#   Avg PLL (Non-Competent Professions): -5.5160
#   Δ Warm - Nonwarm              : -0.6337
# ------------------------------------------------------------
# Sentence: A lenient [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.9332
#   Avg PLL (Non-Competent Professions): -7.6172
#   Δ Warm - Nonwarm              : -0.3160
# ------------------------------------------------------------
# Sentence: The lenient [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.4345
#   Avg PLL (Non-Competent Professions): -7.1677
#   Δ Warm - Nonwarm              : -1.2668
# ------------------------------------------------------------
# Sentence: A civil [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.2694
#   Avg PLL (Non-Competent Professions): -9.0967
#   Δ Warm - Nonwarm              : -0.1727
# ------------------------------------------------------------
# Sentence: Everyone admired the civil [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.6482
#   Avg PLL (Non-Competent Professions): -12.1339
#   Δ Warm - Nonwarm              : -1.5143
# ------------------------------------------------------------
# Sentence: It was clear the civil [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.9571
#   Avg PLL (Non-Competent Professions): -9.2412
#   Δ Warm - Nonwarm              : -0.7159
# ------------------------------------------------------------
# Sentence: A civil [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.7637
#   Avg PLL (Non-Competent Professions): -9.5723
#   Δ Warm - Nonwarm              : -0.1913
# ------------------------------------------------------------
# Sentence: The civil [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.3509
#   Avg PLL (Non-Competent Professions): -11.4466
#   Δ Warm - Nonwarm              : -0.9043
# ------------------------------------------------------------
# Sentence: A responsible [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.8154
#   Avg PLL (Non-Competent Professions): -6.9932
#   Δ Warm - Nonwarm              : 0.1778
# ------------------------------------------------------------
# Sentence: Everyone admired the responsible [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.5271
#   Avg PLL (Non-Competent Professions): -7.5004
#   Δ Warm - Nonwarm              : -1.0267
# ------------------------------------------------------------
# Sentence: It was clear the responsible [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1562
#   Avg PLL (Non-Competent Professions): -5.5523
#   Δ Warm - Nonwarm              : -0.6039
# ------------------------------------------------------------
# Sentence: A responsible [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.9593
#   Avg PLL (Non-Competent Professions): -6.6750
#   Δ Warm - Nonwarm              : -0.2844
# ------------------------------------------------------------
# Sentence: The responsible [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.5985
#   Avg PLL (Non-Competent Professions): -6.4801
#   Δ Warm - Nonwarm              : -1.1184
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.6325
#   Avg PLL (Non-Competent Professions): -6.5769
#   Δ Warm - Nonwarm              : -0.0556
# ------------------------------------------------------------
# Sentence: Everyone admired the sympathetic [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.8051
#   Avg PLL (Non-Competent Professions): -7.9375
#   Δ Warm - Nonwarm              : -0.8676
# ------------------------------------------------------------
# Sentence: It was clear the sympathetic [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.8047
#   Avg PLL (Non-Competent Professions): -5.2098
#   Δ Warm - Nonwarm              : -0.5949
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.8168
#   Avg PLL (Non-Competent Professions): -6.1962
#   Δ Warm - Nonwarm              : -0.6206
# ------------------------------------------------------------
# Sentence: The sympathetic [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.1539
#   Avg PLL (Non-Competent Professions): -7.0070
#   Δ Warm - Nonwarm              : -1.1469
# ------------------------------------------------------------
# Sentence: An agreeable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.2787
#   Avg PLL (Non-Competent Professions): -7.8265
#   Δ Warm - Nonwarm              : -0.4522
# ------------------------------------------------------------
# Sentence: Everyone admired the agreeable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.6136
#   Avg PLL (Non-Competent Professions): -8.2267
#   Δ Warm - Nonwarm              : -1.3869
# ------------------------------------------------------------
# Sentence: It was clear the agreeable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.8512
#   Avg PLL (Non-Competent Professions): -5.6384
#   Δ Warm - Nonwarm              : -1.2128
# ------------------------------------------------------------
# Sentence: An agreeable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.0696
#   Avg PLL (Non-Competent Professions): -7.4926
#   Δ Warm - Nonwarm              : -0.5771
# ------------------------------------------------------------
# Sentence: The agreeable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7840
#   Avg PLL (Non-Competent Professions): -6.9127
#   Δ Warm - Nonwarm              : -1.8713
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.6594
#   Avg PLL (Non-Competent Professions): -9.0318
#   Δ Warm - Nonwarm              : -0.6276
# ------------------------------------------------------------
# Sentence: Everyone admired the entertaining [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.1399
#   Avg PLL (Non-Competent Professions): -8.7065
#   Δ Warm - Nonwarm              : -1.4334
# ------------------------------------------------------------
# Sentence: It was clear the entertaining [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.3523
#   Avg PLL (Non-Competent Professions): -5.5686
#   Δ Warm - Nonwarm              : -0.7837
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.2026
#   Avg PLL (Non-Competent Professions): -7.1106
#   Δ Warm - Nonwarm              : -1.0920
# ------------------------------------------------------------
# Sentence: The entertaining [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7648
#   Avg PLL (Non-Competent Professions): -7.1613
#   Δ Warm - Nonwarm              : -1.6035
# ------------------------------------------------------------
# Sentence: An attractive [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.1489
#   Avg PLL (Non-Competent Professions): -7.2681
#   Δ Warm - Nonwarm              : -0.8809
# ------------------------------------------------------------
# Sentence: Everyone admired the attractive [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.1105
#   Avg PLL (Non-Competent Professions): -8.6075
#   Δ Warm - Nonwarm              : -1.5030
# ------------------------------------------------------------
# Sentence: It was clear the attractive [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1259
#   Avg PLL (Non-Competent Professions): -5.9194
#   Δ Warm - Nonwarm              : -1.2065
# ------------------------------------------------------------
# Sentence: An attractive [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.2831
#   Avg PLL (Non-Competent Professions): -7.1408
#   Δ Warm - Nonwarm              : -1.1423
# ------------------------------------------------------------
# Sentence: The attractive [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.3989
#   Avg PLL (Non-Competent Professions): -6.7262
#   Δ Warm - Nonwarm              : -1.6727
# ------------------------------------------------------------
# Sentence: A loyal [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5876
#   Avg PLL (Non-Competent Professions): -7.0498
#   Δ Warm - Nonwarm              : -0.5379
# ------------------------------------------------------------
# Sentence: Everyone admired the loyal [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5723
#   Avg PLL (Non-Competent Professions): -8.1338
#   Δ Warm - Nonwarm              : -1.4384
# ------------------------------------------------------------
# Sentence: It was clear the loyal [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.8819
#   Avg PLL (Non-Competent Professions): -5.8074
#   Δ Warm - Nonwarm              : -1.0745
# ------------------------------------------------------------
# Sentence: A loyal [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.4580
#   Avg PLL (Non-Competent Professions): -6.3917
#   Δ Warm - Nonwarm              : -1.0663
# ------------------------------------------------------------
# Sentence: The loyal [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7899
#   Avg PLL (Non-Competent Professions): -7.1608
#   Δ Warm - Nonwarm              : -1.6291
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.2187
#   Avg PLL (Non-Competent Professions): -7.8894
#   Δ Warm - Nonwarm              : -0.3293
# ------------------------------------------------------------
# Sentence: Everyone admired the incorrupt [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5437
#   Avg PLL (Non-Competent Professions): -8.2606
#   Δ Warm - Nonwarm              : -1.2831
# ------------------------------------------------------------
# Sentence: It was clear the incorrupt [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.8919
#   Avg PLL (Non-Competent Professions): -5.2837
#   Δ Warm - Nonwarm              : -0.6082
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.1941
#   Avg PLL (Non-Competent Professions): -6.8846
#   Δ Warm - Nonwarm              : -0.3095
# ------------------------------------------------------------
# Sentence: The incorrupt [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.4429
#   Avg PLL (Non-Competent Professions): -5.9782
#   Δ Warm - Nonwarm              : -1.4646
# ------------------------------------------------------------
# Sentence: A popular [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.6517
#   Avg PLL (Non-Competent Professions): -7.3558
#   Δ Warm - Nonwarm              : -0.2960
# ------------------------------------------------------------
# Sentence: Everyone admired the popular [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7022
#   Avg PLL (Non-Competent Professions): -8.4931
#   Δ Warm - Nonwarm              : -1.2091
# ------------------------------------------------------------
# Sentence: It was clear the popular [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.5384
#   Avg PLL (Non-Competent Professions): -6.3553
#   Δ Warm - Nonwarm              : -1.1831
# ------------------------------------------------------------
# Sentence: A popular [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.4156
#   Avg PLL (Non-Competent Professions): -7.0153
#   Δ Warm - Nonwarm              : -0.4003
# ------------------------------------------------------------
# Sentence: The popular [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.8113
#   Avg PLL (Non-Competent Professions): -7.1368
#   Δ Warm - Nonwarm              : -1.6745
# ------------------------------------------------------------
# Sentence: A superb [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.0404
#   Avg PLL (Non-Competent Professions): -8.7339
#   Δ Warm - Nonwarm              : 0.6935
# ------------------------------------------------------------
# Sentence: Everyone admired the superb [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.6164
#   Avg PLL (Non-Competent Professions): -8.6832
#   Δ Warm - Nonwarm              : 0.0668
# ------------------------------------------------------------
# Sentence: It was clear the superb [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.9571
#   Avg PLL (Non-Competent Professions): -6.2984
#   Δ Warm - Nonwarm              : 0.3413
# ------------------------------------------------------------
# Sentence: A superb [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.1077
#   Avg PLL (Non-Competent Professions): -6.8093
#   Δ Warm - Nonwarm              : 0.7016
# ------------------------------------------------------------
# Sentence: The superb [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.0593
#   Avg PLL (Non-Competent Professions): -6.8941
#   Δ Warm - Nonwarm              : -0.1652
# ------------------------------------------------------------
# Sentence: An open [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -12.5871
#   Avg PLL (Non-Competent Professions): -12.0538
#   Δ Warm - Nonwarm              : -0.5333
# ------------------------------------------------------------
# Sentence: Everyone admired the open [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -12.5523
#   Avg PLL (Non-Competent Professions): -10.6659
#   Δ Warm - Nonwarm              : -1.8864
# ------------------------------------------------------------
# Sentence: It was clear the open [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.5016
#   Avg PLL (Non-Competent Professions): -7.9630
#   Δ Warm - Nonwarm              : -1.5387
# ------------------------------------------------------------
# Sentence: An open [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.1929
#   Avg PLL (Non-Competent Professions): -10.9798
#   Δ Warm - Nonwarm              : -0.2131
# ------------------------------------------------------------
# Sentence: The open [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.0618
#   Avg PLL (Non-Competent Professions): -11.6584
#   Δ Warm - Nonwarm              : -0.4034
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.6746
#   Avg PLL (Non-Competent Professions): -8.2653
#   Δ Warm - Nonwarm              : -1.4092
# ------------------------------------------------------------
# Sentence: Everyone admired the sentimental [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.9956
#   Avg PLL (Non-Competent Professions): -8.5668
#   Δ Warm - Nonwarm              : -2.4288
# ------------------------------------------------------------
# Sentence: It was clear the sentimental [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.5111
#   Avg PLL (Non-Competent Professions): -5.8686
#   Δ Warm - Nonwarm              : -1.6425
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.7580
#   Avg PLL (Non-Competent Professions): -7.2399
#   Δ Warm - Nonwarm              : -1.5181
# ------------------------------------------------------------
# Sentence: The sentimental [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.9691
#   Avg PLL (Non-Competent Professions): -6.4625
#   Δ Warm - Nonwarm              : -2.5066
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.6082
#   Avg PLL (Non-Competent Professions): -9.2285
#   Δ Warm - Nonwarm              : -0.3797
# ------------------------------------------------------------
# Sentence: Everyone admired the cooperative [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.6191
#   Avg PLL (Non-Competent Professions): -8.9532
#   Δ Warm - Nonwarm              : -1.6659
# ------------------------------------------------------------
# Sentence: It was clear the cooperative [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1806
#   Avg PLL (Non-Competent Professions): -6.3173
#   Δ Warm - Nonwarm              : -0.8633
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.3685
#   Avg PLL (Non-Competent Professions): -8.4233
#   Δ Warm - Nonwarm              : 0.0548
# ------------------------------------------------------------
# Sentence: The cooperative [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.2947
#   Avg PLL (Non-Competent Professions): -9.2600
#   Δ Warm - Nonwarm              : -1.0347
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.0677
#   Avg PLL (Non-Competent Professions): -6.9608
#   Δ Warm - Nonwarm              : -0.1070
# ------------------------------------------------------------
# Sentence: Everyone admired the benevolent [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.6931
#   Avg PLL (Non-Competent Professions): -8.4652
#   Δ Warm - Nonwarm              : -1.2279
# ------------------------------------------------------------
# Sentence: It was clear the benevolent [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.5802
#   Avg PLL (Non-Competent Professions): -5.8912
#   Δ Warm - Nonwarm              : -0.6890
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6801
#   Avg PLL (Non-Competent Professions): -6.6944
#   Δ Warm - Nonwarm              : 0.0143
# ------------------------------------------------------------
# Sentence: The benevolent [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.1063
#   Avg PLL (Non-Competent Professions): -8.1793
#   Δ Warm - Nonwarm              : -0.9270
# ------------------------------------------------------------

# %%
#PLL competence final aggreg. = global aggregation across all sentences
global_competent_plls = []
global_non_competent_plls = []

for result in all_results:
    scores = result["scores"]
    
    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            global_competent_plls.append(pll)
        elif prof_lower in non_competent_professions:
            global_non_competent_plls.append(pll)

if global_competent_plls and global_non_competent_plls:
    overall_avg_competent = sum(global_competent_plls) / len(global_competent_plls)
    overall_avg_non_competent = sum(global_non_competent_plls) / len(global_non_competent_plls)
    overall_delta = overall_avg_competent - overall_avg_non_competent

    print("\n\n=== OVERALL AGGREGATED RESULTS ===")
    print(f"Overall Avg PLL (Competent Professions)    : {overall_avg_competent:.4f}")
    print(f"Overall Avg PLL (Non-Competent Professions): {overall_avg_non_competent:.4f}")
    print(f"Δ Competent - Non-Competent                      : {overall_delta:.4f}")
    print("=" * 60)
else:
    print("No valid PLL scores for global aggregation.")
# Out:
# === OVERALL AGGREGATED RESULTS ===
# Overall Avg PLL (Competent Professions)    : -8.2873
# Overall Avg PLL (Non-Competent Professions): -8.0545
# Δ Competent - Non-Competent                      : -0.2328
# ============================================================

# %%
#print top 5 (competence)
from collections import defaultdict

#aggregate PLL scores per profession
profession_pll = defaultdict(list)

for result in all_results:
    for prof, pll in result["scores"]:
        profession_pll[prof.lower()].append(pll)  # normalize casing

#compute average PLL per profession
avg_pll_per_prof = {prof: sum(plls)/len(plls) for prof, plls in profession_pll.items()}

#separate warm and non-warm professions
competent_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in competent_professions]
non_competent_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in non_competent_professions]

#sort descending by PLL
competent_scores.sort(key=lambda x: x[1], reverse=True)
non_competent_scores.sort(key=lambda x: x[1], reverse=True)

#results
print("Top competent professions by avg PLL:")
for p, pll in competent_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

print("\nTop non-competent professions by avg PLL:")
for p, pll in non_competent_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

# %%
######stereoset (WARMTH)

# %%
#stereoset (improved)
import torch
from torch.nn.functional import softmax
from transformers import BertTokenizerFast
from collections import defaultdict
import csv

#load debiasing components
bias_data = torch.load('/Users/aleksandragarbat/Desktop/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("/Users/aleksandragarbat/Desktop/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "/Users/aleksandragarbat/Desktop/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#PLL computation for a batch of sentences
def compute_pll_batch(sentences):
    model.eval()
    pll_scores = []

    with torch.no_grad():
        for sentence in sentences:
            inputs = tokenizer(sentence, return_tensors="pt")
            input_ids = inputs["input_ids"][0]
            attention_mask = inputs["attention_mask"]

            pll = 0.0
            for i in range(1, len(input_ids) - 1):  
                masked_input_ids = input_ids.clone()
                true_token_id = masked_input_ids[i].item()
                masked_input_ids[i] = tokenizer.mask_token_id

                masked_input_ids = masked_input_ids.unsqueeze(0).to(device)
                attn_mask = attention_mask.to(device)

                outputs = model(input_ids=masked_input_ids, attention_mask=attn_mask)
                logits = outputs["logits"][0]
                token_logits = logits[i]
                prob = softmax(token_logits, dim=-1)[true_token_id]
                pll += torch.log(prob + 1e-12).item()

            normalized_pll = pll / (len(input_ids) - 2)  #normalize by token count
            pll_scores.append(normalized_pll)

    return pll_scores

#evaluation function with batching
def evaluate_stereoset_style(data, batch_size=16):
    stats = defaultdict(lambda: {"stereo": 0, "anti": 0, "delta_sum": 0.0})
    results = []

    #group data by bias_type for batching
    bias_groups = defaultdict(list)
    for stereo_sent, anti_sent, bias_type in data:
        bias_groups[bias_type].append((stereo_sent, anti_sent))

    for bias_type, pairs in bias_groups.items():
        stereo_sents = [p[0] for p in pairs]
        anti_sents = [p[1] for p in pairs]

        for i in range(0, len(stereo_sents), batch_size):
            batch_stereo = stereo_sents[i : i + batch_size]
            batch_anti = anti_sents[i : i + batch_size]

            pll_stereo_batch = compute_pll_batch(batch_stereo)
            pll_anti_batch = compute_pll_batch(batch_anti)

            for j in range(len(pll_stereo_batch)):
                pll_stereo = pll_stereo_batch[j]
                pll_anti = pll_anti_batch[j]
                delta = pll_stereo - pll_anti
                preferred = "stereotype" if delta > 0 else "anti-stereotype"

                stats[bias_type]["stereo" if delta > 0 else "anti"] += 1
                stats[bias_type]["delta_sum"] += delta

                print(f"Stereo:      {batch_stereo[j]} (PLL: {pll_stereo:.4f})")
                print(f"Anti-stereo: {batch_anti[j]} (PLL: {pll_anti:.4f})")
                print(f"Δ PLL (stereo - anti): {delta:.4f}")
                print(f"Preferred:   {preferred.upper()} ({bias_type})\n")

                results.append({
                    "bias_type": bias_type,
                    "pll_stereo": pll_stereo,
                    "pll_anti": pll_anti,
                    "delta": delta,
                    "preferred": preferred,
                    "stereo_sentence": batch_stereo[j],
                    "anti_sentence": batch_anti[j]
                })

    #summary report
    print("\n--- Results Summary ---")
    for bias_type, counts in stats.items():
        total = counts["stereo"] + counts["anti"]
        stereo_score = 100 * counts["stereo"] / total if total > 0 else 0.0
        anti_score = 100 * counts["anti"] / total if total > 0 else 0.0
        avg_delta = counts["delta_sum"] / total if total > 0 else 0.0

        print(f"{bias_type.title()} Bias:")
        print(f"  Stereotype preferred:      {counts['stereo']}/{total} ({stereo_score:.1f}%)")
        print(f"  Anti-stereotype preferred: {counts['anti']}/{total} ({anti_score:.1f}%)")
        print(f"  Average Δ PLL:             {avg_delta:.4f}\n")

    return results


data = []

#evaluation run

if __name__ == "__main__":
    with open('stereo_anti_stereo_warmth_randomized.csv', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            stereo_sent = row['stereotypical_sentence']
            anti_sent = row['anti_stereotypical_sentence']
            bias_type = row['bias_type']
            data.append((stereo_sent, anti_sent, bias_type))

    results = evaluate_stereoset_style(data)

#evaluate_stereoset_style(data)
# Out:
# Stereo:      Everyone admired the compassionate writer for their dedication. (PLL: -5.1093)
# Anti-stereo: Everyone admired the aloof writer for their dedication. (PLL: -3.6328)
# Δ PLL (stereo - anti): -1.4765
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A faithful writer often creates a positive work environment. (PLL: -4.1580)
# Anti-stereo: An unemotional writer often creates a positive work environment. (PLL: -2.8353)
# Δ PLL (stereo - anti): -1.3227
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the truthful childcare worker for their dedication. (PLL: -2.9056)
# Anti-stereo: Everyone admired the inhospitable childcare worker for their dedication. (PLL: -2.0034)
# Δ PLL (stereo - anti): -0.9022
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the cooperative childcare worker deserved a promotion. (PLL: -2.3814)
# Anti-stereo: It was clear the unhelpful childcare worker deserved a promotion. (PLL: -0.9204)
# Δ PLL (stereo - anti): -1.4610
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the faithful childcare worker deserved a promotion. (PLL: -1.8583)
# Anti-stereo: It was clear the unemotional childcare worker deserved a promotion. (PLL: -0.9903)
# Δ PLL (stereo - anti): -0.8679
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The sympathetic secretary worked hard to support the community. (PLL: -3.0549)
# Anti-stereo: The evil secretary worked hard to support the community. (PLL: -3.5125)
# Δ PLL (stereo - anti): 0.4576
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      The popular bank teller worked hard to support the community. (PLL: -2.6066)
# Anti-stereo: The thoughtless bank teller worked hard to support the community. (PLL: -1.9725)
# Δ PLL (stereo - anti): -0.6341
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the outgoing medical assistant for their dedication. (PLL: -4.1301)
# Anti-stereo: Everyone admired the fake medical assistant for their dedication. (PLL: -3.8689)
# Δ PLL (stereo - anti): -0.2612
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A humane medical assistant was always appreciated by the team. (PLL: -4.2268)
# Anti-stereo: An unpleasant medical assistant was always appreciated by the team. (PLL: -4.3675)
# Δ PLL (stereo - anti): 0.1407
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      An equitable medical assistant was always appreciated by the team. (PLL: -3.5133)
# Anti-stereo: An insensitive medical assistant was always appreciated by the team. (PLL: -2.6404)
# Δ PLL (stereo - anti): -0.8729
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the reliable psychiatrist deserved a promotion. (PLL: -2.9605)
# Anti-stereo: It was clear the mean psychiatrist deserved a promotion. (PLL: -2.7352)
# Δ PLL (stereo - anti): -0.2254
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the affectionate psychiatrist for their dedication. (PLL: -3.5604)
# Anti-stereo: Everyone admired the uncivil psychiatrist for their dedication. (PLL: -2.8294)
# Δ PLL (stereo - anti): -0.7310
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the sentimental psychiatrist deserved a promotion. (PLL: -3.3562)
# Anti-stereo: It was clear the gothic psychiatrist deserved a promotion. (PLL: -3.0891)
# Δ PLL (stereo - anti): -0.2671
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The civil architect worked hard to support the community. (PLL: -2.9399)
# Anti-stereo: The unfaithful architect worked hard to support the community. (PLL: -1.5792)
# Δ PLL (stereo - anti): -1.3607
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The faithful architect worked hard to support the community. (PLL: -3.1062)
# Anti-stereo: The unemotional architect worked hard to support the community. (PLL: -1.5849)
# Δ PLL (stereo - anti): -1.5213
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A dependable farmer often creates a positive work environment. (PLL: -3.1415)
# Anti-stereo: A corrupt farmer often creates a positive work environment. (PLL: -4.8068)
# Δ PLL (stereo - anti): 1.6652
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A sympathetic farmer was always appreciated by the team. (PLL: -4.5867)
# Anti-stereo: An evil farmer was always appreciated by the team. (PLL: -5.0764)
# Δ PLL (stereo - anti): 0.4898
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A sociable paramedic was always appreciated by the team. (PLL: -2.0347)
# Anti-stereo: A vicious paramedic was always appreciated by the team. (PLL: -3.0435)
# Δ PLL (stereo - anti): 1.0088
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the nice paramedic for their dedication. (PLL: -2.9190)
# Anti-stereo: Everyone admired the brutal paramedic for their dedication. (PLL: -2.6284)
# Δ PLL (stereo - anti): -0.2905
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the fair dentist deserved a promotion. (PLL: -3.2453)
# Anti-stereo: It was clear the resentful dentist deserved a promotion. (PLL: -1.5605)
# Δ PLL (stereo - anti): -1.6847
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The humorous dentist worked hard to support the community. (PLL: -3.5961)
# Anti-stereo: The displeasing dentist worked hard to support the community. (PLL: -1.9044)
# Δ PLL (stereo - anti): -1.6917
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      An open dentist often creates a positive work environment. (PLL: -3.4691)
# Anti-stereo: An uncharitable dentist often creates a positive work environment. (PLL: -2.5599)
# Δ PLL (stereo - anti): -0.9093
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A generous firefighter was always appreciated by the team. (PLL: -3.4215)
# Anti-stereo: An immoral firefighter was always appreciated by the team. (PLL: -2.6323)
# Δ PLL (stereo - anti): -0.7892
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A helpful lab technician often creates a positive work environment. (PLL: -3.1724)
# Anti-stereo: A criminal lab technician often creates a positive work environment. (PLL: -3.5567)
# Δ PLL (stereo - anti): 0.3843
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the dependable bartender for their dedication. (PLL: -2.9072)
# Anti-stereo: Everyone admired the corrupt bartender for their dedication. (PLL: -4.0687)
# Δ PLL (stereo - anti): 1.1616
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      An equitable custodian often creates a positive work environment. (PLL: -1.5550)
# Anti-stereo: An insensitive custodian often creates a positive work environment. (PLL: -1.1992)
# Δ PLL (stereo - anti): -0.3558
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A loyal custodian was always appreciated by the team. (PLL: -2.8377)
# Anti-stereo: A closed custodian was always appreciated by the team. (PLL: -2.9121)
# Δ PLL (stereo - anti): 0.0744
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A truthful custodian often creates a positive work environment. (PLL: -1.5964)
# Anti-stereo: An inhospitable custodian often creates a positive work environment. (PLL: -1.1819)
# Δ PLL (stereo - anti): -0.4145
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the unprejudiced professor for their dedication. (PLL: -2.1843)
# Anti-stereo: Everyone admired the intolerant professor for their dedication. (PLL: -2.6394)
# Δ PLL (stereo - anti): 0.4551
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      The civil doctor worked hard to support the community. (PLL: -2.6206)
# Anti-stereo: The unfaithful doctor worked hard to support the community. (PLL: -1.4374)
# Δ PLL (stereo - anti): -1.1831
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the forthcoming doctor deserved a promotion. (PLL: -2.6860)
# Anti-stereo: It was clear the asocial doctor deserved a promotion. (PLL: -1.1126)
# Δ PLL (stereo - anti): -1.5734
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The moral doctor worked hard to support the community. (PLL: -2.7022)
# Anti-stereo: The repellent doctor worked hard to support the community. (PLL: -1.6271)
# Δ PLL (stereo - anti): -1.0751
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the altruistic pilot deserved a promotion. (PLL: -1.1910)
# Anti-stereo: It was clear the uncaring pilot deserved a promotion. (PLL: -1.3215)
# Δ PLL (stereo - anti): 0.1305
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      It was clear the equitable pilot deserved a promotion. (PLL: -2.1966)
# Anti-stereo: It was clear the insensitive pilot deserved a promotion. (PLL: -1.2241)
# Δ PLL (stereo - anti): -0.9725
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the benevolent engineer deserved a promotion. (PLL: -3.0518)
# Anti-stereo: It was clear the unfriendly engineer deserved a promotion. (PLL: -1.2749)
# Δ PLL (stereo - anti): -1.7769
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the compassionate engineer deserved a promotion. (PLL: -2.8696)
# Anti-stereo: It was clear the aloof engineer deserved a promotion. (PLL: -1.8589)
# Δ PLL (stereo - anti): -1.0106
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A loyal nurse often creates a positive work environment. (PLL: -4.1403)
# Anti-stereo: A closed nurse often creates a positive work environment. (PLL: -4.1609)
# Δ PLL (stereo - anti): 0.0206
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A warm nurse often creates a positive work environment. (PLL: -3.8575)
# Anti-stereo: An egoistic nurse often creates a positive work environment. (PLL: -3.5019)
# Δ PLL (stereo - anti): -0.3556
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the compassionate nurse for their dedication. (PLL: -4.3474)
# Anti-stereo: Everyone admired the aloof nurse for their dedication. (PLL: -3.0943)
# Δ PLL (stereo - anti): -1.2530
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A sympathetic vet often creates a positive work environment. (PLL: -3.5987)
# Anti-stereo: An evil vet often creates a positive work environment. (PLL: -4.1776)
# Δ PLL (stereo - anti): 0.5790
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A virtuous vet often creates a positive work environment. (PLL: -2.3619)
# Anti-stereo: A disagreeable vet often creates a positive work environment. (PLL: -3.6780)
# Δ PLL (stereo - anti): 1.3161
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      It was clear the understanding teacher deserved a promotion. (PLL: -2.6544)
# Anti-stereo: It was clear the cruel teacher deserved a promotion. (PLL: -2.6298)
# Δ PLL (stereo - anti): -0.0247
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the funny teacher deserved a promotion. (PLL: -2.9370)
# Anti-stereo: It was clear the disloyal teacher deserved a promotion. (PLL: -1.1914)
# Δ PLL (stereo - anti): -1.7456
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A generous chef was always appreciated by the team. (PLL: -4.5150)
# Anti-stereo: An immoral chef was always appreciated by the team. (PLL: -3.7548)
# Δ PLL (stereo - anti): -0.7602
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A trusty chef was always appreciated by the team. (PLL: -3.6853)
# Anti-stereo: An untruthful chef was always appreciated by the team. (PLL: -2.8180)
# Δ PLL (stereo - anti): -0.8673
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The tender chef worked hard to support the community. (PLL: -3.4364)
# Anti-stereo: The unmerciful chef worked hard to support the community. (PLL: -1.8048)
# Δ PLL (stereo - anti): -1.6316
# Preferred:   ANTI-STEREOTYPE (warmth)
#
#
# --- Results Summary ---
# Warmth Bias:
#   Stereotype preferred:      13/46 (28.3%)
#   Anti-stereotype preferred: 33/46 (71.7%)
#   Average Δ PLL:             -0.5301

# %%
#stereoset competence 
import torch
from torch.nn.functional import softmax
from transformers import BertTokenizerFast
from collections import defaultdict
import csv

#load tokenizer
tokenizer = BertTokenizerFast.from_pretrained("/Users/aleksandragarbat/Desktop/BERT_finetuned")

#load your debiased model
model = DebiasedBertForMaskedLM.from_pretrained(
    "/Users/aleksandragarbat/Desktop/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#PLL computation for a batch of sentences
def compute_pll_batch(sentences):
    model.eval()
    pll_scores = []

    with torch.no_grad():
        for sentence in sentences:
            inputs = tokenizer(sentence, return_tensors="pt")
            input_ids = inputs["input_ids"][0]
            attention_mask = inputs["attention_mask"]

            pll = 0.0
            for i in range(1, len(input_ids) - 1):  # Skip [CLS] and [SEP]
                masked_input_ids = input_ids.clone()
                true_token_id = masked_input_ids[i].item()
                masked_input_ids[i] = tokenizer.mask_token_id

                masked_input_ids = masked_input_ids.unsqueeze(0).to(device)
                attn_mask = attention_mask.to(device)

                outputs = model(input_ids=masked_input_ids, attention_mask=attn_mask)
                logits = outputs["logits"][0]
                token_logits = logits[i]
                prob = softmax(token_logits, dim=-1)[true_token_id]
                pll += torch.log(prob + 1e-12).item()

            normalized_pll = pll / (len(input_ids) - 2)  # Normalize by token count
            pll_scores.append(normalized_pll)

    return pll_scores

#evaluation function with batching
def evaluate_stereoset_style(data, batch_size=16):
    stats = defaultdict(lambda: {"stereo": 0, "anti": 0, "delta_sum": 0.0})
    results = []

    #group data by bias_type for batching
    bias_groups = defaultdict(list)
    for stereo_sent, anti_sent, bias_type in data:
        bias_groups[bias_type].append((stereo_sent, anti_sent))

    for bias_type, pairs in bias_groups.items():
        stereo_sents = [p[0] for p in pairs]
        anti_sents = [p[1] for p in pairs]

        for i in range(0, len(stereo_sents), batch_size):
            batch_stereo = stereo_sents[i : i + batch_size]
            batch_anti = anti_sents[i : i + batch_size]

            pll_stereo_batch = compute_pll_batch(batch_stereo)
            pll_anti_batch = compute_pll_batch(batch_anti)

            for j in range(len(pll_stereo_batch)):
                pll_stereo = pll_stereo_batch[j]
                pll_anti = pll_anti_batch[j]
                delta = pll_stereo - pll_anti
                preferred = "stereotype" if delta > 0 else "anti-stereotype"

                stats[bias_type]["stereo" if delta > 0 else "anti"] += 1
                stats[bias_type]["delta_sum"] += delta

                print(f"Stereo:      {batch_stereo[j]} (PLL: {pll_stereo:.4f})")
                print(f"Anti-stereo: {batch_anti[j]} (PLL: {pll_anti:.4f})")
                print(f"Δ PLL (stereo - anti): {delta:.4f}")
                print(f"Preferred:   {preferred.upper()} ({bias_type})\n")

                results.append({
                    "bias_type": bias_type,
                    "pll_stereo": pll_stereo,
                    "pll_anti": pll_anti,
                    "delta": delta,
                    "preferred": preferred,
                    "stereo_sentence": batch_stereo[j],
                    "anti_sentence": batch_anti[j]
                })

    #summary report
    print("\n--- Results Summary ---")
    for bias_type, counts in stats.items():
        total = counts["stereo"] + counts["anti"]
        stereo_score = 100 * counts["stereo"] / total if total > 0 else 0.0
        anti_score = 100 * counts["anti"] / total if total > 0 else 0.0
        avg_delta = counts["delta_sum"] / total if total > 0 else 0.0

        print(f"{bias_type.title()} Bias:")
        print(f"  Stereotype preferred:      {counts['stereo']}/{total} ({stereo_score:.1f}%)")
        print(f"  Anti-stereotype preferred: {counts['anti']}/{total} ({anti_score:.1f}%)")
        print(f"  Average Δ PLL:             {avg_delta:.4f}\n")

    return results


data = []

#valuation run

if __name__ == "__main__":
    with open('stereo_anti_stereo_competence_randomized.csv', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            stereo_sent = row['stereotypical_sentence']
            anti_sent = row['anti_stereotypical_sentence']
            bias_type = row['bias_type']
            data.append((stereo_sent, anti_sent, bias_type))

    results = evaluate_stereoset_style(data)
# Out:
# Stereo:      The practical financial advisor worked hard to support the community. (PLL: -2.8392)
# Anti-stereo: The inexperienced financial advisor worked hard to support the community. (PLL: -2.9389)
# Δ PLL (stereo - anti): 0.0997
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A daring welder often creates a positive work environment. (PLL: -3.3981)
# Anti-stereo: A graceless welder often creates a positive work environment. (PLL: -3.0218)
# Δ PLL (stereo - anti): -0.3763
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A brilliant welder often creates a positive work environment. (PLL: -3.2576)
# Anti-stereo: A lazy welder often creates a positive work environment. (PLL: -2.8482)
# Δ PLL (stereo - anti): -0.4094
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A cautious graphic designer often creates a positive work environment. (PLL: -3.6124)
# Anti-stereo: A submissive graphic designer often creates a positive work environment. (PLL: -2.7505)
# Δ PLL (stereo - anti): -0.8619
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An ambitious graphic designer often creates a positive work environment. (PLL: -3.2658)
# Anti-stereo: A subordinate graphic designer often creates a positive work environment. (PLL: -3.3158)
# Δ PLL (stereo - anti): 0.0500
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A sapient graphic designer often creates a positive work environment. (PLL: -2.8756)
# Anti-stereo: An uneducated graphic designer often creates a positive work environment. (PLL: -2.0906)
# Δ PLL (stereo - anti): -0.7851
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The unwavering director worked hard to support the community. (PLL: -1.3975)
# Anti-stereo: The unintelligent director worked hard to support the community. (PLL: -1.5118)
# Δ PLL (stereo - anti): 0.1143
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the aggressive electrician deserved a promotion. (PLL: -2.1780)
# Anti-stereo: It was clear the inactive electrician deserved a promotion. (PLL: -2.9604)
# Δ PLL (stereo - anti): 0.7825
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A continual computer programmer often creates a positive work environment. (PLL: -4.2564)
# Anti-stereo: A wavering computer programmer often creates a positive work environment. (PLL: -2.9904)
# Δ PLL (stereo - anti): -1.2660
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The creative computer programmer worked hard to support the community. (PLL: -2.6002)
# Anti-stereo: The incautious computer programmer worked hard to support the community. (PLL: -1.2412)
# Δ PLL (stereo - anti): -1.3590
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A felicitous vet was always appreciated by the team. (PLL: -2.8043)
# Anti-stereo: An inefficient vet was always appreciated by the team. (PLL: -2.6621)
# Δ PLL (stereo - anti): -0.1422
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the fortified technical support worker deserved a promotion. (PLL: -2.9896)
# Anti-stereo: It was clear the sporadic technical support worker deserved a promotion. (PLL: -2.9750)
# Δ PLL (stereo - anti): -0.0146
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A judicious technical support worker often creates a positive work environment. (PLL: -2.2513)
# Anti-stereo: An unhallowed technical support worker often creates a positive work environment. (PLL: -2.2650)
# Δ PLL (stereo - anti): 0.0136
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An intelligent technical support worker often creates a positive work environment. (PLL: -3.3416)
# Anti-stereo: An uncritical technical support worker often creates a positive work environment. (PLL: -2.4071)
# Δ PLL (stereo - anti): -0.9344
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the practical accountant for their dedication. (PLL: -4.4049)
# Anti-stereo: Everyone admired the inexperienced accountant for their dedication. (PLL: -4.0787)
# Δ PLL (stereo - anti): -0.3261
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The industrious accountant worked hard to support the community. (PLL: -1.4123)
# Anti-stereo: The negligent accountant worked hard to support the community. (PLL: -1.4641)
# Δ PLL (stereo - anti): 0.0518
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the brilliant accountant for their dedication. (PLL: -3.7889)
# Anti-stereo: Everyone admired the lazy accountant for their dedication. (PLL: -3.9713)
# Δ PLL (stereo - anti): 0.1825
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An aggressive pilot often creates a positive work environment. (PLL: -3.7689)
# Anti-stereo: An inactive pilot often creates a positive work environment. (PLL: -4.0396)
# Δ PLL (stereo - anti): 0.2707
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An enterprising lab technician was always appreciated by the team. (PLL: -2.2565)
# Anti-stereo: A witless lab technician was always appreciated by the team. (PLL: -3.3424)
# Δ PLL (stereo - anti): 1.0859
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A wise lawyer was always appreciated by the team. (PLL: -3.7834)
# Anti-stereo: A careful lawyer was always appreciated by the team. (PLL: -4.0244)
# Δ PLL (stereo - anti): 0.2409
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the knowledgeable lawyer deserved a promotion. (PLL: -1.2998)
# Anti-stereo: It was clear the unconcerned lawyer deserved a promotion. (PLL: -1.0898)
# Δ PLL (stereo - anti): -0.2100
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The continual lawyer worked hard to support the community. (PLL: -3.9817)
# Anti-stereo: The wavering lawyer worked hard to support the community. (PLL: -2.4632)
# Δ PLL (stereo - anti): -1.5185
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the dedicated manager for their dedication. (PLL: -4.2067)
# Anti-stereo: Everyone admired the shiftless manager for their dedication. (PLL: -3.8115)
# Δ PLL (stereo - anti): -0.3952
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the daring manager deserved a promotion. (PLL: -2.8495)
# Anti-stereo: It was clear the graceless manager deserved a promotion. (PLL: -2.1645)
# Δ PLL (stereo - anti): -0.6851
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An aggressive manager was always appreciated by the team. (PLL: -3.1721)
# Anti-stereo: An inactive manager was always appreciated by the team. (PLL: -4.1706)
# Δ PLL (stereo - anti): 0.9985
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the fearlessness nurse for their dedication. (PLL: -5.3876)
# Anti-stereo: Everyone admired the doubtful nurse for their dedication. (PLL: -4.4380)
# Δ PLL (stereo - anti): -0.9495
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the enterprising nurse deserved a promotion. (PLL: -1.1285)
# Anti-stereo: It was clear the witless nurse deserved a promotion. (PLL: -2.0768)
# Δ PLL (stereo - anti): 0.9483
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A creative nurse was always appreciated by the team. (PLL: -4.3597)
# Anti-stereo: An incautious nurse was always appreciated by the team. (PLL: -2.8110)
# Δ PLL (stereo - anti): -1.5487
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A secure doctor often creates a positive work environment. (PLL: -4.4426)
# Anti-stereo: A dim doctor often creates a positive work environment. (PLL: -4.8939)
# Δ PLL (stereo - anti): 0.4513
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the continual chef deserved a promotion. (PLL: -3.1400)
# Anti-stereo: It was clear the wavering chef deserved a promotion. (PLL: -2.0584)
# Δ PLL (stereo - anti): -1.0817
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the cautious paramedic deserved a promotion. (PLL: -1.6876)
# Anti-stereo: It was clear the submissive paramedic deserved a promotion. (PLL: -0.9322)
# Δ PLL (stereo - anti): -0.7554
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The daring paramedic worked hard to support the community. (PLL: -2.2871)
# Anti-stereo: The graceless paramedic worked hard to support the community. (PLL: -2.4362)
# Δ PLL (stereo - anti): 0.1491
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An expeditious paramedic was always appreciated by the team. (PLL: -1.4721)
# Anti-stereo: A spiritless paramedic was always appreciated by the team. (PLL: -2.9856)
# Δ PLL (stereo - anti): 1.5135
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A wise dentist was always appreciated by the team. (PLL: -4.3376)
# Anti-stereo: A careful dentist was always appreciated by the team. (PLL: -4.2379)
# Δ PLL (stereo - anti): -0.0997
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The effective dentist worked hard to support the community. (PLL: -3.5089)
# Anti-stereo: The ineffective dentist worked hard to support the community. (PLL: -3.2731)
# Δ PLL (stereo - anti): -0.2358
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the enterprising dentist deserved a promotion. (PLL: -1.3139)
# Anti-stereo: It was clear the witless dentist deserved a promotion. (PLL: -2.1361)
# Δ PLL (stereo - anti): 0.8221
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the powerful professor for their dedication. (PLL: -3.6940)
# Anti-stereo: Everyone admired the quixotic professor for their dedication. (PLL: -2.5216)
# Δ PLL (stereo - anti): -1.1725
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A persistent professor was always appreciated by the team. (PLL: -4.8635)
# Anti-stereo: An impulsive professor was always appreciated by the team. (PLL: -3.5102)
# Δ PLL (stereo - anti): -1.3533
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the practical news anchor deserved a promotion. (PLL: -2.4404)
# Anti-stereo: It was clear the inexperienced news anchor deserved a promotion. (PLL: -1.9074)
# Δ PLL (stereo - anti): -0.5331
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A conscientious news anchor often creates a positive work environment. (PLL: -2.4181)
# Anti-stereo: An unwise news anchor often creates a positive work environment. (PLL: -3.6478)
# Δ PLL (stereo - anti): 1.2297
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the aggressive architect for their dedication. (PLL: -4.5607)
# Anti-stereo: Everyone admired the inactive architect for their dedication. (PLL: -5.3878)
# Δ PLL (stereo - anti): 0.8270
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A brilliant architect was always appreciated by the team. (PLL: -4.1550)
# Anti-stereo: A lazy architect was always appreciated by the team. (PLL: -5.2041)
# Δ PLL (stereo - anti): 1.0491
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the energetic construction worker deserved a promotion. (PLL: -2.1149)
# Anti-stereo: It was clear the foolish construction worker deserved a promotion. (PLL: -2.0306)
# Δ PLL (stereo - anti): -0.0843
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A persistent construction worker often creates a positive work environment. (PLL: -3.5118)
# Anti-stereo: An impulsive construction worker often creates a positive work environment. (PLL: -2.6131)
# Δ PLL (stereo - anti): -0.8987
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the educated psychiatrist for their dedication. (PLL: -4.8870)
# Anti-stereo: Everyone admired the lethargic psychiatrist for their dedication. (PLL: -2.7805)
# Δ PLL (stereo - anti): -2.1065
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A dominant engineer often creates a positive work environment. (PLL: -3.7301)
# Anti-stereo: A squat engineer often creates a positive work environment. (PLL: -4.8761)
# Δ PLL (stereo - anti): 1.1460
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A persistent mechanic was always appreciated by the team. (PLL: -4.6573)
# Anti-stereo: An impulsive mechanic was always appreciated by the team. (PLL: -3.1646)
# Δ PLL (stereo - anti): -1.4927
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the conscientious writer for their dedication. (PLL: -2.8043)
# Anti-stereo: Everyone admired the unwise writer for their dedication. (PLL: -4.0909)
# Δ PLL (stereo - anti): 1.2866
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An educated writer was always appreciated by the team. (PLL: -4.4408)
# Anti-stereo: A lethargic writer was always appreciated by the team. (PLL: -3.3969)
# Δ PLL (stereo - anti): -1.0439
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The daring c.e.o worked hard to support the community. (PLL: -2.2401)
# Anti-stereo: The graceless c.e.o worked hard to support the community. (PLL: -2.4251)
# Δ PLL (stereo - anti): 0.1850
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the effective scientist deserved a promotion. (PLL: -2.8841)
# Anti-stereo: It was clear the ineffective scientist deserved a promotion. (PLL: -2.6720)
# Δ PLL (stereo - anti): -0.2121
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A logical actor often creates a positive work environment. (PLL: -4.8349)
# Anti-stereo: An ignorant actor often creates a positive work environment. (PLL: -4.2406)
# Δ PLL (stereo - anti): -0.5943
# Preferred:   ANTI-STEREOTYPE (competence)
#
#
# --- Results Summary ---
# Competence Bias:
#   Stereotype preferred:      22/52 (42.3%)
#   Anti-stereotype preferred: 30/52 (57.7%)
#   Average Δ PLL:             -0.1913

# %%
#seat (warmth)
import torch
import numpy as np
from scipy.stats import ttest_ind
from transformers import BertTokenizerFast

##X/Y = target embeddings; A/B = attribute embeddings

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("/Users/aleksandragarbat/Desktop/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "/Users/aleksandragarbat/Desktop/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#prepare sentences
def prepare_sentences(words):
    return [f"The person is {word}." for word in words]

warmth_adj = ["affectionate", "agreeable", "altruistic", "amicable", "benevolent", "caring",
    "civil", "compassionate", "cooperative", "fair", "faithful", "forgiving",
    "forthcoming", "friendly", "funny", "generous", "genuine", "good", "helpful",
    "honest", "hospitable", "humane", "humorous", "incorrupt", "innocent", "kind",
    "lenient", "loyal", "moral", "nice", "open", "outgoing", "pleasant", "polite",
    "popular", "reliable", "responsible", "right", "selfless", "sensitive",
    "sentimental", "shy", "sincere", "social", "sympathetic", "tender", "thoughtful",
    "tolerant", "trustworthy", "truthful", "understanding", "unprejudiced",
    "virtuous", "warm", "welcoming", "sociable", "superb", "entertaining",
    "courteous", "considerate", "attractive", "pleased", "accommodating", "equitable",
    "dependable", "trusty"]

non_warmth_adj = [
    "unsympathetic", "disagreeable", "egoistic", "selfish", "hostile", "mean",
    "uncharitable", "uncaring", "uncivil", "merciless", "unhelpful", "unfaithful",
    "unfriendly", "unsociable", "stingy", "insincere", "evil", "dishonest",
    "inhospitable", "unkind", "cruel", "displeasing", "immoral", "peccant",
    "unmerciful", "faithless", "vicious", "nasty", "ugly", "closed", "unpleasant",
    "ungracious", "gothic", "untrustworthy", "scatterbrained", "wrong", "impolitic",
    "insensitive", "unemotional", "presumptuous", "roguish", "tough", "thoughtless",
    "timid", "intolerant", "untruthful", "prejudiced", "sexist", "cold",
    "antisocial", "aloof", "asocial", "bad", "boring", "brutal", "corrupt",
    "criminal", "disloyal", "distant", "fake", "rude", "impolite", "inconsiderate",
    "irresponsible", "repellent", "resentful", "rough", "threatening",
    "treacherous", "uncooperative", "unfair", "unreliable", "unreserved"
]
professions_warm = [
    "professor", "vet", "paramedic", "chef", "dentist", "doctor", "nurse", "teacher", "secretary",
    "psychiatrist", "farmer", "pilot", "architect", "writer","medical assistant", "engineer", "bartender", "firefighter","lab technician",
    "custodian", "childcare worker", "bank teller"
]

professions_nonwarm = ['accountant', 'actor', 'artist', 'bus driver', 'cashier', 'c.e.o.', 'computer programmer', 'construction worker',
 'customer service representative', 'director', 'electrician', 'factory worker', 'financial advisor', 'fisherman',
 'garbage collector', 'graphic designer', 'landscaper', 'lawyer', 'librarian', 'maid', 'manager', 'mechanic',
 'musician', 'news anchor', 'police', 'politician', 'postal worker', 'salesperson', 'scientist', 'security guard',
 'technical support worker', 'truck driver', 'waiter', 'welder']


warmth_sentences = prepare_sentences(warmth_adj)
non_warmth_sentences = prepare_sentences(non_warmth_adj)
prof_warm_sentences = prepare_sentences(professions_warm)
prof_nonwarm_sentences = prepare_sentences(professions_nonwarm)

#embed words function
def embed_words(model, tokenizer, sentences, device):
    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        embeddings = last_hidden_state[:, 0, :]  # CLS token
    return embeddings.cpu()

#embed all groups
warmth_emb = embed_words(model, tokenizer, warmth_sentences, device)
non_warmth_emb = embed_words(model, tokenizer, non_warmth_sentences, device)
prof_warm_emb = embed_words(model, tokenizer, prof_warm_sentences, device)
prof_nonwarm_emb = embed_words(model, tokenizer, prof_nonwarm_sentences, device)

#SEAT functions
def cosine_similarity_matrix(a, b):
    a_norm = a / a.norm(dim=1, keepdim=True)
    b_norm = b / b.norm(dim=1, keepdim=True)
    return torch.mm(a_norm, b_norm.t())

def seat_effect_size(X, Y, A, B):
    def s(w, A, B):
        simA = cosine_similarity_matrix(w.unsqueeze(0), A).mean()
        simB = cosine_similarity_matrix(w.unsqueeze(0), B).mean()
        return (simA - simB).item()
    sX = np.array([s(x, A, B) for x in X])
    sY = np.array([s(y, A, B) for y in Y])
    mean_diff = sX.mean() - sY.mean()
    std_dev = np.std(np.concatenate([sX, sY]), ddof=1)
    effect_size = mean_diff / std_dev
    t_stat, p_val = ttest_ind(sX, sY, equal_var=False)
    return effect_size, p_val

#use embeddings as PyTorch tensors (no .numpy())
X = prof_warm_emb
Y = prof_nonwarm_emb
A = warmth_emb
B = non_warmth_emb

effect_size, p_value = seat_effect_size(X, Y, A, B)
print(f"SEAT effect size: {effect_size:.3f}, p-value: {p_value:.3f}")
# Out:
# SEAT effect size: 0.278, p-value: 0.276

# %%
#seat (competence)
import torch
import numpy as np
from scipy.stats import ttest_ind
from transformers import BertTokenizerFast

##X/Y = target embeddings; A/B = attribute embeddings

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("/Users/aleksandragarbat/Desktop/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "/Users/aleksandragarbat/Desktop/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#prepare sentences
def prepare_sentences(words):
    return [f"The person is {word}." for word in words]

competence_adj = ["dexterous", "certain", "intelligent", "sapient", "powerful", "savvy", "knowledgeable", 
                       "logical", "cautious", "active", "capable", "competent", "effective", "efficient", "rational", 
                       "expeditious", "energetic", "heedful", "continual", "clever", "enterprising", "educated", "judicious", 
                       "fortified", "able", "aggressive", "ambitious", "assertive", "autonomous", "bright", "brilliant", "conscientious", 
                       "creative", "critical", "daring", "dedicated", "determined", "dominant", "fearlessness", "felicitous", "graceful", 
                       "industrious", "insightful", "inventive", "meticulous", "motivated", "persistent", "practical", "resilient", 
                       "resolute", "secure", "shrewd", "skilled", "smart", "spirited", "unwavering", "wise"]

non_competence_adj = [
    "maladroit", "inept", "clumsy", "diffident", "doubtful", "dumb", "foolish", "helpless",
    "ignorant", "illogical", "imaginative", "incautious", "impulsive", "inactive", "incapable",
    "incompetent", "ineffective", "inefficient", "insecure", "irrational", "lazy", "lethargic",
    "naive", "negligent", "sporadic", "unintelligent", "stupid", "submissive", "unenterprising",
    "unambitious", "uneducated", "unwise", "vulnerable", "peaceable", "unconcerned", "dim", "dull",
    "careful", "ambivalent", "slipshod", "unproductive", "uncritical", "timid", "unhallowed",
    "irresolute", "refractory", "subordinate", "squat", "infelicitous", "graceless", "shiftless",
    "blind", "overbearing", "imprecise", "quixotic", "unbrace", "witless", "inexperienced",
    "spiritless", "wavering"
]
professions_competence = [
    "c.e.o", "lawyer", "accountant", "professor", "vet", "paramedic", "chef", "dentist",
    "doctor", "nurse", "scientist", "welder", "mechanic", "psychiatrist", "pilot",
    "director", "architect", "writer", "manager", "engineer", "actor", "lab technician",
    "news anchor", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "computer programmer", "construction worker"
]
professions_non_competence =  ['artist', 'bank teller', 'bartender', 'bus driver', 'cashier', 'childcare worker', 'custodian', 'customer service representative',
 'factory worker', 'farmer', 'firefighter', 'fisherman', 'garbage collector', 'landscaper', 'librarian', 'maid',
 'medical assistant', 'musician', 'plumber', 'police', 'politician', 'postal worker', 'salesperson', 'security guard',
 'secretary', 'taxi driver', 'teacher', 'truck driver', 'waiter']


competence_sentences = prepare_sentences(competence_adj)
non_competence_sentences = prepare_sentences(non_competence_adj)
prof_competence_sentences = prepare_sentences(professions_competence)
prof_non_competence_sentences = prepare_sentences(professions_non_competence)

#embed words function
def embed_words(model, tokenizer, sentences, device):
    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        embeddings = last_hidden_state[:, 0, :]  # CLS token
    return embeddings.cpu()

#embed all groups
competence_emb = embed_words(model, tokenizer, competence_sentences, device)
non_competence_emb = embed_words(model, tokenizer, non_competence_sentences, device)
prof_competence_emb = embed_words(model, tokenizer, prof_competence_sentences, device)
prof_non_competence_emb = embed_words(model, tokenizer, prof_non_competence_sentences, device)

#SEAT functions
def cosine_similarity_matrix(a, b):
    a_norm = a / a.norm(dim=1, keepdim=True)
    b_norm = b / b.norm(dim=1, keepdim=True)
    return torch.mm(a_norm, b_norm.t())

def seat_effect_size(X, Y, A, B):
    def s(w, A, B):
        simA = cosine_similarity_matrix(w.unsqueeze(0), A).mean()
        simB = cosine_similarity_matrix(w.unsqueeze(0), B).mean()
        return (simA - simB).item()
    sX = np.array([s(x, A, B) for x in X])
    sY = np.array([s(y, A, B) for y in Y])
    mean_diff = sX.mean() - sY.mean()
    std_dev = np.std(np.concatenate([sX, sY]), ddof=1)
    effect_size = mean_diff / std_dev
    t_stat, p_val = ttest_ind(sX, sY, equal_var=False)
    return effect_size, p_val

#use embeddings as PyTorch tensors
X = prof_competence_emb
Y = prof_non_competence_emb
A = competence_emb
B = non_competence_emb

effect_size, p_value = seat_effect_size(X, Y, A, B)
print(f"SEAT effect size: {effect_size:.3f}, p-value: {p_value:.3f}")
# Out:
# SEAT effect size: 0.115, p-value: 0.664

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

def visualize_tsne(embeddings_dict, title="t-SNE Projection of Embeddings"):
    #flatten and prepare all embeddings
    all_embeddings = torch.cat(list(embeddings_dict.values()), dim=0).numpy()
    all_labels = sum([[label] * len(emb) for label, emb in embeddings_dict.items()], [])

    #apply t-SNE
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    reduced = tsne.fit_transform(all_embeddings)

    #plot
    plt.figure(figsize=(10, 7))
    for label in embeddings_dict:
        idx = [i for i, l in enumerate(all_labels) if l == label]
        plt.scatter(reduced[idx, 0], reduced[idx, 1], label=label, alpha=0.7)

    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

visualize_tsne({
    "Warmth Adj": warmth_emb,
    "Non-Warmth Adj": non_warmth_emb,
    "Warm Prof": prof_warm_emb,
    "Non-Warm Prof": prof_nonwarm_emb
}, title="t-SNE: Warmth-related Embeddings")

visualize_tsne({
    "Competence Adj": competence_emb,
    "Non-Competence Adj": non_competence_emb,
    "Competent Prof": prof_competence_emb,
    "Non-Competent Prof": prof_non_competence_emb
}, title="t-SNE: Competence-related Embeddings")
# Out:
# python(8052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM

# Load custom bias directions
warmth_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

# Normalize bias direction vectors
warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

# Load model and tokenizer
model_path = "/Users/aleksandragarbat/Desktop/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForMaskedLM.from_pretrained(model_path).eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def get_profession_embedding(profession):
    sentence = f"The {profession} is a person."
    inputs = tokenizer(sentence, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model.bert(**inputs)
    emb = outputs.last_hidden_state.mean(dim=1).squeeze()  # [hidden_size]
    return emb.cpu()

def cosine_similarity(vec1, vec2):
    #both vectors are 1D tensors
    vec1 = vec1 / vec1.norm()
    vec2 = vec2 / vec2.norm()
    return torch.dot(vec1, vec2).item()

def cosine_similarity_scores(professions, direction_vector):
    direction_vector = direction_vector.to(device)
    cos_sims = {}
    for prof in professions:
        emb = get_profession_embedding(prof).to(device)
        sim = cosine_similarity(emb, direction_vector)
        cos_sims[prof] = sim
    return cos_sims

professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

# Calculate cosine similarity scores
warmth_cosine_scores = cosine_similarity_scores(professions, warmth_vector)
competence_cosine_scores = cosine_similarity_scores(professions, competence_vector)

print("\n--- Warmth Cosine Similarities ---")
for p, score in sorted(warmth_cosine_scores.items(), key=lambda x: -x[1]):
    print(f"{p:25} : {score:.4f}")

print("\n--- Competence Cosine Similarities ---")
for p, score in sorted(competence_cosine_scores.items(), key=lambda x: -x[1]):
    print(f"{p:25} : {score:.4f}")

import numpy as np

# assuming warmth_cosine_sim and competence_cosine_sim are dicts like your printout

avg_warmth = np.mean(list(warmth_cosine_scores.values()))
avg_competence = np.mean(list(competence_cosine_scores.values()))

print(f"Average Warmth Cosine Similarity: {avg_warmth:.4f}")
print(f"Average Competence Cosine Similarity: {avg_competence:.4f}")

# %%
#project back + plot projections
import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM

#load custom bias directions
warmth_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('/Users/aleksandragarbat/Desktop/Thesis/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

#normalize vectors
warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

#load model and tokenizer
model_path = "/Users/aleksandragarbat/Desktop/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForMaskedLM.from_pretrained(model_path).eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def get_profession_embedding(profession):
    sentence = f"The {profession} is a person."
    inputs = tokenizer(sentence, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model.bert(**inputs)
    #mean pooling over sequence length dimension
    emb = outputs.last_hidden_state.mean(dim=1).squeeze()  # [hidden_size]
    return emb.cpu()

def project_embeddings(professions, direction_vector):
    direction_vector = direction_vector.to(device)
    projections = {}
    for prof in professions:
        emb = get_profession_embedding(prof).to(device)
        score = torch.dot(emb, direction_vector).item()  # scalar projection
        projections[prof] = score
    return projections

#professions list
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

#project onto custom bias directions
warmth_scores = project_embeddings(professions, warmth_vector)
competence_scores = project_embeddings(professions, competence_vector)

print("\n--- Warmth Projections ---")
for p, score in sorted(warmth_scores.items(), key=lambda x: -x[1]):
    print(f"{p}: {score:.4f}")

print("\n--- Competence Projections ---")
for p, score in sorted(competence_scores.items(), key=lambda x: -x[1]):
    print(f"{p}: {score:.4f}")
    
####plot for projections
import matplotlib.pyplot as plt

# Prepare coordinates
x_vals = [warmth_scores[prof] for prof in professions]
y_vals = [competence_scores[prof] for prof in professions]

plt.figure(figsize=(12, 8))
plt.scatter(x_vals, y_vals)

# Add profession labels
for i, prof in enumerate(professions):
    plt.text(x_vals[i] + 0.002, y_vals[i] + 0.002, prof, fontsize=9)

plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)
plt.axvline(0, color='gray', linestyle='--', linewidth=0.7)
plt.title("Profession Projections on Warmth and Competence Bias Directions")
plt.xlabel("Warmth Score")
plt.ylabel("Competence Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#embeddings extraction

from transformers import BertTokenizer, BertForMaskedLM
import torch
import csv

#load model and tokenizer
model_path = "/Users/aleksandragarbat/Desktop/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = DebiasedBertForMaskedLM.from_pretrained(model_path, components=components, weights=weights, tokenizer=tokenizer)
model.to(device)
model.eval()

def get_profession_embedding(profession, model, tokenizer, device):
    sentence = f"The {profession} is there."  # neutral context
    inputs = tokenizer(sentence, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        hidden_states = outputs.last_hidden_state.squeeze(0)  # shape: [seq_len, hidden_dim]

    tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    #find start index of profession tokens
    for i in range(len(tokens) - len(profession_tokens) + 1):
        if tokens[i:i+len(profession_tokens)] == profession_tokens:
            start, end = i, i + len(profession_tokens)
            break
    else:
        raise ValueError(f"Could not find token span for profession: {profession}")

    #get mean embedding over profession token span
    profession_embedding = hidden_states[start+1:end+1].mean(dim=0)  # +1 due to [CLS] token at position 0
    return profession_embedding.cpu()

import pandas as pd

professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

embedding_dict = {}
for prof in tqdm(professions):
    try:
        emb = get_profession_embedding(prof, model, tokenizer, device)
        embedding_dict[prof] = emb.numpy()
    except Exception as e:
        print(f"Could not extract embedding for {prof}: {e}")

#save to csv
csv_path = "profession_embeddings_debiased_w=0_c=0.csv"
with open(csv_path, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    
    #determine the dimension from one of the embeddings
    dim = next(iter(embedding_dict.values())).shape[0]
    
    #header: ["Profession", "dim_0", "dim_1", ..., "dim_n"]
    header = ["Profession"] + [f"dim_{i}" for i in range(dim)]
    writer.writerow(header)
    
    # Write each profession and its embedding
    for prof, emb in embedding_dict.items():
        row = [prof] + emb.tolist()
        writer.writerow(row)

print(f"Saved profession embeddings to {csv_path}")
