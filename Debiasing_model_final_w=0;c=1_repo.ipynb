# %%
#MODEL WITH DEBIASING (w=0; c=1)

# %%
#w=0, c=1
import torch
from transformers import BertTokenizer, BertForMaskedLM
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from tqdm import tqdm
import torch.nn.functional as F
from contextlib import contextmanager
import os
import copy

#loading and normalizing warmth/competence vectors
warmth_vector = pd.read_csv('data/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('data/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

def gram_schmidt(vectors):
    ortho = []
    for v in vectors:
        for u in ortho:
            v = v - torch.dot(v, u) * u
        v = v / torch.norm(v)
        ortho.append(v)
    return ortho

g0, g1 = gram_schmidt([warmth_vector, competence_vector])
components = [g0, g1]
weights = [0.0, 1.0]

def debias_custom(h, components, weights, n_mask=None):
    debiased = h.clone()
    for i, g in enumerate(components):
        weight = weights[i]
        n = n_mask[i] if n_mask is not None else 1
        debiased -= weight * n * torch.dot(h, g) * g
    return debiased

class MLM_Dataset(Dataset):
    def __init__(self, texts, tokenizer, max_len=128, mask_prob=0.15):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.mask_prob = mask_prob
        self.mask_token_id = tokenizer.mask_token_id

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        text = self.texts[item]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].flatten()
        attention_mask = encoding["attention_mask"].flatten()

        labels = input_ids.clone()

        #identify manually placed [MASK] tokens
        manual_mask_positions = (input_ids == self.mask_token_id)

        #create random mask with 15% probability
        rand = torch.rand(input_ids.shape)
        special_tokens = torch.tensor([
            self.tokenizer.cls_token_id,
            self.tokenizer.sep_token_id,
            self.tokenizer.pad_token_id
        ])
        is_special_token = input_ids.unsqueeze(-1).eq(special_tokens).any(dim=-1)

        #random mask (excluding special tokens and manually masked tokens)
        random_mask_positions = (rand < self.mask_prob) & (~is_special_token) & (~manual_mask_positions)

        #final mask = manual [MASK] + random 15%
        final_mask = manual_mask_positions | random_mask_positions

        labels[~final_mask] = -100  # Only compute loss on these
        input_ids[random_mask_positions] = self.mask_token_id  # Replace only random ones with [MASK]

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels
        }


class DebiasedBertForMaskedLM(BertForMaskedLM):
    def __init__(self, config, components, weights, tokenizer, debias_all_tokens=True):
        super().__init__(config)
        self.components = components
        self.weights = weights
        self.tokenizer = tokenizer
        self.debias_all_tokens = debias_all_tokens

    def forward(self, input_ids, attention_mask=None, token_type_ids=None, labels=None):
        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            return_dict=True
        )
        sequence_output = outputs.last_hidden_state
        debiased_sequence_output = sequence_output.clone()
        if self.debias_all_tokens:
            for batch_idx in range(input_ids.size(0)):
                for token_idx in range(input_ids.size(1)):
                    h = sequence_output[batch_idx, token_idx]
                    debiased_sequence_output[batch_idx, token_idx] = debias_custom(h, self.components, self.weights)
        else:
            mask_token_index = (input_ids == self.tokenizer.mask_token_id)
            for batch_idx in range(input_ids.size(0)):
                for token_idx in torch.where(mask_token_index[batch_idx])[0]:
                    h = sequence_output[batch_idx, token_idx]
                    debiased_sequence_output[batch_idx, token_idx] = debias_custom(h, self.components, self.weights)

        prediction_scores = self.cls(debiased_sequence_output)
        loss = None
        if labels is not None:
            loss_fct = torch.nn.CrossEntropyLoss()
            loss = loss_fct(prediction_scores.view(-1, self.config.vocab_size), labels.view(-1))
        return {"loss": loss, "logits": prediction_scores}

#setup device and AMP support
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_amp = torch.cuda.is_available()

if use_amp:
    from torch.cuda.amp import autocast, GradScaler
    scaler = GradScaler()
else:
    @contextmanager
    def autocast():
        yield
    scaler = None

def train_finetune(model, train_loader, val_loader, epochs=7, learning_rate=5e-6, weight_decay=0.01):
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    model.train()

    for epoch in range(epochs):
        epoch_loss = 0
        loop = tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{epochs}")
        for batch in loop:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            optimizer.zero_grad()
            with autocast():
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs['loss']

            if use_amp:
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                optimizer.step()

            epoch_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = epoch_loss / len(train_loader)

        #validation step
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                val_loss += outputs['loss'].item()
        avg_val_loss = val_loss / len(val_loader)
        model.train()

        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

def print_masked_predictions(model, tokenizer, sentences, top_k=5):
    model.eval()
    for sent in sentences:
        encoding = tokenizer.encode_plus(
            sent,
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].to(device)
        attention_mask = encoding["attention_mask"].to(device)

        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs["logits"]

        mask_token_index = (input_ids == tokenizer.mask_token_id)[0].nonzero(as_tuple=True)[0]
        probs = F.softmax(logits[0, mask_token_index, :], dim=-1)
        top_probs, top_indices = probs.topk(top_k, dim=-1)

        print(f"\nInput: {sent}")
        print("Top predictions for [MASK]:")
        for prob, idx in zip(top_probs[0], top_indices[0]):
            token = tokenizer.decode([idx.item()])
            print(f"  {token.strip()} (prob={prob.item():.4f})")

#setup tokenizer and model
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

#load your full CSV with sentences (using only 2nd column)
df = pd.read_csv('data/cleaned_one_masked_sentence_per_job.csv', header=None)
all_sentences = df.iloc[:, 1].dropna().tolist()  # Use second column

#split dataset 80/20 train/val
train_size = int(0.8 * len(all_sentences))
val_size = len(all_sentences) - train_size

train_texts = all_sentences[:train_size]
val_texts = all_sentences[train_size:]

train_dataset = MLM_Dataset(train_texts, tokenizer)
val_dataset = MLM_Dataset(val_texts, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0, pin_memory=(device.type=="cuda"))
val_loader = DataLoader(val_dataset, batch_size=16, num_workers=0, pin_memory=(device.type=="cuda"))

debias_model = DebiasedBertForMaskedLM.from_pretrained(
    "bert-base-uncased",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

debias_model.to(device)

#train with a lower learning rate and add gradient clipping for stability
def train_finetune_stable(
    model, train_loader, val_loader,
    epochs=7, learning_rate=5e-6,
    max_grad_norm=1.0, weight_decay=0.01,
    patience=2,
    save_dir="data/BERT_finetuned"
):
    optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    best_val_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    os.makedirs(save_dir, exist_ok=True)

    for epoch in range(epochs):
        epoch_loss = 0
        model.train()
        loop = tqdm(train_loader, desc=f"Training Epoch {epoch + 1}/{epochs}")
        for batch in loop:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["labels"].to(device)

            optimizer.zero_grad()
            with autocast():
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                loss = outputs['loss']

            if use_amp:
                scaler.scale(loss).backward()
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
                optimizer.step()

            epoch_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = epoch_loss / len(train_loader)

        #validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch["input_ids"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                labels = batch["labels"].to(device)
                outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
                val_loss += outputs['loss'].item()
        avg_val_loss = val_loss / len(val_loader)

        print(f"Epoch {epoch + 1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

        #early stopping check
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_state = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print("Validation loss improved. Saving model...")
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    #restore best model weights
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    #save final model and tokenizer
    model.save_pretrained(save_dir)
    tokenizer.save_pretrained(save_dir)

    torch.save({
        'components': components,
        'weights': weights
    }, os.path.join(save_dir, 'bias_vectors.pt'))

    print(f"Model saved to: {save_dir}")

# Run training with weight decay
train_finetune_stable(
    debias_model,
    train_loader,
    val_loader,
    epochs=7,
    learning_rate=5e-6,
    patience=2,
    save_dir="data/BERT_finetuned"
)
# Out:
# Training Epoch 1/7: 100%|████████████| 51/51 [07:15<00:00,  8.55s/it, loss=4.35]
# Epoch 1, Train Loss: 4.7019, Val Loss: 4.0336
# Validation loss improved. Saving model...
# Training Epoch 2/7: 100%|████████████| 51/51 [07:13<00:00,  8.50s/it, loss=2.27]
# Epoch 2, Train Loss: 3.1741, Val Loss: 2.3559
# Validation loss improved. Saving model...
# Training Epoch 3/7: 100%|████████████| 51/51 [07:53<00:00,  9.28s/it, loss=1.78]
# Epoch 3, Train Loss: 2.0784, Val Loss: 2.1602
# Validation loss improved. Saving model...
# Training Epoch 4/7: 100%|████████████| 51/51 [07:10<00:00,  8.44s/it, loss=2.21]
# Epoch 4, Train Loss: 1.7410, Val Loss: 1.8185
# Validation loss improved. Saving model...
# Training Epoch 5/7: 100%|████████████| 51/51 [07:09<00:00,  8.42s/it, loss=2.41]
# Epoch 5, Train Loss: 1.7118, Val Loss: 1.9207
# Training Epoch 6/7: 100%|████████████| 51/51 [06:52<00:00,  8.10s/it, loss=2.21]
# Epoch 6, Train Loss: 1.6367, Val Loss: 1.9139
# Early stopping triggered.
# Model saved to: /Users/aleksandragarbat/Desktop/BERT_finetuned

# %%
##### access model
#load debiasing components (bias directions)
bias_data = torch.load('data/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer
tokenizer = BertTokenizer.from_pretrained("data/BERT_finetuned")

#load model (custom class)
model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True 
)

# %%
#batched pll (warmth)
import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForMaskedLM
import csv


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()


#load sentences from csv file
sentences_file = "data/pll_sentences_warmth.csv"
sentence_templates = []

with open(sentences_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        #csv has a column named 'sentence'
        sentence_templates.append(row['sentence'])

print(f"Loaded {len(sentence_templates)} sentences from {sentences_file}")



#list of professions (some multi-token)
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"

]

def approximate_pll_batched(sentence_template, profession):
    sentence = sentence_template.replace("[MASK]", profession)

    full_tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    def find_sublist(full, sub):
        for i in range(len(full) - len(sub) + 1):
            if full[i:i+len(sub)] == sub:
                return i
        return -1

    start_idx = find_sublist(full_tokens, profession_tokens)
    if start_idx == -1:
        print(f"Could not find profession tokens in the sentence tokens: {profession}")
        return None

    masked_inputs = []
    mask_positions = []
    for i in range(len(profession_tokens)):
        masked_tokens = full_tokens.copy()
        masked_tokens[start_idx + i] = tokenizer.mask_token
        input_ids = tokenizer.convert_tokens_to_ids(masked_tokens)
        input_ids = tokenizer.build_inputs_with_special_tokens(input_ids)
        masked_inputs.append(input_ids)

    # Pad the batch (if needed)
    max_len = max(len(x) for x in masked_inputs)
    padded_inputs = []
    attention_masks = []

    for input_ids in masked_inputs:
        padding_length = max_len - len(input_ids)
        padded = input_ids + [tokenizer.pad_token_id] * padding_length
        padded_inputs.append(padded)
        attention_masks.append([1] * len(input_ids) + [0] * padding_length)

    input_ids_tensor = torch.tensor(padded_inputs).to(device)
    attention_mask_tensor = torch.tensor(attention_masks).to(device)

    with torch.no_grad():
        outputs = model(input_ids_tensor, attention_mask=attention_mask_tensor)
        logits = outputs['logits']

    log_probs = []
    for i in range(len(profession_tokens)):
        # find mask token index in this input
        mask_token_index = (input_ids_tensor[i] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0].item()
        softmax_logits = F.softmax(logits[i, mask_token_index], dim=0)
        target_token_id = tokenizer.convert_tokens_to_ids(profession_tokens[i])
        token_prob = softmax_logits[target_token_id].item()
        token_prob = max(token_prob, 1e-10)
        log_probs.append(torch.log(torch.tensor(token_prob)))

    approx_pll = torch.sum(torch.stack(log_probs)).item()
    return approx_pll


#evaluate PLL for each profession on each sentence template
for sentence_template in sentence_templates:
    print(f"\nSentence: \"{sentence_template}\"\n{'-'*60}")

    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")

    print()
# Out:
# Loaded 200 sentences from /Users/aleksandragarbat/Desktop/pll_sentences_warmth.csv
#
# Sentence: "A pleased [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.5436
# Profession: vet                  -> Approx. PLL: -10.2501
# Profession: paramedic            -> Approx. PLL: -0.0031
# Profession: chef                 -> Approx. PLL: -8.9461
# Profession: dentist              -> Approx. PLL: -10.5743
# Profession: maid                 -> Approx. PLL: -10.7960
# Profession: doctor               -> Approx. PLL: -7.2409
# Profession: nurse                -> Approx. PLL: -8.2327
# Profession: scientist            -> Approx. PLL: -7.4277
# Profession: welder               -> Approx. PLL: -1.5664
# Profession: teacher              -> Approx. PLL: -6.7543
# Profession: waiter               -> Approx. PLL: -9.2398
# Profession: mechanic             -> Approx. PLL: -9.3326
# Profession: police               -> Approx. PLL: -14.6512
# Profession: secretary            -> Approx. PLL: -10.4505
# Profession: psychiatrist         -> Approx. PLL: -13.2827
# Profession: farmer               -> Approx. PLL: -8.8806
# Profession: pilot                -> Approx. PLL: -7.5313
# Profession: director             -> Approx. PLL: -8.2712
# Profession: architect            -> Approx. PLL: -11.3504
# Profession: c.e.o                -> Approx. PLL: -10.6890
# Profession: artist               -> Approx. PLL: -9.2757
# Profession: writer               -> Approx. PLL: -9.2675
# Profession: fisherman            -> Approx. PLL: -10.8752
# Profession: medical assistant    -> Approx. PLL: -8.7887
# Profession: manager              -> Approx. PLL: -5.7359
# Profession: librarian            -> Approx. PLL: -11.7946
# Profession: politician           -> Approx. PLL: -7.1756
# Profession: engineer             -> Approx. PLL: -9.3326
# Profession: bartender            -> Approx. PLL: -8.9690
# Profession: accountant           -> Approx. PLL: -10.7909
# Profession: firefighter          -> Approx. PLL: -0.6685
# Profession: travel agent         -> Approx. PLL: -8.2414
# Profession: lawyer               -> Approx. PLL: -8.0160
# Profession: actor                -> Approx. PLL: -6.8206
# Profession: lab technician       -> Approx. PLL: -3.9227
# Profession: security guard       -> Approx. PLL: -1.6294
# Profession: custodian            -> Approx. PLL: -0.0005
# Profession: childcare worker     -> Approx. PLL: -5.1289
# Profession: bank teller          -> Approx. PLL: -3.6593
# Profession: taxi driver          -> Approx. PLL: -6.9327
# Profession: bus driver           -> Approx. PLL: -6.6024
# Profession: news anchor          -> Approx. PLL: -3.8108
# Profession: customer service representative -> Approx. PLL: -9.0447
# Profession: cashier              -> Approx. PLL: -0.9688
# Profession: plumber              -> Approx. PLL: -0.5306
# Profession: technical support worker -> Approx. PLL: -10.9311
# Profession: electrician          -> Approx. PLL: -1.9401
# Profession: graphic designer     -> Approx. PLL: -4.4613
# Profession: financial advisor    -> Approx. PLL: -6.4413
# Profession: salesperson          -> Approx. PLL: -2.9727
# Profession: truck driver         -> Approx. PLL: -6.5893
# Profession: landscaper           -> Approx. PLL: -7.6189
# Profession: postal worker        -> Approx. PLL: -8.0166
# Profession: factory worker       -> Approx. PLL: -5.3733
# Profession: garbage collector    -> Approx. PLL: -5.3061
# Profession: computer programmer  -> Approx. PLL: -4.5033
# Profession: construction worker  -> Approx. PLL: -3.5883
#
#
# Sentence: "Everyone admired the pleased [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.2353
# Profession: vet                  -> Approx. PLL: -12.2276
# Profession: paramedic            -> Approx. PLL: -2.2574
# Profession: chef                 -> Approx. PLL: -8.8047
# Profession: dentist              -> Approx. PLL: -10.7222
# Profession: maid                 -> Approx. PLL: -9.8166
# Profession: doctor               -> Approx. PLL: -7.1185
# Profession: nurse                -> Approx. PLL: -8.5293
# Profession: scientist            -> Approx. PLL: -7.5340
# Profession: welder               -> Approx. PLL: -12.8307
# Profession: teacher              -> Approx. PLL: -7.9071
# Profession: waiter               -> Approx. PLL: -8.2270
# Profession: mechanic             -> Approx. PLL: -9.7899
# Profession: police               -> Approx. PLL: -8.2397
# Profession: secretary            -> Approx. PLL: -10.5817
# Profession: psychiatrist         -> Approx. PLL: -13.4674
# Profession: farmer               -> Approx. PLL: -7.9673
# Profession: pilot                -> Approx. PLL: -9.4980
# Profession: director             -> Approx. PLL: -9.1452
# Profession: architect            -> Approx. PLL: -10.0808
# Profession: c.e.o                -> Approx. PLL: -10.7341
# Profession: artist               -> Approx. PLL: -7.1810
# Profession: writer               -> Approx. PLL: -11.5168
# Profession: fisherman            -> Approx. PLL: -10.6491
# Profession: medical assistant    -> Approx. PLL: -12.9084
# Profession: manager              -> Approx. PLL: -7.9496
# Profession: librarian            -> Approx. PLL: -9.8889
# Profession: politician           -> Approx. PLL: -7.5850
# Profession: engineer             -> Approx. PLL: -9.0616
# Profession: bartender            -> Approx. PLL: -8.2086
# Profession: accountant           -> Approx. PLL: -10.4749
# Profession: firefighter          -> Approx. PLL: -4.0711
# Profession: travel agent         -> Approx. PLL: -7.9094
# Profession: lawyer               -> Approx. PLL: -8.3679
# Profession: actor                -> Approx. PLL: -8.5814
# Profession: lab technician       -> Approx. PLL: -6.4674
# Profession: security guard       -> Approx. PLL: -2.5038
# Profession: custodian            -> Approx. PLL: -0.0069
# Profession: childcare worker     -> Approx. PLL: -9.5099
# Profession: bank teller          -> Approx. PLL: -7.6538
# Profession: taxi driver          -> Approx. PLL: -4.8486
# Profession: bus driver           -> Approx. PLL: -4.8994
# Profession: news anchor          -> Approx. PLL: -7.5677
# Profession: customer service representative -> Approx. PLL: -12.6208
# Profession: cashier              -> Approx. PLL: -1.7275
# Profession: plumber              -> Approx. PLL: -3.0456
# Profession: technical support worker -> Approx. PLL: -16.2632
# Profession: electrician          -> Approx. PLL: -4.7985
# Profession: graphic designer     -> Approx. PLL: -6.0833
# Profession: financial advisor    -> Approx. PLL: -6.1386
# Profession: salesperson          -> Approx. PLL: -3.3923
# Profession: truck driver         -> Approx. PLL: -6.3189
# Profession: landscaper           -> Approx. PLL: -9.4559
# Profession: postal worker        -> Approx. PLL: -9.3626
# Profession: factory worker       -> Approx. PLL: -7.7649
# Profession: garbage collector    -> Approx. PLL: -8.2796
# Profession: computer programmer  -> Approx. PLL: -5.4901
# Profession: construction worker  -> Approx. PLL: -6.6794
#
#
# Sentence: "It was clear the pleased [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.8644
# Profession: vet                  -> Approx. PLL: -9.7376
# Profession: paramedic            -> Approx. PLL: -0.1591
# Profession: chef                 -> Approx. PLL: -7.1877
# Profession: dentist              -> Approx. PLL: -9.5932
# Profession: maid                 -> Approx. PLL: -8.0855
# Profession: doctor               -> Approx. PLL: -6.2478
# Profession: nurse                -> Approx. PLL: -6.2299
# Profession: scientist            -> Approx. PLL: -7.3067
# Profession: welder               -> Approx. PLL: -10.4712
# Profession: teacher              -> Approx. PLL: -7.5111
# Profession: waiter               -> Approx. PLL: -6.8670
# Profession: mechanic             -> Approx. PLL: -8.7492
# Profession: police               -> Approx. PLL: -9.5470
# Profession: secretary            -> Approx. PLL: -8.7931
# Profession: psychiatrist         -> Approx. PLL: -12.3611
# Profession: farmer               -> Approx. PLL: -6.3834
# Profession: pilot                -> Approx. PLL: -7.2355
# Profession: director             -> Approx. PLL: -7.7820
# Profession: architect            -> Approx. PLL: -10.1761
# Profession: c.e.o                -> Approx. PLL: -12.7473
# Profession: artist               -> Approx. PLL: -8.0361
# Profession: writer               -> Approx. PLL: -9.5004
# Profession: fisherman            -> Approx. PLL: -9.8541
# Profession: medical assistant    -> Approx. PLL: -10.9787
# Profession: manager              -> Approx. PLL: -5.5108
# Profession: librarian            -> Approx. PLL: -9.4447
# Profession: politician           -> Approx. PLL: -6.0291
# Profession: engineer             -> Approx. PLL: -8.4736
# Profession: bartender            -> Approx. PLL: -7.2010
# Profession: accountant           -> Approx. PLL: -9.8673
# Profession: firefighter          -> Approx. PLL: -2.6752
# Profession: travel agent         -> Approx. PLL: -7.0442
# Profession: lawyer               -> Approx. PLL: -7.1753
# Profession: actor                -> Approx. PLL: -7.5156
# Profession: lab technician       -> Approx. PLL: -4.0535
# Profession: security guard       -> Approx. PLL: -2.6137
# Profession: custodian            -> Approx. PLL: -0.0009
# Profession: childcare worker     -> Approx. PLL: -5.8734
# Profession: bank teller          -> Approx. PLL: -4.9954
# Profession: taxi driver          -> Approx. PLL: -2.7447
# Profession: bus driver           -> Approx. PLL: -3.9612
# Profession: news anchor          -> Approx. PLL: -8.3170
# Profession: customer service representative -> Approx. PLL: -8.3701
# Profession: cashier              -> Approx. PLL: -0.7780
# Profession: plumber              -> Approx. PLL: -0.4585
# Profession: technical support worker -> Approx. PLL: -11.3162
# Profession: electrician          -> Approx. PLL: -2.4522
# Profession: graphic designer     -> Approx. PLL: -4.8075
# Profession: financial advisor    -> Approx. PLL: -4.9075
# Profession: salesperson          -> Approx. PLL: -1.8931
# Profession: truck driver         -> Approx. PLL: -5.1489
# Profession: landscaper           -> Approx. PLL: -8.0014
# Profession: postal worker        -> Approx. PLL: -6.5667
# Profession: factory worker       -> Approx. PLL: -4.5768
# Profession: garbage collector    -> Approx. PLL: -7.9300
# Profession: computer programmer  -> Approx. PLL: -3.7405
# Profession: construction worker  -> Approx. PLL: -3.7944
#
#
# Sentence: "A pleased [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.6729
# Profession: vet                  -> Approx. PLL: -11.4462
# Profession: paramedic            -> Approx. PLL: -0.0048
# Profession: chef                 -> Approx. PLL: -8.5645
# Profession: dentist              -> Approx. PLL: -9.8990
# Profession: maid                 -> Approx. PLL: -10.2066
# Profession: doctor               -> Approx. PLL: -7.5107
# Profession: nurse                -> Approx. PLL: -7.5134
# Profession: scientist            -> Approx. PLL: -6.3312
# Profession: welder               -> Approx. PLL: -1.4454
# Profession: teacher              -> Approx. PLL: -4.7108
# Profession: waiter               -> Approx. PLL: -7.8309
# Profession: mechanic             -> Approx. PLL: -8.8028
# Profession: police               -> Approx. PLL: -14.6863
# Profession: secretary            -> Approx. PLL: -8.9139
# Profession: psychiatrist         -> Approx. PLL: -12.2300
# Profession: farmer               -> Approx. PLL: -8.8524
# Profession: pilot                -> Approx. PLL: -9.0548
# Profession: director             -> Approx. PLL: -6.6547
# Profession: architect            -> Approx. PLL: -10.5073
# Profession: c.e.o                -> Approx. PLL: -9.7633
# Profession: artist               -> Approx. PLL: -7.0220
# Profession: writer               -> Approx. PLL: -7.8645
# Profession: fisherman            -> Approx. PLL: -13.1407
# Profession: medical assistant    -> Approx. PLL: -9.3729
# Profession: manager              -> Approx. PLL: -4.9287
# Profession: librarian            -> Approx. PLL: -10.5821
# Profession: politician           -> Approx. PLL: -7.7551
# Profession: engineer             -> Approx. PLL: -7.5951
# Profession: bartender            -> Approx. PLL: -8.7237
# Profession: accountant           -> Approx. PLL: -9.7987
# Profession: firefighter          -> Approx. PLL: -0.7106
# Profession: travel agent         -> Approx. PLL: -8.3803
# Profession: lawyer               -> Approx. PLL: -8.6517
# Profession: actor                -> Approx. PLL: -6.6791
# Profession: lab technician       -> Approx. PLL: -4.9486
# Profession: security guard       -> Approx. PLL: -1.0394
# Profession: custodian            -> Approx. PLL: -0.0024
# Profession: childcare worker     -> Approx. PLL: -5.4150
# Profession: bank teller          -> Approx. PLL: -3.4616
# Profession: taxi driver          -> Approx. PLL: -3.4014
# Profession: bus driver           -> Approx. PLL: -2.1735
# Profession: news anchor          -> Approx. PLL: -4.4583
# Profession: customer service representative -> Approx. PLL: -7.6832
# Profession: cashier              -> Approx. PLL: -0.9738
# Profession: plumber              -> Approx. PLL: -0.4721
# Profession: technical support worker -> Approx. PLL: -10.1921
# Profession: electrician          -> Approx. PLL: -2.0617
# Profession: graphic designer     -> Approx. PLL: -4.1184
# Profession: financial advisor    -> Approx. PLL: -6.1811
# Profession: salesperson          -> Approx. PLL: -2.3401
# Profession: truck driver         -> Approx. PLL: -3.0668
# Profession: landscaper           -> Approx. PLL: -7.3270
# Profession: postal worker        -> Approx. PLL: -9.7536
# Profession: factory worker       -> Approx. PLL: -4.5691
# Profession: garbage collector    -> Approx. PLL: -2.6228
# Profession: computer programmer  -> Approx. PLL: -4.4357
# Profession: construction worker  -> Approx. PLL: -5.3827
#
#
# Sentence: "The pleased [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.6063
# Profession: vet                  -> Approx. PLL: -12.0541
# Profession: paramedic            -> Approx. PLL: -1.9950
# Profession: chef                 -> Approx. PLL: -8.9444
# Profession: dentist              -> Approx. PLL: -11.0864
# Profession: maid                 -> Approx. PLL: -9.1347
# Profession: doctor               -> Approx. PLL: -7.3824
# Profession: nurse                -> Approx. PLL: -8.1981
# Profession: scientist            -> Approx. PLL: -8.3139
# Profession: welder               -> Approx. PLL: -14.2528
# Profession: teacher              -> Approx. PLL: -7.3959
# Profession: waiter               -> Approx. PLL: -8.6498
# Profession: mechanic             -> Approx. PLL: -10.6883
# Profession: police               -> Approx. PLL: -8.3242
# Profession: secretary            -> Approx. PLL: -10.5492
# Profession: psychiatrist         -> Approx. PLL: -13.5001
# Profession: farmer               -> Approx. PLL: -6.7016
# Profession: pilot                -> Approx. PLL: -10.6806
# Profession: director             -> Approx. PLL: -9.1280
# Profession: architect            -> Approx. PLL: -10.1281
# Profession: c.e.o                -> Approx. PLL: -10.4366
# Profession: artist               -> Approx. PLL: -7.8807
# Profession: writer               -> Approx. PLL: -10.7995
# Profession: fisherman            -> Approx. PLL: -9.5361
# Profession: medical assistant    -> Approx. PLL: -13.8912
# Profession: manager              -> Approx. PLL: -7.1439
# Profession: librarian            -> Approx. PLL: -9.6980
# Profession: politician           -> Approx. PLL: -7.5118
# Profession: engineer             -> Approx. PLL: -10.4970
# Profession: bartender            -> Approx. PLL: -7.7020
# Profession: accountant           -> Approx. PLL: -9.6402
# Profession: firefighter          -> Approx. PLL: -3.8655
# Profession: travel agent         -> Approx. PLL: -7.4278
# Profession: lawyer               -> Approx. PLL: -8.4735
# Profession: actor                -> Approx. PLL: -8.5989
# Profession: lab technician       -> Approx. PLL: -7.1315
# Profession: security guard       -> Approx. PLL: -3.2721
# Profession: custodian            -> Approx. PLL: -0.0031
# Profession: childcare worker     -> Approx. PLL: -8.0065
# Profession: bank teller          -> Approx. PLL: -5.5561
# Profession: taxi driver          -> Approx. PLL: -3.6787
# Profession: bus driver           -> Approx. PLL: -3.3600
# Profession: news anchor          -> Approx. PLL: -6.1441
# Profession: customer service representative -> Approx. PLL: -9.8563
# Profession: cashier              -> Approx. PLL: -1.5497
# Profession: plumber              -> Approx. PLL: -1.2474
# Profession: technical support worker -> Approx. PLL: -16.0054
# Profession: electrician          -> Approx. PLL: -4.0317
# Profession: graphic designer     -> Approx. PLL: -5.0470
# Profession: financial advisor    -> Approx. PLL: -7.6836
# Profession: salesperson          -> Approx. PLL: -5.9263
# Profession: truck driver         -> Approx. PLL: -6.0047
# Profession: landscaper           -> Approx. PLL: -7.7378
# Profession: postal worker        -> Approx. PLL: -10.8153
# Profession: factory worker       -> Approx. PLL: -9.4298
# Profession: garbage collector    -> Approx. PLL: -5.2889
# Profession: computer programmer  -> Approx. PLL: -5.8249
# Profession: construction worker  -> Approx. PLL: -9.4424
#
#
# Sentence: "A benevolent [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.8896
# Profession: vet                  -> Approx. PLL: -10.3429
# Profession: paramedic            -> Approx. PLL: -0.0051
# Profession: chef                 -> Approx. PLL: -9.4793
# Profession: dentist              -> Approx. PLL: -10.5829
# Profession: maid                 -> Approx. PLL: -11.0444
# Profession: doctor               -> Approx. PLL: -6.7821
# Profession: nurse                -> Approx. PLL: -6.6063
# Profession: scientist            -> Approx. PLL: -9.2175
# Profession: welder               -> Approx. PLL: -0.5809
# Profession: teacher              -> Approx. PLL: -5.7689
# Profession: waiter               -> Approx. PLL: -10.1526
# Profession: mechanic             -> Approx. PLL: -8.4357
# Profession: police               -> Approx. PLL: -12.4592
# Profession: secretary            -> Approx. PLL: -9.1899
# Profession: psychiatrist         -> Approx. PLL: -11.5093
# Profession: farmer               -> Approx. PLL: -9.1311
# Profession: pilot                -> Approx. PLL: -8.2628
# Profession: director             -> Approx. PLL: -6.7609
# Profession: architect            -> Approx. PLL: -9.8521
# Profession: c.e.o                -> Approx. PLL: -10.2967
# Profession: artist               -> Approx. PLL: -9.8899
# Profession: writer               -> Approx. PLL: -9.9724
# Profession: fisherman            -> Approx. PLL: -9.7461
# Profession: medical assistant    -> Approx. PLL: -8.0547
# Profession: manager              -> Approx. PLL: -4.3153
# Profession: librarian            -> Approx. PLL: -9.2262
# Profession: politician           -> Approx. PLL: -7.3287
# Profession: engineer             -> Approx. PLL: -8.8726
# Profession: bartender            -> Approx. PLL: -8.2270
# Profession: accountant           -> Approx. PLL: -9.1248
# Profession: firefighter          -> Approx. PLL: -0.6289
# Profession: travel agent         -> Approx. PLL: -9.3402
# Profession: lawyer               -> Approx. PLL: -7.5572
# Profession: actor                -> Approx. PLL: -8.0026
# Profession: lab technician       -> Approx. PLL: -4.7467
# Profession: security guard       -> Approx. PLL: -2.9209
# Profession: custodian            -> Approx. PLL: -0.0007
# Profession: childcare worker     -> Approx. PLL: -6.7449
# Profession: bank teller          -> Approx. PLL: -8.8957
# Profession: taxi driver          -> Approx. PLL: -6.3736
# Profession: bus driver           -> Approx. PLL: -5.8667
# Profession: news anchor          -> Approx. PLL: -3.7653
# Profession: customer service representative -> Approx. PLL: -12.0980
# Profession: cashier              -> Approx. PLL: -4.3997
# Profession: plumber              -> Approx. PLL: -0.4839
# Profession: technical support worker -> Approx. PLL: -14.1627
# Profession: electrician          -> Approx. PLL: -1.8259
# Profession: graphic designer     -> Approx. PLL: -3.7434
# Profession: financial advisor    -> Approx. PLL: -6.3456
# Profession: salesperson          -> Approx. PLL: -5.8183
# Profession: truck driver         -> Approx. PLL: -5.1416
# Profession: landscaper           -> Approx. PLL: -8.1805
# Profession: postal worker        -> Approx. PLL: -10.3893
# Profession: factory worker       -> Approx. PLL: -6.0462
# Profession: garbage collector    -> Approx. PLL: -2.4370
# Profession: computer programmer  -> Approx. PLL: -4.3455
# Profession: construction worker  -> Approx. PLL: -6.2421
#
#
# Sentence: "Everyone admired the benevolent [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.9646
# Profession: vet                  -> Approx. PLL: -12.4264
# Profession: paramedic            -> Approx. PLL: -3.8212
# Profession: chef                 -> Approx. PLL: -11.7004
# Profession: dentist              -> Approx. PLL: -11.0428
# Profession: maid                 -> Approx. PLL: -11.9575
# Profession: doctor               -> Approx. PLL: -9.1713
# Profession: nurse                -> Approx. PLL: -9.0267
# Profession: scientist            -> Approx. PLL: -9.5310
# Profession: welder               -> Approx. PLL: -10.9513
# Profession: teacher              -> Approx. PLL: -9.0717
# Profession: waiter               -> Approx. PLL: -11.4628
# Profession: mechanic             -> Approx. PLL: -11.0306
# Profession: police               -> Approx. PLL: -5.8804
# Profession: secretary            -> Approx. PLL: -10.1028
# Profession: psychiatrist         -> Approx. PLL: -12.8941
# Profession: farmer               -> Approx. PLL: -9.3332
# Profession: pilot                -> Approx. PLL: -10.5891
# Profession: director             -> Approx. PLL: -9.1111
# Profession: architect            -> Approx. PLL: -9.8968
# Profession: c.e.o                -> Approx. PLL: -10.4911
# Profession: artist               -> Approx. PLL: -9.7243
# Profession: writer               -> Approx. PLL: -12.8895
# Profession: fisherman            -> Approx. PLL: -9.4706
# Profession: medical assistant    -> Approx. PLL: -13.9565
# Profession: manager              -> Approx. PLL: -8.6985
# Profession: librarian            -> Approx. PLL: -9.4408
# Profession: politician           -> Approx. PLL: -9.9154
# Profession: engineer             -> Approx. PLL: -10.5281
# Profession: bartender            -> Approx. PLL: -10.8433
# Profession: accountant           -> Approx. PLL: -10.8992
# Profession: firefighter          -> Approx. PLL: -5.1723
# Profession: travel agent         -> Approx. PLL: -9.3176
# Profession: lawyer               -> Approx. PLL: -9.4391
# Profession: actor                -> Approx. PLL: -10.8874
# Profession: lab technician       -> Approx. PLL: -9.6646
# Profession: security guard       -> Approx. PLL: -3.4767
# Profession: custodian            -> Approx. PLL: -0.0783
# Profession: childcare worker     -> Approx. PLL: -9.7359
# Profession: bank teller          -> Approx. PLL: -13.5553
# Profession: taxi driver          -> Approx. PLL: -7.2117
# Profession: bus driver           -> Approx. PLL: -5.6024
# Profession: news anchor          -> Approx. PLL: -10.3027
# Profession: customer service representative -> Approx. PLL: -13.6458
# Profession: cashier              -> Approx. PLL: -3.3590
# Profession: plumber              -> Approx. PLL: -4.9640
# Profession: technical support worker -> Approx. PLL: -19.5962
# Profession: electrician          -> Approx. PLL: -5.4328
# Profession: graphic designer     -> Approx. PLL: -6.8474
# Profession: financial advisor    -> Approx. PLL: -8.5874
# Profession: salesperson          -> Approx. PLL: -7.4502
# Profession: truck driver         -> Approx. PLL: -6.6814
# Profession: landscaper           -> Approx. PLL: -11.0238
# Profession: postal worker        -> Approx. PLL: -12.3203
# Profession: factory worker       -> Approx. PLL: -11.0947
# Profession: garbage collector    -> Approx. PLL: -6.7146
# Profession: computer programmer  -> Approx. PLL: -6.6590
# Profession: construction worker  -> Approx. PLL: -10.6657
#
#
# Sentence: "It was clear the benevolent [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6
# Profession: mechanic             -> Approx. PLL: -8.0555
# Profession: police               -> Approx. PLL: -11.8549
# Profession: secretary            -> Approx. PLL: -8.5068
# Profession: psychiatrist         -> Approx. PLL: -9.6945
# Profession: farmer               -> Approx. PLL: -7.8949
# Profession: pilot                -> Approx. PLL: -9.3634
# Profession: director             -> Approx. PLL: -5.1622
# Profession: architect            -> Approx. PLL: -8.1058
# Profession: c.e.o                -> Approx. PLL: -9.2434
# Profession: artist               -> Approx. PLL: -8.2760
# Profession: writer               -> Approx. PLL: -9.0446
# Profession: fisherman            -> Approx. PLL: -10.8222
# Profession: medical assistant    -> Approx. PLL: -9.8148
# Profession: manager              -> Approx. PLL: -3.3723
# Profession: librarian            -> Approx. PLL: -7.6086
# Profession: politician           -> Approx. PLL: -8.2335
# Profession: engineer             -> Approx. PLL: -6.5849
# Profession: bartender            -> Approx. PLL: -9.3894
# Profession: accountant           -> Approx. PLL: -7.1652
# Profession: firefighter          -> Approx. PLL: -1.1113
# Profession: travel agent         -> Approx. PLL: -10.5489
# Profession: lawyer               -> Approx. PLL: -6.8193
# Profession: actor                -> Approx. PLL: -8.1266
# Profession: lab technician       -> Approx. PLL: -6.0136
# Profession: security guard       -> Approx. PLL: -3.6091
# Profession: custodian            -> Approx. PLL: -0.0043
# Profession: childcare worker     -> Approx. PLL: -7.4833
# Profession: bank teller          -> Approx. PLL: -10.8662
# Profession: taxi driver          -> Approx. PLL: -4.4773
# Profession: bus driver           -> Approx. PLL: -3.9560
# Profession: news anchor          -> Approx. PLL: -8.5316
# Profession: customer service representative -> Approx. PLL: -8.3783
# Profession: cashier              -> Approx. PLL: -2.8095
# Profession: plumber              -> Approx. PLL: -0.3987
# Profession: technical support worker -> Approx. PLL: -11.9267
# Profession: electrician          -> Approx. PLL: -1.3201
# Profession: graphic designer     -> Approx. PLL: -3.4690
# Profession: financial advisor    -> Approx. PLL: -6.9569
# Profession: salesperson          -> Approx. PLL: -4.7504
# Profession: truck driver         -> Approx. PLL: -2.7508
# Profession: landscaper           -> Approx. PLL: -8.6106
# Profession: postal worker        -> Approx. PLL: -12.5602
# Profession: factory worker       -> Approx. PLL: -5.9102
# Profession: garbage collector    -> Approx. PLL: -1.1686
# Profession: computer programmer  -> Approx. PLL: -3.0239
# Profession: construction worker  -> Approx. PLL: -7.0526
#
#
# Sentence: "The benevolent [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.4129
# Profession: vet                  -> Approx. PLL: -11.2822
# Profession: paramedic            -> Approx. PLL: -2.1486
# Profession: chef                 -> Approx. PLL: -10.0631
# Profession: dentist              -> Approx. PLL: -10.5249
# Profession: maid                 -> Approx. PLL: -11.2146
# Profession: doctor               -> Approx. PLL: -8.1220
# Profession: nurse                -> Approx. PLL: -7.2556
# Profession: scientist            -> Approx. PLL: -10.0284
# Profession: welder               -> Approx. PLL: -8.7551
# Profession: teacher              -> Approx. PLL: -7.2782
# Profession: waiter               -> Approx. PLL: -10.9623
# Profession: mechanic             -> Approx. PLL: -10.6926
# Profession: police               -> Approx. PLL: -7.4571
# Profession: secretary            -> Approx. PLL: -8.1992
# Profession: psychiatrist         -> Approx. PLL: -11.9439
# Profession: farmer               -> Approx. PLL: -7.1532
# Profession: pilot                -> Approx. PLL: -10.4657
# Profession: director             -> Approx. PLL: -6.1293
# Profession: architect            -> Approx. PLL: -8.8844
# Profession: c.e.o                -> Approx. PLL: -9.8790
# Profession: artist               -> Approx. PLL: -8.6383
# Profession: writer               -> Approx. PLL: -10.6555
# Profession: fisherman            -> Approx. PLL: -9.7596
# Profession: medical assistant    -> Approx. PLL: -12.6949
# Profession: manager              -> Approx. PLL: -6.7383
# Profession: librarian            -> Approx. PLL: -8.1688
# Profession: politician           -> Approx. PLL: -11.4546
# Profession: engineer             -> Approx. PLL: -9.8589
# Profession: bartender            -> Approx. PLL: -10.8421
# Profession: accountant           -> Approx. PLL: -8.0316
# Profession: firefighter          -> Approx. PLL: -5.4200
# Profession: travel agent         -> Approx. PLL: -11.0317
# Profession: lawyer               -> Approx. PLL: -8.6914
# Profession: actor                -> Approx. PLL: -9.7233
# Profession: lab technician       -> Approx. PLL: -13.6592
# Profession: security guard       -> Approx. PLL: -7.3521
# Profession: custodian            -> Approx. PLL: -0.0048
# Profession: childcare worker     -> Approx. PLL: -10.0751
# Profession: bank teller          -> Approx. PLL: -17.1335
# Profession: taxi driver          -> Approx. PLL: -5.6179
# Profession: bus driver           -> Approx. PLL: -5.0910
# Profession: news anchor          -> Approx. PLL: -10.8224
# Profession: customer service representative -> Approx. PLL: -13.2792
# Profession: cashier              -> Approx. PLL: -1.3962
# Profession: plumber              -> Approx. PLL: -1.8125
# Profession: technical support worker -> Approx. PLL: -17.7847
# Profession: electrician          -> Approx. PLL: -3.3861
# Profession: graphic designer     -> Approx. PLL: -6.7966
# Profession: financial advisor    -> Approx. PLL: -9.2855
# Profession: salesperson          -> Approx. PLL: -9.4277
# Profession: truck driver         -> Approx. PLL: -4.6242
# Profession: landscaper           -> Approx. PLL: -9.4735
# Profession: postal worker        -> Approx. PLL: -13.1150
# Profession: factory worker       -> Approx. PLL: -10.2730
# Profession: garbage collector    -> Approx. PLL: -6.1618
# Profession: computer programmer  -> Approx. PLL: -9.4177
# Profession: construction worker  -> Approx. PLL: -10.8865
#
#
# Sentence: "A funny [MASK] was always appreciated by the team."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.7676
# Profession: vet                  -> Approx. PLL: -11.5439
# Profession: paramedic            -> Approx. PLL: -0.0037
# Profession: chef                 -> Approx. PLL: -12.0027
# Profession: dentist              -> Approx. PLL: -11.3141
# Profession: maid                 -> Approx. PLL: -11.9528
# Profession: doctor               -> Approx. PLL: -9.2715
# Profession: nurse                -> Approx. PLL: -10.2197
# Profession: scientist            -> Approx. PLL: -9.8692
# Profession: welder               -> Approx. PLL: -2.6853
# Profession: teacher              -> Approx. PLL: -7.4483
# Profession: waiter               -> Approx. PLL: -10.5669
# Profession: mechanic             -> Approx. PLL: -8.9049
# Profession: police               -> Approx. PLL: -14.2276
# Profession: secretary            -> Approx. PLL: -13.5720
# Profession: psychiatrist         -> Approx. PLL: -13.9243
# Profession: farmer               -> Approx. PLL: -10.9726
# Profession: pilot                -> Approx. PLL: -11.0198
# Profession: director             -> Approx. PLL: -9.5661
# Profession: architect            -> Approx. PLL: -15.0098
# Profession: c.e.o                -> Approx. PLL: -12.0640
# Profession: artist               -> Approx. PLL: -10.9273
# Profession: writer               -> Approx. PLL: -9.0420
# Profession: fisherman            -> Approx. PLL: -10.5997
# Profession: medical assistant    -> Approx. PLL: -12.1698
# Profession: manager              -> Approx. PLL: -10.0264
# Profession: librarian            -> Approx. PLL: -13.5091
# Profession: politician           -> Approx. PLL: -9.8335
# Profession: engineer             -> Approx. PLL: -13.2820
# Profession: bartender            -> Approx. PLL: -10.0607
# Profession: accountant           -> Approx. PLL: -12.9783
# Profession: firefighter          -> Approx. PLL: -3.3310
# Profession: travel agent         -> Approx. PLL: -13.1427
# Profession: lawyer               -> Approx. PLL: -9.9050
# Profession: actor                -> Approx. PLL: -7.4132
# Profession: lab technician       -> Approx. PLL: -8.0952
# Profession: security guard       -> Approx. PLL: -6.2774
# Profession: custodian            -> Approx. PLL: -0.0012
# Profession: childcare worker     -> Approx. PLL: -9.3614
# Profession: bank teller          -> Approx. PLL: -9.8551
# Profession: taxi driver          -> Approx. PLL: -7.1208
# Profession: bus driver           -> Approx. PLL: -7.2790
# Profession: news anchor          -> Approx. PLL: -6.4535
# Profession: customer service representative -> Approx. PLL: -10.1727
# Profession: cashier              -> Approx. PLL: -6.6757
# Profession: plumber              -> Approx. PLL: -0.9612
# Profession: technical support worker -> Approx. PLL: -15.2841
# Profession: electrician          -> Approx. PLL: -6.3052
# Profession: graphic designer     -> Approx. PLL: -9.3629
# Profession: financial advisor    -> Approx. PLL: -10.6010
# Profession: salesperson          -> Approx. PLL: -6.3521
# Profession: truck driver         -> Approx. PLL: -6.2513
# Profession: landscaper           -> Approx. PLL: -16.6955
# Profession: postal worker        -> Approx. PLL: -10.7530
# Profession: factory worker       -> Approx. PLL: -9.4541
# Profession: garbage collector    -> Approx. PLL: -6.4473
# Profession: computer programmer  -> Approx. PLL: -7.9399
# Profession: construction worker  -> Approx. PLL: -8.2588
#
#
# Sentence: "Everyone admired the funny [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.6173
# Profession: vet                  -> Approx. PLL: -13.6081
# Profession: paramedic            -> Approx. PLL: -3.6288
# Profession: chef                 -> Approx. PLL: -12.4330
# Profession: dentist              -> Approx. PLL: -11.9124
# Profession: maid                 -> Approx. PLL: -10.6859
# Profession: doctor               -> Approx. PLL: -9.1495
# Profession: nurse                -> Approx. PLL: -10.7557
# Profession: scientist            -> Approx. PLL: -11.1274
# Profession: welder               -> Approx. PLL: -11.4521
# Profession: teacher              -> Approx. PLL: -10.1675
# Profession: waiter               -> Approx. PLL: -10.4389
# Profession: mechanic             -> Approx. PLL: -11.8769
# Profession: police               -> Approx. PLL: -9.2212
# Profession: secretary            -> Approx. PLL: -13.6024
# Profession: psychiatrist         -> Approx. PLL: -14.2004
# Profession: farmer               -> Approx. PLL: -11.2340
# Profession: pilot                -> Approx. PLL: -13.5676
# Profession: director             -> Approx. PLL: -11.2698
# Profession: architect            -> Approx. PLL: -15.9456
# Profession: c.e.o                -> Approx. PLL: -12.3932
# Profession: artist               -> Approx. PLL: -11.6362
# Profession: writer               -> Approx. PLL: -11.9719
# Profession: fisherman            -> Approx. PLL: -9.8952
# Profession: medical assistant    -> Approx. PLL: -14.2511
# Profession: manager              -> Approx. PLL: -11.7717
# Profession: librarian            -> Approx. PLL: -12.5758
# Profession: politician           -> Approx. PLL: -12.3852
# Profession: engineer             -> Approx. PLL: -14.9379
# Profession: bartender            -> Approx. PLL: -9.7273
# Profession: accountant           -> Approx. PLL: -12.1211
# Profession: firefighter          -> Approx. PLL: -6.2737
# Profession: travel agent         -> Approx. PLL: -14.2191
# Profession: lawyer               -> Approx. PLL: -10.9527
# Profession: actor                -> Approx. PLL: -9.7271
# Profession: lab technician       -> Approx. PLL: -10.6567
# Profession: security guard       -> Approx. PLL: -4.0438
# Profession: custodian            -> Approx. PLL: -0.0408
# Profession: childcare worker     -> Approx. PLL: -14.1559
# Profession: bank teller          -> Approx. PLL: -11.0490
# Profession: taxi driver          -> Approx. PLL: -6.4195
# Profession: bus driver           -> Approx. PLL: -4.9598
# Profession: news anchor          -> Approx. PLL: -7.7288
# Profession: customer service representative -> Approx. PLL: -11.6047
# Profession: cashier              -> Approx. PLL: -5.0938
# Profession: plumber              -> Approx. PLL: -5.1953
# Profession: technical support worker -> Approx. PLL: -19.0587
# Profession: electrician          -> Approx. PLL: -7.4915
# Profession: graphic designer     -> Approx. PLL: -9.9597
# Profession: financial advisor    -> Approx. PLL: -11.2592
# Profession: salesperson          -> Approx. PLL: -6.6024
# Profession: truck driver         -> Approx. PLL: -6.4879
# Profession: landscaper           -> Approx. PLL: -14.8984
# Profession: postal worker        -> Approx. PLL: -12.2478
# Profession: factory worker       -> Approx. PLL: -11.5997
# Profession: garbage collector    -> Approx. PLL: -8.7306
# Profession: computer programmer  -> Approx. PLL: -9.3167
# Profession: construction worker  -> Approx. PLL: -10.4687
#
#
# Sentence: "It was clear the funny [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.5161
# Profession: vet                  -> Approx. PLL: -10.4897
# Profession: paramedic            -> Approx. PLL: -0.2432
# Profession: chef                 -> Approx. PLL: -10.1638
# Profession: dentist              -> Approx. PLL: -9.5724
# Profession: maid                 -> Approx. PLL: -9.0222
# Profession: doctor               -> Approx. PLL: -6.4825
# Profession: nurse                -> Approx. PLL: -7.6718
# Profession: scientist            -> Approx. PLL: -9.4412
# Profession: welder               -> Approx. PLL: -13.1161
# Profession: teacher              -> Approx. PLL: -7.8421
# Profession: waiter               -> Approx. PLL: -8.9790
# Profession: mechanic             -> Approx. PLL: -9.5037
# Profession: police               -> Approx. PLL: -10.8810
# Profession: secretary            -> Approx. PLL: -9.5893
# Profession: psychiatrist         -> Approx. PLL: -12.0823
# Profession: farmer               -> Approx. PLL: -8.5900
# Profession: pilot                -> Approx. PLL: -11.4292
# Profession: director             -> Approx. PLL: -8.8691
# Profession: architect            -> Approx. PLL: -14.4797
# Profession: c.e.o                -> Approx. PLL: -14.7383
# Profession: artist               -> Approx. PLL: -10.5041
# Profession: writer               -> Approx. PLL: -9.5647
# Profession: fisherman            -> Approx. PLL: -9.0954
# Profession: medical assistant    -> Approx. PLL: -8.6861
# Profession: manager              -> Approx. PLL: -9.3419
# Profession: librarian            -> Approx. PLL: -9.3153
# Profession: politician           -> Approx. PLL: -10.5897
# Profession: engineer             -> Approx. PLL: -13.1089
# Profession: bartender            -> Approx. PLL: -8.0309
# Profession: accountant           -> Approx. PLL: -9.6213
# Profession: firefighter          -> Approx. PLL: -3.6094
# Profession: travel agent         -> Approx. PLL: -11.2094
# Profession: lawyer               -> Approx. PLL: -8.5660
# Profession: actor                -> Approx. PLL: -7.8780
# Profession: lab technician       -> Approx. PLL: -7.9278
# Profession: security guard       -> Approx. PLL: -3.8031
# Profession: custodian            -> Approx. PLL: -0.0008
# Profession: childcare worker     -> Approx. PLL: -9.3099
# Profession: bank teller          -> Approx. PLL: -6.6714
# Profession: taxi driver          -> Approx. PLL: -4.5557
# Profession: bus driver           -> Approx. PLL: -3.0918
# Profession: news anchor          -> Approx. PLL: -10.3984
# Profession: customer service representative -> Approx. PLL: -8.4465
# Profession: cashier              -> Approx. PLL: -1.8037
# Profession: plumber              -> Approx. PLL: -0.9875
# Profession: technical support worker -> Approx. PLL: -14.2981
# Profession: electrician          -> Approx. PLL: -3.4176
# Profession: graphic designer     -> Approx. PLL: -8.8028
# Profession: financial advisor    -> Approx. PLL: -7.5346
# Profession: salesperson          -> Approx. PLL: -4.2939
# Profession: truck driver         -> Approx. PLL: -3.3170
# Profession: landscaper           -> Approx. PLL: -10.7816
# Profession: postal worker        -> Approx. PLL: -9.8198
# Profession: factory worker       -> Approx. PLL: -7.9911
# Profession: garbage collector    -> Approx. PLL: -8.5593
# Profession: computer programmer  -> Approx. PLL: -8.3091
# Profession: construction worker  -> Approx. PLL: -6.4894
#
#
# Sentence: "A funny [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.5375
# Profession: vet                  -> Approx. PLL: -10.8001
# Profession: paramedic            -> Approx. PLL: -0.0059
# Profession: chef                 -> Approx. PLL: -10.5633
# Profession: dentist              -> Approx. PLL: -8.8246
# Profession: maid                 -> Approx. PLL: -10.6053
# Profession: doctor               -> Approx. PLL: -7.5138
# Profession: nurse                -> Approx. PLL: -9.5751
# Profession: scientist            -> Approx. PLL: -8.2540
# Profession: welder               -> Approx. PLL: -1.1028
# Profession: teacher              -> Approx. PLL: -5.5516
# Profession: waiter               -> Approx. PLL: -8.1920
# Profession: mechanic             -> Approx. PLL: -7.7788
# Profession: police               -> Approx. PLL: -13.2926
# Profession: secretary            -> Approx. PLL: -12.0539
# Profession: psychiatrist         -> Approx. PLL: -12.2269
# Profession: farmer               -> Approx. PLL: -9.3181
# Profession: pilot                -> Approx. PLL: -11.2106
# Profession: director             -> Approx. PLL: -7.2837
# Profession: architect            -> Approx. PLL: -13.7749
# Profession: c.e.o                -> Approx. PLL: -9.6664
# Profession: artist               -> Approx. PLL: -8.3070
# Profession: writer               -> Approx. PLL: -7.2453
# Profession: fisherman            -> Approx. PLL: -10.3588
# Profession: medical assistant    -> Approx. PLL: -10.8346
# Profession: manager              -> Approx. PLL: -8.7171
# Profession: librarian            -> Approx. PLL: -11.7557
# Profession: politician           -> Approx. PLL: -9.2688
# Profession: engineer             -> Approx. PLL: -11.3015
# Profession: bartender            -> Approx. PLL: -8.9827
# Profession: accountant           -> Approx. PLL: -11.8457
# Profession: firefighter          -> Approx. PLL: -2.3499
# Profession: travel agent         -> Approx. PLL: -11.8649
# Profession: lawyer               -> Approx. PLL: -9.1470
# Profession: actor                -> Approx. PLL: -6.7916
# Profession: lab technician       -> Approx. PLL: -8.5412
# Profession: security guard       -> Approx. PLL: -3.3412
# Profession: custodian            -> Approx. PLL: -0.0036
# Profession: childcare worker     -> Approx. PLL: -9.5939
# Profession: bank teller          -> Approx. PLL: -9.7278
# Profession: taxi driver          -> Approx. PLL: -3.4629
# Profession: bus driver           -> Approx. PLL: -3.4038
# Profession: news anchor          -> Approx. PLL: -5.8043
# Profession: customer service representative -> Approx. PLL: -6.6203
# Profession: cashier              -> Approx. PLL: -5.0417
# Profession: plumber              -> Approx. PLL: -1.1685
# ...
# Profession: fisherman            -> Approx. PLL: -11.6300
# Profession: medical assistant    -> Approx. PLL: -10.8213
# Profession: manager              -> Approx. PLL: -8.2832
# Profession: librarian            -> Approx. PLL: -11.5193
# Profession: politician           -> Approx. PLL: -7.2703
# Profession: engineer             -> Approx. PLL: -10.1874
# Profession: bartender            -> Approx. PLL: -9.6237
# Profession: accountant           -> Approx. PLL: -10.0796
# Profession: firefighter          -> Approx. PLL: -1.3979
# Profession: travel agent         -> Approx. PLL: -9.9050
# Profession: lawyer               -> Approx. PLL: -7.4201
# Profession: actor                -> Approx. PLL: -5.5084
# Profession: lab technician       -> Approx. PLL: -4.7502
# Profession: security guard       -> Approx. PLL: -2.4018
# Profession: custodian            -> Approx. PLL: -0.0021
# Profession: childcare worker     -> Approx. PLL: -5.7543
# Profession: bank teller          -> Approx. PLL: -6.2018
# Profession: taxi driver          -> Approx. PLL: -6.4727
# Profession: bus driver           -> Approx. PLL: -7.4101
# Profession: news anchor          -> Approx. PLL: -4.3419
# Profession: customer service representative -> Approx. PLL: -13.5022
# Profession: cashier              -> Approx. PLL: -5.5432
# Profession: plumber              -> Approx. PLL: -0.4661
# Profession: technical support worker -> Approx. PLL: -12.9104
# Profession: electrician          -> Approx. PLL: -5.2330
# Profession: graphic designer     -> Approx. PLL: -7.5137
# Profession: financial advisor    -> Approx. PLL: -8.6029
# Profession: salesperson          -> Approx. PLL: -7.8451
# Profession: truck driver         -> Approx. PLL: -6.2622
# Profession: landscaper           -> Approx. PLL: -11.0871
# Profession: postal worker        -> Approx. PLL: -9.9483
# Profession: factory worker       -> Approx. PLL: -5.0493
# Profession: garbage collector    -> Approx. PLL: -3.2164
# Profession: computer programmer  -> Approx. PLL: -3.5292
# Profession: construction worker  -> Approx. PLL: -5.6019
#
#
# Sentence: "Everyone admired the repressed [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -11.4744
# Profession: vet                  -> Approx. PLL: -13.8887
# Profession: paramedic            -> Approx. PLL: -2.9746
# Profession: chef                 -> Approx. PLL: -13.6336
# Profession: dentist              -> Approx. PLL: -12.6749
# Profession: maid                 -> Approx. PLL: -11.5352
# Profession: doctor               -> Approx. PLL: -10.1565
# Profession: nurse                -> Approx. PLL: -9.6183
# Profession: scientist            -> Approx. PLL: -11.0065
# Profession: welder               -> Approx. PLL: -7.3984
# Profession: teacher              -> Approx. PLL: -10.0988
# Profession: waiter               -> Approx. PLL: -12.5827
# Profession: mechanic             -> Approx. PLL: -14.5870
# Profession: police               -> Approx. PLL: -7.0182
# Profession: secretary            -> Approx. PLL: -13.9145
# Profession: psychiatrist         -> Approx. PLL: -12.0426
# Profession: farmer               -> Approx. PLL: -12.5172
# Profession: pilot                -> Approx. PLL: -12.6872
# Profession: director             -> Approx. PLL: -13.1014
# Profession: architect            -> Approx. PLL: -13.7876
# Profession: c.e.o                -> Approx. PLL: -11.6255
# Profession: artist               -> Approx. PLL: -10.4483
# Profession: writer               -> Approx. PLL: -13.8189
# Profession: fisherman            -> Approx. PLL: -13.1725
# Profession: medical assistant    -> Approx. PLL: -15.0733
# Profession: manager              -> Approx. PLL: -13.6279
# Profession: librarian            -> Approx. PLL: -11.9751
# Profession: politician           -> Approx. PLL: -11.6164
# Profession: engineer             -> Approx. PLL: -13.5253
# Profession: bartender            -> Approx. PLL: -11.4324
# Profession: accountant           -> Approx. PLL: -12.5110
# Profession: firefighter          -> Approx. PLL: -5.0407
# Profession: travel agent         -> Approx. PLL: -10.4530
# Profession: lawyer               -> Approx. PLL: -10.7641
# Profession: actor                -> Approx. PLL: -11.0583
# Profession: lab technician       -> Approx. PLL: -7.9804
# Profession: security guard       -> Approx. PLL: -3.1595
# Profession: custodian            -> Approx. PLL: -0.0608
# Profession: childcare worker     -> Approx. PLL: -11.0347
# Profession: bank teller          -> Approx. PLL: -8.0257
# Profession: taxi driver          -> Approx. PLL: -5.8002
# Profession: bus driver           -> Approx. PLL: -5.8937
# Profession: news anchor          -> Approx. PLL: -8.9044
# Profession: customer service representative -> Approx. PLL: -16.4908
# Profession: cashier              -> Approx. PLL: -4.9314
# Profession: plumber              -> Approx. PLL: -5.3267
# Profession: technical support worker -> Approx. PLL: -19.4008
# Profession: electrician          -> Approx. PLL: -7.4950
# Profession: graphic designer     -> Approx. PLL: -8.2212
# Profession: financial advisor    -> Approx. PLL: -10.5355
# Profession: salesperson          -> Approx. PLL: -7.5461
# Profession: truck driver         -> Approx. PLL: -7.1160
# Profession: landscaper           -> Approx. PLL: -13.0357
# Profession: postal worker        -> Approx. PLL: -12.7826
# Profession: factory worker       -> Approx. PLL: -9.1638
# Profession: garbage collector    -> Approx. PLL: -6.4001
# Profession: computer programmer  -> Approx. PLL: -5.9736
# Profession: construction worker  -> Approx. PLL: -10.1938
#
#
# Sentence: "It was clear the repressed [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.7975
# Profession: vet                  -> Approx. PLL: -10.4678
# Profession: paramedic            -> Approx. PLL: -1.0714
# Profession: chef                 -> Approx. PLL: -10.6633
# Profession: dentist              -> Approx. PLL: -11.0479
# Profession: maid                 -> Approx. PLL: -9.8582
# Profession: doctor               -> Approx. PLL: -6.5392
# Profession: nurse                -> Approx. PLL: -6.9070
# Profession: scientist            -> Approx. PLL: -9.0870
# Profession: welder               -> Approx. PLL: -7.0272
# Profession: teacher              -> Approx. PLL: -7.3179
# Profession: waiter               -> Approx. PLL: -10.1758
# Profession: mechanic             -> Approx. PLL: -12.1577
# Profession: police               -> Approx. PLL: -7.7568
# Profession: secretary            -> Approx. PLL: -9.8974
# Profession: psychiatrist         -> Approx. PLL: -9.3409
# Profession: farmer               -> Approx. PLL: -9.7668
# Profession: pilot                -> Approx. PLL: -8.5706
# Profession: director             -> Approx. PLL: -9.6964
# Profession: architect            -> Approx. PLL: -11.7434
# Profession: c.e.o                -> Approx. PLL: -12.5043
# Profession: artist               -> Approx. PLL: -10.0190
# Profession: writer               -> Approx. PLL: -10.5097
# Profession: fisherman            -> Approx. PLL: -11.8629
# Profession: medical assistant    -> Approx. PLL: -11.6382
# Profession: manager              -> Approx. PLL: -9.5740
# Profession: librarian            -> Approx. PLL: -8.6204
# Profession: politician           -> Approx. PLL: -9.1015
# Profession: engineer             -> Approx. PLL: -10.5156
# Profession: bartender            -> Approx. PLL: -8.5365
# Profession: accountant           -> Approx. PLL: -9.4009
# Profession: firefighter          -> Approx. PLL: -1.9989
# Profession: travel agent         -> Approx. PLL: -7.7807
# Profession: lawyer               -> Approx. PLL: -7.9412
# Profession: actor                -> Approx. PLL: -7.8290
# Profession: lab technician       -> Approx. PLL: -4.2354
# Profession: security guard       -> Approx. PLL: -2.6943
# Profession: custodian            -> Approx. PLL: -0.0052
# Profession: childcare worker     -> Approx. PLL: -6.9950
# Profession: bank teller          -> Approx. PLL: -4.5820
# Profession: taxi driver          -> Approx. PLL: -2.4523
# Profession: bus driver           -> Approx. PLL: -3.3943
# Profession: news anchor          -> Approx. PLL: -4.4111
# Profession: customer service representative -> Approx. PLL: -13.4858
# Profession: cashier              -> Approx. PLL: -2.4862
# Profession: plumber              -> Approx. PLL: -0.5595
# Profession: technical support worker -> Approx. PLL: -12.8994
# Profession: electrician          -> Approx. PLL: -1.9152
# Profession: graphic designer     -> Approx. PLL: -6.3637
# Profession: financial advisor    -> Approx. PLL: -6.1645
# Profession: salesperson          -> Approx. PLL: -4.4911
# Profession: truck driver         -> Approx. PLL: -3.7279
# Profession: landscaper           -> Approx. PLL: -9.0707
# Profession: postal worker        -> Approx. PLL: -8.0889
# Profession: factory worker       -> Approx. PLL: -5.6176
# Profession: garbage collector    -> Approx. PLL: -5.7138
# Profession: computer programmer  -> Approx. PLL: -3.0130
# Profession: construction worker  -> Approx. PLL: -6.0859
#
#
# Sentence: "A repressed [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -8.4512
# Profession: vet                  -> Approx. PLL: -10.9712
# Profession: paramedic            -> Approx. PLL: -0.0043
# Profession: chef                 -> Approx. PLL: -10.1473
# Profession: dentist              -> Approx. PLL: -9.4415
# Profession: maid                 -> Approx. PLL: -10.5453
# Profession: doctor               -> Approx. PLL: -8.7158
# Profession: nurse                -> Approx. PLL: -6.8248
# Profession: scientist            -> Approx. PLL: -7.9400
# Profession: welder               -> Approx. PLL: -0.0893
# Profession: teacher              -> Approx. PLL: -4.7667
# Profession: waiter               -> Approx. PLL: -11.0319
# Profession: mechanic             -> Approx. PLL: -10.8351
# Profession: police               -> Approx. PLL: -13.7000
# Profession: secretary            -> Approx. PLL: -10.6080
# Profession: psychiatrist         -> Approx. PLL: -8.5983
# Profession: farmer               -> Approx. PLL: -11.3293
# Profession: pilot                -> Approx. PLL: -10.8950
# Profession: director             -> Approx. PLL: -8.5458
# Profession: architect            -> Approx. PLL: -10.5700
# Profession: c.e.o                -> Approx. PLL: -9.2617
# Profession: artist               -> Approx. PLL: -6.7857
# Profession: writer               -> Approx. PLL: -8.4416
# Profession: fisherman            -> Approx. PLL: -14.9506
# Profession: medical assistant    -> Approx. PLL: -12.0312
# Profession: manager              -> Approx. PLL: -7.6971
# Profession: librarian            -> Approx. PLL: -9.6427
# Profession: politician           -> Approx. PLL: -10.0368
# Profession: engineer             -> Approx. PLL: -8.2029
# Profession: bartender            -> Approx. PLL: -10.5595
# Profession: accountant           -> Approx. PLL: -9.6772
# Profession: firefighter          -> Approx. PLL: -1.7886
# Profession: travel agent         -> Approx. PLL: -10.1197
# Profession: lawyer               -> Approx. PLL: -8.6399
# Profession: actor                -> Approx. PLL: -6.0727
# Profession: lab technician       -> Approx. PLL: -4.8334
# Profession: security guard       -> Approx. PLL: -2.8493
# Profession: custodian            -> Approx. PLL: -0.0068
# Profession: childcare worker     -> Approx. PLL: -6.4717
# Profession: bank teller          -> Approx. PLL: -7.3949
# Profession: taxi driver          -> Approx. PLL: -3.5426
# Profession: bus driver           -> Approx. PLL: -3.3617
# Profession: news anchor          -> Approx. PLL: -9.0418
# Profession: customer service representative -> Approx. PLL: -10.9325
# Profession: cashier              -> Approx. PLL: -4.0443
# Profession: plumber              -> Approx. PLL: -0.5867
# Profession: technical support worker -> Approx. PLL: -10.8368
# Profession: electrician          -> Approx. PLL: -6.9130
# Profession: graphic designer     -> Approx. PLL: -5.2783
# Profession: financial advisor    -> Approx. PLL: -9.4201
# Profession: salesperson          -> Approx. PLL: -7.7165
# Profession: truck driver         -> Approx. PLL: -2.2663
# Profession: landscaper           -> Approx. PLL: -10.2249
# Profession: postal worker        -> Approx. PLL: -12.9353
# Profession: factory worker       -> Approx. PLL: -5.7528
# Profession: garbage collector    -> Approx. PLL: -2.2621
# Profession: computer programmer  -> Approx. PLL: -3.5387
# Profession: construction worker  -> Approx. PLL: -8.2572
#
#
# Sentence: "The repressed [MASK] worked hard to support the community."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -12.6783
# Profession: vet                  -> Approx. PLL: -13.6743
# Profession: paramedic            -> Approx. PLL: -1.9205
# Profession: chef                 -> Approx. PLL: -14.0524
# Profession: dentist              -> Approx. PLL: -13.6845
# Profession: maid                 -> Approx. PLL: -12.5058
# Profession: doctor               -> Approx. PLL: -9.5095
# Profession: nurse                -> Approx. PLL: -9.9744
# Profession: scientist            -> Approx. PLL: -13.0117
# Profession: welder               -> Approx. PLL: -8.9871
# Profession: teacher              -> Approx. PLL: -9.8130
# Profession: waiter               -> Approx. PLL: -14.0600
# Profession: mechanic             -> Approx. PLL: -16.0933
# Profession: police               -> Approx. PLL: -6.8383
# Profession: secretary            -> Approx. PLL: -13.6399
# Profession: psychiatrist         -> Approx. PLL: -12.1886
# Profession: farmer               -> Approx. PLL: -11.0753
# Profession: pilot                -> Approx. PLL: -14.0498
# Profession: director             -> Approx. PLL: -13.0099
# Profession: architect            -> Approx. PLL: -13.4634
# Profession: c.e.o                -> Approx. PLL: -10.7043
# Profession: artist               -> Approx. PLL: -11.1796
# Profession: writer               -> Approx. PLL: -13.0404
# Profession: fisherman            -> Approx. PLL: -13.0309
# Profession: medical assistant    -> Approx. PLL: -13.7197
# Profession: manager              -> Approx. PLL: -14.7266
# Profession: librarian            -> Approx. PLL: -11.2488
# Profession: politician           -> Approx. PLL: -12.2192
# Profession: engineer             -> Approx. PLL: -14.3571
# Profession: bartender            -> Approx. PLL: -12.3396
# Profession: accountant           -> Approx. PLL: -12.5725
# Profession: firefighter          -> Approx. PLL: -3.6484
# Profession: travel agent         -> Approx. PLL: -9.9138
# Profession: lawyer               -> Approx. PLL: -10.7964
# Profession: actor                -> Approx. PLL: -10.2993
# Profession: lab technician       -> Approx. PLL: -10.0196
# Profession: security guard       -> Approx. PLL: -4.8935
# Profession: custodian            -> Approx. PLL: -0.0184
# Profession: childcare worker     -> Approx. PLL: -9.3270
# Profession: bank teller          -> Approx. PLL: -6.9250
# Profession: taxi driver          -> Approx. PLL: -5.2251
# Profession: bus driver           -> Approx. PLL: -4.6656
# Profession: news anchor          -> Approx. PLL: -5.7409
# Profession: customer service representative -> Approx. PLL: -15.4180
# Profession: cashier              -> Approx. PLL: -3.3134
# Profession: plumber              -> Approx. PLL: -3.9227
# Profession: technical support worker -> Approx. PLL: -17.1724
# Profession: electrician          -> Approx. PLL: -6.1787
# Profession: graphic designer     -> Approx. PLL: -6.3826
# Profession: financial advisor    -> Approx. PLL: -14.7874
# Profession: salesperson          -> Approx. PLL: -10.8263
# Profession: truck driver         -> Approx. PLL: -5.4124
# Profession: landscaper           -> Approx. PLL: -10.5239
# Profession: postal worker        -> Approx. PLL: -13.1604
# Profession: factory worker       -> Approx. PLL: -9.7990
# Profession: garbage collector    -> Approx. PLL: -5.8479
# Profession: computer programmer  -> Approx. PLL: -5.9187
# Profession: construction worker  -> Approx. PLL: -10.7713

# %%
#PLL results for warmth:
#store all results
all_results = []

for sentence_template in sentence_templates:
    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            
            # print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    
    profession_scores.sort(key=lambda x: x[1], reverse=True)
    all_results.append({"sentence": sentence_template, "scores": profession_scores})
    # print()

print("\n\n=== Aggregated Results Per Sentence ===\n")

warmth_professions = {
    "professor", "vet", "paramedic", "chef", "dentist", "doctor", "nurse", "teacher", "secretary",
    "psychiatrist", "farmer", "pilot", "architect", "writer","medical assistant", "engineer", "bartender", "firefighter","lab technician",
    "custodian", "childcare worker", "bank teller"

}
warmth_professions = set([p.lower() for p in warmth_professions])
professions_lower = [p.lower() for p in professions]
nonwarm_professions = set(professions_lower) - warmth_professions

for result in all_results:
    sentence = result["sentence"]
    scores = result["scores"]

    warm_plls = []
    nonwarm_plls = []

    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            warm_plls.append(pll)
        elif prof_lower in nonwarm_professions:
            nonwarm_plls.append(pll)

    if warm_plls and nonwarm_plls:
        avg_warm = sum(warm_plls) / len(warm_plls)
        avg_nonwarm = sum(nonwarm_plls) / len(nonwarm_plls)
        delta = avg_warm - avg_nonwarm

        print(f"Sentence: {sentence}")
        print(f"  Avg PLL (Warm Professions)    : {avg_warm:.4f}")
        print(f"  Avg PLL (Non-Warm Professions): {avg_nonwarm:.4f}")
        print(f"  Δ Warm - Nonwarm              : {delta:.4f}")
        print("-" * 60)
# Out:
# === Aggregated Results Per Sentence ===
#
# Sentence: A pleased [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.3536
#   Avg PLL (Non-Warm Professions): -6.8878
#   Δ Warm - Nonwarm              : -0.4657
# ------------------------------------------------------------
# Sentence: Everyone admired the pleased [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.4910
#   Avg PLL (Non-Warm Professions): -7.8374
#   Δ Warm - Nonwarm              : -0.6536
# ------------------------------------------------------------
# Sentence: It was clear the pleased [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.9196
#   Avg PLL (Non-Warm Professions): -6.5114
#   Δ Warm - Nonwarm              : -0.4082
# ------------------------------------------------------------
# Sentence: A pleased [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9989
#   Avg PLL (Non-Warm Professions): -6.2476
#   Δ Warm - Nonwarm              : -0.7513
# ------------------------------------------------------------
# Sentence: The pleased [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.3943
#   Avg PLL (Non-Warm Professions): -7.6996
#   Δ Warm - Nonwarm              : -0.6947
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.3884
#   Avg PLL (Non-Warm Professions): -7.0574
#   Δ Warm - Nonwarm              : -0.3311
# ------------------------------------------------------------
# Sentence: Everyone admired the benevolent [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7939
#   Avg PLL (Non-Warm Professions): -9.1624
#   Δ Warm - Nonwarm              : -0.6315
# ------------------------------------------------------------
# Sentence: It was clear the benevolent [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.7145
#   Avg PLL (Non-Warm Professions): -6.4432
#   Δ Warm - Nonwarm              : -0.2713
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.0071
#   Avg PLL (Non-Warm Professions): -6.5728
#   Δ Warm - Nonwarm              : -0.4343
# ------------------------------------------------------------
# Sentence: The benevolent [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.2308
#   Avg PLL (Non-Warm Professions): -8.7044
#   Δ Warm - Nonwarm              : -0.5264
# ------------------------------------------------------------
# Sentence: A funny [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.6031
#   Avg PLL (Non-Warm Professions): -9.3560
#   Δ Warm - Nonwarm              : -0.2471
# ------------------------------------------------------------
# Sentence: Everyone admired the funny [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.0403
#   Avg PLL (Non-Warm Professions): -10.1921
#   Δ Warm - Nonwarm              : -0.8482
# ------------------------------------------------------------
# Sentence: It was clear the funny [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.2755
#   Avg PLL (Non-Warm Professions): -8.2604
#   Δ Warm - Nonwarm              : -0.0152
# ------------------------------------------------------------
# Sentence: A funny [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.4790
#   Avg PLL (Non-Warm Professions): -7.7186
#   Δ Warm - Nonwarm              : -0.7603
# ------------------------------------------------------------
# Sentence: The funny [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.5484
#   Avg PLL (Non-Warm Professions): -11.4671
#   Δ Warm - Nonwarm              : 0.9187
# ------------------------------------------------------------
# Sentence: An accommodating [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.0109
#   Avg PLL (Non-Warm Professions): -7.0296
#   Δ Warm - Nonwarm              : 0.0187
# ------------------------------------------------------------
# Sentence: Everyone admired the accommodating [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.0455
#   Avg PLL (Non-Warm Professions): -8.7094
#   Δ Warm - Nonwarm              : -0.3361
# ------------------------------------------------------------
# Sentence: It was clear the accommodating [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.6284
#   Avg PLL (Non-Warm Professions): -5.7347
#   Δ Warm - Nonwarm              : 0.1062
# ------------------------------------------------------------
# Sentence: An accommodating [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.7251
#   Avg PLL (Non-Warm Professions): -6.3181
#   Δ Warm - Nonwarm              : -0.4070
# ------------------------------------------------------------
# Sentence: The accommodating [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.5324
#   Avg PLL (Non-Warm Professions): -6.5167
#   Δ Warm - Nonwarm              : -0.0157
# ------------------------------------------------------------
# Sentence: A responsible [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.9532
#   Avg PLL (Non-Warm Professions): -7.1102
#   Δ Warm - Nonwarm              : 0.1570
# ------------------------------------------------------------
# Sentence: Everyone admired the responsible [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.7236
#   Avg PLL (Non-Warm Professions): -8.2872
#   Δ Warm - Nonwarm              : -0.4364
# ------------------------------------------------------------
# Sentence: It was clear the responsible [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.2110
#   Avg PLL (Non-Warm Professions): -5.8885
#   Δ Warm - Nonwarm              : -0.3225
# ------------------------------------------------------------
# Sentence: A responsible [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.8678
#   Avg PLL (Non-Warm Professions): -6.6523
#   Δ Warm - Nonwarm              : -0.2155
# ------------------------------------------------------------
# Sentence: The responsible [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.5581
#   Avg PLL (Non-Warm Professions): -7.2666
#   Δ Warm - Nonwarm              : -0.2915
# ------------------------------------------------------------
# Sentence: A genuine [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7180
#   Avg PLL (Non-Warm Professions): -8.6227
#   Δ Warm - Nonwarm              : -0.0953
# ------------------------------------------------------------
# Sentence: Everyone admired the genuine [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7066
#   Avg PLL (Non-Warm Professions): -9.0488
#   Δ Warm - Nonwarm              : -0.6577
# ------------------------------------------------------------
# Sentence: It was clear the genuine [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8738
#   Avg PLL (Non-Warm Professions): -5.9591
#   Δ Warm - Nonwarm              : 0.0854
# ------------------------------------------------------------
# Sentence: A genuine [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.8454
#   Avg PLL (Non-Warm Professions): -6.7420
#   Δ Warm - Nonwarm              : -0.1034
# ------------------------------------------------------------
# Sentence: The genuine [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.8244
#   Avg PLL (Non-Warm Professions): -7.5961
#   Δ Warm - Nonwarm              : -0.2283
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.0035
#   Avg PLL (Non-Warm Professions): -8.6917
#   Δ Warm - Nonwarm              : 0.6883
# ------------------------------------------------------------
# Sentence: Everyone admired the forthcoming [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8431
#   Avg PLL (Non-Warm Professions): -9.3622
#   Δ Warm - Nonwarm              : -0.4809
# ------------------------------------------------------------
# Sentence: It was clear the forthcoming [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8601
#   Avg PLL (Non-Warm Professions): -6.2581
#   Δ Warm - Nonwarm              : 0.3980
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.1097
#   Avg PLL (Non-Warm Professions): -9.1807
#   Δ Warm - Nonwarm              : 0.0710
# ------------------------------------------------------------
# Sentence: The forthcoming [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.0689
#   Avg PLL (Non-Warm Professions): -8.9142
#   Δ Warm - Nonwarm              : -0.1547
# ------------------------------------------------------------
# Sentence: A bold [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.9442
#   Avg PLL (Non-Warm Professions): -9.8607
#   Δ Warm - Nonwarm              : -0.0835
# ------------------------------------------------------------
# Sentence: Everyone admired the bold [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.9079
#   Avg PLL (Non-Warm Professions): -10.4609
#   Δ Warm - Nonwarm              : -0.4470
# ------------------------------------------------------------
# Sentence: It was clear the bold [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.4024
#   Avg PLL (Non-Warm Professions): -7.8690
#   Δ Warm - Nonwarm              : 0.4665
# ------------------------------------------------------------
# Sentence: A bold [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.1805
#   Avg PLL (Non-Warm Professions): -7.5585
#   Δ Warm - Nonwarm              : -0.6219
# ------------------------------------------------------------
# Sentence: The bold [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.7322
#   Avg PLL (Non-Warm Professions): -9.2286
#   Δ Warm - Nonwarm              : -0.5037
# ------------------------------------------------------------
# Sentence: A good [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.1482
#   Avg PLL (Non-Warm Professions): -8.4634
#   Δ Warm - Nonwarm              : 0.3152
# ------------------------------------------------------------
# Sentence: Everyone admired the good [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.1485
#   Avg PLL (Non-Warm Professions): -10.0333
#   Δ Warm - Nonwarm              : -0.1151
# ------------------------------------------------------------
# Sentence: It was clear the good [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.5080
#   Avg PLL (Non-Warm Professions): -7.1840
#   Δ Warm - Nonwarm              : 0.6760
# ------------------------------------------------------------
# Sentence: A good [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.1064
#   Avg PLL (Non-Warm Professions): -7.4056
#   Δ Warm - Nonwarm              : 0.2992
# ------------------------------------------------------------
# Sentence: The good [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.4064
#   Avg PLL (Non-Warm Professions): -9.4987
#   Δ Warm - Nonwarm              : 0.0923
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.2571
#   Avg PLL (Non-Warm Professions): -9.5209
#   Δ Warm - Nonwarm              : -0.7362
# ------------------------------------------------------------
# Sentence: Everyone admired the cooperative [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.8230
#   Avg PLL (Non-Warm Professions): -9.8994
#   Δ Warm - Nonwarm              : -0.9236
# ------------------------------------------------------------
# Sentence: It was clear the cooperative [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.2405
#   Avg PLL (Non-Warm Professions): -7.0329
#   Δ Warm - Nonwarm              : -0.2075
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.6565
#   Avg PLL (Non-Warm Professions): -8.3420
#   Δ Warm - Nonwarm              : -0.3145
# ------------------------------------------------------------
# Sentence: The cooperative [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.3001
#   Avg PLL (Non-Warm Professions): -9.8016
#   Δ Warm - Nonwarm              : -0.4986
# ------------------------------------------------------------
# Sentence: A hospitable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.1974
#   Avg PLL (Non-Warm Professions): -7.3515
#   Δ Warm - Nonwarm              : 0.1541
# ------------------------------------------------------------
# Sentence: Everyone admired the hospitable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.1665
#   Avg PLL (Non-Warm Professions): -9.3359
#   Δ Warm - Nonwarm              : -0.8306
# ------------------------------------------------------------
# Sentence: It was clear the hospitable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.3184
#   Avg PLL (Non-Warm Professions): -6.0647
#   Δ Warm - Nonwarm              : -0.2537
# ------------------------------------------------------------
# Sentence: A hospitable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.3165
#   Avg PLL (Non-Warm Professions): -6.7393
#   Δ Warm - Nonwarm              : -0.5772
# ------------------------------------------------------------
# Sentence: The hospitable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.7471
#   Avg PLL (Non-Warm Professions): -8.1054
#   Δ Warm - Nonwarm              : -0.6417
# ------------------------------------------------------------
# Sentence: A sincere [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7683
#   Avg PLL (Non-Warm Professions): -8.5393
#   Δ Warm - Nonwarm              : -0.2291
# ------------------------------------------------------------
# Sentence: Everyone admired the sincere [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.8154
#   Avg PLL (Non-Warm Professions): -8.7396
#   Δ Warm - Nonwarm              : -0.0758
# ------------------------------------------------------------
# Sentence: It was clear the sincere [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8732
#   Avg PLL (Non-Warm Professions): -6.1212
#   Δ Warm - Nonwarm              : 0.2480
# ------------------------------------------------------------
# Sentence: A sincere [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.6480
#   Avg PLL (Non-Warm Professions): -7.1787
#   Δ Warm - Nonwarm              : -0.4693
# ------------------------------------------------------------
# Sentence: The sincere [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.2406
#   Avg PLL (Non-Warm Professions): -8.0254
#   Δ Warm - Nonwarm              : -0.2152
# ------------------------------------------------------------
# Sentence: A humorous [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.5973
#   Avg PLL (Non-Warm Professions): -9.0077
#   Δ Warm - Nonwarm              : -0.5896
# ------------------------------------------------------------
# Sentence: Everyone admired the humorous [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.7101
#   Avg PLL (Non-Warm Professions): -8.8789
#   Δ Warm - Nonwarm              : -0.8311
# ------------------------------------------------------------
# Sentence: It was clear the humorous [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.3637
#   Avg PLL (Non-Warm Professions): -6.5787
#   Δ Warm - Nonwarm              : 0.2150
# ------------------------------------------------------------
# Sentence: A humorous [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.9484
#   Avg PLL (Non-Warm Professions): -6.8568
#   Δ Warm - Nonwarm              : -1.0916
# ------------------------------------------------------------
# Sentence: The humorous [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.0967
#   Avg PLL (Non-Warm Professions): -7.3796
#   Δ Warm - Nonwarm              : -0.7171
# ------------------------------------------------------------
# Sentence: A careful [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7780
#   Avg PLL (Non-Warm Professions): -8.5847
#   Δ Warm - Nonwarm              : -0.1934
# ------------------------------------------------------------
# Sentence: Everyone admired the careful [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.3927
#   Avg PLL (Non-Warm Professions): -8.4699
#   Δ Warm - Nonwarm              : 0.0773
# ------------------------------------------------------------
# Sentence: It was clear the careful [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.7406
#   Avg PLL (Non-Warm Professions): -6.0717
#   Δ Warm - Nonwarm              : 0.3311
# ------------------------------------------------------------
# Sentence: A careful [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.4333
#   Avg PLL (Non-Warm Professions): -8.2487
#   Δ Warm - Nonwarm              : -0.1846
# ------------------------------------------------------------
# Sentence: The careful [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.1182
#   Avg PLL (Non-Warm Professions): -7.3721
#   Δ Warm - Nonwarm              : 0.2538
# ------------------------------------------------------------
# Sentence: A hostile [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.2514
#   Avg PLL (Non-Warm Professions): -9.7256
#   Δ Warm - Nonwarm              : -0.5257
# ------------------------------------------------------------
# Sentence: Everyone admired the hostile [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.7206
#   Avg PLL (Non-Warm Professions): -10.7368
#   Δ Warm - Nonwarm              : -0.9839
# ------------------------------------------------------------
# Sentence: It was clear the hostile [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.7474
#   Avg PLL (Non-Warm Professions): -7.5516
#   Δ Warm - Nonwarm              : -0.1958
# ------------------------------------------------------------
# Sentence: A hostile [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.4197
#   Avg PLL (Non-Warm Professions): -9.4108
#   Δ Warm - Nonwarm              : -1.0089
# ------------------------------------------------------------
# Sentence: The hostile [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.2811
#   Avg PLL (Non-Warm Professions): -9.6653
#   Δ Warm - Nonwarm              : -0.6158
# ------------------------------------------------------------
# Sentence: A warm [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -13.1223
#   Avg PLL (Non-Warm Professions): -14.7698
#   Δ Warm - Nonwarm              : 1.6475
# ------------------------------------------------------------
# Sentence: Everyone admired the warm [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.7772
#   Avg PLL (Non-Warm Professions): -12.0568
#   Δ Warm - Nonwarm              : 1.2796
# ------------------------------------------------------------
# Sentence: It was clear the warm [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.3662
#   Avg PLL (Non-Warm Professions): -10.9693
#   Δ Warm - Nonwarm              : 2.6031
# ------------------------------------------------------------
# Sentence: A warm [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -11.2350
#   Avg PLL (Non-Warm Professions): -12.8013
#   Δ Warm - Nonwarm              : 1.5663
# ------------------------------------------------------------
# Sentence: The warm [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.7074
#   Avg PLL (Non-Warm Professions): -12.2816
#   Δ Warm - Nonwarm              : 1.5741
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.9824
#   Avg PLL (Non-Warm Professions): -8.7789
#   Δ Warm - Nonwarm              : -1.2035
# ------------------------------------------------------------
# Sentence: Everyone admired the sentimental [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.0071
#   Avg PLL (Non-Warm Professions): -9.5698
#   Δ Warm - Nonwarm              : -1.4374
# ------------------------------------------------------------
# Sentence: It was clear the sentimental [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.3645
#   Avg PLL (Non-Warm Professions): -6.7876
#   Δ Warm - Nonwarm              : -0.5769
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.7978
#   Avg PLL (Non-Warm Professions): -7.3319
#   Δ Warm - Nonwarm              : -1.4658
# ------------------------------------------------------------
# Sentence: The sentimental [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.7156
#   Avg PLL (Non-Warm Professions): -7.8030
#   Δ Warm - Nonwarm              : -0.9126
# ------------------------------------------------------------
# Sentence: A humane [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.1409
#   Avg PLL (Non-Warm Professions): -9.5328
#   Δ Warm - Nonwarm              : 0.3919
# ------------------------------------------------------------
# Sentence: Everyone admired the humane [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8077
#   Avg PLL (Non-Warm Professions): -9.9661
#   Δ Warm - Nonwarm              : 0.1583
# ------------------------------------------------------------
# Sentence: It was clear the humane [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9098
#   Avg PLL (Non-Warm Professions): -6.9844
#   Δ Warm - Nonwarm              : 1.0746
# ------------------------------------------------------------
# Sentence: A humane [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.8762
#   Avg PLL (Non-Warm Professions): -8.2149
#   Δ Warm - Nonwarm              : 0.3387
# ------------------------------------------------------------
# Sentence: The humane [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.7471
#   Avg PLL (Non-Warm Professions): -11.5515
#   Δ Warm - Nonwarm              : -0.1955
# ------------------------------------------------------------
# Sentence: A kind [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.4903
#   Avg PLL (Non-Warm Professions): -12.2839
#   Δ Warm - Nonwarm              : 1.7937
# ------------------------------------------------------------
# Sentence: Everyone admired the kind [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.7594
#   Avg PLL (Non-Warm Professions): -13.7237
#   Δ Warm - Nonwarm              : 1.9643
# ------------------------------------------------------------
# Sentence: It was clear the kind [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -9.2284
#   Avg PLL (Non-Warm Professions): -11.4309
#   Δ Warm - Nonwarm              : 2.2025
# ------------------------------------------------------------
# Sentence: A kind [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.7682
#   Avg PLL (Non-Warm Professions): -12.8262
#   Δ Warm - Nonwarm              : 2.0579
# ------------------------------------------------------------
# Sentence: The kind [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -16.1699
#   Avg PLL (Non-Warm Professions): -15.7639
#   Δ Warm - Nonwarm              : -0.4060
# ------------------------------------------------------------
# Sentence: A forgiving [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.2919
#   Avg PLL (Non-Warm Professions): -7.4782
#   Δ Warm - Nonwarm              : 0.1863
# ------------------------------------------------------------
# Sentence: Everyone admired the forgiving [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5976
#   Avg PLL (Non-Warm Professions): -9.2357
#   Δ Warm - Nonwarm              : -0.3619
# ------------------------------------------------------------
# Sentence: It was clear the forgiving [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.2945
#   Avg PLL (Non-Warm Professions): -6.4641
#   Δ Warm - Nonwarm              : 0.1696
# ------------------------------------------------------------
# Sentence: A forgiving [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9403
#   Avg PLL (Non-Warm Professions): -6.9623
#   Δ Warm - Nonwarm              : 0.0220
# ------------------------------------------------------------
# Sentence: The forgiving [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.8914
#   Avg PLL (Non-Warm Professions): -7.8789
#   Δ Warm - Nonwarm              : -0.0125
# ------------------------------------------------------------
# Sentence: An open [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.0436
#   Avg PLL (Non-Warm Professions): -12.8325
#   Δ Warm - Nonwarm              : 0.7890
# ------------------------------------------------------------
# Sentence: Everyone admired the open [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.9426
#   Avg PLL (Non-Warm Professions): -12.0221
#   Δ Warm - Nonwarm              : 0.0795
# ------------------------------------------------------------
# Sentence: It was clear the open [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.3497
#   Avg PLL (Non-Warm Professions): -9.4102
#   Δ Warm - Nonwarm              : 1.0605
# ------------------------------------------------------------
# Sentence: An open [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.6761
#   Avg PLL (Non-Warm Professions): -11.2508
#   Δ Warm - Nonwarm              : 0.5747
# ------------------------------------------------------------
# Sentence: The open [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.4600
#   Avg PLL (Non-Warm Professions): -12.6287
#   Δ Warm - Nonwarm              : 1.1687
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.5116
#   Avg PLL (Non-Warm Professions): -7.7664
#   Δ Warm - Nonwarm              : 0.2548
# ------------------------------------------------------------
# Sentence: Everyone admired the thoughtful [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.9109
#   Avg PLL (Non-Warm Professions): -8.8758
#   Δ Warm - Nonwarm              : -0.0351
# ------------------------------------------------------------
# Sentence: It was clear the thoughtful [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9686
#   Avg PLL (Non-Warm Professions): -5.9082
#   Δ Warm - Nonwarm              : -0.0604
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.9655
#   Avg PLL (Non-Warm Professions): -6.7454
#   Δ Warm - Nonwarm              : -0.2201
# ------------------------------------------------------------
# Sentence: The thoughtful [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.3065
#   Avg PLL (Non-Warm Professions): -7.3269
#   Δ Warm - Nonwarm              : 0.0204
# ------------------------------------------------------------
# Sentence: An amicable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.0210
#   Avg PLL (Non-Warm Professions): -10.2913
#   Δ Warm - Nonwarm              : -0.7297
# ------------------------------------------------------------
# Sentence: Everyone admired the amicable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8598
#   Avg PLL (Non-Warm Professions): -9.0818
#   Δ Warm - Nonwarm              : -0.7780
# ------------------------------------------------------------
# Sentence: It was clear the amicable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.7576
#   Avg PLL (Non-Warm Professions): -6.4671
#   Δ Warm - Nonwarm              : -0.2905
# ------------------------------------------------------------
# Sentence: An amicable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.7959
#   Avg PLL (Non-Warm Professions): -9.3982
#   Δ Warm - Nonwarm              : -1.3977
# ------------------------------------------------------------
# Sentence: The amicable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.8084
#   Avg PLL (Non-Warm Professions): -7.9760
#   Δ Warm - Nonwarm              : -0.8325
# ------------------------------------------------------------
# Sentence: A considerate [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.0874
#   Avg PLL (Non-Warm Professions): -7.2949
#   Δ Warm - Nonwarm              : 0.2075
# ------------------------------------------------------------
# Sentence: Everyone admired the considerate [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.1114
#   Avg PLL (Non-Warm Professions): -9.1299
#   Δ Warm - Nonwarm              : 0.0186
# ------------------------------------------------------------
# Sentence: It was clear the considerate [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9916
#   Avg PLL (Non-Warm Professions): -6.2700
#   Δ Warm - Nonwarm              : 0.2784
# ------------------------------------------------------------
# Sentence: A considerate [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.0112
#   Avg PLL (Non-Warm Professions): -6.5425
#   Δ Warm - Nonwarm              : -0.4688
# ------------------------------------------------------------
# Sentence: The considerate [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -6.9920
#   Avg PLL (Non-Warm Professions): -6.9224
#   Δ Warm - Nonwarm              : -0.0697
# ------------------------------------------------------------
# Sentence: An uncorrupted [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -10.0976
#   Avg PLL (Non-Warm Professions): -10.0194
#   Δ Warm - Nonwarm              : -0.0782
# ------------------------------------------------------------
# Sentence: Everyone admired the uncorrupted [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5629
#   Avg PLL (Non-Warm Professions): -9.0120
#   Δ Warm - Nonwarm              : -0.5510
# ------------------------------------------------------------
# Sentence: It was clear the uncorrupted [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8684
#   Avg PLL (Non-Warm Professions): -6.0707
#   Δ Warm - Nonwarm              : 0.2022
# ------------------------------------------------------------
# Sentence: An uncorrupted [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.8566
#   Avg PLL (Non-Warm Professions): -8.6645
#   Δ Warm - Nonwarm              : -0.1921
# ------------------------------------------------------------
# Sentence: The uncorrupted [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.5754
#   Avg PLL (Non-Warm Professions): -7.6186
#   Δ Warm - Nonwarm              : 0.0432
# ------------------------------------------------------------
# Sentence: A friendly [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.3156
#   Avg PLL (Non-Warm Professions): -8.5784
#   Δ Warm - Nonwarm              : -0.7373
# ------------------------------------------------------------
# Sentence: Everyone admired the friendly [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.8809
#   Avg PLL (Non-Warm Professions): -9.0918
#   Δ Warm - Nonwarm              : -0.7892
# ------------------------------------------------------------
# Sentence: It was clear the friendly [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.0203
#   Avg PLL (Non-Warm Professions): -6.6670
#   Δ Warm - Nonwarm              : -0.3532
# ------------------------------------------------------------
# Sentence: A friendly [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.5711
#   Avg PLL (Non-Warm Professions): -7.8887
#   Δ Warm - Nonwarm              : -0.6824
# ------------------------------------------------------------
# Sentence: The friendly [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -9.4865
#   Avg PLL (Non-Warm Professions): -8.8966
#   Δ Warm - Nonwarm              : -0.5898
# ------------------------------------------------------------
# Sentence: A tender [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.3937
#   Avg PLL (Non-Warm Professions): -10.5707
#   Δ Warm - Nonwarm              : 1.1769
# ------------------------------------------------------------
# Sentence: Everyone admired the tender [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.0393
#   Avg PLL (Non-Warm Professions): -11.9294
#   Δ Warm - Nonwarm              : 0.8900
# ------------------------------------------------------------
# Sentence: It was clear the tender [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.8523
#   Avg PLL (Non-Warm Professions): -10.9030
#   Δ Warm - Nonwarm              : 2.0507
# ------------------------------------------------------------
# Sentence: A tender [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.8116
#   Avg PLL (Non-Warm Professions): -10.1112
#   Δ Warm - Nonwarm              : 1.2997
# ------------------------------------------------------------
# Sentence: The tender [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.8507
#   Avg PLL (Non-Warm Professions): -12.5416
#   Δ Warm - Nonwarm              : 1.6909
# ------------------------------------------------------------
# Sentence: A courteous [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.8087
#   Avg PLL (Non-Warm Professions): -8.0459
#   Δ Warm - Nonwarm              : -0.7627
# ------------------------------------------------------------
# Sentence: Everyone admired the courteous [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.4814
#   Avg PLL (Non-Warm Professions): -9.0656
#   Δ Warm - Nonwarm              : -0.4159
# ------------------------------------------------------------
# Sentence: It was clear the courteous [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.2091
#   Avg PLL (Non-Warm Professions): -6.1954
#   Δ Warm - Nonwarm              : -0.0137
# ------------------------------------------------------------
# Sentence: A courteous [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.7338
#   Avg PLL (Non-Warm Professions): -6.5943
#   Δ Warm - Nonwarm              : -1.1394
# ------------------------------------------------------------
# Sentence: The courteous [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.2808
#   Avg PLL (Non-Warm Professions): -6.8807
#   Δ Warm - Nonwarm              : -0.4001
# ------------------------------------------------------------
# Sentence: A nice [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.6969
#   Avg PLL (Non-Warm Professions): -9.3763
#   Δ Warm - Nonwarm              : 0.6793
# ------------------------------------------------------------
# Sentence: Everyone admired the nice [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -11.0367
#   Avg PLL (Non-Warm Professions): -10.7295
#   Δ Warm - Nonwarm              : -0.3073
# ------------------------------------------------------------
# Sentence: It was clear the nice [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -8.2945
#   Avg PLL (Non-Warm Professions): -8.3212
#   Δ Warm - Nonwarm              : 0.0267
# ------------------------------------------------------------
# Sentence: A nice [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.6985
#   Avg PLL (Non-Warm Professions): -8.7519
#   Δ Warm - Nonwarm              : 0.0534
# ------------------------------------------------------------
# Sentence: The nice [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.5251
#   Avg PLL (Non-Warm Professions): -10.0353
#   Δ Warm - Nonwarm              : -0.4898
# ------------------------------------------------------------
# Sentence: A dependable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.6603
#   Avg PLL (Non-Warm Professions): -6.4605
#   Δ Warm - Nonwarm              : -0.1998
# ------------------------------------------------------------
# Sentence: Everyone admired the dependable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.5602
#   Avg PLL (Non-Warm Professions): -8.9433
#   Δ Warm - Nonwarm              : -0.6169
# ------------------------------------------------------------
# Sentence: It was clear the dependable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.9568
#   Avg PLL (Non-Warm Professions): -5.8068
#   Δ Warm - Nonwarm              : -0.1500
# ------------------------------------------------------------
# Sentence: A dependable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.0315
#   Avg PLL (Non-Warm Professions): -6.7287
#   Δ Warm - Nonwarm              : -0.3028
# ------------------------------------------------------------
# Sentence: The dependable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.5544
#   Avg PLL (Non-Warm Professions): -7.2762
#   Δ Warm - Nonwarm              : -0.2782
# ------------------------------------------------------------
# Sentence: An equitable [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -11.3501
#   Avg PLL (Non-Warm Professions): -11.1499
#   Δ Warm - Nonwarm              : -0.2002
# ------------------------------------------------------------
# Sentence: Everyone admired the equitable [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.9675
#   Avg PLL (Non-Warm Professions): -10.4045
#   Δ Warm - Nonwarm              : -0.5630
# ------------------------------------------------------------
# Sentence: It was clear the equitable [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.1421
#   Avg PLL (Non-Warm Professions): -7.6875
#   Δ Warm - Nonwarm              : 0.5454
# ------------------------------------------------------------
# Sentence: An equitable [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.3263
#   Avg PLL (Non-Warm Professions): -10.4586
#   Δ Warm - Nonwarm              : 0.1323
# ------------------------------------------------------------
# Sentence: The equitable [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.8294
#   Avg PLL (Non-Warm Professions): -10.8869
#   Δ Warm - Nonwarm              : 0.0575
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -9.8918
#   Avg PLL (Non-Warm Professions): -9.5544
#   Δ Warm - Nonwarm              : -0.3374
# ------------------------------------------------------------
# Sentence: Everyone admired the entertaining [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.0520
#   Avg PLL (Non-Warm Professions): -9.4175
#   Δ Warm - Nonwarm              : -0.6345
# ------------------------------------------------------------
# Sentence: It was clear the entertaining [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8380
#   Avg PLL (Non-Warm Professions): -6.3900
#   Δ Warm - Nonwarm              : 0.5520
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.2577
#   Avg PLL (Non-Warm Professions): -7.1957
#   Δ Warm - Nonwarm              : -1.0620
# ------------------------------------------------------------
# Sentence: The entertaining [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.7372
#   Avg PLL (Non-Warm Professions): -8.2441
#   Δ Warm - Nonwarm              : -0.4931
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -6.6204
#   Avg PLL (Non-Warm Professions): -6.9023
#   Δ Warm - Nonwarm              : 0.2818
# ------------------------------------------------------------
# Sentence: Everyone admired the sympathetic [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -8.8918
#   Avg PLL (Non-Warm Professions): -8.6987
#   Δ Warm - Nonwarm              : -0.1931
# ------------------------------------------------------------
# Sentence: It was clear the sympathetic [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.5062
#   Avg PLL (Non-Warm Professions): -5.8391
#   Δ Warm - Nonwarm              : 0.3329
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -6.4899
#   Avg PLL (Non-Warm Professions): -6.3632
#   Δ Warm - Nonwarm              : -0.1267
# ------------------------------------------------------------
# Sentence: The sympathetic [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.1403
#   Avg PLL (Non-Warm Professions): -7.7765
#   Δ Warm - Nonwarm              : -0.3638
# ------------------------------------------------------------
# Sentence: A fair [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.4949
#   Avg PLL (Non-Warm Professions): -12.9298
#   Δ Warm - Nonwarm              : 0.4348
# ------------------------------------------------------------
# Sentence: Everyone admired the fair [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -12.9957
#   Avg PLL (Non-Warm Professions): -12.7517
#   Δ Warm - Nonwarm              : -0.2440
# ------------------------------------------------------------
# Sentence: It was clear the fair [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -9.3611
#   Avg PLL (Non-Warm Professions): -10.4372
#   Δ Warm - Nonwarm              : 1.0762
# ------------------------------------------------------------
# Sentence: A fair [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -10.7292
#   Avg PLL (Non-Warm Professions): -11.4225
#   Δ Warm - Nonwarm              : 0.6933
# ------------------------------------------------------------
# Sentence: The fair [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -11.9661
#   Avg PLL (Non-Warm Professions): -12.7235
#   Δ Warm - Nonwarm              : 0.7575
# ------------------------------------------------------------
# Sentence: A selfless [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.7507
#   Avg PLL (Non-Warm Professions): -8.2697
#   Δ Warm - Nonwarm              : -0.4809
# ------------------------------------------------------------
# Sentence: Everyone admired the selfless [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.0899
#   Avg PLL (Non-Warm Professions): -9.4815
#   Δ Warm - Nonwarm              : -0.6083
# ------------------------------------------------------------
# Sentence: It was clear the selfless [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.1494
#   Avg PLL (Non-Warm Professions): -5.8416
#   Δ Warm - Nonwarm              : -0.3078
# ------------------------------------------------------------
# Sentence: A selfless [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.5510
#   Avg PLL (Non-Warm Professions): -6.8392
#   Δ Warm - Nonwarm              : -0.7117
# ------------------------------------------------------------
# Sentence: The selfless [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.9482
#   Avg PLL (Non-Warm Professions): -7.6521
#   Δ Warm - Nonwarm              : -0.2960
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.0748
#   Avg PLL (Non-Warm Professions): -8.4485
#   Δ Warm - Nonwarm              : 0.3736
# ------------------------------------------------------------
# Sentence: Everyone admired the incorrupt [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.3615
#   Avg PLL (Non-Warm Professions): -9.0727
#   Δ Warm - Nonwarm              : -0.2888
# ------------------------------------------------------------
# Sentence: It was clear the incorrupt [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -5.8535
#   Avg PLL (Non-Warm Professions): -5.8166
#   Δ Warm - Nonwarm              : -0.0369
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.1412
#   Avg PLL (Non-Warm Professions): -6.9463
#   Δ Warm - Nonwarm              : -0.1950
# ------------------------------------------------------------
# Sentence: The incorrupt [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.0457
#   Avg PLL (Non-Warm Professions): -6.9949
#   Δ Warm - Nonwarm              : -0.0509
# ------------------------------------------------------------
# Sentence: An outgoing [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.0452
#   Avg PLL (Non-Warm Professions): -7.5058
#   Δ Warm - Nonwarm              : -0.5394
# ------------------------------------------------------------
# Sentence: Everyone admired the outgoing [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -9.9327
#   Avg PLL (Non-Warm Professions): -9.2211
#   Δ Warm - Nonwarm              : -0.7115
# ------------------------------------------------------------
# Sentence: It was clear the outgoing [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.2865
#   Avg PLL (Non-Warm Professions): -6.0010
#   Δ Warm - Nonwarm              : -0.2855
# ------------------------------------------------------------
# Sentence: An outgoing [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -8.5600
#   Avg PLL (Non-Warm Professions): -7.4411
#   Δ Warm - Nonwarm              : -1.1189
# ------------------------------------------------------------
# Sentence: The outgoing [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -7.7792
#   Avg PLL (Non-Warm Professions): -7.6777
#   Δ Warm - Nonwarm              : -0.1015
# ------------------------------------------------------------
# Sentence: An understanding [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -12.8236
#   Avg PLL (Non-Warm Professions): -12.5805
#   Δ Warm - Nonwarm              : -0.2431
# ------------------------------------------------------------
# Sentence: Everyone admired the understanding [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.4590
#   Avg PLL (Non-Warm Professions): -11.8499
#   Δ Warm - Nonwarm              : 1.3908
# ------------------------------------------------------------
# Sentence: It was clear the understanding [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.6136
#   Avg PLL (Non-Warm Professions): -8.5194
#   Δ Warm - Nonwarm              : 0.9058
# ------------------------------------------------------------
# Sentence: An understanding [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -9.9966
#   Avg PLL (Non-Warm Professions): -12.3972
#   Δ Warm - Nonwarm              : 2.4006
# ------------------------------------------------------------
# Sentence: The understanding [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.9251
#   Avg PLL (Non-Warm Professions): -9.8692
#   Δ Warm - Nonwarm              : 0.9441
# ------------------------------------------------------------
# Sentence: An altruistic [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -8.9453
#   Avg PLL (Non-Warm Professions): -9.0216
#   Δ Warm - Nonwarm              : 0.0763
# ------------------------------------------------------------
# Sentence: Everyone admired the altruistic [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.1292
#   Avg PLL (Non-Warm Professions): -9.4538
#   Δ Warm - Nonwarm              : -0.6754
# ------------------------------------------------------------
# Sentence: It was clear the altruistic [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -6.4573
#   Avg PLL (Non-Warm Professions): -6.0156
#   Δ Warm - Nonwarm              : -0.4417
# ------------------------------------------------------------
# Sentence: An altruistic [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.8333
#   Avg PLL (Non-Warm Professions): -7.3733
#   Δ Warm - Nonwarm              : -0.4601
# ------------------------------------------------------------
# Sentence: The altruistic [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -8.2189
#   Avg PLL (Non-Warm Professions): -7.7086
#   Δ Warm - Nonwarm              : -0.5102
# ------------------------------------------------------------
# Sentence: A repressed [MASK] was always appreciated by the team.
#   Avg PLL (Warm Professions)    : -7.7820
#   Avg PLL (Non-Warm Professions): -7.7560
#   Δ Warm - Nonwarm              : -0.0260
# ------------------------------------------------------------
# Sentence: Everyone admired the repressed [MASK] for their dedication.
#   Avg PLL (Warm Professions)    : -10.7028
#   Avg PLL (Non-Warm Professions): -10.0792
#   Δ Warm - Nonwarm              : -0.6235
# ------------------------------------------------------------
# Sentence: It was clear the repressed [MASK] deserved a promotion.
#   Avg PLL (Warm Professions)    : -7.7340
#   Avg PLL (Non-Warm Professions): -7.3063
#   Δ Warm - Nonwarm              : -0.4276
# ------------------------------------------------------------
# Sentence: A repressed [MASK] often creates a positive work environment.
#   Avg PLL (Warm Professions)    : -7.7752
#   Avg PLL (Non-Warm Professions): -7.6481
#   Δ Warm - Nonwarm              : -0.1271
# ------------------------------------------------------------
# Sentence: The repressed [MASK] worked hard to support the community.
#   Avg PLL (Warm Professions)    : -10.5963
#   Avg PLL (Non-Warm Professions): -10.0322
#   Δ Warm - Nonwarm              : -0.5642
# ------------------------------------------------------------

# %%
#pll warmth global avg
# Global aggregation across all sentences
global_warm_plls = []
global_nonwarm_plls = []

for result in all_results:
    scores = result["scores"]
    
    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            global_warm_plls.append(pll)
        elif prof_lower in nonwarm_professions:
            global_nonwarm_plls.append(pll)

if global_warm_plls and global_nonwarm_plls:
    overall_avg_warm = sum(global_warm_plls) / len(global_warm_plls)
    overall_avg_nonwarm = sum(global_nonwarm_plls) / len(global_nonwarm_plls)
    overall_delta = overall_avg_warm - overall_avg_nonwarm

    print("\n\n=== OVERALL AGGREGATED RESULTS ===")
    print(f"Overall Avg PLL (Warm Professions)    : {overall_avg_warm:.4f}")
    print(f"Overall Avg PLL (Non-Warm Professions): {overall_avg_nonwarm:.4f}")
    print(f"Δ Warm - Nonwarm                      : {overall_delta:.4f}")
    print("=" * 60)
else:
    print("No valid PLL scores for global aggregation.")
# Out:
# === OVERALL AGGREGATED RESULTS ===
# Overall Avg PLL (Warm Professions)    : -8.6669
# Overall Avg PLL (Non-Warm Professions): -8.5998
# Δ Warm - Nonwarm                      : -0.0671
# ============================================================

# %%
#print top 5 warmth
from collections import defaultdict

top_k = 5 
#aggregate PLL scores per profession
profession_pll = defaultdict(list)

for result in all_results:
    for prof, pll in result["scores"]:
        profession_pll[prof.lower()].append(pll)  # Normalize casing

#compute average PLL per profession
avg_pll_per_prof = {prof: sum(plls)/len(plls) for prof, plls in profession_pll.items()}

#separate warm and non-warm professions
warm_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in warmth_professions]
nonwarm_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in nonwarm_professions]

#sort descending by PLL
warm_scores.sort(key=lambda x: x[1], reverse=True)
nonwarm_scores.sort(key=lambda x: x[1], reverse=True)

#results
print("Top warm professions by avg PLL:")
for p, pll in warm_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

print("\nTop non-warm professions by avg PLL:")
for p, pll in nonwarm_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")
# Out:
# Top warm professions by avg PLL:
#   custodian            -> PLL: -0.0121
#   paramedic            -> PLL: -1.0888
#   firefighter          -> PLL: -3.3781
#   teacher              -> PLL: -7.4798
#   doctor               -> PLL: -8.4532
#
# Top non-warm professions by avg PLL:
#   plumber              -> PLL: -2.1358
#   cashier              -> PLL: -3.4273
#   security guard       -> PLL: -4.8052
#   electrician          -> PLL: -4.9851
#   truck driver         -> PLL: -6.0421

# %%
#PLL for competence: "/Users/aleksandragarbat/Desktop/pll_sentences_competence.csv"
import torch
import torch.nn.functional as F
from transformers import BertTokenizer, BertForMaskedLM
import csv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#loading sentences from csv file
sentences_file = "/Users/aleksandragarbat/Desktop/pll_sentences_competence.csv"
sentence_templates = []

with open(sentences_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        # Assuming the CSV has a column named 'sentence'
        sentence_templates.append(row['sentence'])

print(f"Loaded {len(sentence_templates)} sentences from {sentences_file}
MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -5.8374
# Profession: vet                  -> Approx. PLL: -8.5652
# Profession: paramedic            -> Approx. PLL: -0.1181
# Profession: chef                 -> Approx. PLL: -5.2439
# Profession: dentist              -> Approx. PLL: -10.1319
# Profession: maid                 -> Approx. PLL: -7.0988
# Profession: doctor               -> Approx. PLL: -5.3479
# Profession: nurse                -> Approx. PLL: -6.8952
# Profession: scientist            -> Approx. PLL: -6.9044
# Profession: welder               -> Approx. PLL: -6.8553
# Profession: teacher              -> Approx. PLL: -6.4165
# Profession: waiter               -> Approx. PLL: -6.5524
# Profession: mechanic             -> Approx. PLL: -6.5077
# Profession: police               -> Approx. PLL: -10.7828
# Profession: secretary            -> Approx. PLL: -7.4955
# Profession: psychiatrist         -> Approx. PLL: -9.8939
# Profession: farmer               -> Approx. PLL: -6.1984
# Profession: pilot                -> Approx. PLL: -6.3278
# Profession: director             -> Approx. PLL: -6.3474
# Profession: architect            -> Approx. PLL: -7.2126
# Profession: c.e.o                -> Approx. PLL: -12.1713
# Profession: artist               -> Approx. PLL: -7.5285
# Profession: writer               -> Approx. PLL: -8.6302
# Profession: fisherman            -> Approx. PLL: -8.2857
# Profession: medical assistant    -> Approx. PLL: -8.2038
# Profession: manager              -> Approx. PLL: -5.7575
# Profession: librarian            -> Approx. PLL: -7.1576
# Profession: politician           -> Approx. PLL: -7.4399
# Profession: engineer             -> Approx. PLL: -6.5431
# Profession: bartender            -> Approx. PLL: -6.6197
# Profession: accountant           -> Approx. PLL: -7.2811
# Profession: firefighter          -> Approx. PLL: -1.2578
# Profession: travel agent         -> Approx. PLL: -7.7828
# Profession: lawyer               -> Approx. PLL: -6.6455
# Profession: actor                -> Approx. PLL: -7.9442
# Profession: lab technician       -> Approx. PLL: -3.5956
# Profession: security guard       -> Approx. PLL: -3.1658
# Profession: custodian            -> Approx. PLL: -0.0008
# Profession: childcare worker     -> Approx. PLL: -6.6761
# Profession: bank teller          -> Approx. PLL: -4.0978
# Profession: taxi driver          -> Approx. PLL: -2.6153
# Profession: bus driver           -> Approx. PLL: -4.1862
# Profession: news anchor          -> Approx. PLL: -6.1842
# Profession: customer service representative -> Approx. PLL: -8.0522
# Profession: cashier              -> Approx. PLL: -0.4363
# Profession: plumber              -> Approx. PLL: -0.2744
# Profession: technical support worker -> Approx. PLL: -10.3299
# Profession: electrician          -> Approx. PLL: -1.0537
# Profession: graphic designer     -> Approx. PLL: -4.1621
# Profession: financial advisor    -> Approx. PLL: -3.9564
# Profession: salesperson          -> Approx. PLL: -2.8525
# Profession: truck driver         -> Approx. PLL: -3.7580
# Profession: landscaper           -> Approx. PLL: -5.9169
# Profession: postal worker        -> Approx. PLL: -6.2830
# Profession: factory worker       -> Approx. PLL: -5.2231
# Profession: garbage collector    -> Approx. PLL: -8.6854
# Profession: computer programmer  -> Approx. PLL: -3.0027
# Profession: construction worker  -> Approx. PLL: -3.5129
#
#
# Sentence: "A thoughtful [MASK] often creates a positive work environment."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -6.5462
# Profession: vet                  -> Approx. PLL: -10.2667
# Profession: paramedic            -> Approx. PLL: -0.0083
# Profession: chef                 -> Approx. PLL: -7.4540
# Profession: dentist              -> Approx. PLL: -10.2226
# Profession: maid                 -> Approx. PLL: -10.2111
# Profession: doctor               -> Approx. PLL: -7.9062
# Profession: nurse                -> Approx. PLL: -8.2441
# Profession: scientist            -> Approx. PLL: -6.4124
# Profession: welder               -> Approx. PLL: -0.1594
# Profession: teacher              -> Approx. PLL: -4.2674
# Profession: farmer               -> Approx. PLL: -10.9708
# Profession: pilot                -> Approx. PLL: -11.6262
# Profession: director             -> Approx. PLL: -8.3310
# Profession: architect            -> Approx. PLL: -13.4963
# Profession: c.e.o                -> Approx. PLL: -11.0342
# Profession: artist               -> Approx. PLL: -13.8043
# Profession: writer               -> Approx. PLL: -10.8786
# Profession: fisherman            -> Approx. PLL: -13.1781
# Profession: medical assistant    -> Approx. PLL: -13.4886
# Profession: manager              -> Approx. PLL: -10.0297
# Profession: librarian            -> Approx. PLL: -12.5713
# Profession: politician           -> Approx. PLL: -12.2230
# Profession: engineer             -> Approx. PLL: -12.7602
# Profession: bartender            -> Approx. PLL: -11.6226
# Profession: accountant           -> Approx. PLL: -11.1041
# Profession: firefighter          -> Approx. PLL: -1.4484
# Profession: travel agent         -> Approx. PLL: -16.1178
# Profession: lawyer               -> Approx. PLL: -9.6542
# Profession: actor                -> Approx. PLL: -10.0268
# Profession: lab technician       -> Approx. PLL: -9.1281
# Profession: security guard       -> Approx. PLL: -3.9481
# Profession: custodian            -> Approx. PLL: -0.0016
# Profession: childcare worker     -> Approx. PLL: -7.8622
# Profession: bank teller          -> Approx. PLL: -12.9783
# Profession: taxi driver          -> Approx. PLL: -10.5121
# Profession: bus driver           -> Approx. PLL: -9.6356
# Profession: news anchor          -> Approx. PLL: -6.0915
# Profession: customer service representative -> Approx. PLL: -13.7334
# Profession: cashier              -> Approx. PLL: -7.6580
# Profession: plumber              -> Approx. PLL: -1.3384
# Profession: technical support worker -> Approx. PLL: -18.6257
# Profession: electrician          -> Approx. PLL: -6.0850
# Profession: graphic designer     -> Approx. PLL: -10.5207
# Profession: financial advisor    -> Approx. PLL: -10.6674
# Profession: salesperson          -> Approx. PLL: -7.4115
# Profession: truck driver         -> Approx. PLL: -10.9642
# Profession: landscaper           -> Approx. PLL: -14.1546
# Profession: postal worker        -> Approx. PLL: -15.9337
# Profession: factory worker       -> Approx. PLL: -10.1943
# Profession: garbage collector    -> Approx. PLL: -7.9671
# Profession: computer programmer  -> Approx. PLL: -12.6242
# Profession: construction worker  -> Approx. PLL: -14.4290
#
#
# Sentence: "Everyone admired the moral [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -10.0018
# Profession: vet                  -> Approx. PLL: -13.1801
# Profession: paramedic            -> Approx. PLL: -3.2725
# Profession: chef                 -> Approx. PLL: -10.4506
# Profession: dentist              -> Approx. PLL: -12.9852
# Profession: maid                 -> Approx. PLL: -10.4159
# Profession: doctor               -> Approx. PLL: -8.0998
# Profession: nurse                -> Approx. PLL: -9.8540
# Profession: scientist            -> Approx. PLL: -9.3367
# Profession: welder               -> Approx. PLL: -11.1946
# Profession: teacher              -> Approx. PLL: -6.4215
# Profession: waiter               -> Approx. PLL: -11.5427
# Profession: mechanic             -> Approx. PLL: -11.4524
# Profession: police               -> Approx. PLL: -4.7941
# Profession: secretary            -> Approx. PLL: -8.8698
# Profession: psychiatrist         -> Approx. PLL: -13.3284
# Profession: farmer               -> Approx. PLL: -9.6852
# Profession: pilot                -> Approx. PLL: -13.3646
# Profession: director             -> Approx. PLL: -6.8333
# Profession: architect            -> Approx. PLL: -12.3129
# Profession: c.e.o                -> Approx. PLL: -9.9991
# Profession: artist               -> Approx. PLL: -12.1866
# Profession: writer               -> Approx. PLL: -10.7450
# Profession: fisherman            -> Approx. PLL: -11.1859
# Profession: medical assistant    -> Approx. PLL: -15.8667
# Profession: manager              -> Approx. PLL: -10.5192
# Profession: librarian            -> Approx. PLL: -10.9707
# Profession: politician           -> Approx. PLL: -11.9761
# Profession: engineer             -> Approx. PLL: -11.5374
# Profession: bartender            -> Approx. PLL: -11.5822
# Profession: accountant           -> Approx. PLL: -10.9068
# Profession: firefighter          -> Approx. PLL: -4.9121
# Profession: travel agent         -> Approx. PLL: -14.7466
# Profession: lawyer               -> Approx. PLL: -8.9359
# Profession: actor                -> Approx. PLL: -10.9884
# Profession: lab technician       -> Approx. PLL: -10.6652
# Profession: security guard       -> Approx. PLL: -2.6963
# Profession: custodian            -> Approx. PLL: -0.0796
# Profession: childcare worker     -> Approx. PLL: -10.8313
# Profession: bank teller          -> Approx. PLL: -10.5478
# Profession: taxi driver          -> Approx. PLL: -9.2648
# Profession: bus driver           -> Approx. PLL: -4.7880
# Profession: news anchor          -> Approx. PLL: -9.1768
# Profession: customer service representative -> Approx. PLL: -13.4170
# Profession: cashier              -> Approx. PLL: -5.9310
# Profession: plumber              -> Approx. PLL: -5.4375
# Profession: technical support worker -> Approx. PLL: -20.4998
# Profession: electrician          -> Approx. PLL: -7.4811
# Profession: graphic designer     -> Approx. PLL: -8.7330
# Profession: financial advisor    -> Approx. PLL: -10.9512
# Profession: salesperson          -> Approx. PLL: -7.8676
# Profession: truck driver         -> Approx. PLL: -8.3151
# Profession: landscaper           -> Approx. PLL: -12.5326
# Profession: postal worker        -> Approx. PLL: -15.4004
# Profession: factory worker       -> Approx. PLL: -12.2661
# Profession: garbage collector    -> Approx. PLL: -8.2384
# Profession: computer programmer  -> Approx. PLL: -11.8714
# Profession: construction worker  -> Approx. PLL: -11.5501
#
#
# Sentence: "It was clear the moral [MASK] deserved a promotion."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -7.8104
# Profession: vet                  -> Approx. PLL: -9.8506
# Profession: paramedic            -> Approx. PLL: -0.5269
# Profession: chef                 -> Approx. PLL: -7.3896
# Profession: dentist              -> Approx. PLL: -10.8871
# Profession: maid                 -> Approx. PLL: -8.8132
# Profession: doctor               -> Approx. PLL: -5.5364
# Profession: nurse                -> Approx. PLL: -6.7650
# Profession: scientist            -> Approx. PLL: -7.1293
# Profession: welder               -> Approx. PLL: -10.5021
# Profession: teacher              -> Approx. PLL: -3.8722
# Profession: waiter               -> Approx. PLL: -10.1629
# Profession: mechanic             -> Approx. PLL: -9.9224
# Profession: police               -> Approx. PLL: -6.0673
# Profession: secretary            -> Approx. PLL: -5.5796
# Profession: psychiatrist         -> Approx. PLL: -10.2564
# Profession: farmer               -> Approx. PLL: -8.6938
# Profession: pilot                -> Approx. PLL: -11.7787
# Profession: director             -> Approx. PLL: -3.8835
# Profession: architect            -> Approx. PLL: -10.5213
# Profession: c.e.o                -> Approx. PLL: -11.9821
# Profession: artist               -> Approx. PLL: -11.0228
# Profession: accountant           -> Approx. PLL: -10.1030
# Profession: firefighter          -> Approx. PLL: -0.2900
# Profession: travel agent         -> Approx. PLL: -9.6168
# Profession: lawyer               -> Approx. PLL: -7.7245
# Profession: actor                -> Approx. PLL: -8.5837
# Profession: lab technician       -> Approx. PLL: -4.4472
# Profession: security guard       -> Approx. PLL: -2.3011
# Profession: custodian            -> Approx. PLL: -0.0006
# Profession: childcare worker     -> Approx. PLL: -6.3515
# Profession: bank teller          -> Approx. PLL: -6.1762
# Profession: taxi driver          -> Approx. PLL: -6.8475
# Profession: bus driver           -> Approx. PLL: -5.3102
# Profession: news anchor          -> Approx. PLL: -3.2853
# Profession: customer service representative -> Approx. PLL: -9.6271
# Profession: cashier              -> Approx. PLL: -2.2675
# Profession: plumber              -> Approx. PLL: -0.2227
# Profession: technical support worker -> Approx. PLL: -13.6930
# Profession: electrician          -> Approx. PLL: -2.6150
# Profession: graphic designer     -> Approx. PLL: -3.4911
# Profession: financial advisor    -> Approx. PLL: -4.3075
# Profession: salesperson          -> Approx. PLL: -5.0116
# Profession: truck driver         -> Approx. PLL: -5.2772
# Profession: landscaper           -> Approx. PLL: -10.4589
# Profession: postal worker        -> Approx. PLL: -9.6317
# Profession: factory worker       -> Approx. PLL: -6.3742
# Profession: garbage collector    -> Approx. PLL: -3.0918
# Profession: computer programmer  -> Approx. PLL: -5.2768
# Profession: construction worker  -> Approx. PLL: -5.2689
#
#
# Sentence: "Everyone admired the caring [MASK] for their dedication."
# ------------------------------------------------------------
# Profession: professor            -> Approx. PLL: -9.1172
# Profession: vet                  -> Approx. PLL: -11.5515
# Profession: paramedic            -> Approx. PLL: -2.7287
# Profession: chef                 -> Approx. PLL: -12.1671
# Profession: dentist              -> Approx. PLL: -11.6309
# Profession: maid                 -> Approx. PLL: -10.1682
# Profession: doctor               -> Approx. PLL: -7.3833
# Profession: nurse                -> Approx. PLL: -7.3956
# Profession: scientist            -> Approx. PLL: -10.9006
# Profession: welder               -> Approx. PLL: -16.4432
# Profession: teacher              -> Approx. PLL: -7.6951
# Profession: waiter               -> Approx. PLL: -11.9167
# Profession: mechanic             -> Approx. PLL: -10.7791
# Profession: police               -> Approx. PLL: -7.9209
# Profession: secretary            -> Approx. PLL: -11.7607
# Profession: psychiatrist         -> Approx. PLL: -12.1778
# Profession: farmer               -> Approx. PLL: -10.4353
# Profession: pilot                -> Approx. PLL: -11.1516
# Profession: director             -> Approx. PLL: -10.0546
# Profession: architect            -> Approx. PLL: -13.1107
# Profession: c.e.o                -> Approx. PLL: -11.3647
# Profession: artist               -> Approx. PLL: -10.7414
# Profession: writer               -> Approx. PLL: -13.7119
# Profession: fisherman            -> Approx. PLL: -11.9648
# Profession: medical assistant    -> Approx. PLL: -12.2938
# Profession: manager              -> Approx. PLL: -10.4115
# Profession: librarian            -> Approx. PLL: -10.0751
# Profession: politician           -> Approx. PLL: -11.9750
# Profession: engineer             -> Approx. PLL: -11.6937
# Profession: bartender            -> Approx. PLL: -9.9828
# Profession: accountant           -> Approx. PLL: -12.7192
# Profession: firefighter          -> Approx. PLL: -3.6551
# Profession: travel agent         -> Approx. PLL: -9.6841
# Profession: accountant           -> Approx. PLL: -8.0316
# Profession: firefighter          -> Approx. PLL: -5.4200
# Profession: travel agent         -> Approx. PLL: -11.0317
# Profession: lawyer               -> Approx. PLL: -8.6914
# Profession: actor                -> Approx. PLL: -9.7233
# Profession: lab technician       -> Approx. PLL: -13.6592
# Profession: security guard       -> Approx. PLL: -7.3521
# Profession: custodian            -> Approx. PLL: -0.0048
# Profession: childcare worker     -> Approx. PLL: -10.0751
# Profession: bank teller          -> Approx. PLL: -17.1335
# Profession: taxi driver          -> Approx. PLL: -5.6179
# Profession: bus driver           -> Approx. PLL: -5.0910
# Profession: news anchor          -> Approx. PLL: -10.8224
# Profession: customer service representative -> Approx. PLL: -13.2792
# Profession: cashier              -> Approx. PLL: -1.3962
# Profession: plumber              -> Approx. PLL: -1.8125
# Profession: technical support worker -> Approx. PLL: -17.7847
# Profession: electrician          -> Approx. PLL: -3.3861
# Profession: graphic designer     -> Approx. PLL: -6.7966
# Profession: financial advisor    -> Approx. PLL: -9.2855
# Profession: salesperson          -> Approx. PLL: -9.4277
# Profession: truck driver         -> Approx. PLL: -4.6242
# Profession: landscaper           -> Approx. PLL: -9.4735
# Profession: postal worker        -> Approx. PLL: -13.1150
# Profession: factory worker       -> Approx. PLL: -10.2730
# Profession: garbage collector    -> Approx. PLL: -6.1618
# Profession: computer programmer  -> Approx. PLL: -9.4177
# Profession: construction worker  -> Approx. PLL: -10.8865

# %%
#storing results for competence
all_results = []

for sentence_template in sentence_templates:
    profession_scores = []
    for profession in professions:
        pll_score = approximate_pll_batched(sentence_template, profession)
        if pll_score is not None:
            profession_scores.append((profession, pll_score))
            #print(f"Profession: {profession:20} -> Approx. PLL: {pll_score:.4f}")
    
    profession_scores.sort(key=lambda x: x[1], reverse=True)
    all_results.append({"sentence": sentence_template, "scores": profession_scores})
   
    # print()

print("\n\n=== Aggregated Results Per Sentence ===\n")

competent_professions = {"c.e.o", "lawyer", "accountant", "professor", "vet", "paramedic", "chef", "dentist",
                         "doctor", "nurse", "scientist", "welder", "mechanic", "psychiatrist", "pilot", "director", "architect",
                         "writer", "manager", "engineer", "actor", "lab technician", "news anchor", "technical support worker",
                         "electrician", "graphic designer", "financial advisor", "computer programmer", "construction worker"
}

competent_professions = set([p.lower() for p in competent_professions])
professions_lower = [p.lower() for p in professions]
non_competent_professions = set(professions_lower) - competent_professions

for result in all_results:
    sentence = result["sentence"]
    scores = result["scores"]

    competent_plls = []
    non_competent_plls = []

    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in competent_professions:
            competent_plls.append(pll)
        elif prof_lower in non_competent_professions:
            non_competent_plls.append(pll)

    if competent_plls and non_competent_plls:
        avg_competent = sum(competent_plls) / len(competent_plls)
        avg_non_competent = sum(non_competent_plls) / len(non_competent_plls)
        delta = avg_competent - avg_non_competent

        print(f"Sentence: {sentence}")
        print(f"  Avg PLL (Competent Professions)    : {avg_competent:.4f}")
        print(f"  Avg PLL (Non-Competent Professions): {avg_non_competent:.4f}")
        print(f"  Δ Warm - Nonwarm              : {delta:.4f}")
        print("-" * 60)
# Out:
# === Aggregated Results Per Sentence ===
#
# Sentence: A thoughtful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.7963
#   Avg PLL (Non-Competent Professions): -7.5432
#   Δ Warm - Nonwarm              : -0.2531
# ------------------------------------------------------------
# Sentence: Everyone admired the thoughtful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.4400
#   Avg PLL (Non-Competent Professions): -8.3383
#   Δ Warm - Nonwarm              : -1.1018
# ------------------------------------------------------------
# Sentence: It was clear the thoughtful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.3089
#   Avg PLL (Non-Competent Professions): -5.5532
#   Δ Warm - Nonwarm              : -0.7557
# ------------------------------------------------------------
# Sentence: A thoughtful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.9254
#   Avg PLL (Non-Competent Professions): -6.7324
#   Δ Warm - Nonwarm              : -0.1930
# ------------------------------------------------------------
# Sentence: The thoughtful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.8644
#   Avg PLL (Non-Competent Professions): -6.7740
#   Δ Warm - Nonwarm              : -1.0904
# ------------------------------------------------------------
# Sentence: A moral [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.6068
#   Avg PLL (Non-Competent Professions): -10.1790
#   Δ Warm - Nonwarm              : -0.4278
# ------------------------------------------------------------
# Sentence: Everyone admired the moral [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.6975
#   Avg PLL (Non-Competent Professions): -9.4058
#   Δ Warm - Nonwarm              : -1.2916
# ------------------------------------------------------------
# Sentence: It was clear the moral [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -8.2734
#   Avg PLL (Non-Competent Professions): -7.4347
#   Δ Warm - Nonwarm              : -0.8387
# ------------------------------------------------------------
# Sentence: A moral [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.2737
#   Avg PLL (Non-Competent Professions): -9.3070
#   Δ Warm - Nonwarm              : 0.0334
# ------------------------------------------------------------
# Sentence: The moral [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.5302
#   Avg PLL (Non-Competent Professions): -8.9179
#   Δ Warm - Nonwarm              : -0.6124
# ------------------------------------------------------------
# Sentence: A caring [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.4367
#   Avg PLL (Non-Competent Professions): -6.9198
#   Δ Warm - Nonwarm              : -0.5168
# ------------------------------------------------------------
# Sentence: Everyone admired the caring [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.4807
#   Avg PLL (Non-Competent Professions): -8.5816
#   Δ Warm - Nonwarm              : -1.8991
# ------------------------------------------------------------
# Sentence: It was clear the caring [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1988
#   Avg PLL (Non-Competent Professions): -5.9101
#   Δ Warm - Nonwarm              : -1.2886
# ------------------------------------------------------------
# Sentence: A caring [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.1511
#   Avg PLL (Non-Competent Professions): -6.9250
#   Δ Warm - Nonwarm              : -0.2261
# ------------------------------------------------------------
# Sentence: The caring [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.4752
#   Avg PLL (Non-Competent Professions): -8.2285
#   Δ Warm - Nonwarm              : -1.2467
# ------------------------------------------------------------
# Sentence: A nice [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.4490
#   Avg PLL (Non-Competent Professions): -8.7882
#   Δ Warm - Nonwarm              : -0.6608
# ------------------------------------------------------------
# Sentence: Everyone admired the nice [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -12.0635
#   Avg PLL (Non-Competent Professions): -9.6286
#   Δ Warm - Nonwarm              : -2.4349
# ------------------------------------------------------------
# Sentence: It was clear the nice [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.3815
#   Avg PLL (Non-Competent Professions): -7.2407
#   Δ Warm - Nonwarm              : -2.1409
# ------------------------------------------------------------
# Sentence: A nice [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.2380
#   Avg PLL (Non-Competent Professions): -8.2253
#   Δ Warm - Nonwarm              : -1.0127
# ------------------------------------------------------------
# Sentence: The nice [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.5728
#   Avg PLL (Non-Competent Professions): -8.8694
#   Δ Warm - Nonwarm              : -2.7034
# ------------------------------------------------------------
# Sentence: A helpful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.8969
#   Avg PLL (Non-Competent Professions): -6.5723
#   Δ Warm - Nonwarm              : -0.3246
# ------------------------------------------------------------
# Sentence: Everyone admired the helpful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7619
#   Avg PLL (Non-Competent Professions): -8.4413
#   Δ Warm - Nonwarm              : -1.3206
# ------------------------------------------------------------
# Sentence: It was clear the helpful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2022
#   Avg PLL (Non-Competent Professions): -5.4369
#   Δ Warm - Nonwarm              : -0.7653
# ------------------------------------------------------------
# Sentence: A helpful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.0573
#   Avg PLL (Non-Competent Professions): -6.6357
#   Δ Warm - Nonwarm              : -0.4216
# ------------------------------------------------------------
# Sentence: The helpful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.2124
#   Avg PLL (Non-Competent Professions): -7.0290
#   Δ Warm - Nonwarm              : -1.1834
# ------------------------------------------------------------
# Sentence: A scheming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.5925
#   Avg PLL (Non-Competent Professions): -6.4406
#   Δ Warm - Nonwarm              : -0.1519
# ------------------------------------------------------------
# Sentence: Everyone admired the scheming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.8818
#   Avg PLL (Non-Competent Professions): -8.4153
#   Δ Warm - Nonwarm              : -1.4665
# ------------------------------------------------------------
# Sentence: It was clear the scheming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.4631
#   Avg PLL (Non-Competent Professions): -5.6875
#   Δ Warm - Nonwarm              : -0.7756
# ------------------------------------------------------------
# Sentence: A scheming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.0759
#   Avg PLL (Non-Competent Professions): -5.7348
#   Δ Warm - Nonwarm              : -0.3411
# ------------------------------------------------------------
# Sentence: The scheming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.5937
#   Avg PLL (Non-Competent Professions): -6.0349
#   Δ Warm - Nonwarm              : -1.5588
# ------------------------------------------------------------
# Sentence: A tolerant [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.0097
#   Avg PLL (Non-Competent Professions): -9.0181
#   Δ Warm - Nonwarm              : -0.9916
# ------------------------------------------------------------
# Sentence: Everyone admired the tolerant [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.8416
#   Avg PLL (Non-Competent Professions): -9.0683
#   Δ Warm - Nonwarm              : -1.7734
# ------------------------------------------------------------
# Sentence: It was clear the tolerant [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.2637
#   Avg PLL (Non-Competent Professions): -6.0261
#   Δ Warm - Nonwarm              : -1.2376
# ------------------------------------------------------------
# Sentence: A tolerant [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.0457
#   Avg PLL (Non-Competent Professions): -9.0849
#   Δ Warm - Nonwarm              : 0.0392
# ------------------------------------------------------------
# Sentence: The tolerant [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.6943
#   Avg PLL (Non-Competent Professions): -8.3987
#   Δ Warm - Nonwarm              : -1.2956
# ------------------------------------------------------------
# Sentence: A polite [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.4735
#   Avg PLL (Non-Competent Professions): -7.6668
#   Δ Warm - Nonwarm              : -1.8067
# ------------------------------------------------------------
# Sentence: Everyone admired the polite [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.0286
#   Avg PLL (Non-Competent Professions): -8.3918
#   Δ Warm - Nonwarm              : -2.6368
# ------------------------------------------------------------
# Sentence: It was clear the polite [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.6625
#   Avg PLL (Non-Competent Professions): -5.6027
#   Δ Warm - Nonwarm              : -2.0598
# ------------------------------------------------------------
# Sentence: A polite [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.3664
#   Avg PLL (Non-Competent Professions): -7.4249
#   Δ Warm - Nonwarm              : -1.9415
# ------------------------------------------------------------
# Sentence: The polite [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.9133
#   Avg PLL (Non-Competent Professions): -8.4415
#   Δ Warm - Nonwarm              : -3.4718
# ------------------------------------------------------------
# Sentence: A trusty [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.2234
#   Avg PLL (Non-Competent Professions): -7.5248
#   Δ Warm - Nonwarm              : -0.6986
# ------------------------------------------------------------
# Sentence: Everyone admired the trusty [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.6990
#   Avg PLL (Non-Competent Professions): -8.6554
#   Δ Warm - Nonwarm              : -2.0436
# ------------------------------------------------------------
# Sentence: It was clear the trusty [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.8602
#   Avg PLL (Non-Competent Professions): -5.9750
#   Δ Warm - Nonwarm              : -0.8851
# ------------------------------------------------------------
# Sentence: A trusty [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6377
#   Avg PLL (Non-Competent Professions): -6.3145
#   Δ Warm - Nonwarm              : -0.3232
# ------------------------------------------------------------
# Sentence: The trusty [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.6918
#   Avg PLL (Non-Competent Professions): -8.2306
#   Δ Warm - Nonwarm              : -1.4612
# ------------------------------------------------------------
# Sentence: A right [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -11.8490
#   Avg PLL (Non-Competent Professions): -11.6889
#   Δ Warm - Nonwarm              : -0.1601
# ------------------------------------------------------------
# Sentence: Everyone admired the right [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.4090
#   Avg PLL (Non-Competent Professions): -9.6489
#   Δ Warm - Nonwarm              : -1.7602
# ------------------------------------------------------------
# Sentence: It was clear the right [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -8.3309
#   Avg PLL (Non-Competent Professions): -7.4291
#   Δ Warm - Nonwarm              : -0.9018
# ------------------------------------------------------------
# Sentence: A right [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.8484
#   Avg PLL (Non-Competent Professions): -10.9814
#   Δ Warm - Nonwarm              : 0.1329
# ------------------------------------------------------------
# Sentence: The right [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.5364
#   Avg PLL (Non-Competent Professions): -9.3564
#   Δ Warm - Nonwarm              : -1.1800
# ------------------------------------------------------------
# Sentence: A welcoming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.4965
#   Avg PLL (Non-Competent Professions): -8.9202
#   Δ Warm - Nonwarm              : -1.5763
# ------------------------------------------------------------
# Sentence: Everyone admired the welcoming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.7322
#   Avg PLL (Non-Competent Professions): -9.0706
#   Δ Warm - Nonwarm              : -2.6616
# ------------------------------------------------------------
# Sentence: It was clear the welcoming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -10.0726
#   Avg PLL (Non-Competent Professions): -7.2474
#   Δ Warm - Nonwarm              : -2.8252
# ------------------------------------------------------------
# Sentence: A welcoming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.0497
#   Avg PLL (Non-Competent Professions): -7.9174
#   Δ Warm - Nonwarm              : -1.1323
# ------------------------------------------------------------
# Sentence: The welcoming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.8498
#   Avg PLL (Non-Competent Professions): -9.7084
#   Δ Warm - Nonwarm              : -2.1414
# ------------------------------------------------------------
# Sentence: An unprejudiced [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5440
#   Avg PLL (Non-Competent Professions): -7.2063
#   Δ Warm - Nonwarm              : -0.3377
# ------------------------------------------------------------
# Sentence: Everyone admired the unprejudiced [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.2438
#   Avg PLL (Non-Competent Professions): -8.5463
#   Δ Warm - Nonwarm              : -1.6974
# ------------------------------------------------------------
# Sentence: It was clear the unprejudiced [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1000
#   Avg PLL (Non-Competent Professions): -5.4245
#   Δ Warm - Nonwarm              : -0.6755
# ------------------------------------------------------------
# Sentence: An unprejudiced [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.2297
#   Avg PLL (Non-Competent Professions): -6.7594
#   Δ Warm - Nonwarm              : -0.4702
# ------------------------------------------------------------
# Sentence: The unprejudiced [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.5162
#   Avg PLL (Non-Competent Professions): -7.3617
#   Δ Warm - Nonwarm              : -2.1545
# ------------------------------------------------------------
# Sentence: A beneficent [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.6433
#   Avg PLL (Non-Competent Professions): -6.5023
#   Δ Warm - Nonwarm              : -0.1410
# ------------------------------------------------------------
# Sentence: Everyone admired the beneficent [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7394
#   Avg PLL (Non-Competent Professions): -8.2025
#   Δ Warm - Nonwarm              : -1.5369
# ------------------------------------------------------------
# Sentence: It was clear the beneficent [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -5.7978
#   Avg PLL (Non-Competent Professions): -5.2610
#   Δ Warm - Nonwarm              : -0.5368
# ------------------------------------------------------------
# Sentence: A beneficent [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.3410
#   Avg PLL (Non-Competent Professions): -6.6544
#   Δ Warm - Nonwarm              : 0.3135
# ------------------------------------------------------------
# Sentence: The beneficent [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.3754
#   Avg PLL (Non-Competent Professions): -7.8796
#   Δ Warm - Nonwarm              : -0.4957
# ------------------------------------------------------------
# Sentence: A faithful [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.3669
#   Avg PLL (Non-Competent Professions): -7.0908
#   Δ Warm - Nonwarm              : -0.2761
# ------------------------------------------------------------
# Sentence: Everyone admired the faithful [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.9437
#   Avg PLL (Non-Competent Professions): -9.1675
#   Δ Warm - Nonwarm              : -1.7762
# ------------------------------------------------------------
# Sentence: It was clear the faithful [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.6802
#   Avg PLL (Non-Competent Professions): -6.3183
#   Δ Warm - Nonwarm              : -1.3618
# ------------------------------------------------------------
# Sentence: A faithful [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.4285
#   Avg PLL (Non-Competent Professions): -6.1633
#   Δ Warm - Nonwarm              : -0.2652
# ------------------------------------------------------------
# Sentence: The faithful [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.5288
#   Avg PLL (Non-Competent Professions): -8.9647
#   Δ Warm - Nonwarm              : -1.5641
# ------------------------------------------------------------
# Sentence: A sincere [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.8121
#   Avg PLL (Non-Competent Professions): -8.4403
#   Δ Warm - Nonwarm              : -0.3718
# ------------------------------------------------------------
# Sentence: Everyone admired the sincere [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.4196
#   Avg PLL (Non-Competent Professions): -8.1171
#   Δ Warm - Nonwarm              : -1.3025
# ------------------------------------------------------------
# Sentence: It was clear the sincere [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.4085
#   Avg PLL (Non-Competent Professions): -5.6459
#   Δ Warm - Nonwarm              : -0.7626
# ------------------------------------------------------------
# Sentence: A sincere [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.5372
#   Avg PLL (Non-Competent Professions): -7.1763
#   Δ Warm - Nonwarm              : -0.3610
# ------------------------------------------------------------
# Sentence: The sincere [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7378
#   Avg PLL (Non-Competent Professions): -7.4762
#   Δ Warm - Nonwarm              : -1.2615
# ------------------------------------------------------------
# Sentence: A reliable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.6450
#   Avg PLL (Non-Competent Professions): -7.7551
#   Δ Warm - Nonwarm              : 0.1101
# ------------------------------------------------------------
# Sentence: Everyone admired the reliable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7960
#   Avg PLL (Non-Competent Professions): -8.5344
#   Δ Warm - Nonwarm              : -1.2616
# ------------------------------------------------------------
# Sentence: It was clear the reliable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2753
#   Avg PLL (Non-Competent Professions): -5.6270
#   Δ Warm - Nonwarm              : -0.6483
# ------------------------------------------------------------
# Sentence: A reliable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.3604
#   Avg PLL (Non-Competent Professions): -7.5931
#   Δ Warm - Nonwarm              : 0.2327
# ------------------------------------------------------------
# Sentence: The reliable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.4109
#   Avg PLL (Non-Competent Professions): -7.1802
#   Δ Warm - Nonwarm              : -1.2307
# ------------------------------------------------------------
# Sentence: A honest [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.4891
#   Avg PLL (Non-Competent Professions): -7.1856
#   Δ Warm - Nonwarm              : -0.3036
# ------------------------------------------------------------
# Sentence: Everyone admired the honest [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.5800
#   Avg PLL (Non-Competent Professions): -8.2444
#   Δ Warm - Nonwarm              : -1.3356
# ------------------------------------------------------------
# Sentence: It was clear the honest [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.7084
#   Avg PLL (Non-Competent Professions): -5.6010
#   Δ Warm - Nonwarm              : -1.1074
# ------------------------------------------------------------
# Sentence: A honest [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.5007
#   Avg PLL (Non-Competent Professions): -6.0705
#   Δ Warm - Nonwarm              : -0.4302
# ------------------------------------------------------------
# Sentence: The honest [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.3320
#   Avg PLL (Non-Competent Professions): -6.5397
#   Δ Warm - Nonwarm              : -1.7923
# ------------------------------------------------------------
# Sentence: A lawfully [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.7503
#   Avg PLL (Non-Competent Professions): -10.6755
#   Δ Warm - Nonwarm              : -0.0748
# ------------------------------------------------------------
# Sentence: Everyone admired the lawfully [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.3151
#   Avg PLL (Non-Competent Professions): -12.3905
#   Δ Warm - Nonwarm              : -0.9246
# ------------------------------------------------------------
# Sentence: It was clear the lawfully [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -11.3223
#   Avg PLL (Non-Competent Professions): -10.5653
#   Δ Warm - Nonwarm              : -0.7570
# ------------------------------------------------------------
# Sentence: A lawfully [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.5218
#   Avg PLL (Non-Competent Professions): -11.1028
#   Δ Warm - Nonwarm              : -0.4190
# ------------------------------------------------------------
# Sentence: The lawfully [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.7660
#   Avg PLL (Non-Competent Professions): -10.5958
#   Δ Warm - Nonwarm              : -1.1702
# ------------------------------------------------------------
# Sentence: A fair [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -13.0330
#   Avg PLL (Non-Competent Professions): -12.4966
#   Δ Warm - Nonwarm              : -0.5364
# ------------------------------------------------------------
# Sentence: Everyone admired the fair [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.8997
#   Avg PLL (Non-Competent Professions): -11.7888
#   Δ Warm - Nonwarm              : -2.1109
# ------------------------------------------------------------
# Sentence: It was clear the fair [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -10.6943
#   Avg PLL (Non-Competent Professions): -9.3637
#   Δ Warm - Nonwarm              : -1.3306
# ------------------------------------------------------------
# Sentence: A fair [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.9558
#   Avg PLL (Non-Competent Professions): -11.3633
#   Δ Warm - Nonwarm              : 0.4075
# ------------------------------------------------------------
# Sentence: The fair [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.6368
#   Avg PLL (Non-Competent Professions): -12.2357
#   Δ Warm - Nonwarm              : -0.4011
# ------------------------------------------------------------
# Sentence: A humorous [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.5370
#   Avg PLL (Non-Competent Professions): -8.9256
#   Δ Warm - Nonwarm              : -0.6114
# ------------------------------------------------------------
# Sentence: Everyone admired the humorous [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.7478
#   Avg PLL (Non-Competent Professions): -8.6405
#   Δ Warm - Nonwarm              : -1.1073
# ------------------------------------------------------------
# Sentence: It was clear the humorous [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.0312
#   Avg PLL (Non-Competent Professions): -5.9631
#   Δ Warm - Nonwarm              : -1.0681
# ------------------------------------------------------------
# Sentence: A humorous [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.5757
#   Avg PLL (Non-Competent Professions): -6.9660
#   Δ Warm - Nonwarm              : -0.6097
# ------------------------------------------------------------
# Sentence: The humorous [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.4855
#   Avg PLL (Non-Competent Professions): -6.8177
#   Δ Warm - Nonwarm              : -1.6678
# ------------------------------------------------------------
# Sentence: A hostile [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.3869
#   Avg PLL (Non-Competent Professions): -9.4632
#   Δ Warm - Nonwarm              : -0.9236
# ------------------------------------------------------------
# Sentence: Everyone admired the hostile [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -12.1116
#   Avg PLL (Non-Competent Professions): -10.1083
#   Δ Warm - Nonwarm              : -2.0033
# ------------------------------------------------------------
# Sentence: It was clear the hostile [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -8.1634
#   Avg PLL (Non-Competent Professions): -7.0883
#   Δ Warm - Nonwarm              : -1.0751
# ------------------------------------------------------------
# Sentence: A hostile [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.2957
#   Avg PLL (Non-Competent Professions): -9.2913
#   Δ Warm - Nonwarm              : -1.0044
# ------------------------------------------------------------
# Sentence: The hostile [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.8292
#   Avg PLL (Non-Competent Professions): -8.9686
#   Δ Warm - Nonwarm              : -1.8606
# ------------------------------------------------------------
# Sentence: An equitable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -11.1287
#   Avg PLL (Non-Competent Professions): -11.3230
#   Δ Warm - Nonwarm              : 0.1943
# ------------------------------------------------------------
# Sentence: Everyone admired the equitable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.1759
#   Avg PLL (Non-Competent Professions): -10.0602
#   Δ Warm - Nonwarm              : -1.1157
# ------------------------------------------------------------
# Sentence: It was clear the equitable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.6562
#   Avg PLL (Non-Competent Professions): -7.3051
#   Δ Warm - Nonwarm              : -0.3511
# ------------------------------------------------------------
# Sentence: An equitable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -10.1091
#   Avg PLL (Non-Competent Professions): -10.7078
#   Δ Warm - Nonwarm              : 0.5987
# ------------------------------------------------------------
# Sentence: The equitable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -11.0111
#   Avg PLL (Non-Competent Professions): -10.7191
#   Δ Warm - Nonwarm              : -0.2920
# ------------------------------------------------------------
# Sentence: A virtuous [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5548
#   Avg PLL (Non-Competent Professions): -6.9924
#   Δ Warm - Nonwarm              : -0.5624
# ------------------------------------------------------------
# Sentence: Everyone admired the virtuous [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.8716
#   Avg PLL (Non-Competent Professions): -9.0701
#   Δ Warm - Nonwarm              : -1.8015
# ------------------------------------------------------------
# Sentence: It was clear the virtuous [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.7117
#   Avg PLL (Non-Competent Professions): -5.8312
#   Δ Warm - Nonwarm              : -0.8805
# ------------------------------------------------------------
# Sentence: A virtuous [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.9810
#   Avg PLL (Non-Competent Professions): -6.2768
#   Δ Warm - Nonwarm              : -0.7043
# ------------------------------------------------------------
# Sentence: The virtuous [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.6917
#   Avg PLL (Non-Competent Professions): -6.8739
#   Δ Warm - Nonwarm              : -1.8177
# ------------------------------------------------------------
# Sentence: A considerate [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.5842
#   Avg PLL (Non-Competent Professions): -6.8481
#   Δ Warm - Nonwarm              : -0.7361
# ------------------------------------------------------------
# Sentence: Everyone admired the considerate [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.8398
#   Avg PLL (Non-Competent Professions): -8.4060
#   Δ Warm - Nonwarm              : -1.4338
# ------------------------------------------------------------
# Sentence: It was clear the considerate [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.6103
#   Avg PLL (Non-Competent Professions): -5.7185
#   Δ Warm - Nonwarm              : -0.8917
# ------------------------------------------------------------
# Sentence: A considerate [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.2007
#   Avg PLL (Non-Competent Professions): -6.2399
#   Δ Warm - Nonwarm              : -0.9607
# ------------------------------------------------------------
# Sentence: The considerate [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.9502
#   Avg PLL (Non-Competent Professions): -5.9474
#   Δ Warm - Nonwarm              : -2.0028
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.2121
#   Avg PLL (Non-Competent Professions): -8.6493
#   Δ Warm - Nonwarm              : 0.4372
# ------------------------------------------------------------
# Sentence: Everyone admired the forthcoming [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.9842
#   Avg PLL (Non-Competent Professions): -9.1051
#   Δ Warm - Nonwarm              : -0.8790
# ------------------------------------------------------------
# Sentence: It was clear the forthcoming [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0745
#   Avg PLL (Non-Competent Professions): -6.1397
#   Δ Warm - Nonwarm              : 0.0652
# ------------------------------------------------------------
# Sentence: A forthcoming [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.0433
#   Avg PLL (Non-Competent Professions): -9.2642
#   Δ Warm - Nonwarm              : 0.2209
# ------------------------------------------------------------
# Sentence: The forthcoming [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2129
#   Avg PLL (Non-Competent Professions): -8.7329
#   Δ Warm - Nonwarm              : -0.4799
# ------------------------------------------------------------
# Sentence: A lenient [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.2945
#   Avg PLL (Non-Competent Professions): -8.8496
#   Δ Warm - Nonwarm              : -0.4449
# ------------------------------------------------------------
# Sentence: Everyone admired the lenient [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.0322
#   Avg PLL (Non-Competent Professions): -8.4633
#   Δ Warm - Nonwarm              : -1.5689
# ------------------------------------------------------------
# Sentence: It was clear the lenient [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.4224
#   Avg PLL (Non-Competent Professions): -5.7135
#   Δ Warm - Nonwarm              : -0.7089
# ------------------------------------------------------------
# Sentence: A lenient [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.0530
#   Avg PLL (Non-Competent Professions): -7.7809
#   Δ Warm - Nonwarm              : -0.2721
# ------------------------------------------------------------
# Sentence: The lenient [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7345
#   Avg PLL (Non-Competent Professions): -7.4608
#   Δ Warm - Nonwarm              : -1.2737
# ------------------------------------------------------------
# Sentence: A civil [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.6184
#   Avg PLL (Non-Competent Professions): -9.4078
#   Δ Warm - Nonwarm              : -0.2106
# ------------------------------------------------------------
# Sentence: Everyone admired the civil [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.8834
#   Avg PLL (Non-Competent Professions): -12.3256
#   Δ Warm - Nonwarm              : -1.5578
# ------------------------------------------------------------
# Sentence: It was clear the civil [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -10.2110
#   Avg PLL (Non-Competent Professions): -9.4005
#   Δ Warm - Nonwarm              : -0.8105
# ------------------------------------------------------------
# Sentence: A civil [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -9.6932
#   Avg PLL (Non-Competent Professions): -9.6745
#   Δ Warm - Nonwarm              : -0.0188
# ------------------------------------------------------------
# Sentence: The civil [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.4848
#   Avg PLL (Non-Competent Professions): -11.6224
#   Δ Warm - Nonwarm              : -0.8624
# ------------------------------------------------------------
# Sentence: A responsible [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.9885
#   Avg PLL (Non-Competent Professions): -7.1129
#   Δ Warm - Nonwarm              : 0.1244
# ------------------------------------------------------------
# Sentence: Everyone admired the responsible [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.0315
#   Avg PLL (Non-Competent Professions): -7.8740
#   Δ Warm - Nonwarm              : -1.1574
# ------------------------------------------------------------
# Sentence: It was clear the responsible [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2934
#   Avg PLL (Non-Competent Professions): -5.7283
#   Δ Warm - Nonwarm              : -0.5651
# ------------------------------------------------------------
# Sentence: A responsible [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.7489
#   Avg PLL (Non-Competent Professions): -6.7191
#   Δ Warm - Nonwarm              : -0.0298
# ------------------------------------------------------------
# Sentence: The responsible [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.8725
#   Avg PLL (Non-Competent Professions): -6.8819
#   Δ Warm - Nonwarm              : -0.9906
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -6.8826
#   Avg PLL (Non-Competent Professions): -6.7082
#   Δ Warm - Nonwarm              : -0.1744
# ------------------------------------------------------------
# Sentence: Everyone admired the sympathetic [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.3119
#   Avg PLL (Non-Competent Professions): -8.2321
#   Δ Warm - Nonwarm              : -1.0798
# ------------------------------------------------------------
# Sentence: It was clear the sympathetic [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.0439
#   Avg PLL (Non-Competent Professions): -5.3818
#   Δ Warm - Nonwarm              : -0.6621
# ------------------------------------------------------------
# Sentence: A sympathetic [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6832
#   Avg PLL (Non-Competent Professions): -6.1393
#   Δ Warm - Nonwarm              : -0.5440
# ------------------------------------------------------------
# Sentence: The sympathetic [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.4900
#   Avg PLL (Non-Competent Professions): -7.3389
#   Δ Warm - Nonwarm              : -1.1510
# ------------------------------------------------------------
# Sentence: An agreeable [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.5047
#   Avg PLL (Non-Competent Professions): -7.9591
#   Δ Warm - Nonwarm              : -0.5456
# ------------------------------------------------------------
# Sentence: Everyone admired the agreeable [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.0136
#   Avg PLL (Non-Competent Professions): -8.4179
#   Δ Warm - Nonwarm              : -1.5956
# ------------------------------------------------------------
# Sentence: It was clear the agreeable [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1811
#   Avg PLL (Non-Competent Professions): -5.8804
#   Δ Warm - Nonwarm              : -1.3006
# ------------------------------------------------------------
# Sentence: An agreeable [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.0287
#   Avg PLL (Non-Competent Professions): -7.4906
#   Δ Warm - Nonwarm              : -0.5381
# ------------------------------------------------------------
# Sentence: The agreeable [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.1322
#   Avg PLL (Non-Competent Professions): -7.2982
#   Δ Warm - Nonwarm              : -1.8340
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.0405
#   Avg PLL (Non-Competent Professions): -9.3242
#   Δ Warm - Nonwarm              : -0.7163
# ------------------------------------------------------------
# Sentence: Everyone admired the entertaining [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.4785
#   Avg PLL (Non-Competent Professions): -8.8379
#   Δ Warm - Nonwarm              : -1.6406
# ------------------------------------------------------------
# Sentence: It was clear the entertaining [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.6079
#   Avg PLL (Non-Competent Professions): -5.7533
#   Δ Warm - Nonwarm              : -0.8546
# ------------------------------------------------------------
# Sentence: An entertaining [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.0893
#   Avg PLL (Non-Competent Professions): -7.1078
#   Δ Warm - Nonwarm              : -0.9815
# ------------------------------------------------------------
# Sentence: The entertaining [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.2584
#   Avg PLL (Non-Competent Professions): -7.6037
#   Δ Warm - Nonwarm              : -1.6547
# ------------------------------------------------------------
# Sentence: An attractive [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.4517
#   Avg PLL (Non-Competent Professions): -7.4610
#   Δ Warm - Nonwarm              : -0.9907
# ------------------------------------------------------------
# Sentence: Everyone admired the attractive [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.6509
#   Avg PLL (Non-Competent Professions): -8.9404
#   Δ Warm - Nonwarm              : -1.7104
# ------------------------------------------------------------
# Sentence: It was clear the attractive [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.5004
#   Avg PLL (Non-Competent Professions): -6.2236
#   Δ Warm - Nonwarm              : -1.2767
# ------------------------------------------------------------
# Sentence: An attractive [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.1757
#   Avg PLL (Non-Competent Professions): -7.1276
#   Δ Warm - Nonwarm              : -1.0481
# ------------------------------------------------------------
# Sentence: The attractive [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.7617
#   Avg PLL (Non-Competent Professions): -7.0728
#   Δ Warm - Nonwarm              : -1.6888
# ------------------------------------------------------------
# Sentence: A loyal [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.6592
#   Avg PLL (Non-Competent Professions): -7.0466
#   Δ Warm - Nonwarm              : -0.6126
# ------------------------------------------------------------
# Sentence: Everyone admired the loyal [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.1081
#   Avg PLL (Non-Competent Professions): -8.5202
#   Δ Warm - Nonwarm              : -1.5879
# ------------------------------------------------------------
# Sentence: It was clear the loyal [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.1565
#   Avg PLL (Non-Competent Professions): -6.0429
#   Δ Warm - Nonwarm              : -1.1136
# ------------------------------------------------------------
# Sentence: A loyal [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.3359
#   Avg PLL (Non-Competent Professions): -6.3197
#   Δ Warm - Nonwarm              : -1.0162
# ------------------------------------------------------------
# Sentence: The loyal [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.1049
#   Avg PLL (Non-Competent Professions): -7.5098
#   Δ Warm - Nonwarm              : -1.5951
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.5418
#   Avg PLL (Non-Competent Professions): -8.0717
#   Δ Warm - Nonwarm              : -0.4701
# ------------------------------------------------------------
# Sentence: Everyone admired the incorrupt [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -9.9083
#   Avg PLL (Non-Competent Professions): -8.4562
#   Δ Warm - Nonwarm              : -1.4521
# ------------------------------------------------------------
# Sentence: It was clear the incorrupt [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.1630
#   Avg PLL (Non-Competent Professions): -5.4982
#   Δ Warm - Nonwarm              : -0.6648
# ------------------------------------------------------------
# Sentence: An incorrupt [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.1313
#   Avg PLL (Non-Competent Professions): -6.9092
#   Δ Warm - Nonwarm              : -0.2221
# ------------------------------------------------------------
# Sentence: The incorrupt [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.7512
#   Avg PLL (Non-Competent Professions): -6.2772
#   Δ Warm - Nonwarm              : -1.4740
# ------------------------------------------------------------
# Sentence: A popular [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.9745
#   Avg PLL (Non-Competent Professions): -7.5576
#   Δ Warm - Nonwarm              : -0.4169
# ------------------------------------------------------------
# Sentence: Everyone admired the popular [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.1494
#   Avg PLL (Non-Competent Professions): -8.7287
#   Δ Warm - Nonwarm              : -1.4208
# ------------------------------------------------------------
# Sentence: It was clear the popular [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.7479
#   Avg PLL (Non-Competent Professions): -6.4895
#   Δ Warm - Nonwarm              : -1.2583
# ------------------------------------------------------------
# Sentence: A popular [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -7.3707
#   Avg PLL (Non-Competent Professions): -7.0889
#   Δ Warm - Nonwarm              : -0.2818
# ------------------------------------------------------------
# Sentence: The popular [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -8.9806
#   Avg PLL (Non-Competent Professions): -7.3131
#   Δ Warm - Nonwarm              : -1.6675
# ------------------------------------------------------------
# Sentence: A superb [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -8.4924
#   Avg PLL (Non-Competent Professions): -9.0363
#   Δ Warm - Nonwarm              : 0.5439
# ------------------------------------------------------------
# Sentence: Everyone admired the superb [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -8.9557
#   Avg PLL (Non-Competent Professions): -8.8952
#   Δ Warm - Nonwarm              : -0.0605
# ------------------------------------------------------------
# Sentence: It was clear the superb [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.2192
#   Avg PLL (Non-Competent Professions): -6.4700
#   Δ Warm - Nonwarm              : 0.2509
# ------------------------------------------------------------
# Sentence: A superb [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.2075
#   Avg PLL (Non-Competent Professions): -7.0046
#   Δ Warm - Nonwarm              : 0.7971
# ------------------------------------------------------------
# Sentence: The superb [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -7.5089
#   Avg PLL (Non-Competent Professions): -7.3597
#   Δ Warm - Nonwarm              : -0.1492
# ------------------------------------------------------------
# Sentence: An open [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -12.8526
#   Avg PLL (Non-Competent Professions): -12.2140
#   Δ Warm - Nonwarm              : -0.6386
# ------------------------------------------------------------
# Sentence: Everyone admired the open [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -13.0114
#   Avg PLL (Non-Competent Professions): -10.9725
#   Δ Warm - Nonwarm              : -2.0389
# ------------------------------------------------------------
# Sentence: It was clear the open [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -9.7709
#   Avg PLL (Non-Competent Professions): -8.2450
#   Δ Warm - Nonwarm              : -1.5260
# ------------------------------------------------------------
# Sentence: An open [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -11.0282
#   Avg PLL (Non-Competent Professions): -11.0375
#   Δ Warm - Nonwarm              : 0.0093
# ------------------------------------------------------------
# Sentence: The open [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -12.2977
#   Avg PLL (Non-Competent Professions): -12.0731
#   Δ Warm - Nonwarm              : -0.2246
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -9.9591
#   Avg PLL (Non-Competent Professions): -8.5117
#   Δ Warm - Nonwarm              : -1.4473
# ------------------------------------------------------------
# Sentence: Everyone admired the sentimental [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.4199
#   Avg PLL (Non-Competent Professions): -8.8101
#   Δ Warm - Nonwarm              : -2.6098
# ------------------------------------------------------------
# Sentence: It was clear the sentimental [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.8816
#   Avg PLL (Non-Competent Professions): -6.1312
#   Δ Warm - Nonwarm              : -1.7504
# ------------------------------------------------------------
# Sentence: A sentimental [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.5953
#   Avg PLL (Non-Competent Professions): -7.1806
#   Δ Warm - Nonwarm              : -1.4146
# ------------------------------------------------------------
# Sentence: The sentimental [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.4091
#   Avg PLL (Non-Competent Professions): -6.8892
#   Δ Warm - Nonwarm              : -2.5200
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -10.0551
#   Avg PLL (Non-Competent Professions): -9.5453
#   Δ Warm - Nonwarm              : -0.5098
# ------------------------------------------------------------
# Sentence: Everyone admired the cooperative [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -11.1882
#   Avg PLL (Non-Competent Professions): -9.3112
#   Δ Warm - Nonwarm              : -1.8771
# ------------------------------------------------------------
# Sentence: It was clear the cooperative [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -7.5956
#   Avg PLL (Non-Competent Professions): -6.6277
#   Δ Warm - Nonwarm              : -0.9680
# ------------------------------------------------------------
# Sentence: A cooperative [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -8.3449
#   Avg PLL (Non-Competent Professions): -8.5776
#   Δ Warm - Nonwarm              : 0.2327
# ------------------------------------------------------------
# Sentence: The cooperative [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -10.5185
#   Avg PLL (Non-Competent Professions): -9.4629
#   Δ Warm - Nonwarm              : -1.0556
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] was always appreciated by the team.
#   Avg PLL (Competent Professions)    : -7.2630
#   Avg PLL (Non-Competent Professions): -7.1029
#   Δ Warm - Nonwarm              : -0.1600
# ------------------------------------------------------------
# Sentence: Everyone admired the benevolent [MASK] for their dedication.
#   Avg PLL (Competent Professions)    : -10.0947
#   Avg PLL (Non-Competent Professions): -8.7091
#   Δ Warm - Nonwarm              : -1.3856
# ------------------------------------------------------------
# Sentence: It was clear the benevolent [MASK] deserved a promotion.
#   Avg PLL (Competent Professions)    : -6.9417
#   Avg PLL (Non-Competent Professions): -6.1506
#   Δ Warm - Nonwarm              : -0.7911
# ------------------------------------------------------------
# Sentence: A benevolent [MASK] often creates a positive work environment.
#   Avg PLL (Competent Professions)    : -6.6348
#   Avg PLL (Non-Competent Professions): -6.8402
#   Δ Warm - Nonwarm              : 0.2054
# ------------------------------------------------------------
# Sentence: The benevolent [MASK] worked hard to support the community.
#   Avg PLL (Competent Professions)    : -9.3560
#   Avg PLL (Non-Competent Professions): -8.4521
#   Δ Warm - Nonwarm              : -0.9039
# ------------------------------------------------------------

# %%
#PLL competence final aggreg. = global aggregation across all sentences
global_competent_plls = []
global_non_competent_plls = []

for result in all_results:
    scores = result["scores"]
    
    for profession, pll in scores:
        prof_lower = profession.lower()
        if prof_lower in warmth_professions:
            global_competent_plls.append(pll)
        elif prof_lower in non_competent_professions:
            global_non_competent_plls.append(pll)

if global_competent_plls and global_non_competent_plls:
    overall_avg_competent = sum(global_competent_plls) / len(global_competent_plls)
    overall_avg_non_competent = sum(global_non_competent_plls) / len(global_non_competent_plls)
    overall_delta = overall_avg_competent - overall_avg_non_competent

    print("\n\n=== OVERALL AGGREGATED RESULTS ===")
    print(f"Overall Avg PLL (Competent Professions)    : {overall_avg_competent:.4f}")
    print(f"Overall Avg PLL (Non-Competent Professions): {overall_avg_non_competent:.4f}")
    print(f"Δ Competent - Non-Competent                      : {overall_delta:.4f}")
    print("=" * 60)
else:
    print("No valid PLL scores for global aggregation.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 global_competent_plls = []
#       5 global_non_competent_plls = []
# ----> 7 for result in all_results:
#       8     scores = result["scores"]
#      10     for profession, pll in scores:
#
# NameError: name 'all_results' is not defined

# %%
#print top 5 (competence)
from collections import defaultdict

#aggregate PLL scores per profession
profession_pll = defaultdict(list)

for result in all_results:
    for prof, pll in result["scores"]:
        profession_pll[prof.lower()].append(pll)  # normalize casing

#compute average PLL per profession
avg_pll_per_prof = {prof: sum(plls)/len(plls) for prof, plls in profession_pll.items()}

#separate warm and non-warm professions
competent_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in competent_professions]
non_competent_scores = [(p, pll) for p, pll in avg_pll_per_prof.items() if p in non_competent_professions]

#sort descending by PLL
competent_scores.sort(key=lambda x: x[1], reverse=True)
non_competent_scores.sort(key=lambda x: x[1], reverse=True)

#results
print("Top competent professions by avg PLL:")
for p, pll in competent_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")

print("\nTop non-competent professions by avg PLL:")
for p, pll in non_competent_scores[:top_k]:
    print(f"  {p:20} -> PLL: {pll:.4f}")
# Out:
# Top competent professions by avg PLL:
#   paramedic            -> PLL: -1.0715
#   electrician          -> PLL: -4.6654
#   welder               -> PLL: -6.9159
#   computer programmer  -> PLL: -6.9392
#   graphic designer     -> PLL: -7.0342
#
# Top non-competent professions by avg PLL:
#   custodian            -> PLL: -0.0121
#   plumber              -> PLL: -1.9081
#   firefighter          -> PLL: -3.1166
#   cashier              -> PLL: -3.1746
#   security guard       -> PLL: -4.5529

# %%
######stereoset (WARMTH)

# %%
#stereoset
import torch
from torch.nn.functional import softmax
from transformers import BertTokenizerFast
from collections import defaultdict
import csv

#load debiasing components
bias_data = torch.load('data/BERT_finetuned/bias_vectors.pt')
components = bias_data['components']
weights = bias_data['weights']

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#PLL computation for a batch of sentences
def compute_pll_batch(sentences):
    model.eval()
    pll_scores = []

    with torch.no_grad():
        for sentence in sentences:
            inputs = tokenizer(sentence, return_tensors="pt")
            input_ids = inputs["input_ids"][0]
            attention_mask = inputs["attention_mask"]

            pll = 0.0
            for i in range(1, len(input_ids) - 1):  # Skip [CLS] and [SEP]
                masked_input_ids = input_ids.clone()
                true_token_id = masked_input_ids[i].item()
                masked_input_ids[i] = tokenizer.mask_token_id

                masked_input_ids = masked_input_ids.unsqueeze(0).to(device)
                attn_mask = attention_mask.to(device)

                outputs = model(input_ids=masked_input_ids, attention_mask=attn_mask)
                logits = outputs["logits"][0]
                token_logits = logits[i]
                prob = softmax(token_logits, dim=-1)[true_token_id]
                pll += torch.log(prob + 1e-12).item()

            normalized_pll = pll / (len(input_ids) - 2)  # Normalize by token count
            pll_scores.append(normalized_pll)

    return pll_scores

#evaluation function with batching
def evaluate_stereoset_style(data, batch_size=16):
    stats = defaultdict(lambda: {"stereo": 0, "anti": 0, "delta_sum": 0.0})
    results = []

    # Group data by bias_type for batching
    bias_groups = defaultdict(list)
    for stereo_sent, anti_sent, bias_type in data:
        bias_groups[bias_type].append((stereo_sent, anti_sent))

    for bias_type, pairs in bias_groups.items():
        stereo_sents = [p[0] for p in pairs]
        anti_sents = [p[1] for p in pairs]

        for i in range(0, len(stereo_sents), batch_size):
            batch_stereo = stereo_sents[i : i + batch_size]
            batch_anti = anti_sents[i : i + batch_size]

            pll_stereo_batch = compute_pll_batch(batch_stereo)
            pll_anti_batch = compute_pll_batch(batch_anti)

            for j in range(len(pll_stereo_batch)):
                pll_stereo = pll_stereo_batch[j]
                pll_anti = pll_anti_batch[j]
                delta = pll_stereo - pll_anti
                preferred = "stereotype" if delta > 0 else "anti-stereotype"

                stats[bias_type]["stereo" if delta > 0 else "anti"] += 1
                stats[bias_type]["delta_sum"] += delta

                print(f"Stereo:      {batch_stereo[j]} (PLL: {pll_stereo:.4f})")
                print(f"Anti-stereo: {batch_anti[j]} (PLL: {pll_anti:.4f})")
                print(f"Δ PLL (stereo - anti): {delta:.4f}")
                print(f"Preferred:   {preferred.upper()} ({bias_type})\n")

                results.append({
                    "bias_type": bias_type,
                    "pll_stereo": pll_stereo,
                    "pll_anti": pll_anti,
                    "delta": delta,
                    "preferred": preferred,
                    "stereo_sentence": batch_stereo[j],
                    "anti_sentence": batch_anti[j]
                })

    #summary report generation
    print("\n--- Results Summary ---")
    for bias_type, counts in stats.items():
        total = counts["stereo"] + counts["anti"]
        stereo_score = 100 * counts["stereo"] / total if total > 0 else 0.0
        anti_score = 100 * counts["anti"] / total if total > 0 else 0.0
        avg_delta = counts["delta_sum"] / total if total > 0 else 0.0

        print(f"{bias_type.title()} Bias:")
        print(f"  Stereotype preferred:      {counts['stereo']}/{total} ({stereo_score:.1f}%)")
        print(f"  Anti-stereotype preferred: {counts['anti']}/{total} ({anti_score:.1f}%)")
        print(f"  Average Δ PLL:             {avg_delta:.4f}\n")

    return results


data = []

#Run evaluation

if __name__ == "__main__":
    with open('stereo_anti_stereo_warmth_randomized.csv', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            stereo_sent = row['stereotypical_sentence']
            anti_sent = row['anti_stereotypical_sentence']
            bias_type = row['bias_type']
            data.append((stereo_sent, anti_sent, bias_type))

    results = evaluate_stereoset_style(data)

#evaluate_stereoset_style(data)
# Out:
# Stereo:      Everyone admired the compassionate writer for their dedication. (PLL: -6.3095)
# Anti-stereo: Everyone admired the aloof writer for their dedication. (PLL: -4.1938)
# Δ PLL (stereo - anti): -2.1157
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A faithful writer often creates a positive work environment. (PLL: -4.5744)
# Anti-stereo: An unemotional writer often creates a positive work environment. (PLL: -3.1309)
# Δ PLL (stereo - anti): -1.4435
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the truthful childcare worker for their dedication. (PLL: -4.8110)
# Anti-stereo: Everyone admired the inhospitable childcare worker for their dedication. (PLL: -3.6042)
# Δ PLL (stereo - anti): -1.2068
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the cooperative childcare worker deserved a promotion. (PLL: -3.3646)
# Anti-stereo: It was clear the unhelpful childcare worker deserved a promotion. (PLL: -1.6486)
# Δ PLL (stereo - anti): -1.7160
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the faithful childcare worker deserved a promotion. (PLL: -2.6890)
# Anti-stereo: It was clear the unemotional childcare worker deserved a promotion. (PLL: -1.7800)
# Δ PLL (stereo - anti): -0.9090
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The sympathetic secretary worked hard to support the community. (PLL: -3.4077)
# Anti-stereo: The evil secretary worked hard to support the community. (PLL: -3.5559)
# Δ PLL (stereo - anti): 0.1482
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      The popular bank teller worked hard to support the community. (PLL: -3.4522)
# Anti-stereo: The thoughtless bank teller worked hard to support the community. (PLL: -2.6206)
# Δ PLL (stereo - anti): -0.8316
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the outgoing medical assistant for their dedication. (PLL: -4.5390)
# Anti-stereo: Everyone admired the fake medical assistant for their dedication. (PLL: -4.5348)
# Δ PLL (stereo - anti): -0.0042
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A humane medical assistant was always appreciated by the team. (PLL: -4.3640)
# Anti-stereo: An unpleasant medical assistant was always appreciated by the team. (PLL: -3.8821)
# Δ PLL (stereo - anti): -0.4820
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      An equitable medical assistant was always appreciated by the team. (PLL: -3.2712)
# Anti-stereo: An insensitive medical assistant was always appreciated by the team. (PLL: -2.4439)
# Δ PLL (stereo - anti): -0.8273
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the reliable psychiatrist deserved a promotion. (PLL: -3.3813)
# Anti-stereo: It was clear the mean psychiatrist deserved a promotion. (PLL: -3.1871)
# Δ PLL (stereo - anti): -0.1942
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the affectionate psychiatrist for their dedication. (PLL: -4.5152)
# Anti-stereo: Everyone admired the uncivil psychiatrist for their dedication. (PLL: -3.7199)
# Δ PLL (stereo - anti): -0.7952
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the sentimental psychiatrist deserved a promotion. (PLL: -3.9992)
# Anti-stereo: It was clear the gothic psychiatrist deserved a promotion. (PLL: -3.4297)
# Δ PLL (stereo - anti): -0.5695
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The civil architect worked hard to support the community. (PLL: -3.2625)
# Anti-stereo: The unfaithful architect worked hard to support the community. (PLL: -1.7008)
# Δ PLL (stereo - anti): -1.5617
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The faithful architect worked hard to support the community. (PLL: -3.4066)
# Anti-stereo: The unemotional architect worked hard to support the community. (PLL: -1.9111)
# Δ PLL (stereo - anti): -1.4955
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A dependable farmer often creates a positive work environment. (PLL: -3.5600)
# Anti-stereo: A corrupt farmer often creates a positive work environment. (PLL: -4.7925)
# Δ PLL (stereo - anti): 1.2325
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A sympathetic farmer was always appreciated by the team. (PLL: -4.3523)
# Anti-stereo: An evil farmer was always appreciated by the team. (PLL: -3.9075)
# Δ PLL (stereo - anti): -0.4448
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A sociable paramedic was always appreciated by the team. (PLL: -1.9140)
# Anti-stereo: A vicious paramedic was always appreciated by the team. (PLL: -2.6884)
# Δ PLL (stereo - anti): 0.7744
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the nice paramedic for their dedication. (PLL: -3.1576)
# Anti-stereo: Everyone admired the brutal paramedic for their dedication. (PLL: -3.0231)
# Δ PLL (stereo - anti): -0.1345
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the fair dentist deserved a promotion. (PLL: -3.7713)
# Anti-stereo: It was clear the resentful dentist deserved a promotion. (PLL: -2.0451)
# Δ PLL (stereo - anti): -1.7262
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The humorous dentist worked hard to support the community. (PLL: -3.8502)
# Anti-stereo: The displeasing dentist worked hard to support the community. (PLL: -2.2816)
# Δ PLL (stereo - anti): -1.5685
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      An open dentist often creates a positive work environment. (PLL: -4.6972)
# Anti-stereo: An uncharitable dentist often creates a positive work environment. (PLL: -3.3655)
# Δ PLL (stereo - anti): -1.3317
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A generous firefighter was always appreciated by the team. (PLL: -3.2954)
# Anti-stereo: An immoral firefighter was always appreciated by the team. (PLL: -2.3374)
# Δ PLL (stereo - anti): -0.9580
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A helpful lab technician often creates a positive work environment. (PLL: -4.8141)
# Anti-stereo: A criminal lab technician often creates a positive work environment. (PLL: -5.0688)
# Δ PLL (stereo - anti): 0.2547
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the dependable bartender for their dedication. (PLL: -4.0777)
# Anti-stereo: Everyone admired the corrupt bartender for their dedication. (PLL: -5.2810)
# Δ PLL (stereo - anti): 1.2034
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      An equitable custodian often creates a positive work environment. (PLL: -2.5207)
# Anti-stereo: An insensitive custodian often creates a positive work environment. (PLL: -1.9342)
# Δ PLL (stereo - anti): -0.5865
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A loyal custodian was always appreciated by the team. (PLL: -2.5231)
# Anti-stereo: A closed custodian was always appreciated by the team. (PLL: -2.6916)
# Δ PLL (stereo - anti): 0.1685
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A truthful custodian often creates a positive work environment. (PLL: -2.3707)
# Anti-stereo: An inhospitable custodian often creates a positive work environment. (PLL: -1.9078)
# Δ PLL (stereo - anti): -0.4629
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the unprejudiced professor for their dedication. (PLL: -3.0808)
# Anti-stereo: Everyone admired the intolerant professor for their dedication. (PLL: -3.3074)
# Δ PLL (stereo - anti): 0.2266
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      The civil doctor worked hard to support the community. (PLL: -2.7182)
# Anti-stereo: The unfaithful doctor worked hard to support the community. (PLL: -1.3653)
# Δ PLL (stereo - anti): -1.3530
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the forthcoming doctor deserved a promotion. (PLL: -3.0133)
# Anti-stereo: It was clear the asocial doctor deserved a promotion. (PLL: -1.5054)
# Δ PLL (stereo - anti): -1.5079
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The moral doctor worked hard to support the community. (PLL: -2.8792)
# Anti-stereo: The repellent doctor worked hard to support the community. (PLL: -1.6705)
# Δ PLL (stereo - anti): -1.2087
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the altruistic pilot deserved a promotion. (PLL: -1.7297)
# Anti-stereo: It was clear the uncaring pilot deserved a promotion. (PLL: -1.7217)
# Δ PLL (stereo - anti): -0.0080
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the equitable pilot deserved a promotion. (PLL: -2.9264)
# Anti-stereo: It was clear the insensitive pilot deserved a promotion. (PLL: -1.7348)
# Δ PLL (stereo - anti): -1.1916
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the benevolent engineer deserved a promotion. (PLL: -3.4577)
# Anti-stereo: It was clear the unfriendly engineer deserved a promotion. (PLL: -1.5769)
# Δ PLL (stereo - anti): -1.8808
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the compassionate engineer deserved a promotion. (PLL: -3.4248)
# Anti-stereo: It was clear the aloof engineer deserved a promotion. (PLL: -2.1305)
# Δ PLL (stereo - anti): -1.2943
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A loyal nurse often creates a positive work environment. (PLL: -4.4065)
# Anti-stereo: A closed nurse often creates a positive work environment. (PLL: -4.9690)
# Δ PLL (stereo - anti): 0.5624
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      A warm nurse often creates a positive work environment. (PLL: -4.7812)
# Anti-stereo: An egoistic nurse often creates a positive work environment. (PLL: -3.7348)
# Δ PLL (stereo - anti): -1.0465
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      Everyone admired the compassionate nurse for their dedication. (PLL: -5.6584)
# Anti-stereo: Everyone admired the aloof nurse for their dedication. (PLL: -3.6149)
# Δ PLL (stereo - anti): -2.0436
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A sympathetic vet often creates a positive work environment. (PLL: -4.7881)
# Anti-stereo: An evil vet often creates a positive work environment. (PLL: -4.3149)
# Δ PLL (stereo - anti): -0.4732
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A virtuous vet often creates a positive work environment. (PLL: -3.2150)
# Anti-stereo: A disagreeable vet often creates a positive work environment. (PLL: -3.7878)
# Δ PLL (stereo - anti): 0.5727
# Preferred:   STEREOTYPE (warmth)
#
# Stereo:      It was clear the understanding teacher deserved a promotion. (PLL: -3.3987)
# Anti-stereo: It was clear the cruel teacher deserved a promotion. (PLL: -3.1084)
# Δ PLL (stereo - anti): -0.2904
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      It was clear the funny teacher deserved a promotion. (PLL: -3.4548)
# Anti-stereo: It was clear the disloyal teacher deserved a promotion. (PLL: -1.5542)
# Δ PLL (stereo - anti): -1.9007
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A generous chef was always appreciated by the team. (PLL: -4.3706)
# Anti-stereo: An immoral chef was always appreciated by the team. (PLL: -3.2559)
# Δ PLL (stereo - anti): -1.1148
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      A trusty chef was always appreciated by the team. (PLL: -3.3156)
# Anti-stereo: An untruthful chef was always appreciated by the team. (PLL: -2.4941)
# Δ PLL (stereo - anti): -0.8215
# Preferred:   ANTI-STEREOTYPE (warmth)
#
# Stereo:      The tender chef worked hard to support the community. (PLL: -3.7327)
# Anti-stereo: The unmerciful chef worked hard to support the community. (PLL: -2.4266)
# Δ PLL (stereo - anti): -1.3061
# Preferred:   ANTI-STEREOTYPE (warmth)
#
#
# --- Results Summary ---
# Warmth Bias:
#   Stereotype preferred:      9/46 (19.6%)
#   Anti-stereotype preferred: 37/46 (80.4%)
#   Average Δ PLL:             -0.7318

# %%
#stereoset competence 
import torch
from torch.nn.functional import softmax
from transformers import BertTokenizerFast
from collections import defaultdict
import csv

#load tokenizer
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

#load debiased model
model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()



#PLL computation for a batch of sentences
def compute_pll_batch(sentences):
    model.eval()
    pll_scores = []

    with torch.no_grad():
        for sentence in sentences:
            inputs = tokenizer(sentence, return_tensors="pt")
            input_ids = inputs["input_ids"][0]
            attention_mask = inputs["attention_mask"]

            pll = 0.0
            for i in range(1, len(input_ids) - 1):  # Skip [CLS] and [SEP]
                masked_input_ids = input_ids.clone()
                true_token_id = masked_input_ids[i].item()
                masked_input_ids[i] = tokenizer.mask_token_id

                masked_input_ids = masked_input_ids.unsqueeze(0).to(device)
                attn_mask = attention_mask.to(device)

                outputs = model(input_ids=masked_input_ids, attention_mask=attn_mask)
                logits = outputs["logits"][0]
                token_logits = logits[i]
                prob = softmax(token_logits, dim=-1)[true_token_id]
                pll += torch.log(prob + 1e-12).item()

            normalized_pll = pll / (len(input_ids) - 2)  # Normalize by token count
            pll_scores.append(normalized_pll)

    return pll_scores

#evaluation function with batching
def evaluate_stereoset_style(data, batch_size=16):
    stats = defaultdict(lambda: {"stereo": 0, "anti": 0, "delta_sum": 0.0})
    results = []

    #group data by bias_type for batching
    bias_groups = defaultdict(list)
    for stereo_sent, anti_sent, bias_type in data:
        bias_groups[bias_type].append((stereo_sent, anti_sent))

    for bias_type, pairs in bias_groups.items():
        stereo_sents = [p[0] for p in pairs]
        anti_sents = [p[1] for p in pairs]

        for i in range(0, len(stereo_sents), batch_size):
            batch_stereo = stereo_sents[i : i + batch_size]
            batch_anti = anti_sents[i : i + batch_size]

            pll_stereo_batch = compute_pll_batch(batch_stereo)
            pll_anti_batch = compute_pll_batch(batch_anti)

            for j in range(len(pll_stereo_batch)):
                pll_stereo = pll_stereo_batch[j]
                pll_anti = pll_anti_batch[j]
                delta = pll_stereo - pll_anti
                preferred = "stereotype" if delta > 0 else "anti-stereotype"

                stats[bias_type]["stereo" if delta > 0 else "anti"] += 1
                stats[bias_type]["delta_sum"] += delta

                print(f"Stereo:      {batch_stereo[j]} (PLL: {pll_stereo:.4f})")
                print(f"Anti-stereo: {batch_anti[j]} (PLL: {pll_anti:.4f})")
                print(f"Δ PLL (stereo - anti): {delta:.4f}")
                print(f"Preferred:   {preferred.upper()} ({bias_type})\n")

                results.append({
                    "bias_type": bias_type,
                    "pll_stereo": pll_stereo,
                    "pll_anti": pll_anti,
                    "delta": delta,
                    "preferred": preferred,
                    "stereo_sentence": batch_stereo[j],
                    "anti_sentence": batch_anti[j]
                })

    #summary report
    print("\n--- Results Summary ---")
    for bias_type, counts in stats.items():
        total = counts["stereo"] + counts["anti"]
        stereo_score = 100 * counts["stereo"] / total if total > 0 else 0.0
        anti_score = 100 * counts["anti"] / total if total > 0 else 0.0
        avg_delta = counts["delta_sum"] / total if total > 0 else 0.0

        print(f"{bias_type.title()} Bias:")
        print(f"  Stereotype preferred:      {counts['stereo']}/{total} ({stereo_score:.1f}%)")
        print(f"  Anti-stereotype preferred: {counts['anti']}/{total} ({anti_score:.1f}%)")
        print(f"  Average Δ PLL:             {avg_delta:.4f}\n")

    return results


data = []

#run evaluation

if __name__ == "__main__":
    with open('stereo_anti_stereo_competence_randomized.csv', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            stereo_sent = row['stereotypical_sentence']
            anti_sent = row['anti_stereotypical_sentence']
            bias_type = row['bias_type']
            data.append((stereo_sent, anti_sent, bias_type))

    results = evaluate_stereoset_style(data)
# Out:
# Stereo:      The practical financial advisor worked hard to support the community. (PLL: -3.1799)
# Anti-stereo: The inexperienced financial advisor worked hard to support the community. (PLL: -2.9685)
# Δ PLL (stereo - anti): -0.2114
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A daring welder often creates a positive work environment. (PLL: -4.2488)
# Anti-stereo: A graceless welder often creates a positive work environment. (PLL: -3.7407)
# Δ PLL (stereo - anti): -0.5081
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A brilliant welder often creates a positive work environment. (PLL: -4.0032)
# Anti-stereo: A lazy welder often creates a positive work environment. (PLL: -3.6688)
# Δ PLL (stereo - anti): -0.3344
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A cautious graphic designer often creates a positive work environment. (PLL: -4.7424)
# Anti-stereo: A submissive graphic designer often creates a positive work environment. (PLL: -3.5862)
# Δ PLL (stereo - anti): -1.1561
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An ambitious graphic designer often creates a positive work environment. (PLL: -4.0646)
# Anti-stereo: A subordinate graphic designer often creates a positive work environment. (PLL: -5.0814)
# Δ PLL (stereo - anti): 1.0168
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A sapient graphic designer often creates a positive work environment. (PLL: -3.9732)
# Anti-stereo: An uneducated graphic designer often creates a positive work environment. (PLL: -2.7529)
# Δ PLL (stereo - anti): -1.2202
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The unwavering director worked hard to support the community. (PLL: -1.5667)
# Anti-stereo: The unintelligent director worked hard to support the community. (PLL: -1.6352)
# Δ PLL (stereo - anti): 0.0685
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the aggressive electrician deserved a promotion. (PLL: -2.7117)
# Anti-stereo: It was clear the inactive electrician deserved a promotion. (PLL: -3.5424)
# Δ PLL (stereo - anti): 0.8307
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A continual computer programmer often creates a positive work environment. (PLL: -5.6410)
# Anti-stereo: A wavering computer programmer often creates a positive work environment. (PLL: -4.2354)
# Δ PLL (stereo - anti): -1.4057
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The creative computer programmer worked hard to support the community. (PLL: -3.6775)
# Anti-stereo: The incautious computer programmer worked hard to support the community. (PLL: -2.2122)
# Δ PLL (stereo - anti): -1.4653
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A felicitous vet was always appreciated by the team. (PLL: -2.4995)
# Anti-stereo: An inefficient vet was always appreciated by the team. (PLL: -2.1817)
# Δ PLL (stereo - anti): -0.3178
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the fortified technical support worker deserved a promotion. (PLL: -3.9703)
# Anti-stereo: It was clear the sporadic technical support worker deserved a promotion. (PLL: -4.2880)
# Δ PLL (stereo - anti): 0.3177
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A judicious technical support worker often creates a positive work environment. (PLL: -3.2083)
# Anti-stereo: An unhallowed technical support worker often creates a positive work environment. (PLL: -3.4494)
# Δ PLL (stereo - anti): 0.2411
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An intelligent technical support worker often creates a positive work environment. (PLL: -4.5835)
# Anti-stereo: An uncritical technical support worker often creates a positive work environment. (PLL: -3.7641)
# Δ PLL (stereo - anti): -0.8194
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the practical accountant for their dedication. (PLL: -5.8824)
# Anti-stereo: Everyone admired the inexperienced accountant for their dedication. (PLL: -5.2240)
# Δ PLL (stereo - anti): -0.6584
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The industrious accountant worked hard to support the community. (PLL: -1.8052)
# Anti-stereo: The negligent accountant worked hard to support the community. (PLL: -1.7711)
# Δ PLL (stereo - anti): -0.0341
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the brilliant accountant for their dedication. (PLL: -5.3288)
# Anti-stereo: Everyone admired the lazy accountant for their dedication. (PLL: -5.3476)
# Δ PLL (stereo - anti): 0.0188
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An aggressive pilot often creates a positive work environment. (PLL: -4.0848)
# Anti-stereo: An inactive pilot often creates a positive work environment. (PLL: -4.4149)
# Δ PLL (stereo - anti): 0.3301
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An enterprising lab technician was always appreciated by the team. (PLL: -2.3505)
# Anti-stereo: A witless lab technician was always appreciated by the team. (PLL: -3.3973)
# Δ PLL (stereo - anti): 1.0468
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A wise lawyer was always appreciated by the team. (PLL: -3.4421)
# Anti-stereo: A careful lawyer was always appreciated by the team. (PLL: -3.8088)
# Δ PLL (stereo - anti): 0.3667
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the knowledgeable lawyer deserved a promotion. (PLL: -1.9228)
# Anti-stereo: It was clear the unconcerned lawyer deserved a promotion. (PLL: -1.3886)
# Δ PLL (stereo - anti): -0.5341
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The continual lawyer worked hard to support the community. (PLL: -4.4704)
# Anti-stereo: The wavering lawyer worked hard to support the community. (PLL: -2.2962)
# Δ PLL (stereo - anti): -2.1742
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the dedicated manager for their dedication. (PLL: -5.2485)
# Anti-stereo: Everyone admired the shiftless manager for their dedication. (PLL: -4.5329)
# Δ PLL (stereo - anti): -0.7156
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the daring manager deserved a promotion. (PLL: -3.4516)
# Anti-stereo: It was clear the graceless manager deserved a promotion. (PLL: -2.5871)
# Δ PLL (stereo - anti): -0.8645
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An aggressive manager was always appreciated by the team. (PLL: -3.4090)
# Anti-stereo: An inactive manager was always appreciated by the team. (PLL: -3.7994)
# Δ PLL (stereo - anti): 0.3904
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the fearlessness nurse for their dedication. (PLL: -6.1760)
# Anti-stereo: Everyone admired the doubtful nurse for their dedication. (PLL: -5.2809)
# Δ PLL (stereo - anti): -0.8951
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the enterprising nurse deserved a promotion. (PLL: -1.5107)
# Anti-stereo: It was clear the witless nurse deserved a promotion. (PLL: -2.2816)
# Δ PLL (stereo - anti): 0.7708
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A creative nurse was always appreciated by the team. (PLL: -4.0060)
# Anti-stereo: An incautious nurse was always appreciated by the team. (PLL: -2.4174)
# Δ PLL (stereo - anti): -1.5885
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A secure doctor often creates a positive work environment. (PLL: -4.8740)
# Anti-stereo: A dim doctor often creates a positive work environment. (PLL: -5.7714)
# Δ PLL (stereo - anti): 0.8974
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the continual chef deserved a promotion. (PLL: -3.9450)
# Anti-stereo: It was clear the wavering chef deserved a promotion. (PLL: -2.4139)
# Δ PLL (stereo - anti): -1.5311
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the cautious paramedic deserved a promotion. (PLL: -2.1796)
# Anti-stereo: It was clear the submissive paramedic deserved a promotion. (PLL: -1.3463)
# Δ PLL (stereo - anti): -0.8333
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The daring paramedic worked hard to support the community. (PLL: -2.3887)
# Anti-stereo: The graceless paramedic worked hard to support the community. (PLL: -2.1087)
# Δ PLL (stereo - anti): -0.2800
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      An expeditious paramedic was always appreciated by the team. (PLL: -1.3639)
# Anti-stereo: A spiritless paramedic was always appreciated by the team. (PLL: -2.5047)
# Δ PLL (stereo - anti): 1.1408
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A wise dentist was always appreciated by the team. (PLL: -4.1704)
# Anti-stereo: A careful dentist was always appreciated by the team. (PLL: -4.3000)
# Δ PLL (stereo - anti): 0.1296
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      The effective dentist worked hard to support the community. (PLL: -3.6343)
# Anti-stereo: The ineffective dentist worked hard to support the community. (PLL: -4.0716)
# Δ PLL (stereo - anti): 0.4373
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the enterprising dentist deserved a promotion. (PLL: -1.8554)
# Anti-stereo: It was clear the witless dentist deserved a promotion. (PLL: -2.5937)
# Δ PLL (stereo - anti): 0.7383
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the powerful professor for their dedication. (PLL: -4.9404)
# Anti-stereo: Everyone admired the quixotic professor for their dedication. (PLL: -3.6401)
# Δ PLL (stereo - anti): -1.3003
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A persistent professor was always appreciated by the team. (PLL: -4.5410)
# Anti-stereo: An impulsive professor was always appreciated by the team. (PLL: -2.9569)
# Δ PLL (stereo - anti): -1.5841
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      It was clear the practical news anchor deserved a promotion. (PLL: -3.1442)
# Anti-stereo: It was clear the inexperienced news anchor deserved a promotion. (PLL: -2.4110)
# Δ PLL (stereo - anti): -0.7332
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A conscientious news anchor often creates a positive work environment. (PLL: -2.9736)
# Anti-stereo: An unwise news anchor often creates a positive work environment. (PLL: -4.2256)
# Δ PLL (stereo - anti): 1.2520
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      Everyone admired the aggressive architect for their dedication. (PLL: -5.6240)
# Anti-stereo: Everyone admired the inactive architect for their dedication. (PLL: -6.3375)
# Δ PLL (stereo - anti): 0.7135
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A brilliant architect was always appreciated by the team. (PLL: -3.9960)
# Anti-stereo: A lazy architect was always appreciated by the team. (PLL: -4.3470)
# Δ PLL (stereo - anti): 0.3510
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the energetic construction worker deserved a promotion. (PLL: -3.1261)
# Anti-stereo: It was clear the foolish construction worker deserved a promotion. (PLL: -2.5563)
# Δ PLL (stereo - anti): -0.5698
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A persistent construction worker often creates a positive work environment. (PLL: -4.7107)
# Anti-stereo: An impulsive construction worker often creates a positive work environment. (PLL: -3.5446)
# Δ PLL (stereo - anti): -1.1662
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the educated psychiatrist for their dedication. (PLL: -6.1663)
# Anti-stereo: Everyone admired the lethargic psychiatrist for their dedication. (PLL: -3.7347)
# Δ PLL (stereo - anti): -2.4315
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A dominant engineer often creates a positive work environment. (PLL: -5.0798)
# Anti-stereo: A squat engineer often creates a positive work environment. (PLL: -5.9057)
# Δ PLL (stereo - anti): 0.8259
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      A persistent mechanic was always appreciated by the team. (PLL: -4.2626)
# Anti-stereo: An impulsive mechanic was always appreciated by the team. (PLL: -2.7940)
# Δ PLL (stereo - anti): -1.4686
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      Everyone admired the conscientious writer for their dedication. (PLL: -3.3388)
# Anti-stereo: Everyone admired the unwise writer for their dedication. (PLL: -4.8205)
# Δ PLL (stereo - anti): 1.4817
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      An educated writer was always appreciated by the team. (PLL: -4.0348)
# Anti-stereo: A lethargic writer was always appreciated by the team. (PLL: -2.7366)
# Δ PLL (stereo - anti): -1.2982
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      The daring c.e.o worked hard to support the community. (PLL: -2.6477)
# Anti-stereo: The graceless c.e.o worked hard to support the community. (PLL: -2.8953)
# Δ PLL (stereo - anti): 0.2476
# Preferred:   STEREOTYPE (competence)
#
# Stereo:      It was clear the effective scientist deserved a promotion. (PLL: -3.5552)
# Anti-stereo: It was clear the ineffective scientist deserved a promotion. (PLL: -3.2494)
# Δ PLL (stereo - anti): -0.3059
# Preferred:   ANTI-STEREOTYPE (competence)
#
# Stereo:      A logical actor often creates a positive work environment. (PLL: -5.6506)
# Anti-stereo: An ignorant actor often creates a positive work environment. (PLL: -4.7213)
# Δ PLL (stereo - anti): -0.9293
# Preferred:   ANTI-STEREOTYPE (competence)
#
#
# --- Results Summary ---
# Competence Bias:
#   Stereotype preferred:      22/52 (42.3%)
#   Anti-stereotype preferred: 30/52 (57.7%)
#   Average Δ PLL:             -0.3023

# %%
#seat (warmth)
import torch
import numpy as np
from scipy.stats import ttest_ind
from transformers import BertTokenizerFast

##X/Y = target embeddings; A/B = attribute embeddings

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#prepare sentences
def prepare_sentences(words):
    return [f"The person is {word}." for word in words]

warmth_adj = ["affectionate", "agreeable", "altruistic", "amicable", "benevolent", "caring",
    "civil", "compassionate", "cooperative", "fair", "faithful", "forgiving",
    "forthcoming", "friendly", "funny", "generous", "genuine", "good", "helpful",
    "honest", "hospitable", "humane", "humorous", "incorrupt", "innocent", "kind",
    "lenient", "loyal", "moral", "nice", "open", "outgoing", "pleasant", "polite",
    "popular", "reliable", "responsible", "right", "selfless", "sensitive",
    "sentimental", "shy", "sincere", "social", "sympathetic", "tender", "thoughtful",
    "tolerant", "trustworthy", "truthful", "understanding", "unprejudiced",
    "virtuous", "warm", "welcoming", "sociable", "superb", "entertaining",
    "courteous", "considerate", "attractive", "pleased", "accommodating", "equitable",
    "dependable", "trusty"]

non_warmth_adj = [
    "unsympathetic", "disagreeable", "egoistic", "selfish", "hostile", "mean",
    "uncharitable", "uncaring", "uncivil", "merciless", "unhelpful", "unfaithful",
    "unfriendly", "unsociable", "stingy", "insincere", "evil", "dishonest",
    "inhospitable", "unkind", "cruel", "displeasing", "immoral", "peccant",
    "unmerciful", "faithless", "vicious", "nasty", "ugly", "closed", "unpleasant",
    "ungracious", "gothic", "untrustworthy", "scatterbrained", "wrong", "impolitic",
    "insensitive", "unemotional", "presumptuous", "roguish", "tough", "thoughtless",
    "timid", "intolerant", "untruthful", "prejudiced", "sexist", "cold",
    "antisocial", "aloof", "asocial", "bad", "boring", "brutal", "corrupt",
    "criminal", "disloyal", "distant", "fake", "rude", "impolite", "inconsiderate",
    "irresponsible", "repellent", "resentful", "rough", "threatening",
    "treacherous", "uncooperative", "unfair", "unreliable", "unreserved"
]
professions_warm = [
    "professor", "vet", "paramedic", "chef", "dentist", "doctor", "nurse", "teacher", "secretary",
    "psychiatrist", "farmer", "pilot", "architect", "writer","medical assistant", "engineer", "bartender", "firefighter","lab technician",
    "custodian", "childcare worker", "bank teller"
]

professions_nonwarm = ['accountant', 'actor', 'artist', 'bus driver', 'cashier', 'c.e.o.', 'computer programmer', 'construction worker',
 'customer service representative', 'director', 'electrician', 'factory worker', 'financial advisor', 'fisherman',
 'garbage collector', 'graphic designer', 'landscaper', 'lawyer', 'librarian', 'maid', 'manager', 'mechanic',
 'musician', 'news anchor', 'police', 'politician', 'postal worker', 'salesperson', 'scientist', 'security guard',
 'technical support worker', 'truck driver', 'waiter', 'welder']


warmth_sentences = prepare_sentences(warmth_adj)
non_warmth_sentences = prepare_sentences(non_warmth_adj)
prof_warm_sentences = prepare_sentences(professions_warm)
prof_nonwarm_sentences = prepare_sentences(professions_nonwarm)

#embedding words function
def embed_words(model, tokenizer, sentences, device):
    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        embeddings = last_hidden_state[:, 0, :]  # CLS token
    return embeddings.cpu()

#embedding all groups
warmth_emb = embed_words(model, tokenizer, warmth_sentences, device)
non_warmth_emb = embed_words(model, tokenizer, non_warmth_sentences, device)
prof_warm_emb = embed_words(model, tokenizer, prof_warm_sentences, device)
prof_nonwarm_emb = embed_words(model, tokenizer, prof_nonwarm_sentences, device)

#SEAT functions(as PyTorch tensors)
def cosine_similarity_matrix(a, b):
    a_norm = a / a.norm(dim=1, keepdim=True)
    b_norm = b / b.norm(dim=1, keepdim=True)
    return torch.mm(a_norm, b_norm.t())

def seat_effect_size(X, Y, A, B):
    def s(w, A, B):
        simA = cosine_similarity_matrix(w.unsqueeze(0), A).mean()
        simB = cosine_similarity_matrix(w.unsqueeze(0), B).mean()
        return (simA - simB).item()
    sX = np.array([s(x, A, B) for x in X])
    sY = np.array([s(y, A, B) for y in Y])
    mean_diff = sX.mean() - sY.mean()
    std_dev = np.std(np.concatenate([sX, sY]), ddof=1)
    effect_size = mean_diff / std_dev
    t_stat, p_val = ttest_ind(sX, sY, equal_var=False)
    return effect_size, p_val

#using embeddings as PyTorch tensors
X = prof_warm_emb
Y = prof_nonwarm_emb
A = warmth_emb
B = non_warmth_emb

effect_size, p_value = seat_effect_size(X, Y, A, B)
print(f"SEAT effect size: {effect_size:.3f}, p-value: {p_value:.3f}")
# Out:
# SEAT effect size: 0.393, p-value: 0.120

# %%
#seat (competence)
import torch
import numpy as np
from scipy.stats import ttest_ind
from transformers import BertTokenizerFast

##X/Y = target embeddings; A/B = attribute embeddings

#load tokenizer and model
tokenizer = BertTokenizerFast.from_pretrained("data/BERT_finetuned")

model = DebiasedBertForMaskedLM.from_pretrained(
    "data/BERT_finetuned",
    components=components,
    weights=weights,
    tokenizer=tokenizer,
    debias_all_tokens=True
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

#prepare sentences
def prepare_sentences(words):
    return [f"The person is {word}." for word in words]

competence_adj = ["dexterous", "certain", "intelligent", "sapient", "powerful", "savvy", "knowledgeable", 
                       "logical", "cautious", "active", "capable", "competent", "effective", "efficient", "rational", 
                       "expeditious", "energetic", "heedful", "continual", "clever", "enterprising", "educated", "judicious", 
                       "fortified", "able", "aggressive", "ambitious", "assertive", "autonomous", "bright", "brilliant", "conscientious", 
                       "creative", "critical", "daring", "dedicated", "determined", "dominant", "fearlessness", "felicitous", "graceful", 
                       "industrious", "insightful", "inventive", "meticulous", "motivated", "persistent", "practical", "resilient", 
                       "resolute", "secure", "shrewd", "skilled", "smart", "spirited", "unwavering", "wise"]

non_competence_adj = [
    "maladroit", "inept", "clumsy", "diffident", "doubtful", "dumb", "foolish", "helpless",
    "ignorant", "illogical", "imaginative", "incautious", "impulsive", "inactive", "incapable",
    "incompetent", "ineffective", "inefficient", "insecure", "irrational", "lazy", "lethargic",
    "naive", "negligent", "sporadic", "unintelligent", "stupid", "submissive", "unenterprising",
    "unambitious", "uneducated", "unwise", "vulnerable", "peaceable", "unconcerned", "dim", "dull",
    "careful", "ambivalent", "slipshod", "unproductive", "uncritical", "timid", "unhallowed",
    "irresolute", "refractory", "subordinate", "squat", "infelicitous", "graceless", "shiftless",
    "blind", "overbearing", "imprecise", "quixotic", "unbrace", "witless", "inexperienced",
    "spiritless", "wavering"
]
professions_competence = [
    "c.e.o", "lawyer", "accountant", "professor", "vet", "paramedic", "chef", "dentist",
    "doctor", "nurse", "scientist", "welder", "mechanic", "psychiatrist", "pilot",
    "director", "architect", "writer", "manager", "engineer", "actor", "lab technician",
    "news anchor", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "computer programmer", "construction worker"
]
professions_non_competence =  ['artist', 'bank teller', 'bartender', 'bus driver', 'cashier', 'childcare worker', 'custodian', 'customer service representative',
 'factory worker', 'farmer', 'firefighter', 'fisherman', 'garbage collector', 'landscaper', 'librarian', 'maid',
 'medical assistant', 'musician', 'plumber', 'police', 'politician', 'postal worker', 'salesperson', 'security guard',
 'secretary', 'taxi driver', 'teacher', 'truck driver', 'waiter']


competence_sentences = prepare_sentences(competence_adj)
non_competence_sentences = prepare_sentences(non_competence_adj)
prof_competence_sentences = prepare_sentences(professions_competence)
prof_non_competence_sentences = prepare_sentences(professions_non_competence)

#embed words function
def embed_words(model, tokenizer, sentences, device):
    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        last_hidden_state = outputs.last_hidden_state
        embeddings = last_hidden_state[:, 0, :]  # CLS token
    return embeddings.cpu()

#embed all groups
competence_emb = embed_words(model, tokenizer, competence_sentences, device)
non_competence_emb = embed_words(model, tokenizer, non_competence_sentences, device)
prof_competence_emb = embed_words(model, tokenizer, prof_competence_sentences, device)
prof_non_competence_emb = embed_words(model, tokenizer, prof_non_competence_sentences, device)

#SEAT functions
def cosine_similarity_matrix(a, b):
    a_norm = a / a.norm(dim=1, keepdim=True)
    b_norm = b / b.norm(dim=1, keepdim=True)
    return torch.mm(a_norm, b_norm.t())

def seat_effect_size(X, Y, A, B):
    def s(w, A, B):
        simA = cosine_similarity_matrix(w.unsqueeze(0), A).mean()
        simB = cosine_similarity_matrix(w.unsqueeze(0), B).mean()
        return (simA - simB).item()
    sX = np.array([s(x, A, B) for x in X])
    sY = np.array([s(y, A, B) for y in Y])
    mean_diff = sX.mean() - sY.mean()
    std_dev = np.std(np.concatenate([sX, sY]), ddof=1)
    effect_size = mean_diff / std_dev
    t_stat, p_val = ttest_ind(sX, sY, equal_var=False)
    return effect_size, p_val

#embeddings as PyTorch tensors
X = prof_competence_emb
Y = prof_non_competence_emb
A = competence_emb
B = non_competence_emb

effect_size, p_value = seat_effect_size(X, Y, A, B)
print(f"SEAT effect size: {effect_size:.3f}, p-value: {p_value:.3f}")
# Out:
# SEAT effect size: 0.199, p-value: 0.453

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

def visualize_tsne(embeddings_dict, title="t-SNE Projection of Embeddings"):
    #flatten and prepare all embeddings
    all_embeddings = torch.cat(list(embeddings_dict.values()), dim=0).numpy()
    all_labels = sum([[label] * len(emb) for label, emb in embeddings_dict.items()], [])

    #apply t-SNE
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    reduced = tsne.fit_transform(all_embeddings)

    #plot
    plt.figure(figsize=(10, 7))
    for label in embeddings_dict:
        idx = [i for i, l in enumerate(all_labels) if l == label]
        plt.scatter(reduced[idx, 0], reduced[idx, 1], label=label, alpha=0.7)

    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

visualize_tsne({
    "Warmth Adj": warmth_emb,
    "Non-Warmth Adj": non_warmth_emb,
    "Warm Prof": prof_warm_emb,
    "Non-Warm Prof": prof_nonwarm_emb
}, title="t-SNE: Warmth-related Embeddings")

visualize_tsne({
    "Competence Adj": competence_emb,
    "Non-Competence Adj": non_competence_emb,
    "Competent Prof": prof_competence_emb,
    "Non-Competent Prof": prof_non_competence_emb
}, title="t-SNE: Competence-related Embeddings")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM


#load custom bias directions
warmth_vector = pd.read_csv('data/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('data/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

#normalize bias direction vectors
warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

#load model and tokenizer
model_path = "data/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForMaskedLM.from_pretrained(model_path).eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def get_profession_embedding(profession):
    sentence = f"The {profession} is a person."
    inputs = tokenizer(sentence, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model.bert(**inputs)
    emb = outputs.last_hidden_state.mean(dim=1).squeeze()  # [hidden_size]
    return emb.cpu()

def cosine_similarity(vec1, vec2):
    #both vectors are 1D tensors
    vec1 = vec1 / vec1.norm()
    vec2 = vec2 / vec2.norm()
    return torch.dot(vec1, vec2).item()

def cosine_similarity_scores(professions, direction_vector):
    direction_vector = direction_vector.to(device)
    cos_sims = {}
    for prof in professions:
        emb = get_profession_embedding(prof).to(device)
        sim = cosine_similarity(emb, direction_vector)
        cos_sims[prof] = sim
    return cos_sims

professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

# Calculate cosine similarity scores
warmth_cosine_scores = cosine_similarity_scores(professions, warmth_vector)
competence_cosine_scores = cosine_similarity_scores(professions, competence_vector)

print("\n--- Warmth Cosine Similarities ---")
for p, score in sorted(warmth_cosine_scores.items(), key=lambda x: -x[1]):
    print(f"{p:25} : {score:.4f}")

print("\n--- Competence Cosine Similarities ---")
for p, score in sorted(competence_cosine_scores.items(), key=lambda x: -x[1]):
    print(f"{p:25} : {score:.4f}")


#average scores

avg_warmth = np.mean(list(warmth_cosine_scores.values()))
avg_competence = np.mean(list(competence_cosine_scores.values()))

print(f"Average Warmth Cosine Similarity: {avg_warmth:.4f}")
print(f"Average Competence Cosine Similarity: {avg_competence:.4f}")
# Out:
# --- Warmth Cosine Similarities ---
# paramedic                 : -0.0517
# doctor                    : -0.1232
# nurse                     : -0.1288
# dentist                   : -0.1325
# vet                       : -0.1337
# teacher                   : -0.1338
# psychiatrist              : -0.1347
# medical assistant         : -0.1357
# professor                 : -0.1372
# police                    : -0.1399
# librarian                 : -0.1466
# artist                    : -0.1500
# writer                    : -0.1522
# politician                : -0.1526
# actor                     : -0.1530
# scientist                 : -0.1534
# firefighter               : -0.1601
# lawyer                    : -0.1644
# pilot                     : -0.1659
# director                  : -0.1667
# maid                      : -0.1673
# c.e.o                     : -0.1685
# chef                      : -0.1694
# waiter                    : -0.1726
# architect                 : -0.1732
# fisherman                 : -0.1755
# secretary                 : -0.1756
# travel agent              : -0.1763
# manager                   : -0.1793
# engineer                  : -0.1794
# mechanic                  : -0.1797
# childcare worker          : -0.1798
# taxi driver               : -0.1800
# farmer                    : -0.1817
# lab technician            : -0.1818
# news anchor               : -0.1849
# bus driver                : -0.1864
# accountant                : -0.1880
# graphic designer          : -0.1895
# bartender                 : -0.1907
# postal worker             : -0.1946
# custodian                 : -0.1953
# security guard            : -0.1955
# cashier                   : -0.1970
# bank teller               : -0.1971
# welder                    : -0.2008
# salesperson               : -0.2021
# landscaper                : -0.2023
# electrician               : -0.2026
# customer service representative : -0.2051
# financial advisor         : -0.2051
# truck driver              : -0.2059
# technical support worker  : -0.2102
# plumber                   : -0.2102
# computer programmer       : -0.2107
# garbage collector         : -0.2116
# construction worker       : -0.2179
# factory worker            : -0.2289
#
# --- Competence Cosine Similarities ---
# professor                 : 0.0107
# news anchor               : -0.0072
# doctor                    : -0.0136
# director                  : -0.0169
# scientist                 : -0.0188
# writer                    : -0.0199
# actor                     : -0.0215
# psychiatrist              : -0.0230
# artist                    : -0.0296
# politician                : -0.0344
# lawyer                    : -0.0354
# teacher                   : -0.0372
# secretary                 : -0.0380
# librarian                 : -0.0452
# vet                       : -0.0513
# c.e.o                     : -0.0524
# chef                      : -0.0538
# police                    : -0.0541
# engineer                  : -0.0550
# nurse                     : -0.0552
# dentist                   : -0.0560
# pilot                     : -0.0590
# manager                   : -0.0593
# architect                 : -0.0618
# maid                      : -0.0725
# fisherman                 : -0.0735
# accountant                : -0.0745
# financial advisor         : -0.0767
# medical assistant         : -0.0772
# farmer                    : -0.0780
# computer programmer       : -0.0807
# waiter                    : -0.0861
# bartender                 : -0.0915
# graphic designer          : -0.0931
# landscaper                : -0.0937
# lab technician            : -0.0947
# travel agent              : -0.0953
# mechanic                  : -0.0957
# custodian                 : -0.1026
# truck driver              : -0.1099
# bus driver                : -0.1147
# postal worker             : -0.1166
# firefighter               : -0.1182
# bank teller               : -0.1183
# salesperson               : -0.1240
# factory worker            : -0.1246
# taxi driver               : -0.1284
# welder                    : -0.1284
# childcare worker          : -0.1331
# cashier                   : -0.1371
# electrician               : -0.1392
# security guard            : -0.1397
# customer service representative : -0.1406
# construction worker       : -0.1417
# plumber                   : -0.1429
# garbage collector         : -0.1495
# paramedic                 : -0.1548
# technical support worker  : -0.1570
# Average Warmth Cosine Similarity: -0.1739
# Average Competence Cosine Similarity: -0.0809

# %%
#project back
import torch
import numpy as np
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM

#load custom bias directions
warmth_vector = pd.read_csv('data/warmth_direction.csv').values.flatten()
competence_vector = pd.read_csv('data/competence_direction.csv').values.flatten()

warmth_vector = torch.tensor(warmth_vector, dtype=torch.float32)
competence_vector = torch.tensor(competence_vector, dtype=torch.float32)

#normalize vectors
warmth_vector = warmth_vector / warmth_vector.norm()
competence_vector = competence_vector / competence_vector.norm()

#load model and tokenizer
model_path = "data/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForMaskedLM.from_pretrained(model_path).eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def get_profession_embedding(profession):
    sentence = f"The {profession} is a person."
    inputs = tokenizer(sentence, return_tensors='pt').to(device)
    with torch.no_grad():
        outputs = model.bert(**inputs)
    #mean pooling over sequence length dimension
    emb = outputs.last_hidden_state.mean(dim=1).squeeze()  # [hidden_size]
    return emb.cpu()

def project_embeddings(professions, direction_vector):
    direction_vector = direction_vector.to(device)
    projections = {}
    for prof in professions:
        emb = get_profession_embedding(prof).to(device)
        score = torch.dot(emb, direction_vector).item()  # scalar projection
        projections[prof] = score
    return projections

#professions list
professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

#project onto custom bias directions
warmth_scores = project_embeddings(professions, warmth_vector)
competence_scores = project_embeddings(professions, competence_vector)

print("\n--- Warmth Projections ---")
for p, score in sorted(warmth_scores.items(), key=lambda x: -x[1]):
    print(f"{p}: {score:.4f}")

print("\n--- Competence Projections ---")
for p, score in sorted(competence_scores.items(), key=lambda x: -x[1]):
    print(f"{p}: {score:.4f}")
# Out:
# --- Warmth Projections ---
# paramedic: -0.4638
# doctor: -1.0180
# nurse: -1.0907
# vet: -1.1239
# professor: -1.1280
# dentist: -1.1297
# teacher: -1.1300
# psychiatrist: -1.1351
# medical assistant: -1.1633
# police: -1.1860
# librarian: -1.2417
# artist: -1.2589
# writer: -1.2702
# scientist: -1.2728
# actor: -1.2753
# politician: -1.3365
# firefighter: -1.3511
# director: -1.3789
# pilot: -1.3851
# lawyer: -1.3956
# maid: -1.4257
# chef: -1.4360
# architect: -1.4584
# secretary: -1.4709
# c.e.o: -1.4714
# travel agent: -1.4750
# fisherman: -1.4792
# waiter: -1.4911
# manager: -1.4994
# engineer: -1.5004
# farmer: -1.5370
# childcare worker: -1.5390
# mechanic: -1.5430
# taxi driver: -1.5489
# lab technician: -1.5600
# news anchor: -1.5732
# bus driver: -1.6107
# accountant: -1.6150
# bartender: -1.6260
# postal worker: -1.6562
# custodian: -1.6598
# cashier: -1.6662
# graphic designer: -1.6684
# bank teller: -1.6693
# welder: -1.6769
# security guard: -1.6854
# financial advisor: -1.7005
# landscaper: -1.7185
# salesperson: -1.7200
# customer service representative: -1.7598
# truck driver: -1.7672
# electrician: -1.7686
# plumber: -1.7734
# computer programmer: -1.8073
# garbage collector: -1.8311
# technical support worker: -1.8490
# construction worker: -1.8731
# factory worker: -1.9431
#
# --- Competence Projections ---
# professor: 0.0880
# news anchor: -0.0615
# doctor: -0.1126
# director: -0.1396
# scientist: -0.1557
# writer: -0.1660
# actor: -0.1793
# psychiatrist: -0.1942
# artist: -0.2484
# lawyer: -0.3008
# politician: -0.3013
# teacher: -0.3144
# secretary: -0.3179
# librarian: -0.3829
# vet: -0.4308
# chef: -0.4561
# c.e.o: -0.4577
# police: -0.4584
# engineer: -0.4599
# nurse: -0.4678
# dentist: -0.4769
# pilot: -0.4924
# manager: -0.4957
# architect: -0.5200
# maid: -0.6174
# fisherman: -0.6194
# financial advisor: -0.6354
# accountant: -0.6404
# farmer: -0.6600
# medical assistant: -0.6616
# computer programmer: -0.6917
# waiter: -0.7442
# bartender: -0.7802
# landscaper: -0.7961
# travel agent: -0.7974
# lab technician: -0.8126
# graphic designer: -0.8196
# mechanic: -0.8220
# custodian: -0.8718
# truck driver: -0.9435
# bus driver: -0.9915
# postal worker: -0.9920
# firefighter: -0.9976
# bank teller: -1.0019
# salesperson: -1.0557
# factory worker: -1.0580
# welder: -1.0725
# taxi driver: -1.1051
# childcare worker: -1.1391
# cashier: -1.1596
# security guard: -1.2045
# plumber: -1.2057
# customer service representative: -1.2069
# electrician: -1.2147
# construction worker: -1.2188
# garbage collector: -1.2940
# technical support worker: -1.3809
# paramedic: -1.3885

# %%
####plot for projections
import matplotlib.pyplot as plt

#preparing coordinates
x_vals = [warmth_scores[prof] for prof in professions]
y_vals = [competence_scores[prof] for prof in professions]

plt.figure(figsize=(12, 8))
plt.scatter(x_vals, y_vals)

#adding profession labels
for i, prof in enumerate(professions):
    plt.text(x_vals[i] + 0.002, y_vals[i] + 0.002, prof, fontsize=9)

plt.axhline(0, color='gray', linestyle='--', linewidth=0.7)
plt.axvline(0, color='gray', linestyle='--', linewidth=0.7)
plt.title("Profession Projections on Warmth and Competence Bias Directions")
plt.xlabel("Warmth Score")
plt.ylabel("Competence Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#embeddings extraction

from transformers import BertTokenizer, BertForMaskedLM
import torch
import csv
import pandas as pd

#load model and tokenizer
model_path = "data/BERT_finetuned"
tokenizer = BertTokenizer.from_pretrained(model_path)
model = DebiasedBertForMaskedLM.from_pretrained(model_path, components=components, weights=weights, tokenizer=tokenizer)
model.to(device)
model.eval()

def get_profession_embedding(profession, model, tokenizer, device):
    sentence = f"The {profession} is there."  # neutral context
    inputs = tokenizer(sentence, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = model.bert(**inputs, return_dict=True)
        hidden_states = outputs.last_hidden_state.squeeze(0)  # shape: [seq_len, hidden_dim]

    tokens = tokenizer.tokenize(sentence)
    profession_tokens = tokenizer.tokenize(profession)

    #find start index of profession tokens
    for i in range(len(tokens) - len(profession_tokens) + 1):
        if tokens[i:i+len(profession_tokens)] == profession_tokens:
            start, end = i, i + len(profession_tokens)
            break
    else:
        raise ValueError(f"Could not find token span for profession: {profession}")

    #get mean embedding over profession token span
    profession_embedding = hidden_states[start+1:end+1].mean(dim=0)  # +1 due to [CLS] token at position 0
    return profession_embedding.cpu()



professions = [
    "professor", "vet", "paramedic", "chef", "dentist", "maid", "doctor", "nurse",
    "scientist", "welder", "teacher", "waiter", "mechanic", "police", "secretary",
    "psychiatrist", "farmer", "pilot", "director", "architect", "c.e.o", "artist",
    "writer", "fisherman", "medical assistant", "manager", "librarian", "politician",
    "engineer", "bartender", "accountant", "firefighter", "travel agent", "lawyer",
    "actor", "lab technician", "security guard", "custodian", "childcare worker",
    "bank teller", "taxi driver", "bus driver", "news anchor", "customer service representative",
    "cashier", "plumber", "technical support worker", "electrician", "graphic designer",
    "financial advisor", "salesperson", "truck driver", "landscaper", "postal worker",
    "factory worker", "garbage collector", "computer programmer", "construction worker"
]

embedding_dict = {}
for prof in tqdm(professions):
    try:
        emb = get_profession_embedding(prof, model, tokenizer, device)
        embedding_dict[prof] = emb.numpy()
    except Exception as e:
        print(f"Could not extract embedding for {prof}: {e}")

#save to csv
csv_path = "profession_embeddings_debiased_w=0_c=1.csv"
with open(csv_path, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    
    #determine the dimension from one of the embeddings
    dim = next(iter(embedding_dict.values())).shape[0]
    
    #header: ["Profession", "dim_0", "dim_1", ..., "dim_n" and so on]
    header = ["Profession"] + [f"dim_{i}" for i in range(dim)]
    writer.writerow(header)
    
    # Write each profession and its embedding
    for prof, emb in embedding_dict.items():
        row = [prof] + emb.tolist()
        writer.writerow(row)

print(f"Saved profession embeddings to {csv_path}")
# Out:
# 100%|███████████████████████████████████████████| 58/58 [00:03<00:00, 19.05it/s]
# Saved profession embeddings to profession_embeddings_debiased_w=0_c=1.csv
